# %%
#Import relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import logging

#pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Read Data

# %%
#Read ESG data set
data = pd.read_csv("ESGData.csv")

#Convert data into pandas dataframe
df = data.copy()
df = df.iloc[3266:]

#Drop empty columns
df = df.drop(columns=['Unnamed: 67'])

# %% [markdown]
# ## Generate a dataframe for all indicators

# %%
# Filter the data for specific 'Indicator Name' values
# Previously decided for these to be 'Life expectancy at birth, total (years)', 'Agricultural land (% of land area)','Population density (people per sq. km of land area)' 
filtered_indicators = [
    'Life expectancy at birth, total (years)',  
    'Agricultural land (% of land area)',
    'Population density (people per sq. km of land area)'
]
#Filter dataframe to only include selected indicators
df_filtered = df[df['Indicator Name'].isin(filtered_indicators)]

# Transpose the year columns and create a new DataFrame
df_formatted = pd.melt(df_filtered, 
                       id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                       var_name='Year', 
                       value_name='Value')

# Display the first few rows of the formatted DataFrame
df_formatted.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                       Indicator Name  Indicator Code  Year  \
# 0                 Agricultural land (% of land area)  AG.LND.AGRI.ZS  1960
# 1            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960
# 2  Population density (people per sq. km of land ...     EN.POP.DNST  1960
# 3                 Agricultural land (% of land area)  AG.LND.AGRI.ZS  1960
# 4            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960
#
#     Value
# 0     NaN
# 1  32.535
# 2     NaN
# 3     NaN
# 4  54.439

# %%
# Splitting df_formatted into separate DataFrames for each indicator
life_expectancy_df = df_formatted[df_formatted['Indicator Name'] == 'Life expectancy at birth, total (years)'][
    ['Country Name', 'Country Code', 'Year', 'Value']
].rename(columns={'Value': 'Life expectancy at birth, total (years)'})

ag_growth_df = df_formatted[df_formatted['Indicator Name'] == 'Agricultural land (% of land area)'][
    ['Country Name', 'Country Code', 'Year', 'Value']
].rename(columns={'Value': 'Agricultural land (% of land area)'})

pop_df = df_formatted[df_formatted['Indicator Name'] == 'Population density (people per sq. km of land area)'][
    ['Country Name', 'Country Code', 'Year', 'Value']
].rename(columns={'Value': 'Population density (people per sq. km of land area)'})

# Merging the DataFrames on 'Country Name', 'Country Code', and 'Year' to combine them
merged_df = life_expectancy_df.merge(ag_growth_df, on=['Country Name', 'Country Code', 'Year'], how='outer')\
                              .merge(pop_df, on=['Country Name', 'Country Code', 'Year'], how='outer')

# %%
# Define a new dataframe with only Country Name, Country Code, Year, and each indicator
selected_df = merged_df[['Country Name', 'Country Code', 'Year', 'Life expectancy at birth, total (years)', 'Agricultural land (% of land area)','Population density (people per sq. km of land area)']].copy()

# Sorting by 'Country Name' and 'Year' to prepare for rolling calculations
selected_df = selected_df.sort_values(by=['Country Name', 'Year'])

# Creating Moving Average and STD columns for the specified time frames (2, 3, 5, and 10 years)
time_frames = [2, 3, 5, 10]
for window in time_frames:
    selected_df[f'LE Moving_Avg_{window}Y'] = selected_df.groupby('Country Name')['Life expectancy at birth, total (years)'].transform(lambda x: x.rolling(window, min_periods=1).mean())
selected_df['Year'] = selected_df['Year'].astype(int)

# Displaying the first few rows of the updated DataFrame
selected_df.loc[selected_df['Country Name'] == 'Austria']
# Out:
#     Country Name Country Code  Year  Life expectancy at birth, total (years)  \
# 567      Austria          AUT  1960                                68.585610
# 568      Austria          AUT  1961                                69.577317
# 569      Austria          AUT  1962                                69.309512
# 570      Austria          AUT  1963                                69.443659
# 571      Austria          AUT  1964                                69.921951
# ..           ...          ...   ...                                      ...
# 625      Austria          AUT  2018                                81.692683
# 626      Austria          AUT  2019                                81.895122
# 627      Austria          AUT  2020                                81.192683
# 628      Austria          AUT  2021                                      NaN
# 629      Austria          AUT  2022                                      NaN
#
#      Agricultural land (% of land area)  \
# 567                                 NaN
# 568                           43.085313
# 569                           42.789627
# 570                           42.290354
# 571                           42.129181
# ..                                  ...
# 625                           32.147722
# 626                           32.128090
# 627                           31.539813
# 628                           31.476726
# 629                                 NaN
#
#      Population density (people per sq. km of land area)  LE Moving_Avg_2Y  \
# 567                                                NaN           68.585610
# 568                                          85.873715           69.081463
# 569                                          86.401648           69.443415
# 570                                          86.958446           69.376585
# 571                                          87.540002           69.682805
# ..                                                 ...                 ...
# 625                                         107.131859           81.668293
# 626                                         107.609307           81.793902
# 627                                         108.057004           81.543902
# 628                                         108.528805           81.192683
# 629                                                NaN                 NaN
#
#      LE Moving_Avg_3Y  LE Moving_Avg_5Y  LE Moving_Avg_10Y
# 567         68.585610         68.585610          68.585610
# 568         69.081463         69.081463          69.081463
# 569         69.157480         69.157480          69.157480
# 570         69.443496         69.229024          69.229024
# 571         69.558374         69.367610          69.367610
# ..                ...               ...                ...
# 625         81.659350         81.531707          81.162683
# 626         81.743902         81.612683          81.319024
# 627         81.593496         81.613171          81.380244
# 628         81.543902         81.606098          81.424390
# 629         81.192683         81.593496          81.485366
#
# [63 rows x 10 columns]

# %%
# Function to plot predictions vs actual values for a specified country
#This function will be utilized later for visually reviewing the model accuracry for each indicator
def plot_country_predictions_vs_actual(country_name, indicator):
    """ This function plots the predicted indicator performance for each indicator versus the year """
    
    # Extracting predictions for the specified country
    if country_name not in country_recursive_predictions_rf:
        logger.error(f"No predictions found for {country_name}.")
        return

    predictions = country_recursive_predictions_rf[country_name]
    predicted_years = [year for year in predictions.keys() if year >= 2010]
    predicted_values = [predictions[year] for year in predicted_years]

    # Extracting actual values for the specified country and prediction years (2010 onward)
    actual_data = test_df[(test_df['Country Name'] == country_name) & (test_df['Year'].isin(predicted_years))]
    actual_years = actual_data['Year'].values
    actual_values = actual_data[indicator].values

    # Plotting predictions vs actual values from 2010 onward
    plt.figure(figsize=(10, 6))
    plt.plot(predicted_years, predicted_values, label=indicator, color='blue', marker='o')
    plt.plot(actual_years, actual_values, label= indicator, color='red', linestyle='--', marker='x')
    plt.xlabel("Year")
    plt.ylabel(indicator)
    plt.title(f"Predicted vs Actual {indicator} for {country_name} (2010-2019)")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Indicator 1 - Train and Test Machine Learning Model

# %%
# Define year variables for training and prediction
TRAIN_START_YEAR = 1990
TRAIN_END_YEAR = 2009
PREDICTION_START_YEAR = 2010
PREDICTION_END_YEAR = 2019

# Setting up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Splitting data into training (2000-2019) set and setting up prediction years
train_df = selected_df[(selected_df['Year'] >= TRAIN_START_YEAR) & (selected_df['Year'] <= TRAIN_END_YEAR)].dropna(subset=['Life expectancy at birth, total (years)'])
prediction_years = range(PREDICTION_START_YEAR, PREDICTION_END_YEAR + 1)

# Preparing training data for the model
X_train = train_df[['Year', 'LE Moving_Avg_2Y', 'LE Moving_Avg_3Y', 'LE Moving_Avg_5Y', 'LE Moving_Avg_10Y']].values
y_train = train_df['Life expectancy at birth, total (years)'].values

# Initializing and training the Random Forest model on all training data
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)
logger.info(f"Model trained on all countries' data ({TRAIN_START_YEAR}-{TRAIN_END_YEAR}). Starting recursive forecasting.")

# Store predictions for each country
country_recursive_predictions_rf = {}

# Recursive forecasting for each country separately with detailed logging
for country in train_df['Country Name'].unique():
    logger.info(f"Processing country: {country}")

    # Get the last available data point for the country to start recursive prediction
    country_data = train_df[train_df['Country Name'] == country].iloc[-1].copy()
    predictions_per_country = {country_data['Year']: country_data['Life expectancy at birth, total (years)']}

    # Recursive prediction loop from PREDICTION_START_YEAR to PREDICTION_END_YEAR
    for year in prediction_years:
        country_data['Year'] = year
        
        # Logging the input data used for this prediction
        logger.info(f"Prediction inputs for {country} in {year}: Year={year}, "
                    f"LE Moving_Avg_2Y={country_data['LE Moving_Avg_2Y']}, "
                    f"LE Moving_Avg_3Y={country_data['LE Moving_Avg_3Y']}, "
                    f"LE Moving_Avg_5Y={country_data['LE Moving_Avg_5Y']}, "
                    f"LE Moving_Avg_10Y={country_data['LE Moving_Avg_10Y']}")
        
        # Preparing the features for the current prediction
        X_test = country_data[['Year', 'LE Moving_Avg_2Y', 'LE Moving_Avg_3Y', 'LE Moving_Avg_5Y', 'LE Moving_Avg_10Y']].values.reshape(1, -1)
        
        # Predicting life expectancy for the current year
        predicted_value = model_rf.predict(X_test)[0]
        logger.info(f"Predicted value for {country} in {year}: {predicted_value}")
        
        # Update the prediction in the dictionary
        predictions_per_country[year] = predicted_value
        
        # Update the features for the next prediction year based on the new prediction
        country_data['Life expectancy at birth, total (years)'] = predicted_value
        country_data['LE Moving_Avg_2Y'] = (predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 2
        country_data['LE Moving_Avg_3Y'] = (predictions_per_country.get(year - 2, predicted_value) +
                                         predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 3
        country_data['LE Moving_Avg_5Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 4, year + 1)) / 5)
        country_data['LE Moving_Avg_10Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 9, year + 1)) / 10)

    # Store the predictions for the country
    country_recursive_predictions_rf[country] = predictions_per_country
# Out:
# 2024-11-19 16:24:51,128 - INFO - Model trained on all countries' data (1990-2009). Starting recursive forecasting.
# 2024-11-19 16:24:51,129 - INFO - Processing country: Afghanistan
# 2024-11-19 16:24:51,129 - INFO - Prediction inputs for Afghanistan in 2010: Year=2010, LE Moving_Avg_2Y=60.108, LE Moving_Avg_3Y=59.775666666666666, LE Moving_Avg_5Y=59.27439999999999, LE Moving_Avg_10Y=57.92100000000001
# 2024-11-19 16:24:51,132 - INFO - Predicted value for Afghanistan in 2010: 60.40797999999991
# 2024-11-19 16:24:51,133 - INFO - Prediction inputs for Afghanistan in 2011: Year=2011, LE Moving_Avg_2Y=60.38598999999995, LE Moving_Avg_3Y=60.39331999999994, LE Moving_Avg_5Y=60.399183999999934, LE Moving_Avg_10Y=60.403581999999915
# 2024-11-19 16:24:51,135 - INFO - Predicted value for Afghanistan in 2011: 60.625
# 2024-11-19 16:24:51,135 - INFO - Prediction inputs for Afghanistan in 2012: Year=2012, LE Moving_Avg_2Y=60.516489999999955, LE Moving_Avg_3Y=60.465659999999964, LE Moving_Avg_5Y=60.529395999999984, LE Moving_Avg_10Y=60.57719799999999
# 2024-11-19 16:24:51,137 - INFO - Predicted value for Afghanistan in 2012: 60.71654000000002
# 2024-11-19 16:24:51,137 - INFO - Prediction inputs for Afghanistan in 2013: Year=2013, LE Moving_Avg_2Y=60.67077000000001, LE Moving_Avg_3Y=60.58317333333331, LE Moving_Avg_5Y=60.566011999999986, LE Moving_Avg_10Y=60.641276000000005
# 2024-11-19 16:24:51,139 - INFO - Predicted value for Afghanistan in 2013: 60.81399999999999
# 2024-11-19 16:24:51,139 - INFO - Prediction inputs for Afghanistan in 2014: Year=2014, LE Moving_Avg_2Y=60.76527000000001, LE Moving_Avg_3Y=60.71851333333334, LE Moving_Avg_5Y=60.58550399999999, LE Moving_Avg_10Y=60.699751999999975
# 2024-11-19 16:24:51,141 - INFO - Predicted value for Afghanistan in 2014: 60.89077999999998
# 2024-11-19 16:24:51,141 - INFO - Prediction inputs for Afghanistan in 2015: Year=2015, LE Moving_Avg_2Y=60.852389999999986, LE Moving_Avg_3Y=60.80710666666666, LE Moving_Avg_5Y=60.69085999999997, LE Moving_Avg_10Y=60.73814199999997
# 2024-11-19 16:24:51,143 - INFO - Predicted value for Afghanistan in 2015: 60.97105000000004
# 2024-11-19 16:24:51,143 - INFO - Prediction inputs for Afghanistan in 2016: Year=2016, LE Moving_Avg_2Y=60.93091500000001, LE Moving_Avg_3Y=60.89194333333334, LE Moving_Avg_5Y=60.80347400000001, LE Moving_Avg_10Y=60.77025
# 2024-11-19 16:24:51,145 - INFO - Predicted value for Afghanistan in 2016: 61.03353000000005
# 2024-11-19 16:24:51,146 - INFO - Prediction inputs for Afghanistan in 2017: Year=2017, LE Moving_Avg_2Y=61.002290000000045, LE Moving_Avg_3Y=60.96512000000002, LE Moving_Avg_5Y=60.88518000000001, LE Moving_Avg_10Y=60.788994
# 2024-11-19 16:24:51,148 - INFO - Predicted value for Afghanistan in 2017: 60.93251999999998
# 2024-11-19 16:24:51,148 - INFO - Prediction inputs for Afghanistan in 2018: Year=2018, LE Moving_Avg_2Y=60.98302500000001, LE Moving_Avg_3Y=60.979033333333355, LE Moving_Avg_5Y=60.928376, LE Moving_Avg_10Y=60.768792
# 2024-11-19 16:24:51,150 - INFO - Predicted value for Afghanistan in 2018: 60.932059999999986
# 2024-11-19 16:24:51,150 - INFO - Prediction inputs for Afghanistan in 2019: Year=2019, LE Moving_Avg_2Y=60.93228999999998, LE Moving_Avg_3Y=60.96603666666667, LE Moving_Avg_5Y=60.95198800000001, LE Moving_Avg_10Y=60.768746
# 2024-11-19 16:24:51,152 - INFO - Predicted value for Afghanistan in 2019: 60.972419999999985
# 2024-11-19 16:24:51,152 - INFO - Processing country: Albania
# 2024-11-19 16:24:51,153 - INFO - Prediction inputs for Albania in 2010: Year=2010, LE Moving_Avg_2Y=77.71700000000001, LE Moving_Avg_3Y=77.661, LE Moving_Avg_5Y=77.284, LE Moving_Avg_10Y=76.5871
# 2024-11-19 16:24:51,157 - INFO - Predicted value for Albania in 2010: 77.85645414634143
# 2024-11-19 16:24:51,157 - INFO - Prediction inputs for Albania in 2011: Year=2011, LE Moving_Avg_2Y=77.81872707317072, LE Moving_Avg_3Y=77.83130276422763, LE Moving_Avg_5Y=77.84136331707315, LE Moving_Avg_10Y=77.84890873170728
# 2024-11-19 16:24:51,159 - INFO - Predicted value for Albania in 2011: 77.56370024390239
# 2024-11-19 16:24:51,159 - INFO - Prediction inputs for Albania in 2012: Year=2012, LE Moving_Avg_2Y=77.71007719512191, LE Moving_Avg_3Y=77.73371813008127, LE Moving_Avg_5Y=77.66571097560973, LE Moving_Avg_10Y=77.61470560975606
# 2024-11-19 16:24:51,161 - INFO - Predicted value for Albania in 2012: 77.7731331707317
# 2024-11-19 16:24:51,161 - INFO - Prediction inputs for Albania in 2013: Year=2013, LE Moving_Avg_2Y=77.66841670731705, LE Moving_Avg_3Y=77.73109585365852, LE Moving_Avg_5Y=77.74948414634144, LE Moving_Avg_10Y=77.76130865853658
# 2024-11-19 16:24:51,163 - INFO - Predicted value for Albania in 2013: 77.70094
# 2024-11-19 16:24:51,163 - INFO - Prediction inputs for Albania in 2014: Year=2014, LE Moving_Avg_2Y=77.73703658536584, LE Moving_Avg_3Y=77.67925780487803, LE Moving_Avg_5Y=77.73504551219511, LE Moving_Avg_10Y=77.71799275609756
# 2024-11-19 16:24:51,165 - INFO - Predicted value for Albania in 2014: 77.79948926829267
# 2024-11-19 16:24:51,166 - INFO - Prediction inputs for Albania in 2015: Year=2015, LE Moving_Avg_2Y=77.75021463414635, LE Moving_Avg_3Y=77.75785414634146, LE Moving_Avg_5Y=77.73874336585365, LE Moving_Avg_10Y=77.7672673902439
# 2024-11-19 16:24:51,168 - INFO - Predicted value for Albania in 2015: 77.7228973170731
# 2024-11-19 16:24:51,168 - INFO - Prediction inputs for Albania in 2016: Year=2016, LE Moving_Avg_2Y=77.76119329268289, LE Moving_Avg_3Y=77.74110886178859, LE Moving_Avg_5Y=77.71203199999998, LE Moving_Avg_10Y=77.73663060975606
# 2024-11-19 16:24:51,170 - INFO - Predicted value for Albania in 2016: 77.77677292682924
# 2024-11-19 16:24:51,170 - INFO - Prediction inputs for Albania in 2017: Year=2017, LE Moving_Avg_2Y=77.74983512195118, LE Moving_Avg_3Y=77.76638650406501, LE Moving_Avg_5Y=77.75464653658534, LE Moving_Avg_10Y=77.75279329268291
# 2024-11-19 16:24:51,172 - INFO - Predicted value for Albania in 2017: 77.7373046341463
# 2024-11-19 16:24:51,172 - INFO - Prediction inputs for Albania in 2018: Year=2018, LE Moving_Avg_2Y=77.75703878048776, LE Moving_Avg_3Y=77.74565829268289, LE Moving_Avg_5Y=77.74748082926826, LE Moving_Avg_10Y=77.74489963414632
# 2024-11-19 16:24:51,174 - INFO - Predicted value for Albania in 2018: 77.73692658536581
# 2024-11-19 16:24:51,174 - INFO - Prediction inputs for Albania in 2019: Year=2019, LE Moving_Avg_2Y=77.73711560975605, LE Moving_Avg_3Y=77.75033471544711, LE Moving_Avg_5Y=77.75467814634142, LE Moving_Avg_10Y=77.74486182926827
# 2024-11-19 16:24:51,176 - INFO - Predicted value for Albania in 2019: 77.73388463414632
# 2024-11-19 16:24:51,176 - INFO - Processing country: Algeria
# 2024-11-19 16:24:51,177 - INFO - Prediction inputs for Algeria in 2010: Year=2010, LE Moving_Avg_2Y=73.28049999999999, LE Moving_Avg_3Y=73.05433333333333, LE Moving_Avg_5Y=72.7116, LE Moving_Avg_10Y=71.9138
# 2024-11-19 16:24:51,179 - INFO - Predicted value for Algeria in 2010: 73.5676626829268
# 2024-11-19 16:24:51,179 - INFO - Prediction inputs for Algeria in 2011: Year=2011, LE Moving_Avg_2Y=73.5938313414634, LE Moving_Avg_3Y=73.58510845528453, LE Moving_Avg_5Y=73.57813014634144, LE Moving_Avg_10Y=73.5728964146341
# 2024-11-19 16:24:51,181 - INFO - Predicted value for Algeria in 2011: 73.628284390244
# 2024-11-19 16:24:51,181 - INFO - Prediction inputs for Algeria in 2012: Year=2012, LE Moving_Avg_2Y=73.5979735365854, LE Moving_Avg_3Y=73.60531569105693, LE Moving_Avg_5Y=73.61450317073175, LE Moving_Avg_10Y=73.62139378048786
# 2024-11-19 16:24:51,183 - INFO - Predicted value for Algeria in 2012: 73.628284390244
# 2024-11-19 16:24:51,183 - INFO - Prediction inputs for Algeria in 2013: Year=2013, LE Moving_Avg_2Y=73.628284390244, LE Moving_Avg_3Y=73.6080771544716, LE Moving_Avg_5Y=73.61450317073175, LE Moving_Avg_10Y=73.62139378048789
# 2024-11-19 16:24:51,185 - INFO - Predicted value for Algeria in 2013: 73.64081219512204
# 2024-11-19 16:24:51,185 - INFO - Prediction inputs for Algeria in 2014: Year=2014, LE Moving_Avg_2Y=73.63454829268302, LE Moving_Avg_3Y=73.63246032520335, LE Moving_Avg_5Y=73.61700873170737, LE Moving_Avg_10Y=73.62891046341471
# 2024-11-19 16:24:51,187 - INFO - Predicted value for Algeria in 2014: 73.67865560975619
# 2024-11-19 16:24:51,188 - INFO - Prediction inputs for Algeria in 2015: Year=2015, LE Moving_Avg_2Y=73.65973390243911, LE Moving_Avg_3Y=73.64925073170741, LE Moving_Avg_5Y=73.62873985365862, LE Moving_Avg_10Y=73.64783217073179
# 2024-11-19 16:24:51,189 - INFO - Predicted value for Algeria in 2015: 74.0514875609757
# 2024-11-19 16:24:51,190 - INFO - Prediction inputs for Algeria in 2016: Year=2016, LE Moving_Avg_2Y=73.86507158536594, LE Moving_Avg_3Y=73.79031845528465, LE Moving_Avg_5Y=73.72550482926839, LE Moving_Avg_10Y=73.79696495121959
# 2024-11-19 16:24:51,192 - INFO - Predicted value for Algeria in 2016: 73.87848170731714
# 2024-11-19 16:24:51,192 - INFO - Prediction inputs for Algeria in 2017: Year=2017, LE Moving_Avg_2Y=73.96498463414642, LE Moving_Avg_3Y=73.86954162601633, LE Moving_Avg_5Y=73.77554429268301, LE Moving_Avg_10Y=73.74506319512201
# 2024-11-19 16:24:51,254 - INFO - Predicted value for Algeria in 2017: 73.99951878048783
# 2024-11-19 16:24:51,254 - INFO - Prediction inputs for Algeria in 2018: Year=2018, LE Moving_Avg_2Y=73.93900024390248, LE Moving_Avg_3Y=73.97649601626023, LE Moving_Avg_5Y=73.84979117073178, LE Moving_Avg_10Y=73.76927060975616
# 2024-11-19 16:24:51,256 - INFO - Predicted value for Algeria in 2018: 73.89642975609759
# 2024-11-19 16:24:51,256 - INFO - Prediction inputs for Algeria in 2019: Year=2019, LE Moving_Avg_2Y=73.94797426829271, LE Moving_Avg_3Y=73.92481008130085, LE Moving_Avg_5Y=73.90091468292688, LE Moving_Avg_10Y=73.75896170731714
# 2024-11-19 16:24:51,258 - INFO - Predicted value for Algeria in 2019: 73.97610878048783
# 2024-11-19 16:24:51,258 - INFO - Processing country: Angola
# 2024-11-19 16:24:51,259 - INFO - Prediction inputs for Angola in 2010: Year=2010, LE Moving_Avg_2Y=55.1925, LE Moving_Avg_3Y=54.67566666666667, LE Moving_Avg_5Y=53.5932, LE Moving_Avg_10Y=50.8175
# 2024-11-19 16:24:51,261 - INFO - Predicted value for Angola in 2010: 55.70728000000006
# 2024-11-19 16:24:51,261 - INFO - Prediction inputs for Angola in 2011: Year=2011, LE Moving_Avg_2Y=55.72964000000003, LE Moving_Avg_3Y=55.72218666666671, LE Moving_Avg_5Y=55.716224000000054, LE Moving_Avg_10Y=55.71175200000006
# 2024-11-19 16:24:51,263 - INFO - Predicted value for Angola in 2011: 55.999570000000034
# 2024-11-19 16:24:51,263 - INFO - Prediction inputs for Angola in 2012: Year=2012, LE Moving_Avg_2Y=55.853425000000044, LE Moving_Avg_3Y=55.8196166666667, LE Moving_Avg_5Y=55.89159800000003, LE Moving_Avg_10Y=55.94558400000004
# 2024-11-19 16:24:51,265 - INFO - Predicted value for Angola in 2012: 56.19798999999998
# 2024-11-19 16:24:51,265 - INFO - Prediction inputs for Angola in 2013: Year=2013, LE Moving_Avg_2Y=56.098780000000005, LE Moving_Avg_3Y=55.96828000000002, LE Moving_Avg_5Y=55.97096600000001, LE Moving_Avg_10Y=56.084478000000004
# 2024-11-19 16:24:51,267 - INFO - Predicted value for Angola in 2013: 56.19007
# 2024-11-19 16:24:51,267 - INFO - Prediction inputs for Angola in 2014: Year=2014, LE Moving_Avg_2Y=56.19402999999999, LE Moving_Avg_3Y=56.12921, LE Moving_Avg_5Y=55.96938200000002, LE Moving_Avg_10Y=56.079726000000015
# 2024-11-19 16:24:51,269 - INFO - Predicted value for Angola in 2014: 56.23010999999999
# 2024-11-19 16:24:51,269 - INFO - Prediction inputs for Angola in 2015: Year=2015, LE Moving_Avg_2Y=56.210089999999994, LE Moving_Avg_3Y=56.206056666666655, LE Moving_Avg_5Y=56.06500400000001, LE Moving_Avg_10Y=56.099746
# 2024-11-19 16:24:51,271 - INFO - Predicted value for Angola in 2015: 56.214980000000004
# 2024-11-19 16:24:51,271 - INFO - Prediction inputs for Angola in 2016: Year=2016, LE Moving_Avg_2Y=56.222545, LE Moving_Avg_3Y=56.21171999999999, LE Moving_Avg_5Y=56.166544, LE Moving_Avg_10Y=56.093694000000006
# 2024-11-19 16:24:51,273 - INFO - Predicted value for Angola in 2016: 56.19892
# 2024-11-19 16:24:51,273 - INFO - Prediction inputs for Angola in 2017: Year=2017, LE Moving_Avg_2Y=56.206950000000006, LE Moving_Avg_3Y=56.21466999999999, LE Moving_Avg_5Y=56.206413999999995, LE Moving_Avg_10Y=56.088876000000006
# 2024-11-19 16:24:51,275 - INFO - Predicted value for Angola in 2017: 56.207950000000004
# 2024-11-19 16:24:51,275 - INFO - Prediction inputs for Angola in 2018: Year=2018, LE Moving_Avg_2Y=56.203435, LE Moving_Avg_3Y=56.20728333333334, LE Moving_Avg_5Y=56.20840599999999, LE Moving_Avg_10Y=56.090682
# 2024-11-19 16:24:51,277 - INFO - Predicted value for Angola in 2018: 56.20222
# 2024-11-19 16:24:51,277 - INFO - Prediction inputs for Angola in 2019: Year=2019, LE Moving_Avg_2Y=56.205085, LE Moving_Avg_3Y=56.20302999999999, LE Moving_Avg_5Y=56.21083599999999, LE Moving_Avg_10Y=56.090109000000005
# 2024-11-19 16:24:51,279 - INFO - Predicted value for Angola in 2019: 56.207950000000004
# 2024-11-19 16:24:51,280 - INFO - Processing country: Antigua and Barbuda
# 2024-11-19 16:24:51,280 - INFO - Prediction inputs for Antigua and Barbuda in 2010: Year=2010, LE Moving_Avg_2Y=76.5395, LE Moving_Avg_3Y=76.40333333333332, LE Moving_Avg_5Y=76.16, LE Moving_Avg_10Y=75.717
# 2024-11-19 16:24:51,282 - INFO - Predicted value for Antigua and Barbuda in 2010: 76.68947682926824
# 2024-11-19 16:24:51,282 - INFO - Prediction inputs for Antigua and Barbuda in 2011: Year=2011, LE Moving_Avg_2Y=76.67923841463411, LE Moving_Avg_3Y=76.68265121951215, LE Moving_Avg_5Y=76.68538146341459, LE Moving_Avg_10Y=76.68742914634143
# 2024-11-19 16:24:51,284 - INFO - Predicted value for Antigua and Barbuda in 2011: 76.76553463414638
# 2024-11-19 16:24:51,284 - INFO - Prediction inputs for Antigua and Barbuda in 2012: Year=2012, LE Moving_Avg_2Y=76.72750573170731, LE Moving_Avg_3Y=76.7080038211382, LE Moving_Avg_5Y=76.73101614634147, LE Moving_Avg_10Y=76.74827539024393
# 2024-11-19 16:24:51,286 - INFO - Predicted value for Antigua and Barbuda in 2012: 76.87557195121946
# 2024-11-19 16:24:51,286 - INFO - Prediction inputs for Antigua and Barbuda in 2013: Year=2013, LE Moving_Avg_2Y=76.82055329268292, LE Moving_Avg_3Y=76.77686113821136, LE Moving_Avg_5Y=76.77503107317071, LE Moving_Avg_10Y=76.82530151219507
# 2024-11-19 16:24:51,288 - INFO - Predicted value for Antigua and Barbuda in 2013: 76.90991878048779
# 2024-11-19 16:24:51,289 - INFO - Prediction inputs for Antigua and Barbuda in 2014: Year=2014, LE Moving_Avg_2Y=76.89274536585361, LE Moving_Avg_3Y=76.85034178861787, LE Moving_Avg_5Y=76.78190043902437, LE Moving_Avg_10Y=76.84590960975608
# 2024-11-19 16:24:51,290 - INFO - Predicted value for Antigua and Barbuda in 2014: 76.9549841463414
# 2024-11-19 16:24:51,291 - INFO - Prediction inputs for Antigua and Barbuda in 2015: Year=2015, LE Moving_Avg_2Y=76.9324514634146, LE Moving_Avg_3Y=76.91349162601621, LE Moving_Avg_5Y=76.83909726829265, LE Moving_Avg_10Y=76.86844229268289
# 2024-11-19 16:24:51,292 - INFO - Predicted value for Antigua and Barbuda in 2015: 76.96765853658529
# 2024-11-19 16:24:51,293 - INFO - Prediction inputs for Antigua and Barbuda in 2016: Year=2016, LE Moving_Avg_2Y=76.96132134146335, LE Moving_Avg_3Y=76.94418715447149, LE Moving_Avg_5Y=76.89473360975606, LE Moving_Avg_10Y=76.87351204878044
# 2024-11-19 16:24:51,294 - INFO - Predicted value for Antigua and Barbuda in 2016: 76.98386829268287
# 2024-11-19 16:24:51,295 - INFO - Prediction inputs for Antigua and Barbuda in 2017: Year=2017, LE Moving_Avg_2Y=76.97576341463409, LE Moving_Avg_3Y=76.96883699186985, LE Moving_Avg_5Y=76.93840034146336, LE Moving_Avg_10Y=76.87837497560972
# 2024-11-19 16:24:51,296 - INFO - Predicted value for Antigua and Barbuda in 2017: 76.97061243902432
# 2024-11-19 16:24:51,297 - INFO - Prediction inputs for Antigua and Barbuda in 2018: Year=2018, LE Moving_Avg_2Y=76.97724036585359, LE Moving_Avg_3Y=76.97404642276416, LE Moving_Avg_5Y=76.95740843902433, LE Moving_Avg_10Y=76.87572380487799
# 2024-11-19 16:24:51,299 - INFO - Predicted value for Antigua and Barbuda in 2018: 76.96528536585359
# 2024-11-19 16:24:51,299 - INFO - Prediction inputs for Antigua and Barbuda in 2019: Year=2019, LE Moving_Avg_2Y=76.96794890243896, LE Moving_Avg_3Y=76.97325536585359, LE Moving_Avg_5Y=76.9684817560975, LE Moving_Avg_10Y=76.87519109756093
# 2024-11-19 16:24:51,301 - INFO - Predicted value for Antigua and Barbuda in 2019: 76.9669460975609
# 2024-11-19 16:24:51,301 - INFO - Processing country: Argentina
# 2024-11-19 16:24:51,301 - INFO - Prediction inputs for Argentina in 2010: Year=2010, LE Moving_Avg_2Y=75.78850000000001, LE Moving_Avg_3Y=75.52766666666668, LE Moving_Avg_5Y=75.43100000000001, LE Moving_Avg_10Y=74.861
# 2024-11-19 16:24:51,303 - INFO - Predicted value for Argentina in 2010: 75.90611292682915
# 2024-11-19 16:24:51,303 - INFO - Prediction inputs for Argentina in 2011: Year=2011, LE Moving_Avg_2Y=75.92105646341457, LE Moving_Avg_3Y=75.91607528455278, LE Moving_Avg_5Y=75.91209034146333, LE Moving_Avg_10Y=75.90910163414624
# 2024-11-19 16:24:51,305 - INFO - Predicted value for Argentina in 2011: 76.13838829268299
# 2024-11-19 16:24:51,306 - INFO - Prediction inputs for Argentina in 2012: Year=2012, LE Moving_Avg_2Y=76.02225060975607, LE Moving_Avg_3Y=75.99350040650404, LE Moving_Avg_5Y=76.05145556097563, LE Moving_Avg_10Y=76.0949219268293
# 2024-11-19 16:24:51,307 - INFO - Predicted value for Argentina in 2012: 76.15027560975615
# 2024-11-19 16:24:51,308 - INFO - Prediction inputs for Argentina in 2013: Year=2013, LE Moving_Avg_2Y=76.14433195121957, LE Moving_Avg_3Y=76.06492560975609, LE Moving_Avg_5Y=76.05621048780489, LE Moving_Avg_10Y=76.10324304878051
# 2024-11-19 16:24:51,309 - INFO - Predicted value for Argentina in 2013: 76.16361634146341
# 2024-11-19 16:24:51,310 - INFO - Prediction inputs for Argentina in 2014: Year=2014, LE Moving_Avg_2Y=76.15694597560977, LE Moving_Avg_3Y=76.15076008130085, LE Moving_Avg_5Y=76.05887863414634, LE Moving_Avg_10Y=76.11124748780487
# 2024-11-19 16:24:51,311 - INFO - Predicted value for Argentina in 2014: 76.16464292682927
# 2024-11-19 16:24:51,312 - INFO - Prediction inputs for Argentina in 2015: Year=2015, LE Moving_Avg_2Y=76.16412963414635, LE Moving_Avg_3Y=76.15951162601628, LE Moving_Avg_5Y=76.10460721951219, LE Moving_Avg_10Y=76.1117607804878
# 2024-11-19 16:24:51,313 - INFO - Predicted value for Argentina in 2015: 76.16599414634146
# 2024-11-19 16:24:51,314 - INFO - Prediction inputs for Argentina in 2016: Year=2016, LE Moving_Avg_2Y=76.16531853658537, LE Moving_Avg_3Y=76.16475113821139, LE Moving_Avg_5Y=76.15658346341465, LE Moving_Avg_10Y=76.11230126829268
# 2024-11-19 16:24:51,315 - INFO - Predicted value for Argentina in 2016: 76.16911
# 2024-11-19 16:24:51,316 - INFO - Prediction inputs for Argentina in 2017: Year=2017, LE Moving_Avg_2Y=76.16755207317073, LE Moving_Avg_3Y=76.16658235772358, LE Moving_Avg_5Y=76.16272780487806, LE Moving_Avg_10Y=76.11323602439025
# 2024-11-19 16:24:51,317 - INFO - Predicted value for Argentina in 2017: 76.16911
# 2024-11-19 16:24:51,318 - INFO - Prediction inputs for Argentina in 2018: Year=2018, LE Moving_Avg_2Y=76.16911, LE Moving_Avg_3Y=76.16807138211381, LE Moving_Avg_5Y=76.16649468292682, LE Moving_Avg_10Y=76.11323602439025
# 2024-11-19 16:24:51,319 - INFO - Predicted value for Argentina in 2018: 76.16659804878049
# 2024-11-19 16:24:51,320 - INFO - Prediction inputs for Argentina in 2019: Year=2019, LE Moving_Avg_2Y=76.16785402439024, LE Moving_Avg_3Y=76.16827268292683, LE Moving_Avg_5Y=76.16709102439025, LE Moving_Avg_10Y=76.1129848292683
# 2024-11-19 16:24:51,321 - INFO - Predicted value for Argentina in 2019: 76.16911
# 2024-11-19 16:24:51,322 - INFO - Processing country: Armenia
# 2024-11-19 16:24:51,322 - INFO - Prediction inputs for Armenia in 2010: Year=2010, LE Moving_Avg_2Y=72.6055, LE Moving_Avg_3Y=72.51266666666668, LE Moving_Avg_5Y=72.2634, LE Moving_Avg_10Y=71.67479999999999
# 2024-11-19 16:24:51,324 - INFO - Predicted value for Armenia in 2010: 72.80556121951227
# 2024-11-19 16:24:51,324 - INFO - Prediction inputs for Armenia in 2011: Year=2011, LE Moving_Avg_2Y=72.80928060975614, LE Moving_Avg_3Y=72.80804081300819, LE Moving_Avg_5Y=72.80704897560982, LE Moving_Avg_10Y=72.80630509756102
# 2024-11-19 16:24:51,326 - INFO - Predicted value for Armenia in 2011: 72.93479487804872
# 2024-11-19 16:24:51,327 - INFO - Prediction inputs for Armenia in 2012: Year=2012, LE Moving_Avg_2Y=72.8701780487805, LE Moving_Avg_3Y=72.851118699187, LE Moving_Avg_5Y=72.88458917073169, LE Moving_Avg_10Y=72.9096920243902
# 2024-11-19 16:24:51,329 - INFO - Predicted value for Armenia in 2012: 73.04077097560975
# 2024-11-19 16:24:51,329 - INFO - Prediction inputs for Armenia in 2013: Year=2013, LE Moving_Avg_2Y=72.98778292682923, LE Moving_Avg_3Y=72.92704235772358, LE Moving_Avg_5Y=72.9269796097561, LE Moving_Avg_10Y=72.98387529268291
# 2024-11-19 16:24:51,331 - INFO - Predicted value for Armenia in 2013: 73.11376292682927
# 2024-11-19 16:24:51,331 - INFO - Prediction inputs for Armenia in 2014: Year=2014, LE Moving_Avg_2Y=73.07726695121951, LE Moving_Avg_3Y=73.02977626016258, LE Moving_Avg_5Y=72.941578, LE Moving_Avg_10Y=73.02767046341464
# 2024-11-19 16:24:51,333 - INFO - Predicted value for Armenia in 2014: 73.21199487804876
# 2024-11-19 16:24:51,333 - INFO - Prediction inputs for Armenia in 2015: Year=2015, LE Moving_Avg_2Y=73.16287890243902, LE Moving_Avg_3Y=73.12217626016259, LE Moving_Avg_5Y=73.02137697560975, LE Moving_Avg_10Y=73.07678643902439
# 2024-11-19 16:24:51,335 - INFO - Predicted value for Armenia in 2015: 73.26232707317075
# 2024-11-19 16:24:51,335 - INFO - Prediction inputs for Armenia in 2016: Year=2016, LE Moving_Avg_2Y=73.23716097560975, LE Moving_Avg_3Y=73.19602829268293, LE Moving_Avg_5Y=73.11273014634145, LE Moving_Avg_10Y=73.09691931707319
# 2024-11-19 16:24:51,337 - INFO - Predicted value for Armenia in 2016: 73.29873292682927
# 2024-11-19 16:24:51,337 - INFO - Prediction inputs for Armenia in 2017: Year=2017, LE Moving_Avg_2Y=73.28053000000001, LE Moving_Avg_3Y=73.25768495934959, LE Moving_Avg_5Y=73.18551775609755, LE Moving_Avg_10Y=73.10784107317073
# 2024-11-19 16:24:51,339 - INFO - Predicted value for Armenia in 2017: 73.3903302439025
# 2024-11-19 16:24:51,340 - INFO - Prediction inputs for Armenia in 2018: Year=2018, LE Moving_Avg_2Y=73.34453158536589, LE Moving_Avg_3Y=73.31713008130085, LE Moving_Avg_5Y=73.25542960975612, LE Moving_Avg_10Y=73.12616053658537
# 2024-11-19 16:24:51,341 - INFO - Predicted value for Armenia in 2018: 73.4337280487805
# 2024-11-19 16:24:51,342 - INFO - Prediction inputs for Armenia in 2019: Year=2019, LE Moving_Avg_2Y=73.4120291463415, LE Moving_Avg_3Y=73.37426373983742, LE Moving_Avg_5Y=73.31942263414635, LE Moving_Avg_10Y=73.13050031707319
# 2024-11-19 16:24:51,344 - INFO - Predicted value for Armenia in 2019: 73.45694780487811
# 2024-11-19 16:24:51,344 - INFO - Processing country: Australia
# 2024-11-19 16:24:51,344 - INFO - Prediction inputs for Australia in 2010: Year=2010, LE Moving_Avg_2Y=81.46951219512195, LE Moving_Avg_3Y=81.41056910569107, LE Moving_Avg_5Y=81.22292682926829, LE Moving_Avg_10Y=80.5648780487805
# 2024-11-19 16:24:51,347 - INFO - Predicted value for Australia in 2010: 81.5489756097561
# 2024-11-19 16:24:51,347 - INFO - Prediction inputs for Australia in 2011: Year=2011, LE Moving_Avg_2Y=81.54643902439025, LE Moving_Avg_3Y=81.54728455284554, LE Moving_Avg_5Y=81.54796097560975, LE Moving_Avg_10Y=81.54846829268293
# 2024-11-19 16:24:51,349 - INFO - Predicted value for Australia in 2011: 81.99789268292689
# 2024-11-19 16:24:51,349 - INFO - Prediction inputs for Australia in 2012: Year=2012, LE Moving_Avg_2Y=81.77343414634149, LE Moving_Avg_3Y=81.6969235772358, LE Moving_Avg_5Y=81.81731121951222, LE Moving_Avg_10Y=81.90760195121956
# 2024-11-19 16:24:51,351 - INFO - Predicted value for Australia in 2012: 82.1167853658537
# 2024-11-19 16:24:51,351 - INFO - Prediction inputs for Australia in 2013: Year=2013, LE Moving_Avg_2Y=82.0573390243903, LE Moving_Avg_3Y=81.88788455284556, LE Moving_Avg_5Y=81.86486829268294, LE Moving_Avg_10Y=81.99082682926834
# 2024-11-19 16:24:51,353 - INFO - Predicted value for Australia in 2013: 82.32277317073167
# 2024-11-19 16:24:51,353 - INFO - Prediction inputs for Australia in 2014: Year=2014, LE Moving_Avg_2Y=82.21977926829268, LE Moving_Avg_3Y=82.14581707317076, LE Moving_Avg_5Y=81.90606585365856, LE Moving_Avg_10Y=82.11441951219511
# 2024-11-19 16:24:51,355 - INFO - Predicted value for Australia in 2014: 82.39536097560969
# 2024-11-19 16:24:51,356 - INFO - Prediction inputs for Australia in 2015: Year=2015, LE Moving_Avg_2Y=82.35906707317068, LE Moving_Avg_3Y=82.27830650406501, LE Moving_Avg_5Y=82.07635756097561, LE Moving_Avg_10Y=82.15071341463413
# 2024-11-19 16:24:51,357 - INFO - Predicted value for Australia in 2015: 82.50523902439019
# 2024-11-19 16:24:51,358 - INFO - Prediction inputs for Australia in 2016: Year=2016, LE Moving_Avg_2Y=82.45029999999994, LE Moving_Avg_3Y=82.40779105691051, LE Moving_Avg_5Y=82.26761024390244, LE Moving_Avg_10Y=82.19466463414633
# 2024-11-19 16:24:51,359 - INFO - Predicted value for Australia in 2016: 82.56458048780482
# 2024-11-19 16:24:51,360 - INFO - Prediction inputs for Australia in 2017: Year=2017, LE Moving_Avg_2Y=82.5349097560975, LE Moving_Avg_3Y=82.4883934959349, LE Moving_Avg_5Y=82.38094780487802, LE Moving_Avg_10Y=82.21246707317071
# 2024-11-19 16:24:51,362 - INFO - Predicted value for Australia in 2017: 82.65978780487798
# 2024-11-19 16:24:51,362 - INFO - Prediction inputs for Australia in 2018: Year=2018, LE Moving_Avg_2Y=82.6121841463414, LE Moving_Avg_3Y=82.57653577235766, LE Moving_Avg_5Y=82.48954829268287, LE Moving_Avg_10Y=82.23150853658535
# 2024-11-19 16:24:51,364 - INFO - Predicted value for Australia in 2018: 82.70402682926823
# 2024-11-19 16:24:51,364 - INFO - Prediction inputs for Australia in 2019: Year=2019, LE Moving_Avg_2Y=82.6819073170731, LE Moving_Avg_3Y=82.64279837398368, LE Moving_Avg_5Y=82.56579902439019, LE Moving_Avg_10Y=82.23593243902437
# 2024-11-19 16:24:51,366 - INFO - Predicted value for Australia in 2019: 82.76104878048773
# 2024-11-19 16:24:51,366 - INFO - Processing country: Austria
# 2024-11-19 16:24:51,367 - INFO - Prediction inputs for Austria in 2010: Year=2010, LE Moving_Avg_2Y=80.3817073170732, LE Moving_Avg_3Y=80.3146341463415, LE Moving_Avg_5Y=80.03121951219516, LE Moving_Avg_10Y=79.33487804878052
# 2024-11-19 16:24:51,368 - INFO - Predicted value for Austria in 2010: 80.42538780487797
# 2024-11-19 16:24:51,369 - INFO - Prediction inputs for Austria in 2011: Year=2011, LE Moving_Avg_2Y=80.37854756097559, LE Moving_Avg_3Y=80.39416097560972, LE Moving_Avg_5Y=80.40665170731702, LE Moving_Avg_10Y=80.41601975609748
# 2024-11-19 16:24:51,371 - INFO - Predicted value for Austria in 2011: 80.58020487804878
# 2024-11-19 16:24:51,371 - INFO - Prediction inputs for Austria in 2012: Year=2012, LE Moving_Avg_2Y=80.50279634146338, LE Moving_Avg_3Y=80.44576666666666, LE Moving_Avg_5Y=80.4995419512195, LE Moving_Avg_10Y=80.53987341463414
# 2024-11-19 16:24:51,373 - INFO - Predicted value for Austria in 2012: 80.70825609756098
# 2024-11-19 16:24:51,373 - INFO - Prediction inputs for Austria in 2013: Year=2013, LE Moving_Avg_2Y=80.64423048780488, LE Moving_Avg_3Y=80.57128292682926, LE Moving_Avg_5Y=80.55076243902438, LE Moving_Avg_10Y=80.62950926829267
# 2024-11-19 16:24:51,375 - INFO - Predicted value for Austria in 2013: 80.80758048780488
# 2024-11-19 16:24:51,375 - INFO - Prediction inputs for Austria in 2014: Year=2014, LE Moving_Avg_2Y=80.75791829268293, LE Moving_Avg_3Y=80.69868048780488, LE Moving_Avg_5Y=80.57062731707317, LE Moving_Avg_10Y=80.68910390243903
# 2024-11-19 16:24:51,377 - INFO - Predicted value for Austria in 2014: 80.99701707317064
# 2024-11-19 16:24:51,377 - INFO - Prediction inputs for Austria in 2015: Year=2015, LE Moving_Avg_2Y=80.90229878048777, LE Moving_Avg_3Y=80.83761788617883, LE Moving_Avg_5Y=80.70368926829266, LE Moving_Avg_10Y=80.78382219512189
# 2024-11-19 16:24:51,379 - INFO - Predicted value for Austria in 2015: 81.16578292682927
# 2024-11-19 16:24:51,379 - INFO - Prediction inputs for Austria in 2016: Year=2016, LE Moving_Avg_2Y=81.08139999999995, LE Moving_Avg_3Y=80.99012682926826, LE Moving_Avg_5Y=80.8517682926829, LE Moving_Avg_10Y=80.85132853658536
# 2024-11-19 16:24:51,381 - INFO - Predicted value for Austria in 2016: 81.35752195121951
# 2024-11-19 16:24:51,382 - INFO - Prediction inputs for Austria in 2017: Year=2017, LE Moving_Avg_2Y=81.26165243902439, LE Moving_Avg_3Y=81.17344065040646, LE Moving_Avg_5Y=81.00723170731706, LE Moving_Avg_10Y=80.90885024390244
# 2024-11-19 16:24:51,384 - INFO - Predicted value for Austria in 2017: 81.42718048780483
# 2024-11-19 16:24:51,384 - INFO - Prediction inputs for Austria in 2018: Year=2018, LE Moving_Avg_2Y=81.39235121951216, LE Moving_Avg_3Y=81.31682845528454, LE Moving_Avg_5Y=81.15101658536582, LE Moving_Avg_10Y=80.92278195121949
# 2024-11-19 16:24:51,386 - INFO - Predicted value for Austria in 2018: 81.52178536585362
# 2024-11-19 16:24:51,386 - INFO - Prediction inputs for Austria in 2019: Year=2019, LE Moving_Avg_2Y=81.47448292682922, LE Moving_Avg_3Y=81.43549593495932, LE Moving_Avg_5Y=81.29385756097557, LE Moving_Avg_10Y=80.93224243902438
# 2024-11-19 16:24:51,388 - INFO - Predicted value for Austria in 2019: 81.59494146341467
# 2024-11-19 16:24:51,388 - INFO - Processing country: Azerbaijan
# 2024-11-19 16:24:51,389 - INFO - Prediction inputs for Azerbaijan in 2010: Year=2010, LE Moving_Avg_2Y=69.0835, LE Moving_Avg_3Y=68.92333333333333, LE Moving_Avg_5Y=68.4994, LE Moving_Avg_10Y=67.32390000000001
# 2024-11-19 16:24:51,391 - INFO - Predicted value for Azerbaijan in 2010: 69.32153756097551
# 2024-11-19 16:24:51,391 - INFO - Prediction inputs for Azerbaijan in 2011: Year=2011, LE Moving_Avg_2Y=69.33876878048775, LE Moving_Avg_3Y=69.33302504065034, LE Moving_Avg_5Y=69.3284300487804, LE Moving_Avg_10Y=69.32498380487796
# 2024-11-19 16:24:51,393 - INFO - Predicted value for Azerbaijan in 2011: 69.49334512195124
# 2024-11-19 16:24:51,394 - INFO - Prediction inputs for Azerbaijan in 2012: Year=2012, LE Moving_Avg_2Y=69.40744134146337, LE Moving_Avg_3Y=69.39029422764224, LE Moving_Avg_5Y=69.43151458536585, LE Moving_Avg_10Y=69.46242985365855
# 2024-11-19 16:24:51,395 - INFO - Predicted value for Azerbaijan in 2012: 69.58121341463416
# 2024-11-19 16:24:51,396 - INFO - Prediction inputs for Azerbaijan in 2013: Year=2013, LE Moving_Avg_2Y=69.5372792682927, LE Moving_Avg_3Y=69.46536536585363, LE Moving_Avg_5Y=69.46666190243903, LE Moving_Avg_10Y=69.5239376585366
# 2024-11-19 16:24:51,397 - INFO - Predicted value for Azerbaijan in 2013: 69.56356292682925
# 2024-11-19 16:24:51,398 - INFO - Prediction inputs for Azerbaijan in 2014: Year=2014, LE Moving_Avg_2Y=69.5723881707317, LE Moving_Avg_3Y=69.54604048780489, LE Moving_Avg_5Y=69.46313180487803, LE Moving_Avg_10Y=69.51334736585365
# 2024-11-19 16:24:51,400 - INFO - Predicted value for Azerbaijan in 2014: 69.56704829268293
# 2024-11-19 16:24:51,400 - INFO - Prediction inputs for Azerbaijan in 2015: Year=2015, LE Moving_Avg_2Y=69.56530560975608, LE Moving_Avg_3Y=69.57060821138211, LE Moving_Avg_5Y=69.50534146341461, LE Moving_Avg_10Y=69.51509004878048
# 2024-11-19 16:24:51,402 - INFO - Predicted value for Azerbaijan in 2015: 69.49453341463419
# 2024-11-19 16:24:51,402 - INFO - Prediction inputs for Azerbaijan in 2016: Year=2016, LE Moving_Avg_2Y=69.53079085365856, LE Moving_Avg_3Y=69.54171487804878, LE Moving_Avg_5Y=69.53994063414635, LE Moving_Avg_10Y=69.48608409756098
# 2024-11-19 16:24:51,404 - INFO - Predicted value for Azerbaijan in 2016: 69.5328448780488
# 2024-11-19 16:24:51,404 - INFO - Prediction inputs for Azerbaijan in 2017: Year=2017, LE Moving_Avg_2Y=69.5136891463415, LE Moving_Avg_3Y=69.5314755284553, LE Moving_Avg_5Y=69.54784058536588, LE Moving_Avg_10Y=69.49757753658537
# 2024-11-19 16:24:51,406 - INFO - Predicted value for Azerbaijan in 2017: 69.48851268292685
# 2024-11-19 16:24:51,406 - INFO - Prediction inputs for Azerbaijan in 2018: Year=2018, LE Moving_Avg_2Y=69.51067878048784, LE Moving_Avg_3Y=69.50529699186995, LE Moving_Avg_5Y=69.52930043902441, LE Moving_Avg_10Y=69.48871109756098
# 2024-11-19 16:24:51,408 - INFO - Predicted value for Azerbaijan in 2018: 69.49270707317075
# 2024-11-19 16:24:51,409 - INFO - Prediction inputs for Azerbaijan in 2019: Year=2019, LE Moving_Avg_2Y=69.4906098780488, LE Moving_Avg_3Y=69.50468821138215, LE Moving_Avg_5Y=69.51512926829271, LE Moving_Avg_10Y=69.48913053658536
# 2024-11-19 16:24:51,410 - INFO - Predicted value for Azerbaijan in 2019: 69.49135951219515
# 2024-11-19 16:24:51,411 - INFO - Processing country: Bahamas, The
# 2024-11-19 16:24:51,411 - INFO - Prediction inputs for Bahamas, The in 2010: Year=2010, LE Moving_Avg_2Y=72.623, LE Moving_Avg_3Y=72.64133333333332, LE Moving_Avg_5Y=72.7088, LE Moving_Avg_10Y=72.4807
# 2024-11-19 16:24:51,413 - INFO - Predicted value for Bahamas, The in 2010: 72.56949975609753
# 2024-11-19 16:24:51,413 - INFO - Prediction inputs for Bahamas, The in 2011: Year=2011, LE Moving_Avg_2Y=72.57424987804876, LE Moving_Avg_3Y=72.57266650406501, LE Moving_Avg_5Y=72.57139980487803, LE Moving_Avg_10Y=72.57044978048778
# 2024-11-19 16:24:51,415 - INFO - Predicted value for Bahamas, The in 2011: 72.58647243902446
# 2024-11-19 16:24:51,416 - INFO - Prediction inputs for Bahamas, The in 2012: Year=2012, LE Moving_Avg_2Y=72.577986097561, LE Moving_Avg_3Y=72.57832406504066, LE Moving_Avg_5Y=72.58158341463418, LE Moving_Avg_10Y=72.58402792682932
# 2024-11-19 16:24:51,418 - INFO - Predicted value for Bahamas, The in 2012: 72.58446292682932
# 2024-11-19 16:24:51,418 - INFO - Prediction inputs for Bahamas, The in 2013: Year=2013, LE Moving_Avg_2Y=72.58546768292689, LE Moving_Avg_3Y=72.58014504065044, LE Moving_Avg_5Y=72.58077960975612, LE Moving_Avg_10Y=72.58262126829273
# 2024-11-19 16:24:51,420 - INFO - Predicted value for Bahamas, The in 2013: 72.59133878048785
# 2024-11-19 16:24:51,420 - INFO - Prediction inputs for Bahamas, The in 2014: Year=2014, LE Moving_Avg_2Y=72.58790085365858, LE Moving_Avg_3Y=72.5874247154472, LE Moving_Avg_5Y=72.58215478048783, LE Moving_Avg_10Y=72.58674678048784
# 2024-11-19 16:24:51,422 - INFO - Predicted value for Bahamas, The in 2014: 72.5943948780488
# 2024-11-19 16:24:51,422 - INFO - Prediction inputs for Bahamas, The in 2015: Year=2015, LE Moving_Avg_2Y=72.59286682926833, LE Moving_Avg_3Y=72.59006552845533, LE Moving_Avg_5Y=72.5852337560976, LE Moving_Avg_10Y=72.58827482926831
# 2024-11-19 16:24:51,424 - INFO - Predicted value for Bahamas, The in 2015: 72.6376480487805
# 2024-11-19 16:24:51,424 - INFO - Prediction inputs for Bahamas, The in 2016: Year=2016, LE Moving_Avg_2Y=72.61602146341465, LE Moving_Avg_3Y=72.60779390243906, LE Moving_Avg_5Y=72.59886341463418, LE Moving_Avg_10Y=72.605576097561
# 2024-11-19 16:24:51,426 - INFO - Predicted value for Bahamas, The in 2016: 72.76929585365856
# 2024-11-19 16:24:51,426 - INFO - Prediction inputs for Bahamas, The in 2017: Year=2017, LE Moving_Avg_2Y=72.70347195121954, LE Moving_Avg_3Y=72.66711292682929, LE Moving_Avg_5Y=72.635428097561, LE Moving_Avg_10Y=72.64507043902441
# 2024-11-19 16:24:51,428 - INFO - Predicted value for Bahamas, The in 2017: 72.64826609756096
# 2024-11-19 16:24:51,428 - INFO - Prediction inputs for Bahamas, The in 2018: Year=2018, LE Moving_Avg_2Y=72.70878097560976, LE Moving_Avg_3Y=72.68507000000001, LE Moving_Avg_5Y=72.64818873170734, LE Moving_Avg_10Y=72.6208644878049
# 2024-11-19 16:24:51,430 - INFO - Predicted value for Bahamas, The in 2018: 72.6598387804878
# 2024-11-19 16:24:51,431 - INFO - Prediction inputs for Bahamas, The in 2019: Year=2019, LE Moving_Avg_2Y=72.65405243902438, LE Moving_Avg_3Y=72.69246691056911, LE Moving_Avg_5Y=72.66188873170732, LE Moving_Avg_10Y=72.62202175609758
# 2024-11-19 16:24:51,432 - INFO - Predicted value for Bahamas, The in 2019: 72.72408634146342
# 2024-11-19 16:24:51,433 - INFO - Processing country: Bahrain
# 2024-11-19 16:24:51,433 - INFO - Prediction inputs for Bahrain in 2010: Year=2010, LE Moving_Avg_2Y=78.27250000000001, LE Moving_Avg_3Y=78.05966666666667, LE Moving_Avg_5Y=77.6532, LE Moving_Avg_10Y=76.8655
# 2024-11-19 16:24:51,435 - INFO - Predicted value for Bahrain in 2010: 78.4377956097561
# 2024-11-19 16:24:51,436 - INFO - Prediction inputs for Bahrain in 2011: Year=2011, LE Moving_Avg_2Y=78.44939780487805, LE Moving_Avg_3Y=78.44553040650406, LE Moving_Avg_5Y=78.44243648780488, LE Moving_Avg_10Y=78.44011604878048
# 2024-11-19 16:24:51,438 - INFO - Predicted value for Bahrain in 2011: 78.47826292682929
# 2024-11-19 16:24:51,438 - INFO - Prediction inputs for Bahrain in 2012: Year=2012, LE Moving_Avg_2Y=78.45802926829269, LE Moving_Avg_3Y=78.45901951219513, LE Moving_Avg_5Y=78.4667168780488, LE Moving_Avg_10Y=78.47248990243904
# 2024-11-19 16:24:51,440 - INFO - Predicted value for Bahrain in 2012: 78.50211853658537
# 2024-11-19 16:24:51,440 - INFO - Prediction inputs for Bahrain in 2013: Year=2013, LE Moving_Avg_2Y=78.49019073170733, LE Moving_Avg_3Y=78.47272569105691, LE Moving_Avg_5Y=78.47625912195123, LE Moving_Avg_10Y=78.4891888292683
# 2024-11-19 16:24:51,442 - INFO - Predicted value for Bahrain in 2013: 78.5084204878049
# 2024-11-19 16:24:51,442 - INFO - Prediction inputs for Bahrain in 2014: Year=2014, LE Moving_Avg_2Y=78.50526951219513, LE Moving_Avg_3Y=78.49626731707319, LE Moving_Avg_5Y=78.47751951219513, LE Moving_Avg_10Y=78.49297000000001
# 2024-11-19 16:24:51,444 - INFO - Predicted value for Bahrain in 2014: 78.56918609756094
# 2024-11-19 16:24:51,444 - INFO - Prediction inputs for Bahrain in 2015: Year=2015, LE Moving_Avg_2Y=78.53880329268293, LE Moving_Avg_3Y=78.5265750406504, LE Moving_Avg_5Y=78.49915673170732, LE Moving_Avg_10Y=78.52335280487804
# 2024-11-19 16:24:51,446 - INFO - Predicted value for Bahrain in 2015: 78.61660048780477
# 2024-11-19 16:24:51,446 - INFO - Prediction inputs for Bahrain in 2016: Year=2016, LE Moving_Avg_2Y=78.59289329268286, LE Moving_Avg_3Y=78.56473569105687, LE Moving_Avg_5Y=78.53491770731705, LE Moving_Avg_10Y=78.54231856097559
# 2024-11-19 16:24:51,448 - INFO - Predicted value for Bahrain in 2016: 78.63253317073163
# 2024-11-19 16:24:51,448 - INFO - Prediction inputs for Bahrain in 2017: Year=2017, LE Moving_Avg_2Y=78.6245668292682, LE Moving_Avg_3Y=78.6061065853658, LE Moving_Avg_5Y=78.56577175609752, LE Moving_Avg_10Y=78.54709836585364
# 2024-11-19 16:24:51,450 - INFO - Predicted value for Bahrain in 2017: 78.55645365853655
# 2024-11-19 16:24:51,451 - INFO - Prediction inputs for Bahrain in 2018: Year=2018, LE Moving_Avg_2Y=78.59449341463409, LE Moving_Avg_3Y=78.60186243902432, LE Moving_Avg_5Y=78.57663878048776, LE Moving_Avg_10Y=78.53188246341463
# 2024-11-19 16:24:51,452 - INFO - Predicted value for Bahrain in 2018: 78.55589609756093
# 2024-11-19 16:24:51,453 - INFO - Prediction inputs for Bahrain in 2019: Year=2019, LE Moving_Avg_2Y=78.55617487804875, LE Moving_Avg_3Y=78.58162764227637, LE Moving_Avg_5Y=78.58613390243897, LE Moving_Avg_10Y=78.53182670731705
# 2024-11-19 16:24:51,455 - INFO - Predicted value for Bahrain in 2019: 78.5479860975609
# 2024-11-19 16:24:51,455 - INFO - Processing country: Bangladesh
# 2024-11-19 16:24:51,455 - INFO - Prediction inputs for Bangladesh in 2010: Year=2010, LE Moving_Avg_2Y=67.227, LE Moving_Avg_3Y=67.056, LE Moving_Avg_5Y=67.1416, LE Moving_Avg_10Y=66.8245
# 2024-11-19 16:24:51,458 - INFO - Predicted value for Bangladesh in 2010: 67.3680224390244
# 2024-11-19 16:24:51,458 - INFO - Prediction inputs for Bangladesh in 2011: Year=2011, LE Moving_Avg_2Y=67.38551121951221, LE Moving_Avg_3Y=67.37968162601628, LE Moving_Avg_5Y=67.37501795121952, LE Moving_Avg_10Y=67.37152019512196
# 2024-11-19 16:24:51,460 - INFO - Predicted value for Bangladesh in 2011: 67.48379585365856
# 2024-11-19 16:24:51,460 - INFO - Prediction inputs for Bangladesh in 2012: Year=2012, LE Moving_Avg_2Y=67.42590914634148, LE Moving_Avg_3Y=67.41827276422767, LE Moving_Avg_5Y=67.44448200000002, LE Moving_Avg_10Y=67.46413892682928
# 2024-11-19 16:24:51,462 - INFO - Predicted value for Bangladesh in 2012: 67.47927585365856
# 2024-11-19 16:24:51,462 - INFO - Prediction inputs for Bangladesh in 2013: Year=2013, LE Moving_Avg_2Y=67.48153585365856, LE Moving_Avg_3Y=67.4436980487805, LE Moving_Avg_5Y=67.44267400000003, LE Moving_Avg_10Y=67.4609749268293
# 2024-11-19 16:24:51,464 - INFO - Predicted value for Bangladesh in 2013: 67.58055682926832
# 2024-11-19 16:24:51,464 - INFO - Prediction inputs for Bangladesh in 2014: Year=2014, LE Moving_Avg_2Y=67.52991634146343, LE Moving_Avg_3Y=67.51454284552848, LE Moving_Avg_5Y=67.46293019512197, LE Moving_Avg_10Y=67.52174351219514
# 2024-11-19 16:24:51,466 - INFO - Predicted value for Bangladesh in 2014: 67.56649682926827
# 2024-11-19 16:24:51,467 - INFO - Prediction inputs for Bangladesh in 2015: Year=2015, LE Moving_Avg_2Y=67.5735268292683, LE Moving_Avg_3Y=67.54210983739837, LE Moving_Avg_5Y=67.49562956097563, LE Moving_Avg_10Y=67.51471351219513
# 2024-11-19 16:24:51,469 - INFO - Predicted value for Bangladesh in 2015: 67.68425390243905
# 2024-11-19 16:24:51,469 - INFO - Prediction inputs for Bangladesh in 2016: Year=2016, LE Moving_Avg_2Y=67.62537536585367, LE Moving_Avg_3Y=67.61043585365856, LE Moving_Avg_5Y=67.55887585365856, LE Moving_Avg_10Y=67.56181634146344
# 2024-11-19 16:24:51,471 - INFO - Predicted value for Bangladesh in 2016: 67.77177902439018
# 2024-11-19 16:24:51,471 - INFO - Prediction inputs for Bangladesh in 2017: Year=2017, LE Moving_Avg_2Y=67.72801646341462, LE Moving_Avg_3Y=67.67417658536584, LE Moving_Avg_5Y=67.61647248780487, LE Moving_Avg_10Y=67.58807387804879
# 2024-11-19 16:24:51,473 - INFO - Predicted value for Bangladesh in 2017: 67.86503317073173
# 2024-11-19 16:24:51,473 - INFO - Prediction inputs for Bangladesh in 2018: Year=2018, LE Moving_Avg_2Y=67.81840609756097, LE Moving_Avg_3Y=67.77368869918699, LE Moving_Avg_5Y=67.69362395121952, LE Moving_Avg_10Y=67.60672470731708
# 2024-11-19 16:24:51,475 - INFO - Predicted value for Bangladesh in 2018: 67.91027317073166
# 2024-11-19 16:24:51,476 - INFO - Prediction inputs for Bangladesh in 2019: Year=2019, LE Moving_Avg_2Y=67.8876531707317, LE Moving_Avg_3Y=67.84902845528454, LE Moving_Avg_5Y=67.75956721951219, LE Moving_Avg_10Y=67.61124870731707
# 2024-11-19 16:24:51,478 - INFO - Predicted value for Bangladesh in 2019: 68.06739999999999
# 2024-11-19 16:24:51,478 - INFO - Processing country: Barbados
# 2024-11-19 16:24:51,478 - INFO - Prediction inputs for Barbados in 2010: Year=2010, LE Moving_Avg_2Y=75.5625, LE Moving_Avg_3Y=75.48899999999999, LE Moving_Avg_5Y=75.285, LE Moving_Avg_10Y=74.8326
# 2024-11-19 16:24:51,480 - INFO - Predicted value for Barbados in 2010: 75.69676268292676
# 2024-11-19 16:24:51,481 - INFO - Prediction inputs for Barbados in 2011: Year=2011, LE Moving_Avg_2Y=75.68738134146338, LE Moving_Avg_3Y=75.6905084552845, LE Moving_Avg_5Y=75.69301014634141, LE Moving_Avg_10Y=75.69488641463408
# 2024-11-19 16:24:51,483 - INFO - Predicted value for Barbados in 2011: 75.84352853658532
# 2024-11-19 16:24:51,483 - INFO - Prediction inputs for Barbados in 2012: Year=2012, LE Moving_Avg_2Y=75.77014560975604, LE Moving_Avg_3Y=75.73943040650403, LE Moving_Avg_5Y=75.78106965853655, LE Moving_Avg_10Y=75.81229909756094
# 2024-11-19 16:24:51,485 - INFO - Predicted value for Barbados in 2012: 75.77816048780491
# 2024-11-19 16:24:51,485 - INFO - Prediction inputs for Barbados in 2013: Year=2013, LE Moving_Avg_2Y=75.81084451219512, LE Moving_Avg_3Y=75.77281723577234, LE Moving_Avg_5Y=75.75492243902438, LE Moving_Avg_10Y=75.76654146341465
# 2024-11-19 16:24:51,487 - INFO - Predicted value for Barbados in 2013: 75.83695146341466
# 2024-11-19 16:24:51,487 - INFO - Prediction inputs for Barbados in 2014: Year=2014, LE Moving_Avg_2Y=75.80755597560979, LE Moving_Avg_3Y=75.8195468292683, LE Moving_Avg_5Y=75.76668063414633, LE Moving_Avg_10Y=75.80181604878051
# 2024-11-19 16:24:51,489 - INFO - Predicted value for Barbados in 2014: 75.86004170731712
# 2024-11-19 16:24:51,489 - INFO - Prediction inputs for Barbados in 2015: Year=2015, LE Moving_Avg_2Y=75.8484965853659, LE Moving_Avg_3Y=75.82505121951223, LE Moving_Avg_5Y=75.80308897560977, LE Moving_Avg_10Y=75.81336117073174
# 2024-11-19 16:24:51,491 - INFO - Predicted value for Barbados in 2015: 76.03445780487809
# 2024-11-19 16:24:51,492 - INFO - Prediction inputs for Barbados in 2016: Year=2016, LE Moving_Avg_2Y=75.9472497560976, LE Moving_Avg_3Y=75.91048365853662, LE Moving_Avg_5Y=75.87062800000004, LE Moving_Avg_10Y=75.8831276097561
# 2024-11-19 16:24:51,493 - INFO - Predicted value for Barbados in 2016: 76.16819024390252
# 2024-11-19 16:24:51,494 - INFO - Prediction inputs for Barbados in 2017: Year=2017, LE Moving_Avg_2Y=76.1013240243903, LE Moving_Avg_3Y=76.0208965853659, LE Moving_Avg_5Y=75.93556034146346, LE Moving_Avg_10Y=75.92324734146345
# 2024-11-19 16:24:51,496 - INFO - Predicted value for Barbados in 2017: 76.15617658536587
# 2024-11-19 16:24:51,509 - INFO - Prediction inputs for Barbados in 2018: Year=2018, LE Moving_Avg_2Y=76.1621834146342, LE Moving_Avg_3Y=76.11960821138216, LE Moving_Avg_5Y=76.01116356097565, LE Moving_Avg_10Y=75.92084460975612
# 2024-11-19 16:24:51,512 - INFO - Predicted value for Barbados in 2018: 76.16464292682927
# 2024-11-19 16:24:51,512 - INFO - Prediction inputs for Barbados in 2019: Year=2019, LE Moving_Avg_2Y=76.16040975609758, LE Moving_Avg_3Y=76.16300325203257, LE Moving_Avg_5Y=76.07670185365858, LE Moving_Avg_10Y=75.92169124390244
# 2024-11-19 16:24:51,517 - INFO - Predicted value for Barbados in 2019: 76.16464292682927
# 2024-11-19 16:24:51,517 - INFO - Processing country: Belarus
# 2024-11-19 16:24:51,518 - INFO - Prediction inputs for Belarus in 2010: Year=2010, LE Moving_Avg_2Y=70.43170731707315, LE Moving_Avg_3Y=70.35691056910566, LE Moving_Avg_5Y=69.86536585365852, LE Moving_Avg_10Y=69.23121951219511
# 2024-11-19 16:24:51,520 - INFO - Predicted value for Belarus in 2010: 70.47596048780491
# 2024-11-19 16:24:51,521 - INFO - Prediction inputs for Belarus in 2011: Year=2011, LE Moving_Avg_2Y=70.4416387804878, LE Moving_Avg_3Y=70.45307934959351, LE Moving_Avg_5Y=70.46223180487807, LE Moving_Avg_10Y=70.46909614634149
# 2024-11-19 16:24:51,523 - INFO - Predicted value for Belarus in 2011: 70.36082170731709
# 2024-11-19 16:24:51,523 - INFO - Prediction inputs for Belarus in 2012: Year=2012, LE Moving_Avg_2Y=70.418391097561, LE Moving_Avg_3Y=70.41469975609756, LE Moving_Avg_5Y=70.39314853658537, LE Moving_Avg_10Y=70.37698512195124
# 2024-11-19 16:24:51,525 - INFO - Predicted value for Belarus in 2012: 70.42306390243901
# 2024-11-19 16:24:51,525 - INFO - Prediction inputs for Belarus in 2013: Year=2013, LE Moving_Avg_2Y=70.39194280487806, LE Moving_Avg_3Y=70.419948699187, LE Moving_Avg_5Y=70.41804541463415, LE Moving_Avg_10Y=70.42055465853659
# 2024-11-19 16:24:51,527 - INFO - Predicted value for Belarus in 2013: 70.2965026829268
# 2024-11-19 16:24:51,527 - INFO - Prediction inputs for Belarus in 2014: Year=2014, LE Moving_Avg_2Y=70.3597832926829, LE Moving_Avg_3Y=70.3601294308943, LE Moving_Avg_5Y=70.3927331707317, LE Moving_Avg_10Y=70.34461792682926
# 2024-11-19 16:24:51,529 - INFO - Predicted value for Belarus in 2014: 70.29730317073171
# 2024-11-19 16:24:51,529 - INFO - Prediction inputs for Belarus in 2015: Year=2015, LE Moving_Avg_2Y=70.29690292682926, LE Moving_Avg_3Y=70.33895658536584, LE Moving_Avg_5Y=70.3707303902439, LE Moving_Avg_10Y=70.34501817073169
# 2024-11-19 16:24:51,531 - INFO - Predicted value for Belarus in 2015: 70.21040268292687
# 2024-11-19 16:24:51,531 - INFO - Prediction inputs for Belarus in 2016: Year=2016, LE Moving_Avg_2Y=70.2538529268293, LE Moving_Avg_3Y=70.26806951219514, LE Moving_Avg_5Y=70.3176188292683, LE Moving_Avg_10Y=70.31025797560977
# 2024-11-19 16:24:51,533 - INFO - Predicted value for Belarus in 2016: 70.25265365853663
# 2024-11-19 16:24:51,534 - INFO - Prediction inputs for Belarus in 2017: Year=2017, LE Moving_Avg_2Y=70.23152817073175, LE Moving_Avg_3Y=70.25345317073175, LE Moving_Avg_5Y=70.2959852195122, LE Moving_Avg_10Y=70.3229332682927
# 2024-11-19 16:24:51,536 - INFO - Predicted value for Belarus in 2017: 70.21012536585367
# 2024-11-19 16:24:51,536 - INFO - Prediction inputs for Belarus in 2018: Year=2018, LE Moving_Avg_2Y=70.23138951219515, LE Moving_Avg_3Y=70.22439390243905, LE Moving_Avg_5Y=70.25339751219515, LE Moving_Avg_10Y=70.31442760975611
# ...
# 2024-11-19 16:24:55,945 - INFO - Prediction inputs for Venezuela, RB in 2010: Year=2010, LE Moving_Avg_2Y=72.5075, LE Moving_Avg_3Y=72.69100000000002, LE Moving_Avg_5Y=72.7194, LE Moving_Avg_10Y=72.4392
# 2024-11-19 16:24:55,947 - INFO - Predicted value for Venezuela, RB in 2010: 72.53829243902432
# 2024-11-19 16:24:55,947 - INFO - Prediction inputs for Venezuela, RB in 2011: Year=2011, LE Moving_Avg_2Y=72.55864621951216, LE Moving_Avg_3Y=72.5518616260162, LE Moving_Avg_5Y=72.54643395121946, LE Moving_Avg_10Y=72.54236319512188
# 2024-11-19 16:24:55,949 - INFO - Predicted value for Venezuela, RB in 2011: 72.60734463414641
# 2024-11-19 16:24:55,949 - INFO - Prediction inputs for Venezuela, RB in 2012: Year=2012, LE Moving_Avg_2Y=72.57281853658537, LE Moving_Avg_3Y=72.57487902439024, LE Moving_Avg_5Y=72.58786526829272, LE Moving_Avg_10Y=72.59760495121957
# 2024-11-19 16:24:55,951 - INFO - Predicted value for Venezuela, RB in 2012: 72.58723560975615
# 2024-11-19 16:24:55,951 - INFO - Prediction inputs for Venezuela, RB in 2013: Year=2013, LE Moving_Avg_2Y=72.59729012195129, LE Moving_Avg_3Y=72.57762422764229, LE Moving_Avg_5Y=72.57982165853659, LE Moving_Avg_10Y=72.58352863414638
# 2024-11-19 16:24:55,953 - INFO - Predicted value for Venezuela, RB in 2013: 72.674786097561
# 2024-11-19 16:24:55,953 - INFO - Prediction inputs for Venezuela, RB in 2014: Year=2014, LE Moving_Avg_2Y=72.63101085365858, LE Moving_Avg_3Y=72.6231221138212, LE Moving_Avg_5Y=72.59733175609759, LE Moving_Avg_10Y=72.63605892682928
# 2024-11-19 16:24:55,955 - INFO - Predicted value for Venezuela, RB in 2014: 72.65031195121952
# 2024-11-19 16:24:55,955 - INFO - Prediction inputs for Venezuela, RB in 2015: Year=2015, LE Moving_Avg_2Y=72.66254902439026, LE Moving_Avg_3Y=72.63744455284557, LE Moving_Avg_5Y=72.61159414634147, LE Moving_Avg_10Y=72.62382185365854
# 2024-11-19 16:24:55,957 - INFO - Predicted value for Venezuela, RB in 2015: 72.63976243902437
# 2024-11-19 16:24:55,957 - INFO - Prediction inputs for Venezuela, RB in 2016: Year=2016, LE Moving_Avg_2Y=72.64503719512194, LE Moving_Avg_3Y=72.65495349593496, LE Moving_Avg_5Y=72.6318881463415, LE Moving_Avg_10Y=72.61960204878048
# 2024-11-19 16:24:55,959 - INFO - Predicted value for Venezuela, RB in 2016: 72.61627780487804
# 2024-11-19 16:24:55,959 - INFO - Prediction inputs for Venezuela, RB in 2017: Year=2017, LE Moving_Avg_2Y=72.62802012195121, LE Moving_Avg_3Y=72.63545073170731, LE Moving_Avg_5Y=72.63367478048782, LE Moving_Avg_10Y=72.61255665853658
# 2024-11-19 16:24:55,961 - INFO - Predicted value for Venezuela, RB in 2017: 72.61428341463416
# 2024-11-19 16:24:55,961 - INFO - Prediction inputs for Venezuela, RB in 2018: Year=2018, LE Moving_Avg_2Y=72.6152806097561, LE Moving_Avg_3Y=72.62344121951219, LE Moving_Avg_5Y=72.63908434146342, LE Moving_Avg_10Y=72.6121577804878
# 2024-11-19 16:24:55,963 - INFO - Predicted value for Venezuela, RB in 2018: 72.76509902439028
# 2024-11-19 16:24:55,964 - INFO - Prediction inputs for Venezuela, RB in 2019: Year=2019, LE Moving_Avg_2Y=72.68969121951221, LE Moving_Avg_3Y=72.66522008130083, LE Moving_Avg_5Y=72.65714692682927, LE Moving_Avg_10Y=72.62723934146342
# 2024-11-19 16:24:55,965 - INFO - Predicted value for Venezuela, RB in 2019: 72.65043512195122
# 2024-11-19 16:24:55,966 - INFO - Processing country: Vietnam
# 2024-11-19 16:24:55,966 - INFO - Prediction inputs for Vietnam in 2010: Year=2010, LE Moving_Avg_2Y=73.4545, LE Moving_Avg_3Y=73.44833333333334, LE Moving_Avg_5Y=73.38700000000001, LE Moving_Avg_10Y=73.096
# 2024-11-19 16:24:55,968 - INFO - Predicted value for Vietnam in 2010: 73.50141073170724
# 2024-11-19 16:24:55,968 - INFO - Prediction inputs for Vietnam in 2011: Year=2011, LE Moving_Avg_2Y=73.49970536585363, LE Moving_Avg_3Y=73.50027382113817, LE Moving_Avg_5Y=73.5007285853658, LE Moving_Avg_10Y=73.50106965853651
# 2024-11-19 16:24:55,970 - INFO - Predicted value for Vietnam in 2011: 73.54919073170736
# 2024-11-19 16:24:55,970 - INFO - Prediction inputs for Vietnam in 2012: Year=2012, LE Moving_Avg_2Y=73.52530073170729, LE Moving_Avg_3Y=73.51620048780488, LE Moving_Avg_5Y=73.52939658536587, LE Moving_Avg_10Y=73.53929365853661
# 2024-11-19 16:24:55,972 - INFO - Predicted value for Vietnam in 2012: 73.57640268292688
# 2024-11-19 16:24:55,972 - INFO - Prediction inputs for Vietnam in 2013: Year=2013, LE Moving_Avg_2Y=73.56279670731712, LE Moving_Avg_3Y=73.54233471544715, LE Moving_Avg_5Y=73.54028136585367, LE Moving_Avg_10Y=73.55834202439027
# 2024-11-19 16:24:55,974 - INFO - Predicted value for Vietnam in 2013: 73.60652951219522
# 2024-11-19 16:24:55,974 - INFO - Prediction inputs for Vietnam in 2014: Year=2014, LE Moving_Avg_2Y=73.59146609756105, LE Moving_Avg_3Y=73.57737430894315, LE Moving_Avg_5Y=73.54630673170735, LE Moving_Avg_10Y=73.57641812195128
# 2024-11-19 16:24:55,976 - INFO - Predicted value for Vietnam in 2014: 73.628284390244
# 2024-11-19 16:24:55,976 - INFO - Prediction inputs for Vietnam in 2015: Year=2015, LE Moving_Avg_2Y=73.6174069512196, LE Moving_Avg_3Y=73.6037388617887, LE Moving_Avg_5Y=73.57236360975614, LE Moving_Avg_10Y=73.58729556097566
# 2024-11-19 16:24:56,014 - INFO - Predicted value for Vietnam in 2015: 73.63215048780496
# 2024-11-19 16:24:56,014 - INFO - Prediction inputs for Vietnam in 2016: Year=2016, LE Moving_Avg_2Y=73.63021743902448, LE Moving_Avg_3Y=73.62232146341472, LE Moving_Avg_5Y=73.59851156097568, LE Moving_Avg_10Y=73.58884200000008
# 2024-11-19 16:24:56,016 - INFO - Predicted value for Vietnam in 2016: 73.63842341463425
# 2024-11-19 16:24:56,017 - INFO - Prediction inputs for Vietnam in 2017: Year=2017, LE Moving_Avg_2Y=73.6352869512196, LE Moving_Avg_3Y=73.63295276422774, LE Moving_Avg_5Y=73.61635809756106, LE Moving_Avg_10Y=73.59072387804886
# 2024-11-19 16:24:56,019 - INFO - Predicted value for Vietnam in 2017: 73.67865560975619
# 2024-11-19 16:24:56,019 - INFO - Prediction inputs for Vietnam in 2018: Year=2018, LE Moving_Avg_2Y=73.65853951219522, LE Moving_Avg_3Y=73.6497431707318, LE Moving_Avg_5Y=73.63680868292693, LE Moving_Avg_10Y=73.59877031707323
# 2024-11-19 16:24:56,021 - INFO - Predicted value for Vietnam in 2018: 73.87032975609763
# 2024-11-19 16:24:56,021 - INFO - Prediction inputs for Vietnam in 2019: Year=2019, LE Moving_Avg_2Y=73.7744926829269, LE Moving_Avg_3Y=73.72913626016269, LE Moving_Avg_5Y=73.6895687317074, LE Moving_Avg_10Y=73.61793773170737
# 2024-11-19 16:24:56,023 - INFO - Predicted value for Vietnam in 2019: 73.86100902439033
# 2024-11-19 16:24:56,023 - INFO - Processing country: Yemen, Rep.
# 2024-11-19 16:24:56,023 - INFO - Prediction inputs for Yemen, Rep. in 2010: Year=2010, LE Moving_Avg_2Y=67.0795, LE Moving_Avg_3Y=66.908, LE Moving_Avg_5Y=66.451, LE Moving_Avg_10Y=65.1518
# 2024-11-19 16:24:56,025 - INFO - Predicted value for Yemen, Rep. in 2010: 67.22221999999995
# 2024-11-19 16:24:56,026 - INFO - Prediction inputs for Yemen, Rep. in 2011: Year=2011, LE Moving_Avg_2Y=67.20910999999998, LE Moving_Avg_3Y=67.21347999999996, LE Moving_Avg_5Y=67.21697599999996, LE Moving_Avg_10Y=67.21959799999996
# 2024-11-19 16:24:56,028 - INFO - Predicted value for Yemen, Rep. in 2011: 67.25228731707315
# 2024-11-19 16:24:56,028 - INFO - Prediction inputs for Yemen, Rep. in 2012: Year=2012, LE Moving_Avg_2Y=67.23725365853656, LE Moving_Avg_3Y=67.22350243902437, LE Moving_Avg_5Y=67.23501639024389, LE Moving_Avg_10Y=67.24365185365853
# 2024-11-19 16:24:56,030 - INFO - Predicted value for Yemen, Rep. in 2012: 67.31670707317076
# 2024-11-19 16:24:56,030 - INFO - Prediction inputs for Yemen, Rep. in 2013: Year=2013, LE Moving_Avg_2Y=67.28449719512196, LE Moving_Avg_3Y=67.2637381300813, LE Moving_Avg_5Y=67.26078429268291, LE Moving_Avg_10Y=67.28874568292684
# 2024-11-19 16:24:56,032 - INFO - Predicted value for Yemen, Rep. in 2013: 67.44300926829268
# 2024-11-19 16:24:56,032 - INFO - Prediction inputs for Yemen, Rep. in 2014: Year=2014, LE Moving_Avg_2Y=67.37985817073172, LE Moving_Avg_3Y=67.33733455284553, LE Moving_Avg_5Y=67.2860447317073, LE Moving_Avg_10Y=67.364527
# 2024-11-19 16:24:56,034 - INFO - Predicted value for Yemen, Rep. in 2014: 67.48051560975611
# 2024-11-19 16:24:56,034 - INFO - Prediction inputs for Yemen, Rep. in 2015: Year=2015, LE Moving_Avg_2Y=67.4617624390244, LE Moving_Avg_3Y=67.41341065040652, LE Moving_Avg_5Y=67.34294785365853, LE Moving_Avg_10Y=67.38328017073171
# 2024-11-19 16:24:56,036 - INFO - Predicted value for Yemen, Rep. in 2015: 67.5470524390244
# 2024-11-19 16:24:56,036 - INFO - Prediction inputs for Yemen, Rep. in 2016: Year=2016, LE Moving_Avg_2Y=67.51378402439025, LE Moving_Avg_3Y=67.4901924390244, LE Moving_Avg_5Y=67.40791434146342, LE Moving_Avg_10Y=67.40989490243902
# 2024-11-19 16:24:56,038 - INFO - Predicted value for Yemen, Rep. in 2016: 67.58262682926828
# 2024-11-19 16:24:56,039 - INFO - Prediction inputs for Yemen, Rep. in 2017: Year=2017, LE Moving_Avg_2Y=67.56483963414634, LE Moving_Avg_3Y=67.53673162601626, LE Moving_Avg_5Y=67.47398224390244, LE Moving_Avg_10Y=67.4205672195122
# 2024-11-19 16:24:56,040 - INFO - Predicted value for Yemen, Rep. in 2017: 67.65686121951222
# 2024-11-19 16:24:56,041 - INFO - Prediction inputs for Yemen, Rep. in 2018: Year=2018, LE Moving_Avg_2Y=67.61974402439026, LE Moving_Avg_3Y=67.59551349593497, LE Moving_Avg_5Y=67.54201307317075, LE Moving_Avg_10Y=67.435414097561
# 2024-11-19 16:24:56,052 - INFO - Predicted value for Yemen, Rep. in 2018: 67.77235682926823
# 2024-11-19 16:24:56,058 - INFO - Prediction inputs for Yemen, Rep. in 2019: Year=2019, LE Moving_Avg_2Y=67.71460902439023, LE Moving_Avg_3Y=67.67061495934958, LE Moving_Avg_5Y=67.60788258536584, LE Moving_Avg_10Y=67.44696365853657
# 2024-11-19 16:24:56,061 - INFO - Predicted value for Yemen, Rep. in 2019: 67.86261097560978
# 2024-11-19 16:24:56,061 - INFO - Processing country: Zambia
# 2024-11-19 16:24:56,062 - INFO - Prediction inputs for Zambia in 2010: Year=2010, LE Moving_Avg_2Y=54.6225, LE Moving_Avg_3Y=53.99466666666666, LE Moving_Avg_5Y=52.8876, LE Moving_Avg_10Y=50.0438
# 2024-11-19 16:24:56,064 - INFO - Predicted value for Zambia in 2010: 55.44106000000004
# 2024-11-19 16:24:56,065 - INFO - Prediction inputs for Zambia in 2011: Year=2011, LE Moving_Avg_2Y=55.37053000000002, LE Moving_Avg_3Y=55.394040000000025, LE Moving_Avg_5Y=55.41284800000003, LE Moving_Avg_10Y=55.42695400000004
# 2024-11-19 16:24:56,068 - INFO - Predicted value for Zambia in 2011: 55.40907999999999
# 2024-11-19 16:24:56,068 - INFO - Prediction inputs for Zambia in 2012: Year=2012, LE Moving_Avg_2Y=55.42507000000002, LE Moving_Avg_3Y=55.38338000000001, LE Moving_Avg_5Y=55.39366, LE Moving_Avg_10Y=55.40137000000001
# 2024-11-19 16:24:56,070 - INFO - Predicted value for Zambia in 2012: 55.42980000000001
# 2024-11-19 16:24:56,071 - INFO - Prediction inputs for Zambia in 2013: Year=2013, LE Moving_Avg_2Y=55.419439999999994, LE Moving_Avg_3Y=55.42664666666668, LE Moving_Avg_5Y=55.40194800000002, LE Moving_Avg_10Y=55.41587400000001
# 2024-11-19 16:24:56,073 - INFO - Predicted value for Zambia in 2013: 55.43102000000001
# 2024-11-19 16:24:56,073 - INFO - Prediction inputs for Zambia in 2014: Year=2014, LE Moving_Avg_2Y=55.43041000000001, LE Moving_Avg_3Y=55.423300000000005, LE Moving_Avg_5Y=55.402192, LE Moving_Avg_10Y=55.416606000000016
# 2024-11-19 16:24:56,075 - INFO - Predicted value for Zambia in 2014: 55.431730000000016
# 2024-11-19 16:24:56,075 - INFO - Prediction inputs for Zambia in 2015: Year=2015, LE Moving_Avg_2Y=55.43137500000002, LE Moving_Avg_3Y=55.430850000000014, LE Moving_Avg_5Y=55.42853800000002, LE Moving_Avg_10Y=55.416961000000015
# 2024-11-19 16:24:56,077 - INFO - Predicted value for Zambia in 2015: 55.431730000000016
# 2024-11-19 16:24:56,077 - INFO - Prediction inputs for Zambia in 2016: Year=2016, LE Moving_Avg_2Y=55.431730000000016, LE Moving_Avg_3Y=55.43149333333335, LE Moving_Avg_5Y=55.42667200000001, LE Moving_Avg_10Y=55.416961000000015
# 2024-11-19 16:24:56,079 - INFO - Predicted value for Zambia in 2016: 55.431730000000016
# 2024-11-19 16:24:56,079 - INFO - Prediction inputs for Zambia in 2017: Year=2017, LE Moving_Avg_2Y=55.431730000000016, LE Moving_Avg_3Y=55.431730000000016, LE Moving_Avg_5Y=55.431202000000006, LE Moving_Avg_10Y=55.416961000000015
# 2024-11-19 16:24:56,081 - INFO - Predicted value for Zambia in 2017: 55.431730000000016
# 2024-11-19 16:24:56,082 - INFO - Prediction inputs for Zambia in 2018: Year=2018, LE Moving_Avg_2Y=55.431730000000016, LE Moving_Avg_3Y=55.431730000000016, LE Moving_Avg_5Y=55.43158800000001, LE Moving_Avg_10Y=55.416961000000015
# 2024-11-19 16:24:56,083 - INFO - Predicted value for Zambia in 2018: 55.431730000000016
# 2024-11-19 16:24:56,084 - INFO - Prediction inputs for Zambia in 2019: Year=2019, LE Moving_Avg_2Y=55.431730000000016, LE Moving_Avg_3Y=55.431730000000016, LE Moving_Avg_5Y=55.431730000000016, LE Moving_Avg_10Y=55.416961000000015
# 2024-11-19 16:24:56,086 - INFO - Predicted value for Zambia in 2019: 55.431730000000016
# 2024-11-19 16:24:56,086 - INFO - Processing country: Zimbabwe
# 2024-11-19 16:24:56,087 - INFO - Prediction inputs for Zimbabwe in 2010: Year=2010, LE Moving_Avg_2Y=47.393, LE Moving_Avg_3Y=46.79866666666666, LE Moving_Avg_5Y=46.105599999999995, LE Moving_Avg_10Y=44.9631
# 2024-11-19 16:24:56,089 - INFO - Predicted value for Zimbabwe in 2010: 47.82141000000006
# 2024-11-19 16:24:56,089 - INFO - Prediction inputs for Zimbabwe in 2011: Year=2011, LE Moving_Avg_2Y=47.94220500000003, LE Moving_Avg_3Y=47.901940000000046, LE Moving_Avg_5Y=47.869728000000045, LE Moving_Avg_10Y=47.845569000000054
# 2024-11-19 16:24:56,091 - INFO - Predicted value for Zimbabwe in 2011: 48.13463999999999
# 2024-11-19 16:24:56,091 - INFO - Prediction inputs for Zimbabwe in 2012: Year=2012, LE Moving_Avg_2Y=47.978025000000024, LE Moving_Avg_3Y=48.00635000000002, LE Moving_Avg_5Y=48.057666000000005, LE Moving_Avg_10Y=48.096153
# 2024-11-19 16:24:56,093 - INFO - Predicted value for Zimbabwe in 2012: 47.99162999999998
# 2024-11-19 16:24:56,093 - INFO - Prediction inputs for Zimbabwe in 2013: Year=2013, LE Moving_Avg_2Y=48.06313499999999, LE Moving_Avg_3Y=47.98256000000001, LE Moving_Avg_5Y=48.000462000000006, LE Moving_Avg_10Y=47.99604599999999
# 2024-11-19 16:24:56,095 - INFO - Predicted value for Zimbabwe in 2013: 48.27426999999998
# 2024-11-19 16:24:56,095 - INFO - Prediction inputs for Zimbabwe in 2014: Year=2014, LE Moving_Avg_2Y=48.13294999999998, LE Moving_Avg_3Y=48.13351333333332, LE Moving_Avg_5Y=48.05699, LE Moving_Avg_10Y=48.16562999999999
# 2024-11-19 16:24:56,097 - INFO - Predicted value for Zimbabwe in 2014: 48.30783999999998
# 2024-11-19 16:24:56,098 - INFO - Prediction inputs for Zimbabwe in 2015: Year=2015, LE Moving_Avg_2Y=48.29105499999998, LE Moving_Avg_3Y=48.19124666666664, LE Moving_Avg_5Y=48.105957999999994, LE Moving_Avg_10Y=48.182415
# 2024-11-19 16:24:56,099 - INFO - Predicted value for Zimbabwe in 2015: 48.32819999999999
# 2024-11-19 16:24:56,100 - INFO - Prediction inputs for Zimbabwe in 2016: Year=2016, LE Moving_Avg_2Y=48.31801999999998, LE Moving_Avg_3Y=48.30343666666665, LE Moving_Avg_5Y=48.20731599999998, LE Moving_Avg_10Y=48.190559
# 2024-11-19 16:24:56,102 - INFO - Predicted value for Zimbabwe in 2016: 48.42842000000003
# 2024-11-19 16:24:56,102 - INFO - Prediction inputs for Zimbabwe in 2017: Year=2017, LE Moving_Avg_2Y=48.37831000000001, LE Moving_Avg_3Y=48.35482, LE Moving_Avg_5Y=48.26607199999999, LE Moving_Avg_10Y=48.22062500000001
# 2024-11-19 16:24:56,104 - INFO - Predicted value for Zimbabwe in 2017: 48.569770000000034
# 2024-11-19 16:24:56,104 - INFO - Prediction inputs for Zimbabwe in 2018: Year=2018, LE Moving_Avg_2Y=48.49909500000003, LE Moving_Avg_3Y=48.44213000000002, LE Moving_Avg_5Y=48.38170000000001, LE Moving_Avg_10Y=48.248895000000005
# 2024-11-19 16:24:56,106 - INFO - Predicted value for Zimbabwe in 2018: 48.654660000000064
# 2024-11-19 16:24:56,106 - INFO - Prediction inputs for Zimbabwe in 2019: Year=2019, LE Moving_Avg_2Y=48.61221500000005, LE Moving_Avg_3Y=48.550950000000036, LE Moving_Avg_5Y=48.45777800000002, LE Moving_Avg_10Y=48.257384
# 2024-11-19 16:24:56,108 - INFO - Predicted value for Zimbabwe in 2019: 48.62993000000004

# %%
# Initialize lists to collect all actual and predicted values across countries
all_actual_values = []
all_predicted_values = []

#For loop to cycle through predictions, establish years as the key and resultant value as the value
for country, predictions in country_recursive_predictions_rf.items():
    predicted_years = list(predictions.keys())
    predicted_values = list(predictions.values())

    # Extract actual values from selected_df for the specified prediction years
    actual_data = selected_df[(selected_df['Country Name'] == country) & (selected_df['Year'].isin(predicted_years))]
    actual_values = actual_data['Life expectancy at birth, total (years)'].values

    # Ensure no NaN or inf values in actual and predicted values
    if len(actual_values) == len(predicted_values):
        actual_values_clean = np.array(actual_values)
        predicted_values_clean = np.array(predicted_values)
        
        # Filter out any NaN or inf values
        valid_indices = ~np.isnan(actual_values_clean) & ~np.isinf(actual_values_clean) & \
                        ~np.isnan(predicted_values_clean) & ~np.isinf(predicted_values_clean)
        actual_values_clean = actual_values_clean[valid_indices]
        predicted_values_clean = predicted_values_clean[valid_indices]

        # Append clean values to the overall lists
        all_actual_values.extend(actual_values_clean)
        all_predicted_values.extend(predicted_values_clean)

# Calculate overall metrics across all countries
if len(all_actual_values) > 0:
    overall_mae = mean_absolute_error(all_actual_values, all_predicted_values)
    overall_mse = mean_squared_error(all_actual_values, all_predicted_values)
    overall_rmse = np.sqrt(overall_mse)
    overall_r2 = r2_score(all_actual_values, all_predicted_values)

else:
    logger.warning("No valid values available for metric calculation.")

# Displaying the overall metrics
print(f"Overall Mean Absolute Error (MAE): {overall_mae:.2f}")
print(f"Overall Mean Squared Error (MSE): {overall_mse:.2f}")
print(f"Overall Root Mean Squared Error (RMSE): {overall_rmse:.2f}")
print(f"Overall R-squared (R²): {overall_r2:.2f}")
# Out:
# Overall Mean Absolute Error (MAE): 1.49
# Overall Mean Squared Error (MSE): 5.29
# Overall Root Mean Squared Error (RMSE): 2.30
# Overall R-squared (R²): 0.92

# %%
# Initialize lists to collect all actual, predicted values, and years across countries
all_actual_values = []
all_predicted_values = []
all_years = []

for country, predictions in country_recursive_predictions_rf.items():
    # Get predictions and corresponding years
    predicted_years = [year for year in predictions.keys() if year >= 2010]
    predicted_values = [predictions[year] for year in predicted_years]

    # Extract actual values from selected_df for the specified prediction years
    actual_data = selected_df[(selected_df['Country Name'] == country) & (selected_df['Year'].isin(predicted_years))]
    actual_values = actual_data['Life expectancy at birth, total (years)'].values
    years = actual_data['Year'].values

    # Ensure no NaN or inf values in actual and predicted values
    if len(actual_values) == len(predicted_values):
        actual_values_clean = np.array(actual_values)
        predicted_values_clean = np.array(predicted_values)
        
        # Filter out any NaN or inf values
        valid_indices = ~np.isnan(actual_values_clean) & ~np.isinf(actual_values_clean) & \
                        ~np.isnan(predicted_values_clean) & ~np.isinf(predicted_values_clean)
        
        actual_values_clean = actual_values_clean[valid_indices]
        predicted_values_clean = predicted_values_clean[valid_indices]
        years_clean = years[valid_indices]

        # Append clean values from 2010 onward to the overall lists
        all_actual_values.extend(actual_values_clean)
        all_predicted_values.extend(predicted_values_clean)
        all_years.extend(years_clean)

# %%
# Redefining test_df based on the years 2010-2019 from selected_df
test_df = selected_df[(selected_df['Year'] >= 2010) & (selected_df['Year'] <= 2019)].dropna(subset=['Life expectancy at birth, total (years)'])

# %% [markdown]
# ## Indicator 1 - Forecasting

# %%
# Define year variables for training and prediction
TRAIN_START_YEAR = 2000
TRAIN_END_YEAR = 2019
PREDICTION_START_YEAR = 2019
PREDICTION_END_YEAR = 2030

# Setting up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Splitting data into training (2000-2019) set and setting up prediction years
train_df = selected_df[(selected_df['Year'] >= TRAIN_START_YEAR) & (selected_df['Year'] <= TRAIN_END_YEAR)].dropna(subset=['Life expectancy at birth, total (years)'])
prediction_years = range(PREDICTION_START_YEAR, PREDICTION_END_YEAR + 1)

# Preparing training data for the model
X_train = train_df[['Year', 'LE Moving_Avg_2Y', 'LE Moving_Avg_3Y', 'LE Moving_Avg_5Y', 'LE Moving_Avg_10Y']].values
y_train = train_df['Life expectancy at birth, total (years)'].values

# Initializing and training the Random Forest model on all training data
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)
logger.info(f"Model trained on all countries' data ({TRAIN_START_YEAR}-{TRAIN_END_YEAR}). Starting recursive forecasting.")

# Dictionary to store predictions for each country
country_recursive_predictions_rf = {}

# Recursive forecasting for each country separately with detailed logging
for country in train_df['Country Name'].unique():
    logger.info(f"Processing country: {country}")

    # Get the last available data point for the country to start recursive prediction
    country_data = train_df[train_df['Country Name'] == country].iloc[-1].copy()
    predictions_per_country = {country_data['Year']: country_data['Life expectancy at birth, total (years)']}

    # Recursive prediction loop from PREDICTION_START_YEAR to PREDICTION_END_YEAR
    for year in prediction_years:
        country_data['Year'] = year
        
        # Logging the input data used for this prediction
        logger.info(f"Prediction inputs for {country} in {year}: Year={year}, "
                    f"LE Moving_Avg_2Y={country_data['LE Moving_Avg_2Y']}, "
                    f"LE Moving_Avg_3Y={country_data['LE Moving_Avg_3Y']}, "
                    f"LE Moving_Avg_5Y={country_data['LE Moving_Avg_5Y']}, "
                    f"LE Moving_Avg_10Y={country_data['LE Moving_Avg_10Y']}")
        
        # Preparing the features for the current prediction
        X_test = country_data[['Year', 'LE Moving_Avg_2Y', 'LE Moving_Avg_3Y', 'LE Moving_Avg_5Y', 'LE Moving_Avg_10Y']].values.reshape(1, -1)
        
        # Predicting life expectancy for the current year
        predicted_value = model_rf.predict(X_test)[0]
        logger.info(f"Predicted value for {country} in {year}: {predicted_value}")
        
        # Update the prediction in the dictionary
        predictions_per_country[year] = predicted_value
        
        # Update the features for the next prediction year based on the new prediction
        country_data['Life expectancy at birth, total (years)'] = predicted_value
        country_data['LE Moving_Avg_2Y'] = (predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 2
        country_data['Moving_Avg_3Y'] = (predictions_per_country.get(year - 2, predicted_value) +
                                         predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 3
        country_data['LE Moving_Avg_5Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 4, year + 1)) / 5)
        country_data['LE Moving_Avg_10Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 9, year + 1)) / 10)

    # Store the predictions for the country
    country_recursive_predictions_rf[country] = predictions_per_country
# Out:
# 2024-11-19 16:24:57,257 - INFO - Model trained on all countries' data (2000-2019). Starting recursive forecasting.
# 2024-11-19 16:24:57,258 - INFO - Processing country: Afghanistan
# 2024-11-19 16:24:57,259 - INFO - Prediction inputs for Afghanistan in 2019: Year=2019, LE Moving_Avg_2Y=63.323, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.0914, LE Moving_Avg_10Y=62.4612
# 2024-11-19 16:24:57,262 - INFO - Predicted value for Afghanistan in 2019: 63.51712999999991
# 2024-11-19 16:24:57,263 - INFO - Prediction inputs for Afghanistan in 2020: Year=2020, LE Moving_Avg_2Y=63.51712999999991, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.51712999999991, LE Moving_Avg_10Y=63.51712999999991
# 2024-11-19 16:24:57,265 - INFO - Predicted value for Afghanistan in 2020: 63.32777
# 2024-11-19 16:24:57,265 - INFO - Prediction inputs for Afghanistan in 2021: Year=2021, LE Moving_Avg_2Y=63.422449999999955, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.36564199999998, LE Moving_Avg_10Y=63.34670599999998
# 2024-11-19 16:24:57,267 - INFO - Predicted value for Afghanistan in 2021: 63.37797999999996
# 2024-11-19 16:24:57,267 - INFO - Prediction inputs for Afghanistan in 2022: Year=2022, LE Moving_Avg_2Y=63.35287499999998, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.39576799999996, LE Moving_Avg_10Y=63.38687399999996
# 2024-11-19 16:24:57,269 - INFO - Predicted value for Afghanistan in 2022: 63.30098999999995
# 2024-11-19 16:24:57,269 - INFO - Prediction inputs for Afghanistan in 2023: Year=2023, LE Moving_Avg_2Y=63.339484999999954, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.364971999999945, LE Moving_Avg_10Y=63.33298099999995
# 2024-11-19 16:24:57,271 - INFO - Predicted value for Afghanistan in 2023: 63.30465999999994
# 2024-11-19 16:24:57,271 - INFO - Prediction inputs for Afghanistan in 2024: Year=2024, LE Moving_Avg_2Y=63.30282499999994, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.36570599999995, LE Moving_Avg_10Y=63.33518299999994
# 2024-11-19 16:24:57,273 - INFO - Predicted value for Afghanistan in 2024: 63.26089999999996
# 2024-11-19 16:24:57,273 - INFO - Prediction inputs for Afghanistan in 2025: Year=2025, LE Moving_Avg_2Y=63.282779999999946, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.31445999999996, LE Moving_Avg_10Y=63.31330299999996
# 2024-11-19 16:24:57,275 - INFO - Predicted value for Afghanistan in 2025: 63.27358999999995
# 2024-11-19 16:24:57,276 - INFO - Prediction inputs for Afghanistan in 2026: Year=2026, LE Moving_Avg_2Y=63.26724499999995, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.30362399999994, LE Moving_Avg_10Y=63.31837899999995
# 2024-11-19 16:24:57,277 - INFO - Predicted value for Afghanistan in 2026: 63.27350999999995
# 2024-11-19 16:24:57,278 - INFO - Prediction inputs for Afghanistan in 2027: Year=2027, LE Moving_Avg_2Y=63.27354999999995, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.282729999999944, LE Moving_Avg_10Y=63.318354999999954
# 2024-11-19 16:24:57,279 - INFO - Predicted value for Afghanistan in 2027: 63.27328999999996
# 2024-11-19 16:24:57,280 - INFO - Prediction inputs for Afghanistan in 2028: Year=2028, LE Moving_Avg_2Y=63.27339999999995, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.27718999999995, LE Moving_Avg_10Y=63.31831099999995
# 2024-11-19 16:24:57,282 - INFO - Predicted value for Afghanistan in 2028: 63.28146999999996
# 2024-11-19 16:24:57,282 - INFO - Prediction inputs for Afghanistan in 2029: Year=2029, LE Moving_Avg_2Y=63.277379999999965, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.27255199999995, LE Moving_Avg_10Y=63.319128999999954
# 2024-11-19 16:24:57,284 - INFO - Predicted value for Afghanistan in 2029: 63.28146999999996
# 2024-11-19 16:24:57,284 - INFO - Prediction inputs for Afghanistan in 2030: Year=2030, LE Moving_Avg_2Y=63.28146999999996, LE Moving_Avg_3Y=63.220666666666666, LE Moving_Avg_5Y=63.276665999999956, LE Moving_Avg_10Y=63.29556299999997
# 2024-11-19 16:24:57,286 - INFO - Predicted value for Afghanistan in 2030: 63.28146999999996
# 2024-11-19 16:24:57,286 - INFO - Processing country: Albania
# 2024-11-19 16:24:57,287 - INFO - Prediction inputs for Albania in 2019: Year=2019, LE Moving_Avg_2Y=79.233, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.00340000000001, LE Moving_Avg_10Y=78.56389999999999
# 2024-11-19 16:24:57,290 - INFO - Predicted value for Albania in 2019: 79.29029121951227
# 2024-11-19 16:24:57,291 - INFO - Prediction inputs for Albania in 2020: Year=2020, LE Moving_Avg_2Y=79.29029121951227, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.29029121951227, LE Moving_Avg_10Y=79.29029121951227
# 2024-11-19 16:24:57,292 - INFO - Predicted value for Albania in 2020: 79.34000487804882
# 2024-11-19 16:24:57,293 - INFO - Prediction inputs for Albania in 2021: Year=2021, LE Moving_Avg_2Y=79.31514804878054, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.3300621463415, LE Moving_Avg_10Y=79.33503351219517
# 2024-11-19 16:24:57,294 - INFO - Predicted value for Albania in 2021: 79.38842902439025
# 2024-11-19 16:24:57,295 - INFO - Prediction inputs for Albania in 2022: Year=2022, LE Moving_Avg_2Y=79.36421695121953, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.35911663414637, LE Moving_Avg_10Y=79.3737728292683
# 2024-11-19 16:24:57,297 - INFO - Predicted value for Albania in 2022: 79.46733731707317
# 2024-11-19 16:24:57,297 - INFO - Prediction inputs for Albania in 2023: Year=2023, LE Moving_Avg_2Y=79.42788317073172, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.39067995121954, LE Moving_Avg_10Y=79.42900863414636
# 2024-11-19 16:24:57,299 - INFO - Predicted value for Albania in 2023: 79.48710707317075
# 2024-11-19 16:24:57,299 - INFO - Prediction inputs for Albania in 2024: Year=2024, LE Moving_Avg_2Y=79.47722219512195, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.39463390243905, LE Moving_Avg_10Y=79.4408704878049
# 2024-11-19 16:24:57,301 - INFO - Predicted value for Albania in 2024: 79.49235878048779
# 2024-11-19 16:24:57,301 - INFO - Prediction inputs for Albania in 2025: Year=2025, LE Moving_Avg_2Y=79.48973292682928, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.43504741463416, LE Moving_Avg_10Y=79.44349634146343
# 2024-11-19 16:24:57,303 - INFO - Predicted value for Albania in 2025: 79.42988731707314
# 2024-11-19 16:24:57,303 - INFO - Prediction inputs for Albania in 2026: Year=2026, LE Moving_Avg_2Y=79.46112304878046, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.45302390243903, LE Moving_Avg_10Y=79.41850775609757
# 2024-11-19 16:24:57,305 - INFO - Predicted value for Albania in 2026: 79.46509731707317
# 2024-11-19 16:24:57,305 - INFO - Prediction inputs for Albania in 2027: Year=2027, LE Moving_Avg_2Y=79.44749231707316, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.46835756097559, LE Moving_Avg_10Y=79.42907075609757
# 2024-11-19 16:24:57,307 - INFO - Predicted value for Albania in 2027: 79.45913243902436
# 2024-11-19 16:24:57,308 - INFO - Prediction inputs for Albania in 2028: Year=2028, LE Moving_Avg_2Y=79.46211487804877, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.46671658536584, LE Moving_Avg_10Y=79.4278777804878
# 2024-11-19 16:24:57,309 - INFO - Predicted value for Albania in 2028: 79.46609975609755
# 2024-11-19 16:24:57,310 - INFO - Prediction inputs for Albania in 2029: Year=2029, LE Moving_Avg_2Y=79.46261609756095, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.46251512195121, LE Moving_Avg_10Y=79.42857451219513
# 2024-11-19 16:24:57,311 - INFO - Predicted value for Albania in 2029: 79.46541682926829
# 2024-11-19 16:24:57,312 - INFO - Prediction inputs for Albania in 2030: Year=2030, LE Moving_Avg_2Y=79.46575829268292, LE Moving_Avg_3Y=79.17099999999999, LE Moving_Avg_5Y=79.4571267317073, LE Moving_Avg_10Y=79.44608707317072
# 2024-11-19 16:24:57,314 - INFO - Predicted value for Albania in 2030: 79.46836414634146
# 2024-11-19 16:24:57,314 - INFO - Processing country: Algeria
# 2024-11-19 16:24:57,314 - INFO - Prediction inputs for Algeria in 2019: Year=2019, LE Moving_Avg_2Y=76.27, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=75.9274, LE Moving_Avg_10Y=75.14949999999999
# 2024-11-19 16:24:57,316 - INFO - Predicted value for Algeria in 2019: 76.45064487804885
# 2024-11-19 16:24:57,317 - INFO - Prediction inputs for Algeria in 2020: Year=2020, LE Moving_Avg_2Y=76.45064487804885, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.45064487804885, LE Moving_Avg_10Y=76.45064487804883
# 2024-11-19 16:24:57,319 - INFO - Predicted value for Algeria in 2020: 76.5469192682927
# 2024-11-19 16:24:57,319 - INFO - Prediction inputs for Algeria in 2021: Year=2021, LE Moving_Avg_2Y=76.49878207317077, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.52766439024393, LE Moving_Avg_10Y=76.53729182926831
# 2024-11-19 16:24:57,321 - INFO - Predicted value for Algeria in 2021: 76.62675219512194
# 2024-11-19 16:24:57,321 - INFO - Prediction inputs for Algeria in 2022: Year=2022, LE Moving_Avg_2Y=76.58683573170731, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.57556414634146, LE Moving_Avg_10Y=76.6011581707317
# 2024-11-19 16:24:57,323 - INFO - Predicted value for Algeria in 2022: 76.65948073170725
# 2024-11-19 16:24:57,323 - INFO - Prediction inputs for Algeria in 2023: Year=2023, LE Moving_Avg_2Y=76.6431164634146, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.5886555609756, LE Moving_Avg_10Y=76.62406814634143
# 2024-11-19 16:24:57,325 - INFO - Predicted value for Algeria in 2023: 76.65813292682921
# 2024-11-19 16:24:57,325 - INFO - Prediction inputs for Algeria in 2024: Year=2024, LE Moving_Avg_2Y=76.65880682926823, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.58838599999999, LE Moving_Avg_10Y=76.6232594634146
# 2024-11-19 16:24:57,327 - INFO - Predicted value for Algeria in 2024: 76.68105439024384
# 2024-11-19 16:24:57,327 - INFO - Prediction inputs for Algeria in 2025: Year=2025, LE Moving_Avg_2Y=76.66959365853653, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.63446790243898, LE Moving_Avg_10Y=76.63472019512191
# 2024-11-19 16:24:57,329 - INFO - Predicted value for Algeria in 2025: 76.68393512195117
# 2024-11-19 16:24:57,330 - INFO - Prediction inputs for Algeria in 2026: Year=2026, LE Moving_Avg_2Y=76.6824947560975, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.66187107317067, LE Moving_Avg_10Y=76.63587248780485
# 2024-11-19 16:24:57,331 - INFO - Predicted value for Algeria in 2026: 76.67824439024385
# 2024-11-19 16:24:57,332 - INFO - Prediction inputs for Algeria in 2027: Year=2027, LE Moving_Avg_2Y=76.6810897560975, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.67216951219505, LE Moving_Avg_10Y=76.63416526829266
# 2024-11-19 16:24:57,333 - INFO - Predicted value for Algeria in 2027: 76.67824439024385
# 2024-11-19 16:24:57,334 - INFO - Prediction inputs for Algeria in 2028: Year=2028, LE Moving_Avg_2Y=76.67824439024385, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.67592224390238, LE Moving_Avg_10Y=76.63416526829266
# 2024-11-19 16:24:57,335 - INFO - Predicted value for Algeria in 2028: 76.68141512195116
# 2024-11-19 16:24:57,336 - INFO - Prediction inputs for Algeria in 2029: Year=2029, LE Moving_Avg_2Y=76.6798297560975, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.68057868292676, LE Moving_Avg_10Y=76.6344823414634
# 2024-11-19 16:24:57,338 - INFO - Predicted value for Algeria in 2029: 76.68141512195116
# 2024-11-19 16:24:57,338 - INFO - Prediction inputs for Algeria in 2030: Year=2030, LE Moving_Avg_2Y=76.68141512195116, LE Moving_Avg_3Y=76.09433333333334, LE Moving_Avg_5Y=76.68065082926823, LE Moving_Avg_10Y=76.65755936585363
# 2024-11-19 16:24:57,340 - INFO - Predicted value for Algeria in 2030: 76.67824439024385
# 2024-11-19 16:24:57,340 - INFO - Processing country: Angola
# 2024-11-19 16:24:57,340 - INFO - Prediction inputs for Angola in 2019: Year=2019, LE Moving_Avg_2Y=62.296, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=61.6038, LE Moving_Avg_10Y=60.031099999999995
# 2024-11-19 16:24:57,342 - INFO - Predicted value for Angola in 2019: 62.45921000000004
# 2024-11-19 16:24:57,343 - INFO - Prediction inputs for Angola in 2020: Year=2020, LE Moving_Avg_2Y=62.45921000000004, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.45921000000004, LE Moving_Avg_10Y=62.45921000000003
# 2024-11-19 16:24:57,345 - INFO - Predicted value for Angola in 2020: 62.63417999999996
# 2024-11-19 16:24:57,345 - INFO - Prediction inputs for Angola in 2021: Year=2021, LE Moving_Avg_2Y=62.546695, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.599185999999975, LE Moving_Avg_10Y=62.616682999999966
# 2024-11-19 16:24:57,347 - INFO - Predicted value for Angola in 2021: 62.72494
# 2024-11-19 16:24:57,347 - INFO - Prediction inputs for Angola in 2022: Year=2022, LE Moving_Avg_2Y=62.67955999999998, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.653642000000005, LE Moving_Avg_10Y=62.68929099999999
# 2024-11-19 16:24:57,349 - INFO - Predicted value for Angola in 2022: 62.729249999999986
# 2024-11-19 16:24:57,349 - INFO - Prediction inputs for Angola in 2023: Year=2023, LE Moving_Avg_2Y=62.72709499999999, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.655365999999994, LE Moving_Avg_10Y=62.69230799999999
# 2024-11-19 16:24:57,351 - INFO - Predicted value for Angola in 2023: 62.774840000000005
# 2024-11-19 16:24:57,351 - INFO - Prediction inputs for Angola in 2024: Year=2024, LE Moving_Avg_2Y=62.752044999999995, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.664483999999995, LE Moving_Avg_10Y=62.71966200000001
# 2024-11-19 16:24:57,353 - INFO - Predicted value for Angola in 2024: 62.769829999999985
# 2024-11-19 16:24:57,353 - INFO - Prediction inputs for Angola in 2025: Year=2025, LE Moving_Avg_2Y=62.772335, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.726607999999985, LE Moving_Avg_10Y=62.717156999999986
# 2024-11-19 16:24:57,355 - INFO - Predicted value for Angola in 2025: 62.758089999999996
# 2024-11-19 16:24:57,355 - INFO - Prediction inputs for Angola in 2026: Year=2026, LE Moving_Avg_2Y=62.76395999999999, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.751389999999994, LE Moving_Avg_10Y=62.712461
# 2024-11-19 16:24:57,357 - INFO - Predicted value for Angola in 2026: 62.76481999999999
# 2024-11-19 16:24:57,357 - INFO - Prediction inputs for Angola in 2027: Year=2027, LE Moving_Avg_2Y=62.761455, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.759365999999986, LE Moving_Avg_10Y=62.714479999999995
# 2024-11-19 16:24:57,359 - INFO - Predicted value for Angola in 2027: 62.76481999999999
# 2024-11-19 16:24:57,360 - INFO - Prediction inputs for Angola in 2028: Year=2028, LE Moving_Avg_2Y=62.76481999999999, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.76647999999999, LE Moving_Avg_10Y=62.714479999999995
# 2024-11-19 16:24:57,361 - INFO - Predicted value for Angola in 2028: 62.76379999999999
# 2024-11-19 16:24:57,362 - INFO - Prediction inputs for Angola in 2029: Year=2029, LE Moving_Avg_2Y=62.764309999999995, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.76427199999999, LE Moving_Avg_10Y=62.71437799999999
# 2024-11-19 16:24:57,364 - INFO - Predicted value for Angola in 2029: 62.76379999999999
# 2024-11-19 16:24:57,364 - INFO - Prediction inputs for Angola in 2030: Year=2030, LE Moving_Avg_2Y=62.76379999999999, LE Moving_Avg_3Y=62.090666666666664, LE Moving_Avg_5Y=62.763065999999995, LE Moving_Avg_10Y=62.74483699999998
# 2024-11-19 16:24:57,366 - INFO - Predicted value for Angola in 2030: 62.76481999999999
# 2024-11-19 16:24:57,366 - INFO - Processing country: Antigua and Barbuda
# 2024-11-19 16:24:57,366 - INFO - Prediction inputs for Antigua and Barbuda in 2019: Year=2019, LE Moving_Avg_2Y=78.601, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.307, LE Moving_Avg_10Y=77.825
# 2024-11-19 16:24:57,369 - INFO - Predicted value for Antigua and Barbuda in 2019: 78.66947170731699
# 2024-11-19 16:24:57,369 - INFO - Prediction inputs for Antigua and Barbuda in 2020: Year=2020, LE Moving_Avg_2Y=78.66947170731699, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.66947170731699, LE Moving_Avg_10Y=78.669471707317
# 2024-11-19 16:24:57,371 - INFO - Predicted value for Antigua and Barbuda in 2020: 78.69132829268293
# 2024-11-19 16:24:57,371 - INFO - Prediction inputs for Antigua and Barbuda in 2021: Year=2021, LE Moving_Avg_2Y=78.68039999999996, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.68695697560975, LE Moving_Avg_10Y=78.68914263414632
# 2024-11-19 16:24:57,373 - INFO - Predicted value for Antigua and Barbuda in 2021: 78.69137707317073
# 2024-11-19 16:24:57,373 - INFO - Prediction inputs for Antigua and Barbuda in 2022: Year=2022, LE Moving_Avg_2Y=78.69135268292683, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.68698624390241, LE Moving_Avg_10Y=78.68918165853657
# 2024-11-19 16:24:57,375 - INFO - Predicted value for Antigua and Barbuda in 2022: 78.7074068292683
# 2024-11-19 16:24:57,375 - INFO - Prediction inputs for Antigua and Barbuda in 2023: Year=2023, LE Moving_Avg_2Y=78.69939195121951, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.69339814634144, LE Moving_Avg_10Y=78.70040248780487
# 2024-11-19 16:24:57,377 - INFO - Predicted value for Antigua and Barbuda in 2023: 78.70273195121949
# 2024-11-19 16:24:57,377 - INFO - Prediction inputs for Antigua and Barbuda in 2024: Year=2024, LE Moving_Avg_2Y=78.70506939024389, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.69246317073168, LE Moving_Avg_10Y=78.6975975609756
# 2024-11-19 16:24:57,379 - INFO - Predicted value for Antigua and Barbuda in 2024: 78.7078282926829
# 2024-11-19 16:24:57,379 - INFO - Prediction inputs for Antigua and Barbuda in 2025: Year=2025, LE Moving_Avg_2Y=78.7052801219512, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.70013448780487, LE Moving_Avg_10Y=78.7001457317073
# 2024-11-19 16:24:57,381 - INFO - Predicted value for Antigua and Barbuda in 2025: 78.7078282926829
# 2024-11-19 16:24:57,382 - INFO - Prediction inputs for Antigua and Barbuda in 2026: Year=2026, LE Moving_Avg_2Y=78.7078282926829, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.70343448780486, LE Moving_Avg_10Y=78.7001457317073
# 2024-11-19 16:24:57,383 - INFO - Predicted value for Antigua and Barbuda in 2026: 78.76346414634142
# 2024-11-19 16:24:57,384 - INFO - Prediction inputs for Antigua and Barbuda in 2027: Year=2027, LE Moving_Avg_2Y=78.73564621951216, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.717851902439, LE Moving_Avg_10Y=78.71683648780485
# 2024-11-19 16:24:57,385 - INFO - Predicted value for Antigua and Barbuda in 2027: 78.76347073170726
# 2024-11-19 16:24:57,386 - INFO - Prediction inputs for Antigua and Barbuda in 2028: Year=2028, LE Moving_Avg_2Y=78.76346743902434, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.72906468292679, LE Moving_Avg_10Y=78.71683780487801
# 2024-11-19 16:24:57,388 - INFO - Predicted value for Antigua and Barbuda in 2028: 78.76707707317065
# 2024-11-19 16:24:57,388 - INFO - Prediction inputs for Antigua and Barbuda in 2029: Year=2029, LE Moving_Avg_2Y=78.76527390243896, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.74193370731703, LE Moving_Avg_10Y=78.71719843902436
# 2024-11-19 16:24:57,390 - INFO - Predicted value for Antigua and Barbuda in 2029: 78.76707707317065
# 2024-11-19 16:24:57,390 - INFO - Prediction inputs for Antigua and Barbuda in 2030: Year=2030, LE Moving_Avg_2Y=78.76707707317065, LE Moving_Avg_3Y=78.49, LE Moving_Avg_5Y=78.75378346341458, LE Moving_Avg_10Y=78.72695897560972
# 2024-11-19 16:24:57,392 - INFO - Predicted value for Antigua and Barbuda in 2030: 78.7676136585365
# 2024-11-19 16:24:57,392 - INFO - Processing country: Argentina
# 2024-11-19 16:24:57,393 - INFO - Prediction inputs for Argentina in 2019: Year=2019, LE Moving_Avg_2Y=77.14150000000001, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=76.83680000000001, LE Moving_Avg_10Y=76.57419999999999
# 2024-11-19 16:24:57,395 - INFO - Predicted value for Argentina in 2019: 77.26353121951207
# 2024-11-19 16:24:57,395 - INFO - Prediction inputs for Argentina in 2020: Year=2020, LE Moving_Avg_2Y=77.26353121951207, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.26353121951207, LE Moving_Avg_10Y=77.26353121951207
# 2024-11-19 16:24:57,397 - INFO - Predicted value for Argentina in 2020: 77.36452682926829
# 2024-11-19 16:24:57,397 - INFO - Prediction inputs for Argentina in 2021: Year=2021, LE Moving_Avg_2Y=77.31402902439018, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.34432770731703, LE Moving_Avg_10Y=77.35442726829265
# 2024-11-19 16:24:57,399 - INFO - Predicted value for Argentina in 2021: 77.42632853658539
# 2024-11-19 16:24:57,399 - INFO - Prediction inputs for Argentina in 2022: Year=2022, LE Moving_Avg_2Y=77.39542768292684, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.38140873170731, LE Moving_Avg_10Y=77.40386863414633
# 2024-11-19 16:24:57,401 - INFO - Predicted value for Argentina in 2022: 77.47763243902442
# 2024-11-19 16:24:57,401 - INFO - Prediction inputs for Argentina in 2023: Year=2023, LE Moving_Avg_2Y=77.4519804878049, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.40193029268292, LE Moving_Avg_10Y=77.43978136585368
# 2024-11-19 16:24:57,403 - INFO - Predicted value for Argentina in 2023: 77.5327163414634
# 2024-11-19 16:24:57,404 - INFO - Prediction inputs for Argentina in 2024: Year=2024, LE Moving_Avg_2Y=77.50517439024391, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.41294707317073, LE Moving_Avg_10Y=77.47283170731706
# 2024-11-19 16:24:57,405 - INFO - Predicted value for Argentina in 2024: 77.52796024390243
# 2024-11-19 16:24:57,406 - INFO - Prediction inputs for Argentina in 2025: Year=2025, LE Moving_Avg_2Y=77.53033829268291, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.46583287804879, LE Moving_Avg_10Y=77.47045365853657
# 2024-11-19 16:24:57,407 - INFO - Predicted value for Argentina in 2025: 77.5261719512195
# 2024-11-19 16:24:57,408 - INFO - Prediction inputs for Argentina in 2026: Year=2026, LE Moving_Avg_2Y=77.52706609756096, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.49816190243902, LE Moving_Avg_10Y=77.46973834146338
# 2024-11-19 16:24:57,410 - INFO - Predicted value for Argentina in 2026: 77.52680195121948
# 2024-11-19 16:24:57,410 - INFO - Prediction inputs for Argentina in 2027: Year=2027, LE Moving_Avg_2Y=77.52648695121948, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.51825658536583, LE Moving_Avg_10Y=77.46992734146338
# 2024-11-19 16:24:57,412 - INFO - Predicted value for Argentina in 2027: 77.52450195121948
# 2024-11-19 16:24:57,412 - INFO - Prediction inputs for Argentina in 2028: Year=2028, LE Moving_Avg_2Y=77.52565195121949, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.52763048780484, LE Moving_Avg_10Y=77.46946734146339
# 2024-11-19 16:24:57,414 - INFO - Predicted value for Argentina in 2028: 77.52450195121948
# 2024-11-19 16:24:57,414 - INFO - Prediction inputs for Argentina in 2029: Year=2029, LE Moving_Avg_2Y=77.52450195121948, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.52598760975607, LE Moving_Avg_10Y=77.4694673414634
# 2024-11-19 16:24:57,416 - INFO - Predicted value for Argentina in 2029: 77.52583195121947
# 2024-11-19 16:24:57,416 - INFO - Prediction inputs for Argentina in 2030: Year=2030, LE Moving_Avg_2Y=77.52516695121948, LE Moving_Avg_3Y=77.03866666666666, LE Moving_Avg_5Y=77.52556195121947, LE Moving_Avg_10Y=77.49569741463414
# 2024-11-19 16:24:57,418 - INFO - Predicted value for Argentina in 2030: 77.52450195121948
# 2024-11-19 16:24:57,418 - INFO - Processing country: Armenia
# 2024-11-19 16:24:57,419 - INFO - Prediction inputs for Armenia in 2019: Year=2019, LE Moving_Avg_2Y=75.2515, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=74.90180000000001, LE Moving_Avg_10Y=74.2162
# 2024-11-19 16:24:57,421 - INFO - Predicted value for Armenia in 2019: 75.40625097560982
# 2024-11-19 16:24:57,421 - INFO - Prediction inputs for Armenia in 2020: Year=2020, LE Moving_Avg_2Y=75.40625097560982, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.40625097560982, LE Moving_Avg_10Y=75.40625097560984
# 2024-11-19 16:24:57,423 - INFO - Predicted value for Armenia in 2020: 75.4485836585366
# 2024-11-19 16:24:57,423 - INFO - Prediction inputs for Armenia in 2021: Year=2021, LE Moving_Avg_2Y=75.4274173170732, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.44011712195126, LE Moving_Avg_10Y=75.44435039024393
# 2024-11-19 16:24:57,425 - INFO - Predicted value for Armenia in 2021: 75.44942902439027
# 2024-11-19 16:24:57,426 - INFO - Prediction inputs for Armenia in 2022: Year=2022, LE Moving_Avg_2Y=75.44900634146344, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.44062434146345, LE Moving_Avg_10Y=75.44502668292685
# 2024-11-19 16:24:57,427 - INFO - Predicted value for Armenia in 2022: 75.67232756097566
# 2024-11-19 16:24:57,428 - INFO - Prediction inputs for Armenia in 2023: Year=2023, LE Moving_Avg_2Y=75.56087829268296, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.5297837560976, LE Moving_Avg_10Y=75.60105565853662
# 2024-11-19 16:24:57,429 - INFO - Predicted value for Armenia in 2023: 75.73455390243903
# 2024-11-19 16:24:57,430 - INFO - Prediction inputs for Armenia in 2024: Year=2024, LE Moving_Avg_2Y=75.70344073170735, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.54222902439027, LE Moving_Avg_10Y=75.63839146341465
# 2024-11-19 16:24:57,432 - INFO - Predicted value for Armenia in 2024: 75.87436902439025
# 2024-11-19 16:24:57,432 - INFO - Prediction inputs for Armenia in 2025: Year=2025, LE Moving_Avg_2Y=75.80446146341464, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.63585263414636, LE Moving_Avg_10Y=75.70829902439027
# 2024-11-19 16:24:57,434 - INFO - Predicted value for Armenia in 2025: 75.93345658536587
# 2024-11-19 16:24:57,434 - INFO - Prediction inputs for Armenia in 2026: Year=2026, LE Moving_Avg_2Y=75.90391280487806, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.73282721951222, LE Moving_Avg_10Y=75.73193404878052
# 2024-11-19 16:24:57,436 - INFO - Predicted value for Armenia in 2026: 75.94069390243901
# 2024-11-19 16:24:57,436 - INFO - Prediction inputs for Armenia in 2027: Year=2027, LE Moving_Avg_2Y=75.93707524390244, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.83108019512197, LE Moving_Avg_10Y=75.73410524390246
# 2024-11-19 16:24:57,438 - INFO - Predicted value for Armenia in 2027: 75.94316195121951
# 2024-11-19 16:24:57,439 - INFO - Prediction inputs for Armenia in 2028: Year=2028, LE Moving_Avg_2Y=75.94192792682927, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.88524707317075, LE Moving_Avg_10Y=75.73459885365854
# 2024-11-19 16:24:57,440 - INFO - Predicted value for Armenia in 2028: 75.95489365853659
# 2024-11-19 16:24:57,441 - INFO - Prediction inputs for Armenia in 2029: Year=2029, LE Moving_Avg_2Y=75.94902780487806, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.92931502439025, LE Moving_Avg_10Y=75.73577202439024
# 2024-11-19 16:24:57,443 - INFO - Predicted value for Armenia in 2029: 75.99064585365855
# 2024-11-19 16:24:57,443 - INFO - Prediction inputs for Armenia in 2030: Year=2030, LE Moving_Avg_2Y=75.97276975609756, LE Moving_Avg_3Y=75.13633333333333, LE Moving_Avg_5Y=75.9525703902439, LE Moving_Avg_10Y=75.79421151219512
# 2024-11-19 16:24:57,445 - INFO - Predicted value for Armenia in 2030: 76.00540951219513
# 2024-11-19 16:24:57,445 - INFO - Processing country: Australia
# 2024-11-19 16:24:57,446 - INFO - Prediction inputs for Australia in 2019: Year=2019, LE Moving_Avg_2Y=82.82439024390246, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=82.59951219512196, LE Moving_Avg_10Y=82.30829268292682
# 2024-11-19 16:24:57,450 - INFO - Predicted value for Australia in 2019: 82.91559268292674
# 2024-11-19 16:24:57,450 - INFO - Prediction inputs for Australia in 2020: Year=2020, LE Moving_Avg_2Y=82.91559268292674, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=82.91559268292674, LE Moving_Avg_10Y=82.91559268292676
# 2024-11-19 16:24:57,452 - INFO - Predicted value for Australia in 2020: 83.19254390243907
# 2024-11-19 16:24:57,452 - INFO - Prediction inputs for Australia in 2021: Year=2021, LE Moving_Avg_2Y=83.0540682926829, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.1371536585366, LE Moving_Avg_10Y=83.16484878048784
# 2024-11-19 16:24:57,454 - INFO - Predicted value for Australia in 2021: 83.26632439024395
# 2024-11-19 16:24:57,454 - INFO - Prediction inputs for Australia in 2022: Year=2022, LE Moving_Avg_2Y=83.2294341463415, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.18142195121953, LE Moving_Avg_10Y=83.22387317073175
# 2024-11-19 16:24:57,456 - INFO - Predicted value for Australia in 2022: 83.28984634146346
# 2024-11-19 16:24:57,456 - INFO - Prediction inputs for Australia in 2023: Year=2023, LE Moving_Avg_2Y=83.27808536585371, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.19083073170734, LE Moving_Avg_10Y=83.2403385365854
# 2024-11-19 16:24:57,458 - INFO - Predicted value for Australia in 2023: 83.28679512195126
# 2024-11-19 16:24:57,458 - INFO - Prediction inputs for Australia in 2024: Year=2024, LE Moving_Avg_2Y=83.28832073170736, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.1902204878049, LE Moving_Avg_10Y=83.23850780487808
# 2024-11-19 16:24:57,460 - INFO - Predicted value for Australia in 2024: 83.28679512195126
# 2024-11-19 16:24:57,460 - INFO - Prediction inputs for Australia in 2025: Year=2025, LE Moving_Avg_2Y=83.28679512195126, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.2644609756098, LE Moving_Avg_10Y=83.23850780487808
# 2024-11-19 16:24:57,462 - INFO - Predicted value for Australia in 2025: 83.28613658536588
# 2024-11-19 16:24:57,462 - INFO - Prediction inputs for Australia in 2026: Year=2026, LE Moving_Avg_2Y=83.28646585365857, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.28317951219518, LE Moving_Avg_10Y=83.23824439024392
# 2024-11-19 16:24:57,464 - INFO - Predicted value for Australia in 2026: 83.28947804878051
# 2024-11-19 16:24:57,464 - INFO - Prediction inputs for Australia in 2027: Year=2027, LE Moving_Avg_2Y=83.2878073170732, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.28781024390247, LE Moving_Avg_10Y=83.23924682926832
# 2024-11-19 16:24:57,466 - INFO - Predicted value for Australia in 2027: 83.28947804878051
# 2024-11-19 16:24:57,466 - INFO - Prediction inputs for Australia in 2028: Year=2028, LE Moving_Avg_2Y=83.28947804878051, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.28773658536588, LE Moving_Avg_10Y=83.23924682926832
# 2024-11-19 16:24:57,468 - INFO - Predicted value for Australia in 2028: 83.28947804878051
# 2024-11-19 16:24:57,468 - INFO - Prediction inputs for Australia in 2029: Year=2029, LE Moving_Avg_2Y=83.28947804878051, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.28827317073173, LE Moving_Avg_10Y=83.23924682926832
# 2024-11-19 16:24:57,470 - INFO - Predicted value for Australia in 2029: 83.28947804878051
# 2024-11-19 16:24:57,470 - INFO - Prediction inputs for Australia in 2030: Year=2030, LE Moving_Avg_2Y=83.28947804878051, LE Moving_Avg_3Y=82.71626016260163, LE Moving_Avg_5Y=83.28880975609758, LE Moving_Avg_10Y=83.2766353658537
# 2024-11-19 16:24:57,472 - INFO - Predicted value for Australia in 2030: 83.28947804878051
# 2024-11-19 16:24:57,472 - INFO - Processing country: Austria
# 2024-11-19 16:24:57,473 - INFO - Prediction inputs for Austria in 2019: Year=2019, LE Moving_Avg_2Y=81.79390243902441, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=81.61268292682928, LE Moving_Avg_10Y=81.31902439024392
# 2024-11-19 16:24:57,475 - INFO - Predicted value for Austria in 2019: 81.87954146341451
# 2024-11-19 16:24:57,475 - INFO - Prediction inputs for Austria in 2020: Year=2020, LE Moving_Avg_2Y=81.87954146341451, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=81.87954146341451, LE Moving_Avg_10Y=81.87954146341451
# 2024-11-19 16:24:57,477 - INFO - Predicted value for Austria in 2020: 81.90011951219515
# 2024-11-19 16:24:57,477 - INFO - Prediction inputs for Austria in 2021: Year=2021, LE Moving_Avg_2Y=81.88983048780483, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=81.89600390243902, LE Moving_Avg_10Y=81.89806170731708
# 2024-11-19 16:24:57,479 - INFO - Predicted value for Austria in 2021: 82.00823902439029
# 2024-11-19 16:24:57,479 - INFO - Prediction inputs for Austria in 2022: Year=2022, LE Moving_Avg_2Y=81.95417926829272, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=81.96087560975612, LE Moving_Avg_10Y=81.98455731707318
# 2024-11-19 16:24:57,481 - INFO - Predicted value for Austria in 2022: 82.0303585365854
# 2024-11-19 16:24:57,481 - INFO - Prediction inputs for Austria in 2023: Year=2023, LE Moving_Avg_2Y=82.01929878048784, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=81.96972341463416, LE Moving_Avg_10Y=82.00004097560976
# 2024-11-19 16:24:57,492 - INFO - Predicted value for Austria in 2023: 82.09649999999999
# 2024-11-19 16:24:57,493 - INFO - Prediction inputs for Austria in 2024: Year=2024, LE Moving_Avg_2Y=82.0634292682927, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=81.98295170731707, LE Moving_Avg_10Y=82.03972585365852
# 2024-11-19 16:24:57,502 - INFO - Predicted value for Austria in 2024: 82.15829268292684
# 2024-11-19 16:24:57,502 - INFO - Prediction inputs for Austria in 2025: Year=2025, LE Moving_Avg_2Y=82.12739634146342, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=82.03870195121954, LE Moving_Avg_10Y=82.07062219512196
# 2024-11-19 16:24:57,504 - INFO - Predicted value for Austria in 2025: 82.09350243902438
# 2024-11-19 16:24:57,505 - INFO - Prediction inputs for Austria in 2026: Year=2026, LE Moving_Avg_2Y=82.1258975609756, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=82.07737853658539, LE Moving_Avg_10Y=82.04470609756096
# 2024-11-19 16:24:57,508 - INFO - Predicted value for Austria in 2026: 82.08503902439021
# 2024-11-19 16:24:57,509 - INFO - Prediction inputs for Austria in 2027: Year=2027, LE Moving_Avg_2Y=82.0892707317073, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=82.09273853658536, LE Moving_Avg_10Y=82.0421670731707
# 2024-11-19 16:24:57,511 - INFO - Predicted value for Austria in 2027: 82.08417073170735
# 2024-11-19 16:24:57,511 - INFO - Prediction inputs for Austria in 2028: Year=2028, LE Moving_Avg_2Y=82.08460487804878, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=82.10350097560976, LE Moving_Avg_10Y=82.04199341463413
# 2024-11-19 16:24:57,513 - INFO - Predicted value for Austria in 2028: 82.08417073170735
# 2024-11-19 16:24:57,513 - INFO - Prediction inputs for Austria in 2029: Year=2029, LE Moving_Avg_2Y=82.08417073170735, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=82.10103512195121, LE Moving_Avg_10Y=82.04199341463415
# 2024-11-19 16:24:57,515 - INFO - Predicted value for Austria in 2029: 82.08417073170735
# 2024-11-19 16:24:57,516 - INFO - Prediction inputs for Austria in 2030: Year=2030, LE Moving_Avg_2Y=82.08417073170735, LE Moving_Avg_3Y=81.7439024390244, LE Moving_Avg_5Y=82.08621073170733, LE Moving_Avg_10Y=82.06245634146343
# 2024-11-19 16:24:57,517 - INFO - Predicted value for Austria in 2030: 82.08417073170735
# 2024-11-19 16:24:57,518 - INFO - Processing country: Azerbaijan
# 2024-11-19 16:24:57,518 - INFO - Prediction inputs for Azerbaijan in 2019: Year=2019, LE Moving_Avg_2Y=72.93100000000001, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=72.313, LE Moving_Avg_10Y=71.34349999999999
# 2024-11-19 16:24:57,522 - INFO - Predicted value for Azerbaijan in 2019: 73.09722243902432
# 2024-11-19 16:24:57,522 - INFO - Prediction inputs for Azerbaijan in 2020: Year=2020, LE Moving_Avg_2Y=73.09722243902432, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.09722243902432, LE Moving_Avg_10Y=73.09722243902432
# 2024-11-19 16:24:57,524 - INFO - Predicted value for Azerbaijan in 2020: 73.16781292682931
# 2024-11-19 16:24:57,525 - INFO - Prediction inputs for Azerbaijan in 2021: Year=2021, LE Moving_Avg_2Y=73.13251768292682, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.15369482926832, LE Moving_Avg_10Y=73.16075387804882
# 2024-11-19 16:24:57,527 - INFO - Predicted value for Azerbaijan in 2021: 73.1567592682927
# 2024-11-19 16:24:57,527 - INFO - Prediction inputs for Azerbaijan in 2022: Year=2022, LE Moving_Avg_2Y=73.16228609756101, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.14706263414635, LE Moving_Avg_10Y=73.15191095121953
# 2024-11-19 16:24:57,529 - INFO - Predicted value for Azerbaijan in 2022: 73.19393414634146
# 2024-11-19 16:24:57,529 - INFO - Prediction inputs for Azerbaijan in 2023: Year=2023, LE Moving_Avg_2Y=73.17534670731709, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.16193258536586, LE Moving_Avg_10Y=73.17793336585366
# 2024-11-19 16:24:57,531 - INFO - Predicted value for Azerbaijan in 2023: 73.20230097560975
# 2024-11-19 16:24:57,531 - INFO - Prediction inputs for Azerbaijan in 2024: Year=2024, LE Moving_Avg_2Y=73.1981175609756, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.16360595121951, LE Moving_Avg_10Y=73.18295346341463
# 2024-11-19 16:24:57,533 - INFO - Predicted value for Azerbaijan in 2024: 73.23505195121948
# 2024-11-19 16:24:57,533 - INFO - Prediction inputs for Azerbaijan in 2025: Year=2025, LE Moving_Avg_2Y=73.21867646341461, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.19117185365853, LE Moving_Avg_10Y=73.19932895121948
# 2024-11-19 16:24:57,535 - INFO - Predicted value for Azerbaijan in 2025: 73.27570048780485
# 2024-11-19 16:24:57,535 - INFO - Prediction inputs for Azerbaijan in 2026: Year=2026, LE Moving_Avg_2Y=73.25537621951216, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.21274936585365, LE Moving_Avg_10Y=73.21558836585365
# 2024-11-19 16:24:57,537 - INFO - Predicted value for Azerbaijan in 2026: 73.32344975609753
# 2024-11-19 16:24:57,537 - INFO - Prediction inputs for Azerbaijan in 2027: Year=2027, LE Moving_Avg_2Y=73.2995751219512, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.24608746341463, LE Moving_Avg_10Y=73.22991314634145
# 2024-11-19 16:24:57,539 - INFO - Predicted value for Azerbaijan in 2027: 73.45167317073177
# 2024-11-19 16:24:57,539 - INFO - Prediction inputs for Azerbaijan in 2028: Year=2028, LE Moving_Avg_2Y=73.38756146341464, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.29763526829268, LE Moving_Avg_10Y=73.25555782926828
# 2024-11-19 16:24:57,541 - INFO - Predicted value for Azerbaijan in 2028: 73.51725390243907
# 2024-11-19 16:24:57,542 - INFO - Prediction inputs for Azerbaijan in 2029: Year=2029, LE Moving_Avg_2Y=73.48446353658542, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.36062585365853, LE Moving_Avg_10Y=73.26211590243902
# 2024-11-19 16:24:57,543 - INFO - Predicted value for Azerbaijan in 2029: 73.58412170731707
# 2024-11-19 16:24:57,544 - INFO - Prediction inputs for Azerbaijan in 2030: Year=2030, LE Moving_Avg_2Y=73.55068780487807, LE Moving_Avg_3Y=72.70333333333333, LE Moving_Avg_5Y=73.43043980487806, LE Moving_Avg_10Y=73.31080582926829
# 2024-11-19 16:24:57,546 - INFO - Predicted value for Azerbaijan in 2030: 73.65349512195121
# 2024-11-19 16:24:57,546 - INFO - Processing country: Bahamas, The
# 2024-11-19 16:24:57,546 - INFO - Prediction inputs for Bahamas, The in 2019: Year=2019, LE Moving_Avg_2Y=72.50550000000001, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=73.05680000000001, LE Moving_Avg_10Y=72.9722
# 2024-11-19 16:24:57,548 - INFO - Predicted value for Bahamas, The in 2019: 71.72009999999997
# 2024-11-19 16:24:57,549 - INFO - Prediction inputs for Bahamas, The in 2020: Year=2020, LE Moving_Avg_2Y=71.72009999999997, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.72009999999997, LE Moving_Avg_10Y=71.72009999999999
# 2024-11-19 16:24:57,551 - INFO - Predicted value for Bahamas, The in 2020: 71.57886634146345
# 2024-11-19 16:24:57,551 - INFO - Prediction inputs for Bahamas, The in 2021: Year=2021, LE Moving_Avg_2Y=71.64948317073171, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.60711307317077, LE Moving_Avg_10Y=71.59298970731712
# 2024-11-19 16:24:57,553 - INFO - Predicted value for Bahamas, The in 2021: 71.6107812195122
# 2024-11-19 16:24:57,553 - INFO - Prediction inputs for Bahamas, The in 2022: Year=2022, LE Moving_Avg_2Y=71.59482378048783, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.62626200000001, LE Moving_Avg_10Y=71.61852160975612
# 2024-11-19 16:24:57,555 - INFO - Predicted value for Bahamas, The in 2022: 71.72281707317076
# 2024-11-19 16:24:57,555 - INFO - Prediction inputs for Bahamas, The in 2023: Year=2023, LE Moving_Avg_2Y=71.66679914634148, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.67107634146343, LE Moving_Avg_10Y=71.6969467073171
# 2024-11-19 16:24:57,557 - INFO - Predicted value for Bahamas, The in 2023: 71.56720097560978
# 2024-11-19 16:24:57,557 - INFO - Prediction inputs for Bahamas, The in 2024: Year=2024, LE Moving_Avg_2Y=71.64500902439028, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.63995312195122, LE Moving_Avg_10Y=71.60357704878052
# 2024-11-19 16:24:57,559 - INFO - Predicted value for Bahamas, The in 2024: 71.59732414634146
# 2024-11-19 16:24:57,559 - INFO - Prediction inputs for Bahamas, The in 2025: Year=2025, LE Moving_Avg_2Y=71.58226256097562, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.61539795121953, LE Moving_Avg_10Y=71.61863863414635
# 2024-11-19 16:24:57,561 - INFO - Predicted value for Bahamas, The in 2025: 71.7156004878049
# 2024-11-19 16:24:57,561 - INFO - Prediction inputs for Bahamas, The in 2026: Year=2026, LE Moving_Avg_2Y=71.65646231707319, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.64274478048782, LE Moving_Avg_10Y=71.66594917073172
# 2024-11-19 16:24:57,563 - INFO - Predicted value for Bahamas, The in 2026: 71.55064439024392
# 2024-11-19 16:24:57,563 - INFO - Prediction inputs for Bahamas, The in 2027: Year=2027, LE Moving_Avg_2Y=71.63312243902442, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.63071741463418, LE Moving_Avg_10Y=71.61646234146342
# 2024-11-19 16:24:57,565 - INFO - Predicted value for Bahamas, The in 2027: 71.61353731707318
# 2024-11-19 16:24:57,566 - INFO - Prediction inputs for Bahamas, The in 2028: Year=2028, LE Moving_Avg_2Y=71.58209085365854, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.60886146341464, LE Moving_Avg_10Y=71.62904092682929
# 2024-11-19 16:24:57,567 - INFO - Predicted value for Bahamas, The in 2028: 71.71773390243905
# 2024-11-19 16:24:57,568 - INFO - Prediction inputs for Bahamas, The in 2029: Year=2029, LE Moving_Avg_2Y=71.66563560975612, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.6389680487805, LE Moving_Avg_10Y=71.63946058536587
# 2024-11-19 16:24:57,570 - INFO - Predicted value for Bahamas, The in 2029: 71.59311804878051
# 2024-11-19 16:24:57,570 - INFO - Prediction inputs for Bahamas, The in 2030: Year=2030, LE Moving_Avg_2Y=71.65542597560977, LE Moving_Avg_3Y=72.88099999999999, LE Moving_Avg_5Y=71.63812682926832, LE Moving_Avg_10Y=71.62676239024393
# 2024-11-19 16:24:57,572 - INFO - Predicted value for Bahamas, The in 2030: 71.58405780487807
# 2024-11-19 16:24:57,572 - INFO - Processing country: Bahrain
# 2024-11-19 16:24:57,572 - INFO - Prediction inputs for Bahrain in 2019: Year=2019, LE Moving_Avg_2Y=79.938, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=79.7054, LE Moving_Avg_10Y=79.38199999999999
# 2024-11-19 16:24:57,574 - INFO - Predicted value for Bahrain in 2019: 80.04863780487818
# 2024-11-19 16:24:57,575 - INFO - Prediction inputs for Bahrain in 2020: Year=2020, LE Moving_Avg_2Y=80.04863780487818, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.04863780487818, LE Moving_Avg_10Y=80.04863780487817
# 2024-11-19 16:24:57,577 - INFO - Predicted value for Bahrain in 2020: 80.09157878048785
# 2024-11-19 16:24:57,577 - INFO - Prediction inputs for Bahrain in 2021: Year=2021, LE Moving_Avg_2Y=80.07010829268302, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.08299058536592, LE Moving_Avg_10Y=80.08728468292688
# 2024-11-19 16:24:57,579 - INFO - Predicted value for Bahrain in 2021: 80.09767975609759
# 2024-11-19 16:24:57,579 - INFO - Prediction inputs for Bahrain in 2022: Year=2022, LE Moving_Avg_2Y=80.09462926829272, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.08665117073176, LE Moving_Avg_10Y=80.09216546341469
# 2024-11-19 16:24:57,581 - INFO - Predicted value for Bahrain in 2022: 80.10894975609759
# 2024-11-19 16:24:57,581 - INFO - Prediction inputs for Bahrain in 2023: Year=2023, LE Moving_Avg_2Y=80.10331475609759, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.09115917073174, LE Moving_Avg_10Y=80.10005446341468
# 2024-11-19 16:24:57,583 - INFO - Predicted value for Bahrain in 2023: 80.10782780487808
# 2024-11-19 16:24:57,583 - INFO - Prediction inputs for Bahrain in 2024: Year=2024, LE Moving_Avg_2Y=80.10838878048784, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.09093478048786, LE Moving_Avg_10Y=80.09938129268296
# 2024-11-19 16:24:57,585 - INFO - Predicted value for Bahrain in 2024: 80.1132909756098
# 2024-11-19 16:24:57,585 - INFO - Prediction inputs for Bahrain in 2025: Year=2025, LE Moving_Avg_2Y=80.11055939024394, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.10386541463419, LE Moving_Avg_10Y=80.10211287804881
# 2024-11-19 16:24:57,587 - INFO - Predicted value for Bahrain in 2025: 80.1132909756098
# 2024-11-19 16:24:57,587 - INFO - Prediction inputs for Bahrain in 2026: Year=2026, LE Moving_Avg_2Y=80.1132909756098, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.10820785365857, LE Moving_Avg_10Y=80.10211287804881
# 2024-11-19 16:24:57,589 - INFO - Predicted value for Bahrain in 2026: 80.1132909756098
# 2024-11-19 16:24:57,590 - INFO - Prediction inputs for Bahrain in 2027: Year=2027, LE Moving_Avg_2Y=80.1132909756098, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.11133009756102, LE Moving_Avg_10Y=80.10211287804881
# 2024-11-19 16:24:57,591 - INFO - Predicted value for Bahrain in 2027: 80.1132909756098
# 2024-11-19 16:24:57,592 - INFO - Prediction inputs for Bahrain in 2028: Year=2028, LE Moving_Avg_2Y=80.1132909756098, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.11219834146345, LE Moving_Avg_10Y=80.10211287804881
# 2024-11-19 16:24:57,594 - INFO - Predicted value for Bahrain in 2028: 80.1132909756098
# 2024-11-19 16:24:57,594 - INFO - Prediction inputs for Bahrain in 2029: Year=2029, LE Moving_Avg_2Y=80.1132909756098, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.1132909756098, LE Moving_Avg_10Y=80.10211287804881
# 2024-11-19 16:24:57,596 - INFO - Predicted value for Bahrain in 2029: 80.1132909756098
# 2024-11-19 16:24:57,596 - INFO - Prediction inputs for Bahrain in 2030: Year=2030, LE Moving_Avg_2Y=80.1132909756098, LE Moving_Avg_3Y=79.855, LE Moving_Avg_5Y=80.1132909756098, LE Moving_Avg_10Y=80.10857819512198
# 2024-11-19 16:24:57,598 - INFO - Predicted value for Bahrain in 2030: 80.1132909756098
# 2024-11-19 16:24:57,598 - INFO - Processing country: Bangladesh
# 2024-11-19 16:24:57,598 - INFO - Prediction inputs for Bangladesh in 2019: Year=2019, LE Moving_Avg_2Y=72.6865, LE Moving_Avg_3Y=72.387, LE Moving_Avg_5Y=71.7484, LE Moving_Avg_10Y=70.5294
# 2024-11-19 16:24:57,600 - INFO - Predicted value for Bangladesh in 2019: 72.84598634146329
# 2024-11-19 16:24:57,601 - INFO - Prediction inputs for Bangladesh in 2020: Year=2020, LE Moving_Avg_2Y=72.84598634146329, LE Moving_Avg_3Y=72.387, LE Moving_Avg_5Y=72.84598634146329, LE Moving_Avg_10Y=72.84598634146327
# 2024-11-19 16:24:57,603 - INFO - Predicted value for Bangladesh in 2020: 72.88263951219514
# 2024-11-19 16:24:57,603 - INFO - Prediction inputs for Bangladesh in 2021: Year=2021, LE Moving_Avg_2Y=72.86431292682921, LE Moving_Avg_3Y=72.387, LE Moving_Avg_5Y=72.87530887804878, LE Moving_Avg_10Y=72.87897419512197
# 2024-11-19 16:24:57,605 - INFO - Predicted value for Bangladesh in 2021: 72.89824317073173
# 2024-11-19 16:24:57,605 - INFO - Prediction inputs for Bangladesh in 2022: Year=2022, LE Moving_Avg_2Y=72.89044134146343, LE Moving_Avg_3Y=72.387, LE Moving_Avg_5Y=72.88467107317072, LE Moving_Avg_10Y=72.89145712195122
# 2024-11-19 16:24:57,607 - INFO - Predicted value for Bangladesh in 2022: 72.90709634146342
# 2024-11-19 16:24:57,607 - INFO - Prediction inputs for Bangladesh in 2023: Year=2023, LE Moving_Avg_2Y=72.90266975609757, LE Moving_Avg_3Y=72.387, LE Moving_Avg_5Y=72.8882123414634, LE Moving_Avg_10Y=72.89765434146341
# 2024-11-19 16:24:57,609 - INFO - Predicted value for Bangladesh in 2023: 72.90443292682927
# ...
# 2024-11-19 16:25:03,020 - INFO - Predicted value for Venezuela, RB in 2028: 72.21680780487809
# 2024-11-19 16:25:03,020 - INFO - Prediction inputs for Venezuela, RB in 2029: Year=2029, LE Moving_Avg_2Y=72.19294756097563, LE Moving_Avg_3Y=72.02766666666668, LE Moving_Avg_5Y=72.1915648780488, LE Moving_Avg_10Y=72.19513219512194
# 2024-11-19 16:25:03,022 - INFO - Predicted value for Venezuela, RB in 2029: 72.21734780487809
# 2024-11-19 16:25:03,023 - INFO - Prediction inputs for Venezuela, RB in 2030: Year=2030, LE Moving_Avg_2Y=72.21707780487809, LE Moving_Avg_3Y=72.02766666666668, LE Moving_Avg_5Y=72.21240843902441, LE Moving_Avg_10Y=72.2011733902439
# 2024-11-19 16:25:03,024 - INFO - Predicted value for Venezuela, RB in 2030: 72.18468024390243
# 2024-11-19 16:25:03,025 - INFO - Processing country: Vietnam
# 2024-11-19 16:25:03,025 - INFO - Prediction inputs for Vietnam in 2019: Year=2019, LE Moving_Avg_2Y=74.03450000000001, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=73.9692, LE Moving_Avg_10Y=73.8385
# 2024-11-19 16:25:03,027 - INFO - Predicted value for Vietnam in 2019: 74.1255965853658
# 2024-11-19 16:25:03,027 - INFO - Prediction inputs for Vietnam in 2020: Year=2020, LE Moving_Avg_2Y=74.1255965853658, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.1255965853658, LE Moving_Avg_10Y=74.12559658536578
# 2024-11-19 16:25:03,029 - INFO - Predicted value for Vietnam in 2020: 74.22749365853657
# 2024-11-19 16:25:03,030 - INFO - Prediction inputs for Vietnam in 2021: Year=2021, LE Moving_Avg_2Y=74.1765451219512, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.20711424390242, LE Moving_Avg_10Y=74.21730395121949
# 2024-11-19 16:25:03,032 - INFO - Predicted value for Vietnam in 2021: 74.23533512195124
# 2024-11-19 16:25:03,032 - INFO - Prediction inputs for Vietnam in 2022: Year=2022, LE Moving_Avg_2Y=74.23141439024391, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.21181912195122, LE Moving_Avg_10Y=74.22357712195124
# 2024-11-19 16:25:03,034 - INFO - Predicted value for Vietnam in 2022: 74.28144951219508
# 2024-11-19 16:25:03,034 - INFO - Prediction inputs for Vietnam in 2023: Year=2023, LE Moving_Avg_2Y=74.25839231707316, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.23026487804876, LE Moving_Avg_10Y=74.25585719512192
# 2024-11-19 16:25:03,036 - INFO - Predicted value for Vietnam in 2023: 74.31737658536582
# 2024-11-19 16:25:03,036 - INFO - Prediction inputs for Vietnam in 2024: Year=2024, LE Moving_Avg_2Y=74.29941304878045, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.2374502926829, LE Moving_Avg_10Y=74.27741343902437
# 2024-11-19 16:25:03,038 - INFO - Predicted value for Vietnam in 2024: 74.41637878048786
# 2024-11-19 16:25:03,038 - INFO - Prediction inputs for Vietnam in 2025: Year=2025, LE Moving_Avg_2Y=74.36687768292684, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.29560673170731, LE Moving_Avg_10Y=74.32691453658539
# 2024-11-19 16:25:03,040 - INFO - Predicted value for Vietnam in 2025: 74.4858634146342
# 2024-11-19 16:25:03,040 - INFO - Prediction inputs for Vietnam in 2026: Year=2026, LE Moving_Avg_2Y=74.45112109756103, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.34728068292684, LE Moving_Avg_10Y=74.35470839024391
# 2024-11-19 16:25:03,042 - INFO - Predicted value for Vietnam in 2026: 74.55590878048783
# 2024-11-19 16:25:03,042 - INFO - Prediction inputs for Vietnam in 2027: Year=2027, LE Moving_Avg_2Y=74.520886097561, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.41139541463414, LE Moving_Avg_10Y=74.375722
# 2024-11-19 16:25:03,044 - INFO - Predicted value for Vietnam in 2027: 74.5823997560976
# 2024-11-19 16:25:03,044 - INFO - Prediction inputs for Vietnam in 2028: Year=2028, LE Moving_Avg_2Y=74.56915426829272, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.47158546341466, LE Moving_Avg_10Y=74.38102019512196
# 2024-11-19 16:25:03,046 - INFO - Predicted value for Vietnam in 2028: 74.67393390243905
# 2024-11-19 16:25:03,047 - INFO - Prediction inputs for Vietnam in 2029: Year=2029, LE Moving_Avg_2Y=74.62816682926832, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.54289692682931, LE Moving_Avg_10Y=74.3901736097561
# 2024-11-19 16:25:03,048 - INFO - Predicted value for Vietnam in 2029: 74.70715707317073
# 2024-11-19 16:25:03,049 - INFO - Prediction inputs for Vietnam in 2030: Year=2030, LE Moving_Avg_2Y=74.69054548780488, LE Moving_Avg_3Y=74.01066666666667, LE Moving_Avg_5Y=74.60105258536586, LE Moving_Avg_10Y=74.4483296585366
# 2024-11-19 16:25:03,050 - INFO - Predicted value for Vietnam in 2030: 74.77489658536584
# 2024-11-19 16:25:03,051 - INFO - Processing country: Yemen, Rep.
# 2024-11-19 16:25:03,051 - INFO - Prediction inputs for Yemen, Rep. in 2019: Year=2019, LE Moving_Avg_2Y=64.8335, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.5122, LE Moving_Avg_10Y=66.45320000000001
# 2024-11-19 16:25:03,053 - INFO - Predicted value for Yemen, Rep. in 2019: 65.00554999999994
# 2024-11-19 16:25:03,054 - INFO - Prediction inputs for Yemen, Rep. in 2020: Year=2020, LE Moving_Avg_2Y=65.00554999999994, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00554999999994, LE Moving_Avg_10Y=65.00554999999996
# 2024-11-19 16:25:03,056 - INFO - Predicted value for Yemen, Rep. in 2020: 65.00781609756098
# 2024-11-19 16:25:03,056 - INFO - Prediction inputs for Yemen, Rep. in 2021: Year=2021, LE Moving_Avg_2Y=65.00668304878046, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00736287804878, LE Moving_Avg_10Y=65.00758948780488
# 2024-11-19 16:25:03,058 - INFO - Predicted value for Yemen, Rep. in 2021: 65.00777609756098
# 2024-11-19 16:25:03,058 - INFO - Prediction inputs for Yemen, Rep. in 2022: Year=2022, LE Moving_Avg_2Y=65.00779609756097, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00733887804877, LE Moving_Avg_10Y=65.00755748780486
# 2024-11-19 16:25:03,060 - INFO - Predicted value for Yemen, Rep. in 2022: 65.00777609756098
# 2024-11-19 16:25:03,060 - INFO - Prediction inputs for Yemen, Rep. in 2023: Year=2023, LE Moving_Avg_2Y=65.00777609756098, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00733887804877, LE Moving_Avg_10Y=65.00755748780486
# 2024-11-19 16:25:03,062 - INFO - Predicted value for Yemen, Rep. in 2023: 65.00777609756098
# 2024-11-19 16:25:03,062 - INFO - Prediction inputs for Yemen, Rep. in 2024: Year=2024, LE Moving_Avg_2Y=65.00777609756098, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00733887804877, LE Moving_Avg_10Y=65.00755748780486
# 2024-11-19 16:25:03,064 - INFO - Predicted value for Yemen, Rep. in 2024: 65.00777609756098
# 2024-11-19 16:25:03,064 - INFO - Prediction inputs for Yemen, Rep. in 2025: Year=2025, LE Moving_Avg_2Y=65.00777609756098, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00778409756097, LE Moving_Avg_10Y=65.00755748780486
# 2024-11-19 16:25:03,066 - INFO - Predicted value for Yemen, Rep. in 2025: 65.00777609756098
# 2024-11-19 16:25:03,066 - INFO - Prediction inputs for Yemen, Rep. in 2026: Year=2026, LE Moving_Avg_2Y=65.00777609756098, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00777609756098, LE Moving_Avg_10Y=65.00755748780486
# 2024-11-19 16:25:03,068 - INFO - Predicted value for Yemen, Rep. in 2026: 65.00777609756098
# 2024-11-19 16:25:03,068 - INFO - Prediction inputs for Yemen, Rep. in 2027: Year=2027, LE Moving_Avg_2Y=65.00777609756098, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00777609756098, LE Moving_Avg_10Y=65.00755748780486
# 2024-11-19 16:25:03,070 - INFO - Predicted value for Yemen, Rep. in 2027: 65.00777609756098
# 2024-11-19 16:25:03,070 - INFO - Prediction inputs for Yemen, Rep. in 2028: Year=2028, LE Moving_Avg_2Y=65.00777609756098, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00777609756098, LE Moving_Avg_10Y=65.00755748780486
# 2024-11-19 16:25:03,072 - INFO - Predicted value for Yemen, Rep. in 2028: 65.00777609756098
# 2024-11-19 16:25:03,072 - INFO - Prediction inputs for Yemen, Rep. in 2029: Year=2029, LE Moving_Avg_2Y=65.00777609756098, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00777609756098, LE Moving_Avg_10Y=65.00755748780486
# 2024-11-19 16:25:03,074 - INFO - Predicted value for Yemen, Rep. in 2029: 65.00777609756098
# 2024-11-19 16:25:03,074 - INFO - Prediction inputs for Yemen, Rep. in 2030: Year=2030, LE Moving_Avg_2Y=65.00777609756098, LE Moving_Avg_3Y=65.208, LE Moving_Avg_5Y=65.00777609756098, LE Moving_Avg_10Y=65.00778009756097
# 2024-11-19 16:25:03,076 - INFO - Predicted value for Yemen, Rep. in 2030: 65.00777609756098
# 2024-11-19 16:25:03,076 - INFO - Processing country: Zambia
# 2024-11-19 16:25:03,077 - INFO - Prediction inputs for Zambia in 2019: Year=2019, LE Moving_Avg_2Y=62.567499999999995, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.0514, LE Moving_Avg_10Y=60.427099999999996
# 2024-11-19 16:25:03,079 - INFO - Predicted value for Zambia in 2019: 62.78457999999992
# 2024-11-19 16:25:03,079 - INFO - Prediction inputs for Zambia in 2020: Year=2020, LE Moving_Avg_2Y=62.78457999999992, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.78457999999991, LE Moving_Avg_10Y=62.784579999999906
# 2024-11-19 16:25:03,081 - INFO - Predicted value for Zambia in 2020: 62.774779999999986
# 2024-11-19 16:25:03,081 - INFO - Prediction inputs for Zambia in 2021: Year=2021, LE Moving_Avg_2Y=62.779679999999956, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.776739999999975, LE Moving_Avg_10Y=62.77575999999997
# 2024-11-19 16:25:03,083 - INFO - Predicted value for Zambia in 2021: 62.76466999999999
# 2024-11-19 16:25:03,084 - INFO - Prediction inputs for Zambia in 2022: Year=2022, LE Moving_Avg_2Y=62.76972499999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.77067399999997, LE Moving_Avg_10Y=62.76767199999998
# 2024-11-19 16:25:03,085 - INFO - Predicted value for Zambia in 2022: 62.76063999999999
# 2024-11-19 16:25:03,086 - INFO - Prediction inputs for Zambia in 2023: Year=2023, LE Moving_Avg_2Y=62.76265499999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.76906199999998, LE Moving_Avg_10Y=62.76485099999998
# 2024-11-19 16:25:03,088 - INFO - Predicted value for Zambia in 2023: 62.76736999999999
# 2024-11-19 16:25:03,088 - INFO - Prediction inputs for Zambia in 2024: Year=2024, LE Moving_Avg_2Y=62.76400499999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.770407999999975, LE Moving_Avg_10Y=62.76888899999999
# 2024-11-19 16:25:03,090 - INFO - Predicted value for Zambia in 2024: 62.76736999999999
# 2024-11-19 16:25:03,090 - INFO - Prediction inputs for Zambia in 2025: Year=2025, LE Moving_Avg_2Y=62.76736999999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.76696599999999, LE Moving_Avg_10Y=62.76888899999998
# 2024-11-19 16:25:03,092 - INFO - Predicted value for Zambia in 2025: 62.76063999999999
# 2024-11-19 16:25:03,092 - INFO - Prediction inputs for Zambia in 2026: Year=2026, LE Moving_Avg_2Y=62.76400499999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.76413799999999, LE Moving_Avg_10Y=62.76619699999998
# 2024-11-19 16:25:03,094 - INFO - Predicted value for Zambia in 2026: 62.76736999999999
# 2024-11-19 16:25:03,094 - INFO - Prediction inputs for Zambia in 2027: Year=2027, LE Moving_Avg_2Y=62.76400499999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.76467799999999, LE Moving_Avg_10Y=62.76821599999998
# 2024-11-19 16:25:03,096 - INFO - Predicted value for Zambia in 2027: 62.76736999999999
# 2024-11-19 16:25:03,096 - INFO - Prediction inputs for Zambia in 2028: Year=2028, LE Moving_Avg_2Y=62.76736999999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.766023999999994, LE Moving_Avg_10Y=62.76821599999998
# 2024-11-19 16:25:03,098 - INFO - Predicted value for Zambia in 2028: 62.76063999999999
# 2024-11-19 16:25:03,098 - INFO - Prediction inputs for Zambia in 2029: Year=2029, LE Moving_Avg_2Y=62.76400499999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.76467799999999, LE Moving_Avg_10Y=62.767542999999975
# 2024-11-19 16:25:03,100 - INFO - Predicted value for Zambia in 2029: 62.76736999999999
# 2024-11-19 16:25:03,100 - INFO - Prediction inputs for Zambia in 2030: Year=2030, LE Moving_Avg_2Y=62.76400499999999, LE Moving_Avg_3Y=62.41833333333333, LE Moving_Avg_5Y=62.76467799999999, LE Moving_Avg_10Y=62.76582199999999
# 2024-11-19 16:25:03,102 - INFO - Predicted value for Zambia in 2030: 62.76736999999999
# 2024-11-19 16:25:03,102 - INFO - Processing country: Zimbabwe
# 2024-11-19 16:25:03,103 - INFO - Prediction inputs for Zimbabwe in 2019: Year=2019, LE Moving_Avg_2Y=61.353, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=60.662400000000005, LE Moving_Avg_10Y=57.924099999999996
# 2024-11-19 16:25:03,105 - INFO - Predicted value for Zimbabwe in 2019: 61.43001000000007
# 2024-11-19 16:25:03,105 - INFO - Prediction inputs for Zimbabwe in 2020: Year=2020, LE Moving_Avg_2Y=61.43001000000007, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=61.43001000000006, LE Moving_Avg_10Y=61.43001000000005
# 2024-11-19 16:25:03,108 - INFO - Predicted value for Zimbabwe in 2020: 61.638589999999986
# 2024-11-19 16:25:03,108 - INFO - Prediction inputs for Zimbabwe in 2021: Year=2021, LE Moving_Avg_2Y=61.53430000000003, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=61.596874, LE Moving_Avg_10Y=61.61773199999999
# 2024-11-19 16:25:03,110 - INFO - Predicted value for Zimbabwe in 2021: 61.74409999999995
# 2024-11-19 16:25:03,110 - INFO - Prediction inputs for Zimbabwe in 2022: Year=2022, LE Moving_Avg_2Y=61.69134499999997, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=61.66017999999999, LE Moving_Avg_10Y=61.70213999999997
# 2024-11-19 16:25:03,112 - INFO - Predicted value for Zimbabwe in 2022: 61.79906999999997
# 2024-11-19 16:25:03,112 - INFO - Prediction inputs for Zimbabwe in 2023: Year=2023, LE Moving_Avg_2Y=61.77158499999996, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=61.68216799999999, LE Moving_Avg_10Y=61.74061899999997
# 2024-11-19 16:25:03,114 - INFO - Predicted value for Zimbabwe in 2023: 61.84421000000001
# 2024-11-19 16:25:03,114 - INFO - Prediction inputs for Zimbabwe in 2024: Year=2024, LE Moving_Avg_2Y=61.82163999999999, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=61.691196000000005, LE Moving_Avg_10Y=61.767703000000004
# 2024-11-19 16:25:03,134 - INFO - Predicted value for Zimbabwe in 2024: 62.04348
# 2024-11-19 16:25:03,134 - INFO - Prediction inputs for Zimbabwe in 2025: Year=2025, LE Moving_Avg_2Y=61.94384500000001, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=61.81388999999998, LE Moving_Avg_10Y=61.867338000000004
# 2024-11-19 16:25:03,138 - INFO - Predicted value for Zimbabwe in 2025: 62.115799999999965
# 2024-11-19 16:25:03,139 - INFO - Prediction inputs for Zimbabwe in 2026: Year=2026, LE Moving_Avg_2Y=62.07963999999998, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=61.909331999999985, LE Moving_Avg_10Y=61.89626599999998
# 2024-11-19 16:25:03,140 - INFO - Predicted value for Zimbabwe in 2026: 62.213349999999934
# 2024-11-19 16:25:03,141 - INFO - Prediction inputs for Zimbabwe in 2027: Year=2027, LE Moving_Avg_2Y=62.16457499999995, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=62.00318199999998, LE Moving_Avg_10Y=61.92553099999998
# 2024-11-19 16:25:03,143 - INFO - Predicted value for Zimbabwe in 2027: 62.387270000000015
# 2024-11-19 16:25:03,143 - INFO - Prediction inputs for Zimbabwe in 2028: Year=2028, LE Moving_Avg_2Y=62.300309999999975, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=62.12082199999999, LE Moving_Avg_10Y=61.960315
# 2024-11-19 16:25:03,145 - INFO - Predicted value for Zimbabwe in 2028: 62.49138000000004
# 2024-11-19 16:25:03,145 - INFO - Prediction inputs for Zimbabwe in 2029: Year=2029, LE Moving_Avg_2Y=62.439325000000025, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=62.25025599999999, LE Moving_Avg_10Y=61.970726
# 2024-11-19 16:25:03,147 - INFO - Predicted value for Zimbabwe in 2029: 62.64674999999997
# 2024-11-19 16:25:03,147 - INFO - Prediction inputs for Zimbabwe in 2030: Year=2030, LE Moving_Avg_2Y=62.56906500000001, LE Moving_Avg_3Y=61.13833333333334, LE Moving_Avg_5Y=62.37090999999998, LE Moving_Avg_10Y=62.092399999999984
# 2024-11-19 16:25:03,149 - INFO - Predicted value for Zimbabwe in 2030: 62.77248999999999

# %%
# Displaying feature importances from the Random Forest model directly

# Calculating feature importances
feature_importances = model_rf.feature_importances_
feature_names = ['Year', 'LE Moving_Avg_2Y', 'LE Moving_Avg_3Y', 'LE Moving_Avg_5Y', 'LE Moving_Avg_10Y']

# Creating a DataFrame to organize and sort feature importances
import pandas as pd
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Display the sorted feature importances
importance_df.reset_index(drop=True, inplace=True)
importance_df
# Out:
#              Feature  Importance
# 0   LE Moving_Avg_2Y    0.983208
# 1   LE Moving_Avg_3Y    0.016070
# 2   LE Moving_Avg_5Y    0.000441
# 3  LE Moving_Avg_10Y    0.000219
# 4               Year    0.000062

# %%
# Converting the dictionary of predictions for each country (country_recursive_predictions_rf) into a DataFrame

# Initialize an empty list to store rows for the DataFrame
rows = []

# Loop through each country and its predictions to build the DataFrame rows
for country, predictions in country_recursive_predictions_rf.items():
    for year, life_expectancy in predictions.items():
        # Append each prediction as a new row with the country, year, and predicted value
        rows.append({'Country Name': country, 'Year': year, 'Life expectancy at birth, total (years)': life_expectancy})

# Convert the list of predictions into a DataFrame
predictions_df_1= pd.DataFrame(rows)

# %% [markdown]
# ## Indicator 2 - Train and Test Machine Learning Model

# %%
# Selecting specified columns
selected_df_2 = merged_df[['Country Name', 'Country Code', 'Year', 'Agricultural land (% of land area)']].copy()

# Sorting by 'Country Name' and 'Year' to prepare for rolling calculations
selected_df_2 = selected_df_2.sort_values(by=['Country Name', 'Year'])

# Creating Moving Average and STD columns for the specified time frames (2, 3, 5, and 10 years)
time_frames = [2, 3, 5, 10]
for window in time_frames:
    selected_df_2[f'AL Moving_Avg_{window}Y'] = selected_df_2.groupby('Country Name')['Agricultural land (% of land area)'].transform(lambda x: x.rolling(window, min_periods=1).mean())
    
# Displaying the first few rows of the updated DataFrame
selected_df_2.loc[selected_df_2['Country Name'] == 'Canada']
selected_df_2['Year'] = selected_df_2['Year'].astype(int)

# Define year variables for training and prediction
TRAIN_START_YEAR = 1990
TRAIN_END_YEAR = 2009
PREDICTION_START_YEAR = 2010
PREDICTION_END_YEAR = 2019

# Setting up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Splitting data into training (2000-2019) set and setting up prediction years
train_df_2 = selected_df_2[(selected_df_2['Year'] >= TRAIN_START_YEAR) & (selected_df_2['Year'] <= TRAIN_END_YEAR)].dropna(subset=['Agricultural land (% of land area)'])
prediction_years = range(PREDICTION_START_YEAR, PREDICTION_END_YEAR + 1)

# Preparing training data for the model
X_train = train_df_2[['Year', 'AL Moving_Avg_2Y', 'AL Moving_Avg_3Y', 'AL Moving_Avg_5Y', 'AL Moving_Avg_10Y']].values
y_train = train_df_2['Agricultural land (% of land area)'].values

# Initializing and training the Random Forest model on all training data
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)
logger.info(f"Model trained on all countries' data ({TRAIN_START_YEAR}-{TRAIN_END_YEAR}). Starting recursive forecasting.")

# Dictionary to store predictions for each country
country_recursive_predictions_rf = {}

# Recursive forecasting for each country separately with detailed logging
for country in train_df_2['Country Name'].unique():
    logger.info(f"Processing country: {country}")

    # Get the last available data point for the country to start recursive prediction
    country_data = train_df_2[train_df_2['Country Name'] == country].iloc[-1].copy()
    predictions_per_country = {country_data['Year']: country_data['Agricultural land (% of land area)']}

    # Recursive prediction loop from PREDICTION_START_YEAR to PREDICTION_END_YEAR
    for year in prediction_years:
        country_data['Year'] = year
        
        # Logging the input data used for this prediction
        logger.info(f"Prediction inputs for {country} in {year}: Year={year}, "
                    f"AL Moving_Avg_2Y={country_data['AL Moving_Avg_2Y']}, "
                    f"AL Moving_Avg_3Y={country_data['AL Moving_Avg_3Y']}, "
                    f"AL Moving_Avg_5Y={country_data['AL Moving_Avg_5Y']}, "
                    f"AL Moving_Avg_10Y={country_data['AL Moving_Avg_10Y']}")
        
        # Preparing the features for the current prediction
        X_test = country_data[['Year', 'AL Moving_Avg_2Y', 'AL Moving_Avg_3Y', 'AL Moving_Avg_5Y', 'AL Moving_Avg_10Y']].values.reshape(1, -1)
        
        # Predicting agricultural land use for the current year
        predicted_value = model_rf.predict(X_test)[0]
        logger.info(f"Predicted value for {country} in {year}: {predicted_value}")
        
        # Update the prediction in the dictionary
        predictions_per_country[year] = predicted_value
        
        # Update the features for the next prediction year based on the new prediction
        country_data['Agricultural land (% of land area)'] = predicted_value
        country_data['AL Moving_Avg_2Y'] = (predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 2
        country_data['AL Moving_Avg_3Y'] = (predictions_per_country.get(year - 2, predicted_value) +
                                         predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 3
        country_data['AL Moving_Avg_5Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 4, year + 1)) / 5)
        country_data['AL Moving_Avg_10Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 9, year + 1)) / 10)

    # Store the predictions for the country
    country_recursive_predictions_rf[country] = predictions_per_country
# Out:
# 2024-11-19 16:25:04,030 - INFO - Model trained on all countries' data (1990-2009). Starting recursive forecasting.
# 2024-11-19 16:25:04,030 - INFO - Processing country: Afghanistan
# 2024-11-19 16:25:04,031 - INFO - Prediction inputs for Afghanistan in 2010: Year=2010, AL Moving_Avg_2Y=58.132867240084, AL Moving_Avg_3Y=58.131845105765336, AL Moving_Avg_5Y=58.130720758014796, AL Moving_Avg_10Y=58.07215246155497
# 2024-11-19 16:25:04,034 - INFO - Predicted value for Afghanistan in 2010: 58.132778863462484
# 2024-11-19 16:25:04,034 - INFO - Prediction inputs for Afghanistan in 2011: Year=2011, AL Moving_Avg_2Y=58.132823051773244, AL Moving_Avg_3Y=58.132808322336324, AL Moving_Avg_5Y=58.13279653878679, AL Moving_Avg_10Y=58.13278770112463
# 2024-11-19 16:25:04,036 - INFO - Predicted value for Afghanistan in 2011: 58.128393907235385
# 2024-11-19 16:25:04,036 - INFO - Prediction inputs for Afghanistan in 2012: Year=2012, AL Moving_Avg_2Y=58.130586385348934, AL Moving_Avg_3Y=58.131346670260626, AL Moving_Avg_5Y=58.130165565050525, AL Moving_Avg_10Y=58.12927973614295
# 2024-11-19 16:25:04,038 - INFO - Predicted value for Afghanistan in 2012: 58.13015708893509
# 2024-11-19 16:25:04,039 - INFO - Prediction inputs for Afghanistan in 2013: Year=2013, AL Moving_Avg_2Y=58.129275498085235, AL Moving_Avg_3Y=58.13044328654431, AL Moving_Avg_5Y=58.13087083773041, AL Moving_Avg_10Y=58.13051396333276
# 2024-11-19 16:25:04,057 - INFO - Predicted value for Afghanistan in 2013: 58.12948248028474
# 2024-11-19 16:25:04,057 - INFO - Prediction inputs for Afghanistan in 2014: Year=2014, AL Moving_Avg_2Y=58.12981978460992, AL Moving_Avg_3Y=58.12934449215174, AL Moving_Avg_5Y=58.13073591600035, AL Moving_Avg_10Y=58.13010919814254
# 2024-11-19 16:25:04,060 - INFO - Predicted value for Afghanistan in 2014: 58.129727792521244
# 2024-11-19 16:25:04,060 - INFO - Prediction inputs for Afghanistan in 2015: Year=2015, AL Moving_Avg_2Y=58.12960513640299, AL Moving_Avg_3Y=58.12978912058036, AL Moving_Avg_5Y=58.13010802648779, AL Moving_Avg_10Y=58.1302318542608
# 2024-11-19 16:25:04,064 - INFO - Predicted value for Afghanistan in 2015: 58.12948248028474
# 2024-11-19 16:25:04,065 - INFO - Prediction inputs for Afghanistan in 2016: Year=2016, AL Moving_Avg_2Y=58.12960513640299, AL Moving_Avg_3Y=58.129564251030246, AL Moving_Avg_5Y=58.12944874985224, AL Moving_Avg_10Y=58.13013372936619
# 2024-11-19 16:25:04,067 - INFO - Predicted value for Afghanistan in 2016: 58.129421152225625
# 2024-11-19 16:25:04,067 - INFO - Prediction inputs for Afghanistan in 2017: Year=2017, AL Moving_Avg_2Y=58.129451816255184, AL Moving_Avg_3Y=58.12954380834387, AL Moving_Avg_5Y=58.12965419885029, AL Moving_Avg_10Y=58.130115330948456
# 2024-11-19 16:25:04,069 - INFO - Predicted value for Afghanistan in 2017: 58.12948248028474
# 2024-11-19 16:25:04,069 - INFO - Prediction inputs for Afghanistan in 2018: Year=2018, AL Moving_Avg_2Y=58.129451816255184, AL Moving_Avg_3Y=58.129462037598365, AL Moving_Avg_5Y=58.129519277120224, AL Moving_Avg_10Y=58.130127596560285
# 2024-11-19 16:25:04,071 - INFO - Predicted value for Afghanistan in 2018: 58.12948248028474
# 2024-11-19 16:25:04,071 - INFO - Prediction inputs for Afghanistan in 2019: Year=2019, AL Moving_Avg_2Y=58.12948248028474, AL Moving_Avg_3Y=58.129462037598365, AL Moving_Avg_5Y=58.129519277120224, AL Moving_Avg_10Y=58.130127596560285
# 2024-11-19 16:25:04,073 - INFO - Predicted value for Afghanistan in 2019: 58.12948248028474
# 2024-11-19 16:25:04,073 - INFO - Processing country: Albania
# 2024-11-19 16:25:04,074 - INFO - Prediction inputs for Albania in 2010: Year=2010, AL Moving_Avg_2Y=43.472627737226304, AL Moving_Avg_3Y=42.594890510948936, AL Moving_Avg_5Y=41.59343065693432, AL Moving_Avg_10Y=41.475547445255486
# 2024-11-19 16:25:04,076 - INFO - Predicted value for Albania in 2010: 43.93677996389264
# 2024-11-19 16:25:04,077 - INFO - Prediction inputs for Albania in 2011: Year=2011, AL Moving_Avg_2Y=43.88992282866167, AL Moving_Avg_3Y=43.905541873738656, AL Moving_Avg_5Y=43.91803710980025, AL Moving_Avg_10Y=43.92740853684646
# 2024-11-19 16:25:04,079 - INFO - Predicted value for Albania in 2011: 43.87906446780715
# 2024-11-19 16:25:04,079 - INFO - Prediction inputs for Albania in 2012: Year=2012, AL Moving_Avg_2Y=43.907922215849894, AL Moving_Avg_3Y=43.8863033750435, AL Moving_Avg_5Y=43.88340781214895, AL Moving_Avg_10Y=43.88123613997806
# 2024-11-19 16:25:04,081 - INFO - Predicted value for Albania in 2012: 43.99742087639067
# 2024-11-19 16:25:04,081 - INFO - Prediction inputs for Albania in 2013: Year=2013, AL Moving_Avg_2Y=43.93824267209891, AL Moving_Avg_3Y=43.93775510269682, AL Moving_Avg_5Y=43.93075037558236, AL Moving_Avg_10Y=43.96408562598652
# 2024-11-19 16:25:04,083 - INFO - Predicted value for Albania in 2013: 44.00977213854526
# 2024-11-19 16:25:04,083 - INFO - Prediction inputs for Albania in 2014: Year=2014, AL Moving_Avg_2Y=44.00359650746796, AL Moving_Avg_3Y=43.96208582758103, AL Moving_Avg_5Y=43.93322062801328, AL Moving_Avg_10Y=43.97149638327927
# 2024-11-19 16:25:04,085 - INFO - Predicted value for Albania in 2014: 44.009082782580066
# 2024-11-19 16:25:04,085 - INFO - Prediction inputs for Albania in 2015: Year=2015, AL Moving_Avg_2Y=44.00942746056266, AL Moving_Avg_3Y=44.00542526583866, AL Moving_Avg_5Y=43.966424045843155, AL Moving_Avg_10Y=43.97115170529668
# 2024-11-19 16:25:04,087 - INFO - Predicted value for Albania in 2015: 44.0115667217371
# 2024-11-19 16:25:04,087 - INFO - Prediction inputs for Albania in 2016: Year=2016, AL Moving_Avg_2Y=44.01032475215858, AL Moving_Avg_3Y=44.01014054762081, AL Moving_Avg_5Y=43.98138139741205, AL Moving_Avg_10Y=43.97214528095948
# 2024-11-19 16:25:04,089 - INFO - Predicted value for Albania in 2016: 44.006114882492945
# 2024-11-19 16:25:04,089 - INFO - Prediction inputs for Albania in 2017: Year=2017, AL Moving_Avg_2Y=44.00884080211502, AL Moving_Avg_3Y=44.00892146227003, AL Moving_Avg_5Y=44.00679148034921, AL Moving_Avg_10Y=43.97050972918625
# 2024-11-19 16:25:04,091 - INFO - Predicted value for Albania in 2017: 44.006864364061855
# 2024-11-19 16:25:04,091 - INFO - Prediction inputs for Albania in 2018: Year=2018, AL Moving_Avg_2Y=44.0064896232774, AL Moving_Avg_3Y=44.008181989430625, AL Moving_Avg_5Y=44.00868017788345, AL Moving_Avg_10Y=43.970659625500026
# 2024-11-19 16:25:04,093 - INFO - Predicted value for Albania in 2018: 44.006864364061855
# 2024-11-19 16:25:04,094 - INFO - Prediction inputs for Albania in 2019: Year=2019, AL Moving_Avg_2Y=44.006864364061855, AL Moving_Avg_3Y=44.00661453687221, AL Moving_Avg_5Y=44.008098622986765, AL Moving_Avg_10Y=43.97065962550003
# 2024-11-19 16:25:04,095 - INFO - Predicted value for Albania in 2019: 44.006864364061855
# 2024-11-19 16:25:04,096 - INFO - Processing country: Algeria
# 2024-11-19 16:25:04,096 - INFO - Prediction inputs for Algeria in 2010: Year=2010, AL Moving_Avg_2Y=17.358947660114048, AL Moving_Avg_3Y=17.346001942557397, AL Moving_Avg_5Y=17.32624047964934, AL Moving_Avg_10Y=17.10382745387826
# 2024-11-19 16:25:04,099 - INFO - Predicted value for Algeria in 2010: 17.35906612762473
# 2024-11-19 16:25:04,099 - INFO - Prediction inputs for Algeria in 2011: Year=2011, AL Moving_Avg_2Y=17.366459428570913, AL Moving_Avg_3Y=17.363994994922184, AL Moving_Avg_5Y=17.362023448003203, AL Moving_Avg_10Y=17.360544787813968
# 2024-11-19 16:25:04,101 - INFO - Predicted value for Algeria in 2011: 17.353862788384053
# 2024-11-19 16:25:04,101 - INFO - Prediction inputs for Algeria in 2012: Year=2012, AL Moving_Avg_2Y=17.35646445800439, AL Moving_Avg_3Y=17.362260548508626, AL Moving_Avg_5Y=17.358901444458798, AL Moving_Avg_10Y=17.356382116421422
# 2024-11-19 16:25:04,103 - INFO - Predicted value for Algeria in 2012: 17.352867049188973
# 2024-11-19 16:25:04,103 - INFO - Prediction inputs for Algeria in 2013: Year=2013, AL Moving_Avg_2Y=17.35336491878651, AL Moving_Avg_3Y=17.355265321732585, AL Moving_Avg_5Y=17.358503148780763, AL Moving_Avg_10Y=17.35568509898487
# 2024-11-19 16:25:04,105 - INFO - Predicted value for Algeria in 2013: 17.352867049188973
# 2024-11-19 16:25:04,106 - INFO - Prediction inputs for Algeria in 2014: Year=2014, AL Moving_Avg_2Y=17.352867049188973, AL Moving_Avg_3Y=17.353198962253998, AL Moving_Avg_5Y=17.358503148780763, AL Moving_Avg_10Y=17.35568509898487
# 2024-11-19 16:25:04,107 - INFO - Predicted value for Algeria in 2014: 17.352867049188973
# 2024-11-19 16:25:04,108 - INFO - Prediction inputs for Algeria in 2015: Year=2015, AL Moving_Avg_2Y=17.352867049188973, AL Moving_Avg_3Y=17.352867049188973, AL Moving_Avg_5Y=17.35430601271514, AL Moving_Avg_10Y=17.355685098984868
# 2024-11-19 16:25:04,109 - INFO - Predicted value for Algeria in 2015: 17.352867049188973
# 2024-11-19 16:25:04,110 - INFO - Prediction inputs for Algeria in 2016: Year=2016, AL Moving_Avg_2Y=17.352867049188973, AL Moving_Avg_3Y=17.352867049188973, AL Moving_Avg_5Y=17.35306619702799, AL Moving_Avg_10Y=17.355685098984868
# 2024-11-19 16:25:04,112 - INFO - Predicted value for Algeria in 2016: 17.352867049188973
# 2024-11-19 16:25:04,112 - INFO - Prediction inputs for Algeria in 2017: Year=2017, AL Moving_Avg_2Y=17.352867049188973, AL Moving_Avg_3Y=17.352867049188973, AL Moving_Avg_5Y=17.352867049188973, AL Moving_Avg_10Y=17.355685098984868
# 2024-11-19 16:25:04,114 - INFO - Predicted value for Algeria in 2017: 17.352867049188973
# 2024-11-19 16:25:04,114 - INFO - Prediction inputs for Algeria in 2018: Year=2018, AL Moving_Avg_2Y=17.352867049188973, AL Moving_Avg_3Y=17.352867049188973, AL Moving_Avg_5Y=17.352867049188973, AL Moving_Avg_10Y=17.355685098984868
# 2024-11-19 16:25:04,116 - INFO - Predicted value for Algeria in 2018: 17.352867049188973
# 2024-11-19 16:25:04,116 - INFO - Prediction inputs for Algeria in 2019: Year=2019, AL Moving_Avg_2Y=17.352867049188973, AL Moving_Avg_3Y=17.352867049188973, AL Moving_Avg_5Y=17.352867049188973, AL Moving_Avg_10Y=17.355685098984868
# 2024-11-19 16:25:04,118 - INFO - Predicted value for Algeria in 2019: 17.352867049188973
# 2024-11-19 16:25:04,118 - INFO - Processing country: Andorra
# 2024-11-19 16:25:04,119 - INFO - Prediction inputs for Andorra in 2010: Year=2010, AL Moving_Avg_2Y=44.18085106382975, AL Moving_Avg_3Y=44.184397163120536, AL Moving_Avg_5Y=45.05531914893616, AL Moving_Avg_10Y=46.840425531914875
# 2024-11-19 16:25:04,120 - INFO - Predicted value for Andorra in 2010: 44.14231289645369
# 2024-11-19 16:25:04,121 - INFO - Prediction inputs for Andorra in 2011: Year=2011, AL Moving_Avg_2Y=44.16690112907789, AL Moving_Avg_3Y=44.158705051536494, AL Moving_Avg_5Y=44.15214818950337, AL Moving_Avg_10Y=44.147230542978534
# 2024-11-19 16:25:04,123 - INFO - Predicted value for Andorra in 2011: 44.13296858739566
# 2024-11-19 16:25:04,123 - INFO - Prediction inputs for Andorra in 2012: Year=2012, AL Moving_Avg_2Y=44.13764074192467, AL Moving_Avg_3Y=44.155590281850486, AL Moving_Avg_5Y=44.14654160406855, AL Moving_Avg_10Y=44.13975509573211
# 2024-11-19 16:25:04,125 - INFO - Predicted value for Andorra in 2012: 44.1245362621205
# 2024-11-19 16:25:04,125 - INFO - Prediction inputs for Andorra in 2013: Year=2013, AL Moving_Avg_2Y=44.128752424758076, AL Moving_Avg_3Y=44.13327258198995, AL Moving_Avg_5Y=44.14316867395849, AL Moving_Avg_10Y=44.1338524680395
# 2024-11-19 16:25:04,127 - INFO - Predicted value for Andorra in 2013: 44.13912532341916
# 2024-11-19 16:25:04,127 - INFO - Prediction inputs for Andorra in 2014: Year=2014, AL Moving_Avg_2Y=44.13183079276983, AL Moving_Avg_3Y=44.1322100576451, AL Moving_Avg_5Y=44.14608648621822, AL Moving_Avg_10Y=44.142605904818694
# 2024-11-19 16:25:04,129 - INFO - Predicted value for Andorra in 2014: 44.13735105110432
# 2024-11-19 16:25:04,129 - INFO - Prediction inputs for Andorra in 2015: Year=2015, AL Moving_Avg_2Y=44.138238187261734, AL Moving_Avg_3Y=44.13367087888133, AL Moving_Avg_5Y=44.13525882409866, AL Moving_Avg_10Y=44.14171876866127
# 2024-11-19 16:25:04,131 - INFO - Predicted value for Andorra in 2015: 44.13500907943735
# 2024-11-19 16:25:04,131 - INFO - Prediction inputs for Andorra in 2016: Year=2016, AL Moving_Avg_2Y=44.136180065270835, AL Moving_Avg_3Y=44.13716181798694, AL Moving_Avg_5Y=44.13379806069539, AL Moving_Avg_10Y=44.140781979994486
# 2024-11-19 16:25:04,133 - INFO - Predicted value for Andorra in 2016: 44.12498132358603
# 2024-11-19 16:25:04,133 - INFO - Prediction inputs for Andorra in 2017: Year=2017, AL Moving_Avg_2Y=44.12999520151169, AL Moving_Avg_3Y=44.13244715137589, AL Moving_Avg_5Y=44.13220060793348, AL Moving_Avg_10Y=44.13777365323908
# 2024-11-19 16:25:04,135 - INFO - Predicted value for Andorra in 2017: 44.13735105110432
# 2024-11-19 16:25:04,136 - INFO - Prediction inputs for Andorra in 2018: Year=2018, AL Moving_Avg_2Y=44.13116618734517, AL Moving_Avg_3Y=44.13244715137589, AL Moving_Avg_5Y=44.13476356573024, AL Moving_Avg_10Y=44.14024759874274
# 2024-11-19 16:25:04,138 - INFO - Predicted value for Andorra in 2018: 44.13735105110432
# 2024-11-19 16:25:04,138 - INFO - Prediction inputs for Andorra in 2019: Year=2019, AL Moving_Avg_2Y=44.13735105110432, AL Moving_Avg_3Y=44.133227808598214, AL Moving_Avg_5Y=44.134408711267255, AL Moving_Avg_10Y=44.14024759874274
# 2024-11-19 16:25:04,140 - INFO - Predicted value for Andorra in 2019: 44.13821260267028
# 2024-11-19 16:25:04,140 - INFO - Processing country: Angola
# 2024-11-19 16:25:04,140 - INFO - Prediction inputs for Angola in 2010: Year=2010, AL Moving_Avg_2Y=35.62404748536135, AL Moving_Avg_3Y=35.57926258656187, AL Moving_Avg_5Y=35.51616266944736, AL Moving_Avg_10Y=35.57993101788722
# 2024-11-19 16:25:04,142 - INFO - Predicted value for Angola in 2010: 35.67348977488261
# 2024-11-19 16:25:04,143 - INFO - Prediction inputs for Angola in 2011: Year=2011, AL Moving_Avg_2Y=35.7359989180822, AL Moving_Avg_3Y=35.71516253701567, AL Moving_Avg_5Y=35.698493432162444, AL Moving_Avg_10Y=35.68599160352254
# 2024-11-19 16:25:04,145 - INFO - Predicted value for Angola in 2011: 35.65706331712108
# 2024-11-19 16:25:04,145 - INFO - Prediction inputs for Angola in 2012: Year=2012, AL Moving_Avg_2Y=35.66527654600185, AL Moving_Avg_3Y=35.70968705109516, AL Moving_Avg_5Y=35.68863755750552, AL Moving_Avg_10Y=35.6728504373133
# 2024-11-19 16:25:04,147 - INFO - Predicted value for Angola in 2012: 35.615189512644925
# 2024-11-19 16:25:04,147 - INFO - Prediction inputs for Angola in 2013: Year=2013, AL Moving_Avg_2Y=35.636126414883, AL Moving_Avg_3Y=35.64858086821621, AL Moving_Avg_5Y=35.67188803571507, AL Moving_Avg_10Y=35.643538774179994
# 2024-11-19 16:25:04,149 - INFO - Predicted value for Angola in 2013: 35.61798104336684
# 2024-11-19 16:25:04,149 - INFO - Prediction inputs for Angola in 2014: Year=2014, AL Moving_Avg_2Y=35.616585278005886, AL Moving_Avg_3Y=35.630077957710945, AL Moving_Avg_5Y=35.67244634185945, AL Moving_Avg_10Y=35.64521369261315
# 2024-11-19 16:25:04,151 - INFO - Predicted value for Angola in 2014: 35.57338579130804
# 2024-11-19 16:25:04,151 - INFO - Prediction inputs for Angola in 2015: Year=2015, AL Moving_Avg_2Y=35.59568341733744, AL Moving_Avg_3Y=35.60218544910661, AL Moving_Avg_5Y=35.627421887864706, AL Moving_Avg_10Y=35.62291606658375
# 2024-11-19 16:25:04,153 - INFO - Predicted value for Angola in 2015: 35.55666943835045
# 2024-11-19 16:25:04,153 - INFO - Prediction inputs for Angola in 2016: Year=2016, AL Moving_Avg_2Y=35.56502761482925, AL Moving_Avg_3Y=35.582678757675104, AL Moving_Avg_5Y=35.60405782055827, AL Moving_Avg_10Y=35.61622952540071
# 2024-11-19 16:25:04,155 - INFO - Predicted value for Angola in 2016: 35.50973966591462
# 2024-11-19 16:25:04,155 - INFO - Prediction inputs for Angola in 2017: Year=2017, AL Moving_Avg_2Y=35.53320455213253, AL Moving_Avg_3Y=35.54659829852437, AL Moving_Avg_5Y=35.57459309031698, AL Moving_Avg_10Y=35.60215059366997
# 2024-11-19 16:25:04,157 - INFO - Predicted value for Angola in 2017: 35.49496231559921
# 2024-11-19 16:25:04,157 - INFO - Prediction inputs for Angola in 2018: Year=2018, AL Moving_Avg_2Y=35.502350990756916, AL Moving_Avg_3Y=35.52045713995476, AL Moving_Avg_5Y=35.55054765090783, AL Moving_Avg_10Y=35.599195123606876
# 2024-11-19 16:25:04,159 - INFO - Predicted value for Angola in 2018: 35.50236941652072
# 2024-11-19 16:25:04,159 - INFO - Prediction inputs for Angola in 2019: Year=2019, AL Moving_Avg_2Y=35.498665866059966, AL Moving_Avg_3Y=35.502357132678185, AL Moving_Avg_5Y=35.5274253255386, AL Moving_Avg_10Y=35.59993583369903
# 2024-11-19 16:25:04,161 - INFO - Predicted value for Angola in 2019: 35.51162294154644
# 2024-11-19 16:25:04,162 - INFO - Processing country: Antigua and Barbuda
# 2024-11-19 16:25:04,162 - INFO - Prediction inputs for Antigua and Barbuda in 2010: Year=2010, AL Moving_Avg_2Y=20.4545454545455, AL Moving_Avg_3Y=20.4545454545455, AL Moving_Avg_5Y=20.4545454545455, AL Moving_Avg_10Y=20.4545454545455
# 2024-11-19 16:25:04,164 - INFO - Predicted value for Antigua and Barbuda in 2010: 20.454432539977724
# 2024-11-19 16:25:04,164 - INFO - Prediction inputs for Antigua and Barbuda in 2011: Year=2011, AL Moving_Avg_2Y=20.454488997261613, AL Moving_Avg_3Y=20.454470178166982, AL Moving_Avg_5Y=20.45445512289128, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,166 - INFO - Predicted value for Antigua and Barbuda in 2011: 20.454432539977724
# 2024-11-19 16:25:04,166 - INFO - Prediction inputs for Antigua and Barbuda in 2012: Year=2012, AL Moving_Avg_2Y=20.454432539977724, AL Moving_Avg_3Y=20.454470178166982, AL Moving_Avg_5Y=20.45445512289128, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,168 - INFO - Predicted value for Antigua and Barbuda in 2012: 20.454432539977724
# 2024-11-19 16:25:04,169 - INFO - Prediction inputs for Antigua and Barbuda in 2013: Year=2013, AL Moving_Avg_2Y=20.454432539977724, AL Moving_Avg_3Y=20.454432539977724, AL Moving_Avg_5Y=20.45445512289128, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,171 - INFO - Predicted value for Antigua and Barbuda in 2013: 20.454432539977724
# 2024-11-19 16:25:04,171 - INFO - Prediction inputs for Antigua and Barbuda in 2014: Year=2014, AL Moving_Avg_2Y=20.454432539977724, AL Moving_Avg_3Y=20.454432539977724, AL Moving_Avg_5Y=20.45445512289128, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,173 - INFO - Predicted value for Antigua and Barbuda in 2014: 20.454432539977724
# 2024-11-19 16:25:04,173 - INFO - Prediction inputs for Antigua and Barbuda in 2015: Year=2015, AL Moving_Avg_2Y=20.454432539977724, AL Moving_Avg_3Y=20.454432539977724, AL Moving_Avg_5Y=20.454432539977724, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,175 - INFO - Predicted value for Antigua and Barbuda in 2015: 20.454432539977724
# 2024-11-19 16:25:04,175 - INFO - Prediction inputs for Antigua and Barbuda in 2016: Year=2016, AL Moving_Avg_2Y=20.454432539977724, AL Moving_Avg_3Y=20.454432539977724, AL Moving_Avg_5Y=20.454432539977724, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,177 - INFO - Predicted value for Antigua and Barbuda in 2016: 20.454432539977724
# 2024-11-19 16:25:04,177 - INFO - Prediction inputs for Antigua and Barbuda in 2017: Year=2017, AL Moving_Avg_2Y=20.454432539977724, AL Moving_Avg_3Y=20.454432539977724, AL Moving_Avg_5Y=20.454432539977724, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,179 - INFO - Predicted value for Antigua and Barbuda in 2017: 20.454432539977724
# 2024-11-19 16:25:04,179 - INFO - Prediction inputs for Antigua and Barbuda in 2018: Year=2018, AL Moving_Avg_2Y=20.454432539977724, AL Moving_Avg_3Y=20.454432539977724, AL Moving_Avg_5Y=20.454432539977724, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,181 - INFO - Predicted value for Antigua and Barbuda in 2018: 20.454432539977724
# 2024-11-19 16:25:04,181 - INFO - Prediction inputs for Antigua and Barbuda in 2019: Year=2019, AL Moving_Avg_2Y=20.454432539977724, AL Moving_Avg_3Y=20.454432539977724, AL Moving_Avg_5Y=20.454432539977724, AL Moving_Avg_10Y=20.454443831434496
# 2024-11-19 16:25:04,183 - INFO - Predicted value for Antigua and Barbuda in 2019: 20.454432539977724
# 2024-11-19 16:25:04,183 - INFO - Processing country: Argentina
# 2024-11-19 16:25:04,184 - INFO - Prediction inputs for Argentina in 2010: Year=2010, AL Moving_Avg_2Y=45.9268861288637, AL Moving_Avg_3Y=46.448288504239294, AL Moving_Avg_5Y=46.87439936565706, AL Moving_Avg_10Y=46.9848393497254
# 2024-11-19 16:25:04,186 - INFO - Predicted value for Argentina in 2010: 45.59649094183715
# 2024-11-19 16:25:04,186 - INFO - Prediction inputs for Argentina in 2011: Year=2011, AL Moving_Avg_2Y=45.51335021423988, AL Moving_Avg_3Y=45.54106379010563, AL Moving_Avg_5Y=45.56323465079824, AL Moving_Avg_10Y=45.5798627963177
# 2024-11-19 16:25:04,188 - INFO - Predicted value for Argentina in 2011: 45.46820216623618
# 2024-11-19 16:25:04,188 - INFO - Prediction inputs for Argentina in 2012: Year=2012, AL Moving_Avg_2Y=45.532346554036664, AL Moving_Avg_3Y=45.49830086490531, AL Moving_Avg_5Y=45.48626138543766, AL Moving_Avg_10Y=45.47723177583691
# 2024-11-19 16:25:04,190 - INFO - Predicted value for Argentina in 2012: 45.4902594724123
# 2024-11-19 16:25:04,190 - INFO - Prediction inputs for Argentina in 2013: Year=2013, AL Moving_Avg_2Y=45.47923081932424, AL Moving_Avg_3Y=45.51831752682855, AL Moving_Avg_5Y=45.49508430790811, AL Moving_Avg_10Y=45.492671890160196
# 2024-11-19 16:25:04,192 - INFO - Predicted value for Argentina in 2013: 45.59146722829755
# 2024-11-19 16:25:04,192 - INFO - Prediction inputs for Argentina in 2014: Year=2014, AL Moving_Avg_2Y=45.540863350354925, AL Moving_Avg_3Y=45.51664295564868, AL Moving_Avg_5Y=45.51532585908516, AL Moving_Avg_10Y=45.55339654369135
# 2024-11-19 16:25:04,194 - INFO - Predicted value for Argentina in 2014: 45.52574550124928
# 2024-11-19 16:25:04,194 - INFO - Prediction inputs for Argentina in 2015: Year=2015, AL Moving_Avg_2Y=45.55860636477342, AL Moving_Avg_3Y=45.53582406731971, AL Moving_Avg_5Y=45.53443306200649, AL Moving_Avg_10Y=45.52053568016722
# 2024-11-19 16:25:04,196 - INFO - Predicted value for Argentina in 2015: 45.58135548309413
# 2024-11-19 16:25:04,196 - INFO - Prediction inputs for Argentina in 2016: Year=2016, AL Moving_Avg_2Y=45.55355049217171, AL Moving_Avg_3Y=45.56618940421365, AL Moving_Avg_5Y=45.53140597025789, AL Moving_Avg_10Y=45.542779672905155
# 2024-11-19 16:25:04,198 - INFO - Predicted value for Argentina in 2016: 45.55050429029834
# 2024-11-19 16:25:04,199 - INFO - Prediction inputs for Argentina in 2017: Year=2017, AL Moving_Avg_2Y=45.56592988669624, AL Moving_Avg_3Y=45.55253509154725, AL Moving_Avg_5Y=45.547866395070315, AL Moving_Avg_10Y=45.53352431506642
# 2024-11-19 16:25:04,200 - INFO - Predicted value for Argentina in 2017: 45.58791945535605
# 2024-11-19 16:25:04,201 - INFO - Prediction inputs for Argentina in 2018: Year=2018, AL Moving_Avg_2Y=45.569211872827196, AL Moving_Avg_3Y=45.57325974291618, AL Moving_Avg_5Y=45.56739839165907, AL Moving_Avg_10Y=45.54100734807797
# 2024-11-19 16:25:04,203 - INFO - Predicted value for Argentina in 2018: 45.60107330808668
# 2024-11-19 16:25:04,203 - INFO - Prediction inputs for Argentina in 2019: Year=2019, AL Moving_Avg_2Y=45.59449638172137, AL Moving_Avg_3Y=45.57983235124703, AL Moving_Avg_5Y=45.5693196076169, AL Moving_Avg_10Y=45.54232273335102
# 2024-11-19 16:25:04,205 - INFO - Predicted value for Argentina in 2019: 45.60628767596101
# 2024-11-19 16:25:04,205 - INFO - Processing country: Armenia
# 2024-11-19 16:25:04,205 - INFO - Prediction inputs for Armenia in 2010: Year=2010, AL Moving_Avg_2Y=61.382156656129254, AL Moving_Avg_3Y=61.4330874604847, AL Moving_Avg_5Y=60.4734808570425, AL Moving_Avg_10Y=54.79241306638566
# 2024-11-19 16:25:04,207 - INFO - Predicted value for Armenia in 2010: 61.36740536630743
# 2024-11-19 16:25:04,208 - INFO - Prediction inputs for Armenia in 2011: Year=2011, AL Moving_Avg_2Y=61.352828078306516, AL Moving_Avg_3Y=61.35768717430682, AL Moving_Avg_5Y=61.361574451107074, AL Moving_Avg_10Y=61.364489908707256
# 2024-11-19 16:25:04,210 - INFO - Predicted value for Armenia in 2011: 61.33221226224382
# 2024-11-19 16:25:04,210 - INFO - Prediction inputs for Armenia in 2012: Year=2012, AL Moving_Avg_2Y=61.349808814275626, AL Moving_Avg_3Y=61.34595613961895, AL Moving_Avg_5Y=61.3404585886689, AL Moving_Avg_10Y=61.33633542545637
# 2024-11-19 16:25:04,212 - INFO - Predicted value for Armenia in 2012: 61.354441225549515
# 2024-11-19 16:25:04,212 - INFO - Prediction inputs for Armenia in 2013: Year=2013, AL Moving_Avg_2Y=61.34332674389667, AL Moving_Avg_3Y=61.35135295136692, AL Moving_Avg_5Y=61.34935017399117, AL Moving_Avg_10Y=61.35189569977034
# 2024-11-19 16:25:04,214 - INFO - Predicted value for Armenia in 2013: 61.3325547388258
# 2024-11-19 16:25:04,214 - INFO - Prediction inputs for Armenia in 2014: Year=2014, AL Moving_Avg_2Y=61.34349798218766, AL Moving_Avg_3Y=61.33973607553971, AL Moving_Avg_5Y=61.34497287664643, AL Moving_Avg_10Y=61.33876380773612
# 2024-11-19 16:25:04,216 - INFO - Predicted value for Armenia in 2014: 61.35712851079883
# 2024-11-19 16:25:04,216 - INFO - Prediction inputs for Armenia in 2015: Year=2015, AL Moving_Avg_2Y=61.34484162481232, AL Moving_Avg_3Y=61.34804149172472, AL Moving_Avg_5Y=61.348748420745075, AL Moving_Avg_10Y=61.35105069372263
# 2024-11-19 16:25:04,218 - INFO - Predicted value for Armenia in 2015: 61.355085933049
# 2024-11-19 16:25:04,218 - INFO - Prediction inputs for Armenia in 2016: Year=2016, AL Moving_Avg_2Y=61.356107221923914, AL Moving_Avg_3Y=61.34825639422454, AL Moving_Avg_5Y=61.346284534093385, AL Moving_Avg_10Y=61.35023366262271
# 2024-11-19 16:25:04,220 - INFO - Predicted value for Armenia in 2016: 61.351719516913384
# 2024-11-19 16:25:04,220 - INFO - Prediction inputs for Armenia in 2017: Year=2017, AL Moving_Avg_2Y=61.353402724981194, AL Moving_Avg_3Y=61.354644653587066, AL Moving_Avg_5Y=61.3501859850273, AL Moving_Avg_10Y=61.34922373778202
# 2024-11-19 16:25:04,222 - INFO - Predicted value for Armenia in 2017: 61.35474345646701
# 2024-11-19 16:25:04,222 - INFO - Prediction inputs for Armenia in 2018: Year=2018, AL Moving_Avg_2Y=61.3532314866902, AL Moving_Avg_3Y=61.35384963547647, AL Moving_Avg_5Y=61.350246431210806, AL Moving_Avg_10Y=61.349828525692736
# 2024-11-19 16:25:04,224 - INFO - Predicted value for Armenia in 2018: 61.35474345646701
# 2024-11-19 16:25:04,224 - INFO - Prediction inputs for Armenia in 2019: Year=2019, AL Moving_Avg_2Y=61.35474345646701, AL Moving_Avg_3Y=61.3537354766158, AL Moving_Avg_5Y=61.35468417473904, AL Moving_Avg_10Y=61.34982852569273
# 2024-11-19 16:25:04,226 - INFO - Predicted value for Armenia in 2019: 61.351719516913384
# 2024-11-19 16:25:04,226 - INFO - Processing country: Australia
# 2024-11-19 16:25:04,227 - INFO - Prediction inputs for Australia in 2010: Year=2010, AL Moving_Avg_2Y=50.34592504848809, AL Moving_Avg_3Y=50.84850891009203, AL Moving_Avg_5Y=51.8446949481275, AL Moving_Avg_10Y=54.46295380289755
# 2024-11-19 16:25:04,229 - INFO - Predicted value for Australia in 2010: 49.79571914566536
# 2024-11-19 16:25:04,229 - INFO - Prediction inputs for Australia in 2011: Year=2011, AL Moving_Avg_2Y=49.90710159670573, AL Moving_Avg_3Y=49.86997411302561, AL Moving_Avg_5Y=49.8402721260815, AL Moving_Avg_10Y=49.81799563587344
# 2024-11-19 16:25:04,231 - INFO - Predicted value for Australia in 2011: 50.06512900700428
# 2024-11-19 16:25:04,231 - INFO - Prediction inputs for Australia in 2012: Year=2012, AL Moving_Avg_2Y=49.930424076334816, AL Moving_Avg_3Y=49.959777400138584, AL Moving_Avg_5Y=50.00191804288487, AL Moving_Avg_10Y=50.03352352494456
# 2024-11-19 16:25:04,233 - INFO - Predicted value for Australia in 2012: 50.040406584007435
# 2024-11-19 16:25:04,233 - INFO - Prediction inputs for Australia in 2013: Year=2013, AL Moving_Avg_2Y=50.05276779550586, AL Moving_Avg_3Y=49.96708491222569, AL Moving_Avg_5Y=49.99202907368612, AL Moving_Avg_10Y=50.01621782884678
# 2024-11-19 16:25:04,235 - INFO - Predicted value for Australia in 2013: 50.0328849522661
# 2024-11-19 16:25:04,235 - INFO - Prediction inputs for Australia in 2014: Year=2014, AL Moving_Avg_2Y=50.036645768136765, AL Moving_Avg_3Y=50.0461401810926, AL Moving_Avg_5Y=49.99052474733786, AL Moving_Avg_10Y=50.01170484980197
# 2024-11-19 16:25:04,237 - INFO - Predicted value for Australia in 2014: 50.01385157256999
# 2024-11-19 16:25:04,237 - INFO - Prediction inputs for Australia in 2015: Year=2015, AL Moving_Avg_2Y=50.023368262418046, AL Moving_Avg_3Y=50.02904770294784, AL Moving_Avg_5Y=49.98959825230263, AL Moving_Avg_10Y=50.00218815995392
# 2024-11-19 16:25:04,239 - INFO - Predicted value for Australia in 2015: 50.0221278046009
# 2024-11-19 16:25:04,239 - INFO - Prediction inputs for Australia in 2016: Year=2016, AL Moving_Avg_2Y=50.017989688585445, AL Moving_Avg_3Y=50.022954776479, AL Moving_Avg_5Y=50.03487998408974, AL Moving_Avg_10Y=50.00549865276629
# 2024-11-19 16:25:04,241 - INFO - Predicted value for Australia in 2016: 50.010107454150905
# 2024-11-19 16:25:04,241 - INFO - Prediction inputs for Australia in 2017: Year=2017, AL Moving_Avg_2Y=50.0161176293759, AL Moving_Avg_3Y=50.015362277107265, AL Moving_Avg_5Y=50.023875673519065, AL Moving_Avg_10Y=50.00189254763129
# 2024-11-19 16:25:04,243 - INFO - Predicted value for Australia in 2017: 50.01728668393269
# 2024-11-19 16:25:04,244 - INFO - Prediction inputs for Australia in 2018: Year=2018, AL Moving_Avg_2Y=50.0136970690418, AL Moving_Avg_3Y=50.016507314228164, AL Moving_Avg_5Y=50.01925169350412, AL Moving_Avg_10Y=50.003328393587644
# 2024-11-19 16:25:04,245 - INFO - Predicted value for Australia in 2018: 50.02296839047631
# 2024-11-19 16:25:04,245 - INFO - Prediction inputs for Australia in 2019: Year=2019, AL Moving_Avg_2Y=50.0201275372045, AL Moving_Avg_3Y=50.016787509519965, AL Moving_Avg_5Y=50.01726838114616, AL Moving_Avg_10Y=50.00389656424201
# 2024-11-19 16:25:04,247 - INFO - Predicted value for Australia in 2019: 50.0160041320356
# 2024-11-19 16:25:04,247 - INFO - Processing country: Austria
# 2024-11-19 16:25:04,248 - INFO - Prediction inputs for Austria in 2010: Year=2010, AL Moving_Avg_2Y=33.957828405235105, AL Moving_Avg_3Y=34.070528356762004, AL Moving_Avg_5Y=34.257392147358225, AL Moving_Avg_10Y=34.71368153174987
# 2024-11-19 16:25:04,250 - INFO - Predicted value for Austria in 2010: 33.98321350704037
# 2024-11-19 16:25:04,250 - INFO - Prediction inputs for Austria in 2011: Year=2011, AL Moving_Avg_2Y=33.92689516844989, AL Moving_Avg_3Y=33.94566794798005, AL Moving_Avg_5Y=33.96068617160417, AL Moving_Avg_10Y=33.97194983932228
# 2024-11-19 16:25:04,252 - INFO - Predicted value for Austria in 2011: 33.97247280405578
# 2024-11-19 16:25:04,252 - INFO - Prediction inputs for Austria in 2012: Year=2012, AL Moving_Avg_2Y=33.97784315554807, AL Moving_Avg_3Y=33.94208771365185, AL Moving_Avg_5Y=33.95424174981342, AL Moving_Avg_10Y=33.9633572769346
# 2024-11-19 16:25:04,254 - INFO - Predicted value for Austria in 2012: 34.053224604172506
# 2024-11-19 16:25:04,255 - INFO - Prediction inputs for Austria in 2013: Year=2013, AL Moving_Avg_2Y=34.01284870411415, AL Moving_Avg_3Y=34.00297030508955, AL Moving_Avg_5Y=33.98654246986011, AL Moving_Avg_10Y=34.019883537016305
# 2024-11-19 16:25:04,256 - INFO - Predicted value for Austria in 2013: 34.04173951665471
# 2024-11-19 16:25:04,257 - INFO - Prediction inputs for Austria in 2014: Year=2014, AL Moving_Avg_2Y=34.04748206041361, AL Moving_Avg_3Y=34.022478974961, AL Moving_Avg_5Y=33.984245452356554, AL Moving_Avg_10Y=34.01299248450563
# 2024-11-19 16:25:04,258 - INFO - Predicted value for Austria in 2014: 34.04499796803757
# 2024-11-19 16:25:04,259 - INFO - Prediction inputs for Austria in 2015: Year=2015, AL Moving_Avg_2Y=34.04336874234614, AL Moving_Avg_3Y=34.0466540296216, AL Moving_Avg_5Y=34.01912967999218, AL Moving_Avg_10Y=34.01462171019706
# 2024-11-19 16:25:04,261 - INFO - Predicted value for Austria in 2015: 34.04407780386226
# 2024-11-19 16:25:04,261 - INFO - Prediction inputs for Austria in 2016: Year=2016, AL Moving_Avg_2Y=34.044537885949914, AL Moving_Avg_3Y=34.04360509618485, AL Moving_Avg_5Y=34.03130253935656, AL Moving_Avg_10Y=34.01425364452694
# 2024-11-19 16:25:04,263 - INFO - Predicted value for Austria in 2016: 34.04407780386226
# 2024-11-19 16:25:04,263 - INFO - Prediction inputs for Austria in 2017: Year=2017, AL Moving_Avg_2Y=34.04407780386226, AL Moving_Avg_3Y=34.04438452525403, AL Moving_Avg_5Y=34.04562353931786, AL Moving_Avg_10Y=34.01425364452693
# 2024-11-19 16:25:04,265 - INFO - Predicted value for Austria in 2017: 34.04407780386226
# 2024-11-19 16:25:04,265 - INFO - Prediction inputs for Austria in 2018: Year=2018, AL Moving_Avg_2Y=34.04407780386226, AL Moving_Avg_3Y=34.04407780386226, AL Moving_Avg_5Y=34.04379417925581, AL Moving_Avg_10Y=34.01425364452693
# 2024-11-19 16:25:04,267 - INFO - Predicted value for Austria in 2018: 34.04407780386226
# 2024-11-19 16:25:04,267 - INFO - Prediction inputs for Austria in 2019: Year=2019, AL Moving_Avg_2Y=34.04407780386226, AL Moving_Avg_3Y=34.04407780386226, AL Moving_Avg_5Y=34.044261836697316, AL Moving_Avg_10Y=34.01425364452693
# 2024-11-19 16:25:04,269 - INFO - Predicted value for Austria in 2019: 34.04407780386226
# 2024-11-19 16:25:04,269 - INFO - Processing country: Azerbaijan
# 2024-11-19 16:25:04,269 - INFO - Prediction inputs for Azerbaijan in 2010: Year=2010, AL Moving_Avg_2Y=57.573722242582846, AL Moving_Avg_3Y=57.57065997960667, AL Moving_Avg_5Y=57.56664887181692, AL Moving_Avg_10Y=57.51421677375706
# 2024-11-19 16:25:04,271 - INFO - Predicted value for Azerbaijan in 2010: 57.59158112539807
# 2024-11-19 16:25:04,272 - INFO - Prediction inputs for Azerbaijan in 2011: Year=2011, AL Moving_Avg_2Y=57.58533814082594, AL Moving_Avg_3Y=57.58741913568332, AL Moving_Avg_5Y=57.58908393156921, AL Moving_Avg_10Y=57.59033252848364
# 2024-11-19 16:25:04,274 - INFO - Predicted value for Azerbaijan in 2011: 57.85393336403891
# 2024-11-19 16:25:04,274 - INFO - Prediction inputs for Azerbaijan in 2012: Year=2012, AL Moving_Avg_2Y=57.722757244718494, AL Moving_Avg_3Y=57.67486988189693, AL Moving_Avg_5Y=57.74649527475371, AL Moving_Avg_10Y=57.8002143193963
# 2024-11-19 16:25:04,276 - INFO - Predicted value for Azerbaijan in 2012: 57.772021290956665
# 2024-11-19 16:25:04,276 - INFO - Prediction inputs for Azerbaijan in 2013: Year=2013, AL Moving_Avg_2Y=57.81297732749779, AL Moving_Avg_3Y=57.73917859346455, AL Moving_Avg_5Y=57.713730445520824, AL Moving_Avg_10Y=57.74287586823874
# 2024-11-19 16:25:04,278 - INFO - Predicted value for Azerbaijan in 2013: 57.86011193411824
# 2024-11-19 16:25:04,278 - INFO - Prediction inputs for Azerbaijan in 2014: Year=2014, AL Moving_Avg_2Y=57.816066612537455, AL Moving_Avg_3Y=57.82868886303794, AL Moving_Avg_5Y=57.73134857415314, AL Moving_Avg_10Y=57.795730254135684
# 2024-11-19 16:25:04,280 - INFO - Predicted value for Azerbaijan in 2014: 57.84322543767809
# 2024-11-19 16:25:04,280 - INFO - Prediction inputs for Azerbaijan in 2015: Year=2015, AL Moving_Avg_2Y=57.85166868589816, AL Moving_Avg_3Y=57.825119554250996, AL Moving_Avg_5Y=57.784174630437995, AL Moving_Avg_10Y=57.787287005915616
# 2024-11-19 16:25:04,282 - INFO - Predicted value for Azerbaijan in 2015: 57.86461050671079
# 2024-11-19 16:25:04,282 - INFO - Prediction inputs for Azerbaijan in 2016: Year=2016, AL Moving_Avg_2Y=57.85391797219444, AL Moving_Avg_3Y=57.85598262616904, AL Moving_Avg_5Y=57.83878050670054, AL Moving_Avg_10Y=57.7958410335287
# 2024-11-19 16:25:04,284 - INFO - Predicted value for Azerbaijan in 2016: 57.8686226160254
# 2024-11-19 16:25:04,285 - INFO - Prediction inputs for Azerbaijan in 2017: Year=2017, AL Moving_Avg_2Y=57.86661656136809, AL Moving_Avg_3Y=57.85881952013809, AL Moving_Avg_5Y=57.84171835709784, AL Moving_Avg_10Y=57.797044666323075
# 2024-11-19 16:25:04,286 - INFO - Predicted value for Azerbaijan in 2017: 57.855808872210325
# 2024-11-19 16:25:04,287 - INFO - Prediction inputs for Azerbaijan in 2018: Year=2018, AL Moving_Avg_2Y=57.86221574411786, AL Moving_Avg_3Y=57.8630139983155, AL Moving_Avg_5Y=57.85847587334856, AL Moving_Avg_10Y=57.79448191756006
# 2024-11-19 16:25:04,288 - INFO - Predicted value for Azerbaijan in 2018: 57.855808872210325
# 2024-11-19 16:25:04,289 - INFO - Prediction inputs for Azerbaijan in 2019: Year=2019, AL Moving_Avg_2Y=57.855808872210325, AL Moving_Avg_3Y=57.86008012014869, AL Moving_Avg_5Y=57.85761526096699, AL Moving_Avg_10Y=57.79448191756006
# 2024-11-19 16:25:04,291 - INFO - Predicted value for Azerbaijan in 2019: 57.8686226160254
# 2024-11-19 16:25:04,291 - INFO - Processing country: Bahamas, The
# 2024-11-19 16:25:04,291 - INFO - Prediction inputs for Bahamas, The in 2010: Year=2010, AL Moving_Avg_2Y=1.0989010989011, AL Moving_Avg_3Y=1.0989010989011, AL Moving_Avg_5Y=1.0989010989011, AL Moving_Avg_10Y=1.0989010989011
# 2024-11-19 16:25:04,293 - INFO - Predicted value for Bahamas, The in 2010: 1.0975478987870912
# 2024-11-19 16:25:04,293 - INFO - Prediction inputs for Bahamas, The in 2011: Year=2011, AL Moving_Avg_2Y=1.0982244988440957, AL Moving_Avg_3Y=1.0979989654917608, AL Moving_Avg_5Y=1.097818538809893, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,295 - INFO - Predicted value for Bahamas, The in 2011: 1.0975478987870912
# 2024-11-19 16:25:04,296 - INFO - Prediction inputs for Bahamas, The in 2012: Year=2012, AL Moving_Avg_2Y=1.0975478987870912, AL Moving_Avg_3Y=1.0979989654917608, AL Moving_Avg_5Y=1.097818538809893, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,297 - INFO - Predicted value for Bahamas, The in 2012: 1.0975478987870912
# 2024-11-19 16:25:04,298 - INFO - Prediction inputs for Bahamas, The in 2013: Year=2013, AL Moving_Avg_2Y=1.0975478987870912, AL Moving_Avg_3Y=1.0975478987870912, AL Moving_Avg_5Y=1.097818538809893, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,299 - INFO - Predicted value for Bahamas, The in 2013: 1.0975478987870912
# 2024-11-19 16:25:04,300 - INFO - Prediction inputs for Bahamas, The in 2014: Year=2014, AL Moving_Avg_2Y=1.0975478987870912, AL Moving_Avg_3Y=1.0975478987870912, AL Moving_Avg_5Y=1.097818538809893, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,302 - INFO - Predicted value for Bahamas, The in 2014: 1.0975478987870912
# 2024-11-19 16:25:04,302 - INFO - Prediction inputs for Bahamas, The in 2015: Year=2015, AL Moving_Avg_2Y=1.0975478987870912, AL Moving_Avg_3Y=1.0975478987870912, AL Moving_Avg_5Y=1.0975478987870912, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,304 - INFO - Predicted value for Bahamas, The in 2015: 1.0975478987870912
# 2024-11-19 16:25:04,304 - INFO - Prediction inputs for Bahamas, The in 2016: Year=2016, AL Moving_Avg_2Y=1.0975478987870912, AL Moving_Avg_3Y=1.0975478987870912, AL Moving_Avg_5Y=1.0975478987870912, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,306 - INFO - Predicted value for Bahamas, The in 2016: 1.0975478987870912
# 2024-11-19 16:25:04,321 - INFO - Prediction inputs for Bahamas, The in 2017: Year=2017, AL Moving_Avg_2Y=1.0975478987870912, AL Moving_Avg_3Y=1.0975478987870912, AL Moving_Avg_5Y=1.0975478987870912, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,325 - INFO - Predicted value for Bahamas, The in 2017: 1.0975478987870912
# 2024-11-19 16:25:04,325 - INFO - Prediction inputs for Bahamas, The in 2018: Year=2018, AL Moving_Avg_2Y=1.0975478987870912, AL Moving_Avg_3Y=1.0975478987870912, AL Moving_Avg_5Y=1.0975478987870912, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,327 - INFO - Predicted value for Bahamas, The in 2018: 1.0975478987870912
# 2024-11-19 16:25:04,328 - INFO - Prediction inputs for Bahamas, The in 2019: Year=2019, AL Moving_Avg_2Y=1.0975478987870912, AL Moving_Avg_3Y=1.0975478987870912, AL Moving_Avg_5Y=1.0975478987870912, AL Moving_Avg_10Y=1.0976832187984922
# 2024-11-19 16:25:04,330 - INFO - Predicted value for Bahamas, The in 2019: 1.0975478987870912
# 2024-11-19 16:25:04,330 - INFO - Processing country: Bahrain
# 2024-11-19 16:25:04,330 - INFO - Prediction inputs for Bahrain in 2010: Year=2010, AL Moving_Avg_2Y=11.8486842105263, AL Moving_Avg_3Y=11.970233918128633, AL Moving_Avg_5Y=12.21997818871502, AL Moving_Avg_10Y=12.87720295591346
# 2024-11-19 16:25:04,333 - INFO - Predicted value for Bahrain in 2010: 11.82752313871507
# 2024-11-19 16:25:04,334 - INFO - Prediction inputs for Bahrain in 2011: Year=2011, AL Moving_Avg_2Y=11.801919464094386, AL Moving_Avg_3Y=11.81045402230128, AL Moving_Avg_5Y=11.817281668866796, AL Moving_Avg_10Y=11.822402403790932
# 2024-11-19 16:25:04,337 - INFO - Predicted value for Bahrain in 2011: 11.856344086053841
# 2024-11-19 16:25:04,337 - INFO - Prediction inputs for Bahrain in 2012: Year=2012, AL Moving_Avg_2Y=11.841933612384455, AL Moving_Avg_3Y=11.820061004747538, AL Moving_Avg_5Y=11.834574237270058, AL Moving_Avg_10Y=11.845459161661948
# 2024-11-19 16:25:04,339 - INFO - Predicted value for Bahrain in 2012: 11.840883947220803
# 2024-11-19 16:25:04,339 - INFO - Prediction inputs for Bahrain in 2013: Year=2013, AL Moving_Avg_2Y=11.848614016637322, AL Moving_Avg_3Y=11.841583723996571, AL Moving_Avg_5Y=11.828390181736845, AL Moving_Avg_10Y=11.834637064478823
# 2024-11-19 16:25:04,341 - INFO - Predicted value for Bahrain in 2013: 11.85251165076229
# 2024-11-19 16:25:04,341 - INFO - Prediction inputs for Bahrain in 2014: Year=2014, AL Moving_Avg_2Y=11.846697798991546, AL Moving_Avg_3Y=11.849913228012312, AL Moving_Avg_5Y=11.830715722445142, AL Moving_Avg_10Y=11.841613686603715
# 2024-11-19 16:25:04,343 - INFO - Predicted value for Bahrain in 2014: 11.841778363555145
# 2024-11-19 16:25:04,344 - INFO - Prediction inputs for Bahrain in 2015: Year=2015, AL Moving_Avg_2Y=11.847145007158717, AL Moving_Avg_3Y=11.84505798717941, AL Moving_Avg_5Y=11.84380823726143, AL Moving_Avg_10Y=11.836247043000144
# 2024-11-19 16:25:04,346 - INFO - Predicted value for Bahrain in 2015: 11.842890815362809
# 2024-11-19 16:25:04,346 - INFO - Prediction inputs for Bahrain in 2016: Year=2016, AL Moving_Avg_2Y=11.842334589458977, AL Moving_Avg_3Y=11.84572694322675, AL Moving_Avg_5Y=11.846881772590978, AL Moving_Avg_10Y=11.83669202372321
# 2024-11-19 16:25:04,348 - INFO - Predicted value for Bahrain in 2016: 11.842890815362809
# 2024-11-19 16:25:04,348 - INFO - Prediction inputs for Bahrain in 2017: Year=2017, AL Moving_Avg_2Y=11.842890815362809, AL Moving_Avg_3Y=11.842519998093588, AL Moving_Avg_5Y=11.84419111845277, AL Moving_Avg_10Y=11.83669202372321
# 2024-11-19 16:25:04,350 - INFO - Predicted value for Bahrain in 2017: 11.842890815362809
# 2024-11-19 16:25:04,350 - INFO - Prediction inputs for Bahrain in 2018: Year=2018, AL Moving_Avg_2Y=11.842890815362809, AL Moving_Avg_3Y=11.842890815362809, AL Moving_Avg_5Y=11.844592492081173, AL Moving_Avg_10Y=11.83669202372321
# 2024-11-19 16:25:04,352 - INFO - Predicted value for Bahrain in 2018: 11.842890815362809
# 2024-11-19 16:25:04,352 - INFO - Prediction inputs for Bahrain in 2019: Year=2019, AL Moving_Avg_2Y=11.842890815362809, AL Moving_Avg_3Y=11.842890815362809, AL Moving_Avg_5Y=11.842668325001275, AL Moving_Avg_10Y=11.836692023723208
# 2024-11-19 16:25:04,354 - INFO - Predicted value for Bahrain in 2019: 11.842890815362809
# 2024-11-19 16:25:04,354 - INFO - Processing country: Bangladesh
# 2024-11-19 16:25:04,355 - INFO - Prediction inputs for Bangladesh in 2010: Year=2010, AL Moving_Avg_2Y=71.0570792041177, AL Moving_Avg_3Y=71.09933164323577, AL Moving_Avg_5Y=71.22378428209267, AL Moving_Avg_10Y=71.57025428286087
# 2024-11-19 16:25:04,357 - INFO - Predicted value for Bangladesh in 2010: 71.05181976739281
# 2024-11-19 16:25:04,357 - INFO - Prediction inputs for Bangladesh in 2011: Year=2011, AL Moving_Avg_2Y=71.04100552785405, AL Moving_Avg_3Y=71.04461027436697, AL Moving_Avg_5Y=71.0474940715773, AL Moving_Avg_10Y=71.04965691948506
# 2024-11-19 16:25:04,359 - INFO - Predicted value for Bangladesh in 2011: 71.07683330736657
# 2024-11-19 16:25:04,359 - INFO - Prediction inputs for Bangladesh in 2012: Year=2012, AL Moving_Avg_2Y=71.06432653737969, AL Moving_Avg_3Y=71.0529481210249, AL Moving_Avg_5Y=71.06250219556156, AL Moving_Avg_10Y=71.06966775146405
# 2024-11-19 16:25:04,361 - INFO - Predicted value for Bangladesh in 2012: 71.0778004419179
# 2024-11-19 16:25:04,361 - INFO - Prediction inputs for Bangladesh in 2013: Year=2013, AL Moving_Avg_2Y=71.07731687464224, AL Moving_Avg_3Y=71.06881783889243, AL Moving_Avg_5Y=71.06288904938211, AL Moving_Avg_10Y=71.07034474565
# 2024-11-19 16:25:04,363 - INFO - Predicted value for Bangladesh in 2013: 71.0960819989642
# 2024-11-19 16:25:04,363 - INFO - Prediction inputs for Bangladesh in 2014: Year=2014, AL Moving_Avg_2Y=71.08694122044105, AL Moving_Avg_3Y=71.08357191608289, AL Moving_Avg_5Y=71.06654536079137, AL Moving_Avg_10Y=71.08131367987778
# 2024-11-19 16:25:04,365 - INFO - Predicted value for Bangladesh in 2014: 71.09638848540361
# 2024-11-19 16:25:04,365 - INFO - Prediction inputs for Bangladesh in 2015: Year=2015, AL Moving_Avg_2Y=71.0962352421839, AL Moving_Avg_3Y=71.0900903087619, AL Moving_Avg_5Y=71.07978480020901, AL Moving_Avg_10Y=71.0814669230975
# 2024-11-19 16:25:04,367 - INFO - Predicted value for Bangladesh in 2015: 71.1143754072877
# 2024-11-19 16:25:04,367 - INFO - Prediction inputs for Bangladesh in 2016: Year=2016, AL Moving_Avg_2Y=71.10538194634566, AL Moving_Avg_3Y=71.10228196388516, AL Moving_Avg_5Y=71.092295928188, AL Moving_Avg_10Y=71.08866169185112
# 2024-11-19 16:25:04,369 - INFO - Predicted value for Bangladesh in 2016: 71.11663969920492
# 2024-11-19 16:25:04,370 - INFO - Prediction inputs for Bangladesh in 2017: Year=2017, AL Moving_Avg_2Y=71.11550755324632, AL Moving_Avg_3Y=71.10913453063209, AL Moving_Avg_5Y=71.10025720655567, AL Moving_Avg_10Y=71.0893409794263
# 2024-11-19 16:25:04,371 - INFO - Predicted value for Bangladesh in 2017: 71.12893636955489
# 2024-11-19 16:25:04,372 - INFO - Prediction inputs for Bangladesh in 2018: Year=2018, AL Moving_Avg_2Y=71.12278803437991, AL Moving_Avg_3Y=71.11998382534917, AL Moving_Avg_5Y=71.11048439208307, AL Moving_Avg_10Y=71.0918003134963
# 2024-11-19 16:25:04,374 - INFO - Predicted value for Bangladesh in 2018: 71.1520895623227
# 2024-11-19 16:25:04,374 - INFO - Prediction inputs for Bangladesh in 2019: Year=2019, AL Moving_Avg_2Y=71.1405129659388, AL Moving_Avg_3Y=71.13255521036085, AL Moving_Avg_5Y=71.12168590475477, AL Moving_Avg_10Y=71.09411563277305
# 2024-11-19 16:25:04,376 - INFO - Predicted value for Bangladesh in 2019: 71.15201039447146
# 2024-11-19 16:25:04,376 - INFO - Processing country: Barbados
# 2024-11-19 16:25:04,376 - INFO - Prediction inputs for Barbados in 2010: Year=2010, AL Moving_Avg_2Y=37.2093023255814, AL Moving_Avg_3Y=37.2093023255814, AL Moving_Avg_5Y=37.2093023255814, AL Moving_Avg_10Y=38.604651162790695
# 2024-11-19 16:25:04,378 - INFO - Predicted value for Barbados in 2010: 37.180345760906214
# 2024-11-19 16:25:04,379 - INFO - Prediction inputs for Barbados in 2011: Year=2011, AL Moving_Avg_2Y=37.194824043243806, AL Moving_Avg_3Y=37.189997949131275, AL Moving_Avg_5Y=37.18613707384125, AL Moving_Avg_10Y=37.183241417373736
# 2024-11-19 16:25:04,381 - INFO - Predicted value for Barbados in 2011: 37.154215680123144
# 2024-11-19 16:25:04,381 - INFO - Prediction inputs for Barbados in 2012: Year=2012, AL Moving_Avg_2Y=37.16728072051468, AL Moving_Avg_3Y=37.18128792220359, AL Moving_Avg_5Y=37.170459025371414, AL Moving_Avg_10Y=37.162337352747286
# 2024-11-19 16:25:04,383 - INFO - Predicted value for Barbados in 2012: 37.155886458937744
# 2024-11-19 16:25:04,383 - INFO - Prediction inputs for Barbados in 2013: Year=2013, AL Moving_Avg_2Y=37.155051069530444, AL Moving_Avg_3Y=37.16348263332237, AL Moving_Avg_5Y=37.17112733689725, AL Moving_Avg_10Y=37.1635068979175
# 2024-11-19 16:25:04,385 - INFO - Predicted value for Barbados in 2013: 37.14275119744215
# 2024-11-19 16:25:04,385 - INFO - Prediction inputs for Barbados in 2014: Year=2014, AL Moving_Avg_2Y=37.14931882818995, AL Moving_Avg_3Y=37.15095111216768, AL Moving_Avg_5Y=37.168500284598124, AL Moving_Avg_10Y=37.15562574102014
# 2024-11-19 16:25:04,387 - INFO - Predicted value for Barbados in 2014: 37.150789376220395
# 2024-11-19 16:25:04,387 - INFO - Prediction inputs for Barbados in 2015: Year=2015, AL Moving_Avg_2Y=37.14677028683127, AL Moving_Avg_3Y=37.14980901086676, AL Moving_Avg_5Y=37.15679769472593, AL Moving_Avg_10Y=37.15964483040927
# 2024-11-19 16:25:04,389 - INFO - Predicted value for Barbados in 2015: 37.14992626296188
# ...
# 2024-11-19 16:25:08,963 - INFO - Prediction inputs for Venezuela, RB in 2011: Year=2011, AL Moving_Avg_2Y=24.396638512556002, AL Moving_Avg_3Y=24.40383954046447, AL Moving_Avg_5Y=24.409600362791245, AL Moving_Avg_10Y=24.41392097953633
# 2024-11-19 16:25:08,965 - INFO - Predicted value for Venezuela, RB in 2011: 24.423209396602434
# 2024-11-19 16:25:08,965 - INFO - Prediction inputs for Venezuela, RB in 2012: Year=2012, AL Moving_Avg_2Y=24.42072549644192, AL Moving_Avg_3Y=24.40549547390481, AL Moving_Avg_5Y=24.412581042983863, AL Moving_Avg_10Y=24.41789521979315
# 2024-11-19 16:25:08,978 - INFO - Predicted value for Venezuela, RB in 2012: 24.420539838360174
# 2024-11-19 16:25:08,982 - INFO - Prediction inputs for Venezuela, RB in 2013: Year=2013, AL Moving_Avg_2Y=24.421874617481304, AL Moving_Avg_3Y=24.420663610414675, AL Moving_Avg_5Y=24.411513219686956, AL Moving_Avg_10Y=24.416026529023565
# 2024-11-19 16:25:08,985 - INFO - Predicted value for Venezuela, RB in 2013: 24.422214533020988
# 2024-11-19 16:25:08,985 - INFO - Prediction inputs for Venezuela, RB in 2014: Year=2014, AL Moving_Avg_2Y=24.42137718569058, AL Moving_Avg_3Y=24.4219879226612, AL Moving_Avg_5Y=24.41184815861912, AL Moving_Avg_10Y=24.417031345820057
# 2024-11-19 16:25:08,987 - INFO - Predicted value for Venezuela, RB in 2014: 24.422214533020988
# 2024-11-19 16:25:08,988 - INFO - Prediction inputs for Venezuela, RB in 2015: Year=2015, AL Moving_Avg_2Y=24.422214533020988, AL Moving_Avg_3Y=24.421656301467383, AL Moving_Avg_5Y=24.4212839794572, AL Moving_Avg_10Y=24.417031345820057
# 2024-11-19 16:25:08,990 - INFO - Predicted value for Venezuela, RB in 2015: 24.420539838360174
# 2024-11-19 16:25:08,990 - INFO - Prediction inputs for Venezuela, RB in 2016: Year=2016, AL Moving_Avg_2Y=24.42137718569058, AL Moving_Avg_3Y=24.421656301467383, AL Moving_Avg_5Y=24.42174362787295, AL Moving_Avg_10Y=24.41636146795573
# 2024-11-19 16:25:08,993 - INFO - Predicted value for Venezuela, RB in 2016: 24.420539838360174
# 2024-11-19 16:25:08,993 - INFO - Prediction inputs for Venezuela, RB in 2017: Year=2017, AL Moving_Avg_2Y=24.420539838360174, AL Moving_Avg_3Y=24.42109806991378, AL Moving_Avg_5Y=24.4212097162245, AL Moving_Avg_10Y=24.41636146795573
# 2024-11-19 16:25:08,997 - INFO - Predicted value for Venezuela, RB in 2017: 24.420539838360174
# 2024-11-19 16:25:08,999 - INFO - Prediction inputs for Venezuela, RB in 2018: Year=2018, AL Moving_Avg_2Y=24.420539838360174, AL Moving_Avg_3Y=24.420539838360174, AL Moving_Avg_5Y=24.4212097162245, AL Moving_Avg_10Y=24.41636146795573
# 2024-11-19 16:25:09,002 - INFO - Predicted value for Venezuela, RB in 2018: 24.420539838360174
# 2024-11-19 16:25:09,003 - INFO - Prediction inputs for Venezuela, RB in 2019: Year=2019, AL Moving_Avg_2Y=24.420539838360174, AL Moving_Avg_3Y=24.420539838360174, AL Moving_Avg_5Y=24.420874777292333, AL Moving_Avg_10Y=24.41636146795573
# 2024-11-19 16:25:09,006 - INFO - Predicted value for Venezuela, RB in 2019: 24.420539838360174
# 2024-11-19 16:25:09,007 - INFO - Processing country: Vietnam
# 2024-11-19 16:25:09,007 - INFO - Prediction inputs for Vietnam in 2010: Year=2010, AL Moving_Avg_2Y=32.8233893519142, AL Moving_Avg_3Y=32.61370781114886, AL Moving_Avg_5Y=32.4397540810856, AL Moving_Avg_10Y=31.37031059438945
# 2024-11-19 16:25:09,009 - INFO - Predicted value for Vietnam in 2010: 32.893467846144716
# 2024-11-19 16:25:09,010 - INFO - Prediction inputs for Vietnam in 2011: Year=2011, AL Moving_Avg_2Y=32.90013938793061, AL Moving_Avg_3Y=32.89791554066864, AL Moving_Avg_5Y=32.896136462859076, AL Moving_Avg_10Y=32.894802154501896
# 2024-11-19 16:25:09,012 - INFO - Predicted value for Vietnam in 2011: 33.13740386015378
# 2024-11-19 16:25:09,012 - INFO - Prediction inputs for Vietnam in 2012: Year=2012, AL Moving_Avg_2Y=33.01543585314925, AL Moving_Avg_3Y=32.97922754533833, AL Moving_Avg_5Y=33.04249807126452, AL Moving_Avg_10Y=33.08995096570915
# 2024-11-19 16:25:09,014 - INFO - Predicted value for Vietnam in 2012: 33.18713760418134
# 2024-11-19 16:25:09,015 - INFO - Prediction inputs for Vietnam in 2013: Year=2013, AL Moving_Avg_2Y=33.162270732167556, AL Moving_Avg_3Y=33.07266977015994, AL Moving_Avg_5Y=33.06239156887554, AL Moving_Avg_10Y=33.12476458652843
# 2024-11-19 16:25:09,017 - INFO - Predicted value for Vietnam in 2013: 33.27746415541745
# 2024-11-19 16:25:09,017 - INFO - Prediction inputs for Vietnam in 2014: Year=2014, AL Moving_Avg_2Y=33.232300879799396, AL Moving_Avg_3Y=33.20066853991752, AL Moving_Avg_5Y=33.08045687912276, AL Moving_Avg_10Y=33.178960517270106
# 2024-11-19 16:25:09,020 - INFO - Predicted value for Vietnam in 2014: 33.31886816130888
# 2024-11-19 16:25:09,020 - INFO - Prediction inputs for Vietnam in 2015: Year=2015, AL Moving_Avg_2Y=33.29816615836316, AL Moving_Avg_3Y=33.26115664030255, AL Moving_Avg_5Y=33.16286832544123, AL Moving_Avg_10Y=33.199662520215824
# 2024-11-19 16:25:09,022 - INFO - Predicted value for Vietnam in 2015: 33.40979984703621
# 2024-11-19 16:25:09,023 - INFO - Prediction inputs for Vietnam in 2016: Year=2016, AL Moving_Avg_2Y=33.36433400417255, AL Moving_Avg_3Y=33.33537738792084, AL Moving_Avg_5Y=33.26613472561953, AL Moving_Avg_10Y=33.236035194506755
# 2024-11-19 16:25:09,025 - INFO - Predicted value for Vietnam in 2016: 33.3598005439702
# 2024-11-19 16:25:09,025 - INFO - Prediction inputs for Vietnam in 2017: Year=2017, AL Moving_Avg_2Y=33.3848001955032, AL Moving_Avg_3Y=33.36282285077177, AL Moving_Avg_5Y=33.31061406238282, AL Moving_Avg_10Y=33.22103540358695
# 2024-11-19 16:25:09,027 - INFO - Predicted value for Vietnam in 2017: 33.3598005439702
# 2024-11-19 16:25:09,028 - INFO - Prediction inputs for Vietnam in 2018: Year=2018, AL Moving_Avg_2Y=33.3598005439702, AL Moving_Avg_3Y=33.37646697832554, AL Moving_Avg_5Y=33.34514665034059, AL Moving_Avg_10Y=33.22103540358695
# 2024-11-19 16:25:09,030 - INFO - Predicted value for Vietnam in 2018: 33.339697282267636
# 2024-11-19 16:25:09,030 - INFO - Prediction inputs for Vietnam in 2019: Year=2019, AL Moving_Avg_2Y=33.349748913118916, AL Moving_Avg_3Y=33.35309945673601, AL Moving_Avg_5Y=33.357593275710634, AL Moving_Avg_10Y=33.219025077416696
# 2024-11-19 16:25:09,033 - INFO - Predicted value for Vietnam in 2019: 33.33502705299186
# 2024-11-19 16:25:09,034 - INFO - Processing country: Yemen, Rep.
# 2024-11-19 16:25:09,034 - INFO - Prediction inputs for Yemen, Rep. in 2010: Year=2010, AL Moving_Avg_2Y=44.48074701214085, AL Moving_Avg_3Y=44.57071424512756, AL Moving_Avg_5Y=44.603291853703794, AL Moving_Avg_10Y=44.64609731613538
# 2024-11-19 16:25:09,036 - INFO - Predicted value for Yemen, Rep. in 2010: 44.45846840795674
# 2024-11-19 16:25:09,037 - INFO - Prediction inputs for Yemen, Rep. in 2011: Year=2011, AL Moving_Avg_2Y=44.43882944613227, AL Moving_Avg_3Y=44.445375766740426, AL Moving_Avg_5Y=44.45061282322695, AL Moving_Avg_10Y=44.454540615591846
# 2024-11-19 16:25:09,038 - INFO - Predicted value for Yemen, Rep. in 2011: 44.49253909710081
# 2024-11-19 16:25:09,039 - INFO - Prediction inputs for Yemen, Rep. in 2012: Year=2012, AL Moving_Avg_2Y=44.47550375252877, AL Moving_Avg_3Y=44.456732663121784, AL Moving_Avg_5Y=44.47105523671339, AL Moving_Avg_10Y=44.4817971669071
# 2024-11-19 16:25:09,041 - INFO - Predicted value for Yemen, Rep. in 2012: 44.569060845583515
# 2024-11-19 16:25:09,041 - INFO - Prediction inputs for Yemen, Rep. in 2013: Year=2013, AL Moving_Avg_2Y=44.53079997134216, AL Moving_Avg_3Y=44.506689450213685, AL Moving_Avg_5Y=44.501663936106475, AL Moving_Avg_10Y=44.535362390844995
# 2024-11-19 16:25:09,043 - INFO - Predicted value for Yemen, Rep. in 2013: 44.56801543431678
# 2024-11-19 16:25:09,044 - INFO - Prediction inputs for Yemen, Rep. in 2014: Year=2014, AL Moving_Avg_2Y=44.56853813995015, AL Moving_Avg_3Y=44.543205125667036, AL Moving_Avg_5Y=44.50145485385313, AL Moving_Avg_10Y=44.53473514408495
# 2024-11-19 16:25:09,046 - INFO - Predicted value for Yemen, Rep. in 2014: 44.59861499726403
# 2024-11-19 16:25:09,046 - INFO - Prediction inputs for Yemen, Rep. in 2015: Year=2015, AL Moving_Avg_2Y=44.58331521579041, AL Moving_Avg_3Y=44.57856375905478, AL Moving_Avg_5Y=44.537339756444375, AL Moving_Avg_10Y=44.55003492555858
# 2024-11-19 16:25:09,048 - INFO - Predicted value for Yemen, Rep. in 2015: 44.59328442747552
# 2024-11-19 16:25:09,049 - INFO - Prediction inputs for Yemen, Rep. in 2016: Year=2016, AL Moving_Avg_2Y=44.59594971236977, AL Moving_Avg_3Y=44.586638286352105, AL Moving_Avg_5Y=44.56430296034813, AL Moving_Avg_10Y=44.54790269764317
# 2024-11-19 16:25:09,051 - INFO - Predicted value for Yemen, Rep. in 2016: 44.57697353471673
# 2024-11-19 16:25:09,051 - INFO - Prediction inputs for Yemen, Rep. in 2017: Year=2017, AL Moving_Avg_2Y=44.58512898109612, AL Moving_Avg_3Y=44.58962431981876, AL Moving_Avg_5Y=44.581189847871315, AL Moving_Avg_10Y=44.543009429815534
# 2024-11-19 16:25:09,054 - INFO - Predicted value for Yemen, Rep. in 2017: 44.580480669686246
# 2024-11-19 16:25:09,054 - INFO - Prediction inputs for Yemen, Rep. in 2018: Year=2018, AL Moving_Avg_2Y=44.57872710220148, AL Moving_Avg_3Y=44.583579543959495, AL Moving_Avg_5Y=44.58347381269186, AL Moving_Avg_10Y=44.54371085680944
# 2024-11-19 16:25:09,056 - INFO - Predicted value for Yemen, Rep. in 2018: 44.58347955996358
# 2024-11-19 16:25:09,056 - INFO - Prediction inputs for Yemen, Rep. in 2019: Year=2019, AL Moving_Avg_2Y=44.581980114824916, AL Moving_Avg_3Y=44.58031125478885, AL Moving_Avg_5Y=44.586566637821214, AL Moving_Avg_10Y=44.54401074583718
# 2024-11-19 16:25:09,059 - INFO - Predicted value for Yemen, Rep. in 2019: 44.58049961015635
# 2024-11-19 16:25:09,060 - INFO - Processing country: Zambia
# 2024-11-19 16:25:09,061 - INFO - Prediction inputs for Zambia in 2010: Year=2010, AL Moving_Avg_2Y=31.3920015066116, AL Moving_Avg_3Y=31.2339418071268, AL Moving_Avg_5Y=31.064986077294538, AL Moving_Avg_10Y=30.800790971091892
# 2024-11-19 16:25:09,063 - INFO - Predicted value for Zambia in 2010: 31.61636217200808
# 2024-11-19 16:25:09,064 - INFO - Prediction inputs for Zambia in 2011: Year=2011, AL Moving_Avg_2Y=31.671994158550092, AL Moving_Avg_3Y=31.653450163036087, AL Moving_Avg_5Y=31.638614966624885, AL Moving_Avg_10Y=31.627488569316483
# 2024-11-19 16:25:09,066 - INFO - Predicted value for Zambia in 2011: 31.809190665831892
# 2024-11-19 16:25:09,067 - INFO - Prediction inputs for Zambia in 2012: Year=2012, AL Moving_Avg_2Y=31.712776418919987, AL Moving_Avg_3Y=31.717726327644026, AL Moving_Avg_5Y=31.754312062919173, AL Moving_Avg_10Y=31.78175136437553
# 2024-11-19 16:25:09,069 - INFO - Predicted value for Zambia in 2012: 31.848535137515906
# 2024-11-19 16:25:09,069 - INFO - Prediction inputs for Zambia in 2013: Year=2013, AL Moving_Avg_2Y=31.8288629016739, AL Moving_Avg_3Y=31.758029325118628, AL Moving_Avg_5Y=31.77004985159278, AL Moving_Avg_10Y=31.80929249455434
# 2024-11-19 16:25:09,071 - INFO - Predicted value for Zambia in 2013: 31.745328150910158
# 2024-11-19 16:25:09,071 - INFO - Prediction inputs for Zambia in 2014: Year=2014, AL Moving_Avg_2Y=31.796931644213032, AL Moving_Avg_3Y=31.80101798475265, AL Moving_Avg_5Y=31.749408454271627, AL Moving_Avg_10Y=31.747368302590893
# 2024-11-19 16:25:09,073 - INFO - Predicted value for Zambia in 2014: 31.666504155163725
# 2024-11-19 16:25:09,074 - INFO - Prediction inputs for Zambia in 2015: Year=2015, AL Moving_Avg_2Y=31.70591615303694, AL Moving_Avg_3Y=31.75345581452993, AL Moving_Avg_5Y=31.73718405628595, AL Moving_Avg_10Y=31.70795630471768
# 2024-11-19 16:25:09,075 - INFO - Predicted value for Zambia in 2015: 31.83132386760549
# 2024-11-19 16:25:09,076 - INFO - Prediction inputs for Zambia in 2016: Year=2016, AL Moving_Avg_2Y=31.748914011384606, AL Moving_Avg_3Y=31.747718724559792, AL Moving_Avg_5Y=31.78017639540543, AL Moving_Avg_10Y=31.77388418969438
# 2024-11-19 16:25:09,078 - INFO - Predicted value for Zambia in 2016: 31.77272730566691
# 2024-11-19 16:25:09,078 - INFO - Prediction inputs for Zambia in 2017: Year=2017, AL Moving_Avg_2Y=31.802025586636198, AL Moving_Avg_3Y=31.75685177614537, AL Moving_Avg_5Y=31.772883723372438, AL Moving_Avg_10Y=31.756305221112807
# 2024-11-19 16:25:09,082 - INFO - Predicted value for Zambia in 2017: 31.663131387801517
# 2024-11-19 16:25:09,083 - INFO - Prediction inputs for Zambia in 2018: Year=2018, AL Moving_Avg_2Y=31.717929346734213, AL Moving_Avg_3Y=31.75572752035797, AL Moving_Avg_5Y=31.73580297342956, AL Moving_Avg_10Y=31.73438603753973
# 2024-11-19 16:25:09,084 - INFO - Predicted value for Zambia in 2018: 31.83132386760549
# 2024-11-19 16:25:09,085 - INFO - Prediction inputs for Zambia in 2019: Year=2019, AL Moving_Avg_2Y=31.747227627703502, AL Moving_Avg_3Y=31.755727520357976, AL Moving_Avg_5Y=31.753002116768624, AL Moving_Avg_10Y=31.751205285520125
# 2024-11-19 16:25:09,086 - INFO - Predicted value for Zambia in 2019: 31.77626700748648
# 2024-11-19 16:25:09,088 - INFO - Processing country: Zimbabwe
# 2024-11-19 16:25:09,089 - INFO - Prediction inputs for Zimbabwe in 2010: Year=2010, AL Moving_Avg_2Y=42.32906811425615, AL Moving_Avg_3Y=42.178277540821135, AL Moving_Avg_5Y=42.05764508207314, AL Moving_Avg_10Y=41.04174744733101
# 2024-11-19 16:25:09,091 - INFO - Predicted value for Zimbabwe in 2010: 42.18240269080113
# 2024-11-19 16:25:09,092 - INFO - Prediction inputs for Zimbabwe in 2011: Year=2011, AL Moving_Avg_2Y=42.15879860532041, AL Moving_Avg_3Y=42.16666663381398, AL Moving_Avg_5Y=42.17296105660885, AL Moving_Avg_10Y=42.17768187370499
# 2024-11-19 16:25:09,094 - INFO - Predicted value for Zimbabwe in 2011: 42.02186267763445
# 2024-11-19 16:25:09,094 - INFO - Prediction inputs for Zimbabwe in 2012: Year=2012, AL Moving_Avg_2Y=42.10213268421779, AL Moving_Avg_3Y=42.11315329609176, AL Moving_Avg_5Y=42.07663704870884, AL Moving_Avg_10Y=42.049249863171646
# 2024-11-19 16:25:09,097 - INFO - Predicted value for Zimbabwe in 2012: 42.14430879022714
# 2024-11-19 16:25:09,097 - INFO - Prediction inputs for Zimbabwe in 2013: Year=2013, AL Moving_Avg_2Y=42.0830857339308, AL Moving_Avg_3Y=42.11619138622091, AL Moving_Avg_5Y=42.12561549374591, AL Moving_Avg_10Y=42.13496214198652
# 2024-11-19 16:25:09,099 - INFO - Predicted value for Zimbabwe in 2013: 42.12088809331642
# 2024-11-19 16:25:09,100 - INFO - Prediction inputs for Zimbabwe in 2014: Year=2014, AL Moving_Avg_2Y=42.132598441771776, AL Moving_Avg_3Y=42.09568652039267, AL Moving_Avg_5Y=42.12093135436377, AL Moving_Avg_10Y=42.12090972384009
# 2024-11-19 16:25:09,102 - INFO - Predicted value for Zimbabwe in 2014: 42.07622645256866
# 2024-11-19 16:25:09,103 - INFO - Prediction inputs for Zimbabwe in 2015: Year=2015, AL Moving_Avg_2Y=42.09855727294254, AL Moving_Avg_3Y=42.11380777870407, AL Moving_Avg_5Y=42.10913774090956, AL Moving_Avg_10Y=42.09857890346621
# 2024-11-19 16:25:09,105 - INFO - Predicted value for Zimbabwe in 2015: 42.146567551348824
# 2024-11-19 16:25:09,105 - INFO - Prediction inputs for Zimbabwe in 2016: Year=2016, AL Moving_Avg_2Y=42.11139700195874, AL Moving_Avg_3Y=42.11456069907797, AL Moving_Avg_5Y=42.1019707130191, AL Moving_Avg_10Y=42.12671534297828
# 2024-11-19 16:25:09,108 - INFO - Predicted value for Zimbabwe in 2016: 42.13565447268404
# 2024-11-19 16:25:09,109 - INFO - Prediction inputs for Zimbabwe in 2017: Year=2017, AL Moving_Avg_2Y=42.14111101201643, AL Moving_Avg_3Y=42.119482825533844, AL Moving_Avg_5Y=42.12472907202901, AL Moving_Avg_10Y=42.12344141937885
# 2024-11-19 16:25:09,111 - INFO - Predicted value for Zimbabwe in 2017: 42.163416043695825
# 2024-11-19 16:25:09,111 - INFO - Prediction inputs for Zimbabwe in 2018: Year=2018, AL Moving_Avg_2Y=42.14953525818993, AL Moving_Avg_3Y=42.14854602257623, AL Moving_Avg_5Y=42.12855052272276, AL Moving_Avg_10Y=42.1289937335812
# 2024-11-19 16:25:09,113 - INFO - Predicted value for Zimbabwe in 2018: 42.15359695249481
# 2024-11-19 16:25:09,113 - INFO - Prediction inputs for Zimbabwe in 2019: Year=2019, AL Moving_Avg_2Y=42.15850649809532, AL Moving_Avg_3Y=42.150889156291555, AL Moving_Avg_5Y=42.13509229455843, AL Moving_Avg_10Y=42.1280118244611
# 2024-11-19 16:25:09,115 - INFO - Predicted value for Zimbabwe in 2019: 42.060750269928995

# %%
for country, predictions in country_recursive_predictions_rf.items():
    predicted_years = list(predictions.keys())
    predicted_values = list(predictions.values())

    # Extract actual values from selected_df for the specified prediction years
    actual_data = selected_df_2[(selected_df_2['Country Name'] == country) & (selected_df_2['Year'].isin(predicted_years))]
    actual_values = actual_data['Agricultural land (% of land area)'].values

    # Ensure no NaN or inf values in actual and predicted values
    if len(actual_values) == len(predicted_values):
        actual_values_clean = np.array(actual_values)
        predicted_values_clean = np.array(predicted_values)
        
        # Filter out any NaN or inf values
        valid_indices = ~np.isnan(actual_values_clean) & ~np.isinf(actual_values_clean) & \
                        ~np.isnan(predicted_values_clean) & ~np.isinf(predicted_values_clean)
        actual_values_clean = actual_values_clean[valid_indices]
        predicted_values_clean = predicted_values_clean[valid_indices]

        # Append clean values to the overall lists
        all_actual_values.extend(actual_values_clean)
        all_predicted_values.extend(predicted_values_clean)

# Calculate overall metrics across all countries
if len(all_actual_values) > 0:
    overall_mae = mean_absolute_error(all_actual_values, all_predicted_values)
    overall_mse = mean_squared_error(all_actual_values, all_predicted_values)
    overall_rmse = np.sqrt(overall_mse)
    overall_r2 = r2_score(all_actual_values, all_predicted_values)

else:
    logger.warning("No valid values available for metric calculation.")

# Displaying the overall metrics
print(f"Overall Mean Absolute Error (MAE): {overall_mae:.2f}")
print(f"Overall Mean Squared Error (MSE): {overall_mse:.2f}")
print(f"Overall Root Mean Squared Error (RMSE): {overall_rmse:.2f}")
print(f"Overall R-squared (R²): {overall_r2:.2f}")
# Out:
# Overall Mean Absolute Error (MAE): 1.46
# Overall Mean Squared Error (MSE): 6.69
# Overall Root Mean Squared Error (RMSE): 2.59
# Overall R-squared (R²): 0.99

# %%
# Initialize lists to collect all actual, predicted values, and years across countries
all_actual_values = []
all_predicted_values = []
all_years = []

for country, predictions in country_recursive_predictions_rf.items():
    # Get predictions and corresponding years
    predicted_years = [year for year in predictions.keys() if year >= 2010]
    predicted_values = [predictions[year] for year in predicted_years]

    # Extract actual values from selected_df for the specified prediction years
    actual_data = selected_df_2[(selected_df_2['Country Name'] == country) & (selected_df_2['Year'].isin(predicted_years))]
    actual_values = actual_data['Agricultural land (% of land area)'].values
    years = actual_data['Year'].values

    # Ensure no NaN or inf values in actual and predicted values
    if len(actual_values) == len(predicted_values):
        actual_values_clean = np.array(actual_values)
        predicted_values_clean = np.array(predicted_values)
        
        # Filter out any NaN or inf values
        valid_indices = ~np.isnan(actual_values_clean) & ~np.isinf(actual_values_clean) & \
                        ~np.isnan(predicted_values_clean) & ~np.isinf(predicted_values_clean)
        
        actual_values_clean = actual_values_clean[valid_indices]
        predicted_values_clean = predicted_values_clean[valid_indices]
        years_clean = years[valid_indices]

        # Append clean values from 2010 onward to the overall lists
        all_actual_values.extend(actual_values_clean)
        all_predicted_values.extend(predicted_values_clean)
        all_years.extend(years_clean)

# Create a DataFrame for easier plotting with hue
plot_data = pd.DataFrame({
    'Actual': all_actual_values,
    'Predicted': all_predicted_values,
    'Residuals': np.array(all_actual_values) - np.array(all_predicted_values),
    'Year': all_years
})

# %%
# Function to plot predictions vs actual values for a test country
# Useful for visual assessment of accuracy of the model

# Redefining test_df based on the years 2010-2019 from selected_df
test_df = selected_df_2[(selected_df_2['Year'] >= 2010) & (selected_df_2['Year'] <= 2019)].dropna(subset=['Agricultural land (% of land area)'])

# Rerun the plotting function for Kenya as an example
plot_country_predictions_vs_actual("United States", "Agricultural land (% of land area)")

# %%
# Define year variables for training and prediction
TRAIN_START_YEAR = 2000
TRAIN_END_YEAR = 2019
PREDICTION_START_YEAR = 2019
PREDICTION_END_YEAR = 2030

# Setting up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Splitting data into training (2000-2019) set and setting up prediction years
train_df = selected_df_2[(selected_df_2['Year'] >= TRAIN_START_YEAR) & (selected_df_2['Year'] <= TRAIN_END_YEAR)].dropna(subset=['Agricultural land (% of land area)'])
prediction_years = range(PREDICTION_START_YEAR, PREDICTION_END_YEAR + 1)

# Preparing training data for the model
X_train = train_df[['Year', 'AL Moving_Avg_2Y', 'AL Moving_Avg_3Y', 'AL Moving_Avg_5Y', 'AL Moving_Avg_10Y']].values
y_train = train_df['Agricultural land (% of land area)'].values

# Initializing and training the Random Forest model on all training data
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)
logger.info(f"Model trained on all countries' data ({TRAIN_START_YEAR}-{TRAIN_END_YEAR}). Starting recursive forecasting.")

# Dictionary to store predictions for each country
country_recursive_predictions_rf = {}

# Recursive forecasting for each country separately with detailed logging
for country in train_df['Country Name'].unique():
    logger.info(f"Processing country: {country}")

    # Get the last available data point for the country to start recursive prediction
    country_data = train_df[train_df['Country Name'] == country].iloc[-1].copy()
    predictions_per_country = {country_data['Year']: country_data['Agricultural land (% of land area)']}

    # Recursive prediction loop from PREDICTION_START_YEAR to PREDICTION_END_YEAR
    for year in prediction_years:
        country_data['Year'] = year
        
        # Logging the input data used for this prediction
        logger.info(f"Prediction inputs for {country} in {year}: Year={year}, "
                    f"AL Moving_Avg_2Y={country_data['AL Moving_Avg_2Y']}, "
                    f"AL Moving_Avg_3Y={country_data['AL Moving_Avg_3Y']}, "
                    f"AL Moving_Avg_5Y={country_data['AL Moving_Avg_5Y']}, "
                    f"AL Moving_Avg_10Y={country_data['AL Moving_Avg_10Y']}")
        
        # Preparing the features for the current prediction
        X_test = country_data[['Year', 'AL Moving_Avg_2Y', 'AL Moving_Avg_3Y', 'AL Moving_Avg_5Y', 'AL Moving_Avg_10Y']].values.reshape(1, -1)
        
        # Predicting agricultural land use for the current year
        predicted_value = model_rf.predict(X_test)[0]
        logger.info(f"Predicted value for {country} in {year}: {predicted_value}")
        
        # Update the prediction in the dictionary
        predictions_per_country[year] = predicted_value
        
        # Update the features for the next prediction year based on the new prediction
        country_data['Agricultural land (% of land area)'] = predicted_value
        country_data['AL Moving_Avg_2Y'] = (predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 2
        country_data['AL Moving_Avg_3Y'] = (predictions_per_country.get(year - 2, predicted_value) +
                                         predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 3
        country_data['AL Moving_Avg_5Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 4, year + 1)) / 5)
        country_data['AL Moving_Avg_10Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 9, year + 1)) / 10)

    # Store the predictions for the country
    country_recursive_predictions_rf[country] = predictions_per_country
# Out:
# 2024-11-19 16:25:10,350 - INFO - Model trained on all countries' data (2000-2019). Starting recursive forecasting.
# 2024-11-19 16:25:10,351 - INFO - Processing country: Afghanistan
# 2024-11-19 16:25:10,352 - INFO - Prediction inputs for Afghanistan in 2019: Year=2019, AL Moving_Avg_2Y=58.2769881790166, AL Moving_Avg_3Y=58.22588146308306, AL Moving_Avg_5Y=58.184996090336234, AL Moving_Avg_10Y=58.156785183140926
# 2024-11-19 16:25:10,354 - INFO - Predicted value for Afghanistan in 2019: 58.312729703808735
# 2024-11-19 16:25:10,355 - INFO - Prediction inputs for Afghanistan in 2020: Year=2020, AL Moving_Avg_2Y=58.312729703808735, AL Moving_Avg_3Y=58.312729703808735, AL Moving_Avg_5Y=58.312729703808735, AL Moving_Avg_10Y=58.31272970380873
# 2024-11-19 16:25:10,357 - INFO - Predicted value for Afghanistan in 2020: 58.38285559270273
# 2024-11-19 16:25:10,357 - INFO - Prediction inputs for Afghanistan in 2021: Year=2021, AL Moving_Avg_2Y=58.347792648255734, AL Moving_Avg_3Y=58.35948029640473, AL Moving_Avg_5Y=58.368830414923934, AL Moving_Avg_10Y=58.37584300381334
# 2024-11-19 16:25:10,359 - INFO - Predicted value for Afghanistan in 2021: 58.44485410669546
# 2024-11-19 16:25:10,359 - INFO - Prediction inputs for Afghanistan in 2022: Year=2022, AL Moving_Avg_2Y=58.41385484969909, AL Moving_Avg_3Y=58.38014646773564, AL Moving_Avg_5Y=58.40602952331957, AL Moving_Avg_10Y=58.4254418150075
# 2024-11-19 16:25:10,361 - INFO - Predicted value for Afghanistan in 2022: 58.4751745631404
# 2024-11-19 16:25:10,361 - INFO - Prediction inputs for Afghanistan in 2023: Year=2023, AL Moving_Avg_2Y=58.46001433491793, AL Moving_Avg_3Y=58.434294754179525, AL Moving_Avg_5Y=58.41815770589754, AL Moving_Avg_10Y=58.44666613451898
# 2024-11-19 16:25:10,363 - INFO - Predicted value for Afghanistan in 2023: 58.46087642358617
# 2024-11-19 16:25:10,364 - INFO - Prediction inputs for Afghanistan in 2024: Year=2024, AL Moving_Avg_2Y=58.468025493363285, AL Moving_Avg_3Y=58.460301697807346, AL Moving_Avg_5Y=58.4152980779867, AL Moving_Avg_10Y=58.43808725078643
# 2024-11-19 16:25:10,366 - INFO - Predicted value for Afghanistan in 2024: 58.436175230515204
# 2024-11-19 16:25:10,366 - INFO - Prediction inputs for Afghanistan in 2025: Year=2025, AL Moving_Avg_2Y=58.44852582705069, AL Moving_Avg_3Y=58.45740873908059, AL Moving_Avg_5Y=58.43998718332799, AL Moving_Avg_10Y=58.425736654250954
# 2024-11-19 16:25:10,368 - INFO - Predicted value for Afghanistan in 2025: 58.448261747573746
# 2024-11-19 16:25:10,368 - INFO - Prediction inputs for Afghanistan in 2026: Year=2026, AL Moving_Avg_2Y=58.44221848904448, AL Moving_Avg_3Y=58.448437800558374, AL Moving_Avg_5Y=58.453068414302194, AL Moving_Avg_10Y=58.43057126107436
# 2024-11-19 16:25:10,370 - INFO - Predicted value for Afghanistan in 2026: 58.44145683996206
# 2024-11-19 16:25:10,370 - INFO - Prediction inputs for Afghanistan in 2027: Year=2027, AL Moving_Avg_2Y=58.444859293767905, AL Moving_Avg_3Y=58.441964606017, AL Moving_Avg_5Y=58.452388960955524, AL Moving_Avg_10Y=58.428529788790854
# 2024-11-19 16:25:10,372 - INFO - Predicted value for Afghanistan in 2027: 58.445249763611194
# 2024-11-19 16:25:10,372 - INFO - Prediction inputs for Afghanistan in 2028: Year=2028, AL Moving_Avg_2Y=58.44335330178663, AL Moving_Avg_3Y=58.44498945038234, AL Moving_Avg_5Y=58.44640400104968, AL Moving_Avg_10Y=58.429288373520684
# 2024-11-19 16:25:10,374 - INFO - Predicted value for Afghanistan in 2028: 58.44145683996206
# 2024-11-19 16:25:10,374 - INFO - Prediction inputs for Afghanistan in 2029: Year=2029, AL Moving_Avg_2Y=58.44335330178663, AL Moving_Avg_3Y=58.442721147845106, AL Moving_Avg_5Y=58.44252008432486, AL Moving_Avg_10Y=58.428909081155766
# 2024-11-19 16:25:10,376 - INFO - Predicted value for Afghanistan in 2029: 58.445249763611194
# 2024-11-19 16:25:10,376 - INFO - Prediction inputs for Afghanistan in 2030: Year=2030, AL Moving_Avg_2Y=58.44335330178663, AL Moving_Avg_3Y=58.44398545572815, AL Moving_Avg_5Y=58.44433499094405, AL Moving_Avg_10Y=58.442161087136014
# 2024-11-19 16:25:10,378 - INFO - Predicted value for Afghanistan in 2030: 58.44145683996206
# 2024-11-19 16:25:10,378 - INFO - Processing country: Albania
# 2024-11-19 16:25:10,379 - INFO - Prediction inputs for Albania in 2019: Year=2019, AL Moving_Avg_2Y=42.84819343065695, AL Moving_Avg_3Y=42.8511192214112, AL Moving_Avg_5Y=42.90775182481752, AL Moving_Avg_10Y=43.22464233576644
# 2024-11-19 16:25:10,381 - INFO - Predicted value for Albania in 2019: 42.87328030956756
# 2024-11-19 16:25:10,381 - INFO - Prediction inputs for Albania in 2020: Year=2020, AL Moving_Avg_2Y=42.87328030956756, AL Moving_Avg_3Y=42.873280309567555, AL Moving_Avg_5Y=42.87328030956756, AL Moving_Avg_10Y=42.87328030956757
# 2024-11-19 16:25:10,383 - INFO - Predicted value for Albania in 2020: 42.90622487321132
# 2024-11-19 16:25:10,383 - INFO - Prediction inputs for Albania in 2021: Year=2021, AL Moving_Avg_2Y=42.88975259138944, AL Moving_Avg_3Y=42.89524335199673, AL Moving_Avg_5Y=42.89963596048257, AL Moving_Avg_10Y=42.90293041684695
# 2024-11-19 16:25:10,385 - INFO - Predicted value for Albania in 2021: 42.888927869031825
# 2024-11-19 16:25:10,385 - INFO - Prediction inputs for Albania in 2022: Year=2022, AL Moving_Avg_2Y=42.89757637112157, AL Moving_Avg_3Y=42.889477683936896, AL Moving_Avg_5Y=42.889257757974875, AL Moving_Avg_10Y=42.88909281350335
# 2024-11-19 16:25:10,387 - INFO - Predicted value for Albania in 2022: 42.89270681599042
# 2024-11-19 16:25:10,387 - INFO - Prediction inputs for Albania in 2023: Year=2023, AL Moving_Avg_2Y=42.89081734251113, AL Moving_Avg_3Y=42.89595318607786, AL Moving_Avg_5Y=42.89076933675831, AL Moving_Avg_10Y=42.891738076374374
# 2024-11-19 16:25:10,389 - INFO - Predicted value for Albania in 2023: 42.888927869031825
# 2024-11-19 16:25:10,389 - INFO - Prediction inputs for Albania in 2024: Year=2024, AL Moving_Avg_2Y=42.89081734251113, AL Moving_Avg_3Y=42.890187518018024, AL Moving_Avg_5Y=42.890013547366586, AL Moving_Avg_10Y=42.889470708199205
# 2024-11-19 16:25:10,392 - INFO - Predicted value for Albania in 2024: 42.888927869031825
# 2024-11-19 16:25:10,392 - INFO - Prediction inputs for Albania in 2025: Year=2025, AL Moving_Avg_2Y=42.888927869031825, AL Moving_Avg_3Y=42.890187518018024, AL Moving_Avg_5Y=42.893143059259444, AL Moving_Avg_10Y=42.889470708199205
# 2024-11-19 16:25:10,394 - INFO - Predicted value for Albania in 2025: 42.888927869031825
# 2024-11-19 16:25:10,394 - INFO - Prediction inputs for Albania in 2026: Year=2026, AL Moving_Avg_2Y=42.888927869031825, AL Moving_Avg_3Y=42.888927869031825, AL Moving_Avg_5Y=42.88968365842354, AL Moving_Avg_10Y=42.889470708199205
# 2024-11-19 16:25:10,396 - INFO - Predicted value for Albania in 2026: 42.89270681599042
# 2024-11-19 16:25:10,396 - INFO - Prediction inputs for Albania in 2027: Year=2027, AL Moving_Avg_2Y=42.89081734251113, AL Moving_Avg_3Y=42.890187518018024, AL Moving_Avg_5Y=42.89043944781527, AL Moving_Avg_10Y=42.89060439228679
# 2024-11-19 16:25:10,398 - INFO - Predicted value for Albania in 2027: 42.888927869031825
# 2024-11-19 16:25:10,398 - INFO - Prediction inputs for Albania in 2028: Year=2028, AL Moving_Avg_2Y=42.89081734251113, AL Moving_Avg_3Y=42.890187518018024, AL Moving_Avg_5Y=42.88968365842354, AL Moving_Avg_10Y=42.88984860289507
# 2024-11-19 16:25:10,400 - INFO - Predicted value for Albania in 2028: 42.888927869031825
# 2024-11-19 16:25:10,400 - INFO - Prediction inputs for Albania in 2029: Year=2029, AL Moving_Avg_2Y=42.888927869031825, AL Moving_Avg_3Y=42.890187518018024, AL Moving_Avg_5Y=42.88968365842354, AL Moving_Avg_10Y=42.889848602895064
# 2024-11-19 16:25:10,402 - INFO - Predicted value for Albania in 2029: 42.888927869031825
# 2024-11-19 16:25:10,403 - INFO - Prediction inputs for Albania in 2030: Year=2030, AL Moving_Avg_2Y=42.888927869031825, AL Moving_Avg_3Y=42.888927869031825, AL Moving_Avg_5Y=42.88968365842354, AL Moving_Avg_10Y=42.89141335884149
# 2024-11-19 16:25:10,404 - INFO - Predicted value for Albania in 2030: 42.89270681599042
# 2024-11-19 16:25:10,405 - INFO - Processing country: Algeria
# 2024-11-19 16:25:10,405 - INFO - Prediction inputs for Algeria in 2019: Year=2019, AL Moving_Avg_2Y=17.35178606741875, AL Moving_Avg_3Y=17.35286098138573, AL Moving_Avg_5Y=17.366007588566497, AL Moving_Avg_10Y=17.37508710312469
# 2024-11-19 16:25:10,407 - INFO - Predicted value for Algeria in 2019: 17.350063071143634
# 2024-11-19 16:25:10,408 - INFO - Prediction inputs for Algeria in 2020: Year=2020, AL Moving_Avg_2Y=17.350063071143634, AL Moving_Avg_3Y=17.350063071143634, AL Moving_Avg_5Y=17.350063071143634, AL Moving_Avg_10Y=17.350063071143634
# 2024-11-19 16:25:10,409 - INFO - Predicted value for Algeria in 2020: 17.35349820529463
# 2024-11-19 16:25:10,410 - INFO - Prediction inputs for Algeria in 2021: Year=2021, AL Moving_Avg_2Y=17.351780638219132, AL Moving_Avg_3Y=17.352353160577632, AL Moving_Avg_5Y=17.35281117846443, AL Moving_Avg_10Y=17.35315469187953
# 2024-11-19 16:25:10,411 - INFO - Predicted value for Algeria in 2021: 17.3532205684415
# 2024-11-19 16:25:10,412 - INFO - Prediction inputs for Algeria in 2022: Year=2022, AL Moving_Avg_2Y=17.353359386868064, AL Moving_Avg_3Y=17.35226061495992, AL Moving_Avg_5Y=17.352644596352555, AL Moving_Avg_10Y=17.352932582397028
# 2024-11-19 16:25:10,414 - INFO - Predicted value for Algeria in 2022: 17.3532205684415
# 2024-11-19 16:25:10,414 - INFO - Prediction inputs for Algeria in 2023: Year=2023, AL Moving_Avg_2Y=17.3532205684415, AL Moving_Avg_3Y=17.35331311405921, AL Moving_Avg_5Y=17.352644596352555, AL Moving_Avg_10Y=17.352932582397028
# 2024-11-19 16:25:10,416 - INFO - Predicted value for Algeria in 2023: 17.352859301839864
# 2024-11-19 16:25:10,416 - INFO - Prediction inputs for Algeria in 2024: Year=2024, AL Moving_Avg_2Y=17.353039935140682, AL Moving_Avg_3Y=17.353100146240955, AL Moving_Avg_5Y=17.35257234303223, AL Moving_Avg_10Y=17.352715822436043
# 2024-11-19 16:25:10,418 - INFO - Predicted value for Algeria in 2024: 17.352859301839864
# 2024-11-19 16:25:10,418 - INFO - Prediction inputs for Algeria in 2025: Year=2025, AL Moving_Avg_2Y=17.352859301839864, AL Moving_Avg_3Y=17.35297972404041, AL Moving_Avg_5Y=17.353131589171472, AL Moving_Avg_10Y=17.352715822436046
# 2024-11-19 16:25:10,420 - INFO - Predicted value for Algeria in 2025: 17.352859301839864
# 2024-11-19 16:25:10,420 - INFO - Prediction inputs for Algeria in 2026: Year=2026, AL Moving_Avg_2Y=17.352859301839864, AL Moving_Avg_3Y=17.352859301839864, AL Moving_Avg_5Y=17.35300380848052, AL Moving_Avg_10Y=17.352715822436043
# 2024-11-19 16:25:10,422 - INFO - Predicted value for Algeria in 2026: 17.352859301839864
# 2024-11-19 16:25:10,422 - INFO - Prediction inputs for Algeria in 2027: Year=2027, AL Moving_Avg_2Y=17.352859301839864, AL Moving_Avg_3Y=17.352859301839864, AL Moving_Avg_5Y=17.35293155516019, AL Moving_Avg_10Y=17.352715822436043
# 2024-11-19 16:25:10,424 - INFO - Predicted value for Algeria in 2027: 17.352859301839864
# 2024-11-19 16:25:10,424 - INFO - Prediction inputs for Algeria in 2028: Year=2028, AL Moving_Avg_2Y=17.352859301839864, AL Moving_Avg_3Y=17.352859301839864, AL Moving_Avg_5Y=17.352859301839864, AL Moving_Avg_10Y=17.352715822436043
# 2024-11-19 16:25:10,426 - INFO - Predicted value for Algeria in 2028: 17.352859301839864
# 2024-11-19 16:25:10,426 - INFO - Prediction inputs for Algeria in 2029: Year=2029, AL Moving_Avg_2Y=17.352859301839864, AL Moving_Avg_3Y=17.352859301839864, AL Moving_Avg_5Y=17.352859301839864, AL Moving_Avg_10Y=17.352715822436043
# 2024-11-19 16:25:10,428 - INFO - Predicted value for Algeria in 2029: 17.352859301839864
# 2024-11-19 16:25:10,429 - INFO - Prediction inputs for Algeria in 2030: Year=2030, AL Moving_Avg_2Y=17.352859301839864, AL Moving_Avg_3Y=17.352859301839864, AL Moving_Avg_5Y=17.352859301839864, AL Moving_Avg_10Y=17.352995445505663
# 2024-11-19 16:25:10,430 - INFO - Predicted value for Algeria in 2030: 17.352859301839864
# 2024-11-19 16:25:10,431 - INFO - Processing country: Andorra
# 2024-11-19 16:25:10,431 - INFO - Prediction inputs for Andorra in 2019: Year=2019, AL Moving_Avg_2Y=40.03627659574465, AL Moving_Avg_3Y=40.03836879432623, AL Moving_Avg_5Y=40.03578723404256, AL Moving_Avg_10Y=40.42427659574468
# 2024-11-19 16:25:10,433 - INFO - Predicted value for Andorra in 2019: 40.00004521452722
# 2024-11-19 16:25:10,433 - INFO - Prediction inputs for Andorra in 2020: Year=2020, AL Moving_Avg_2Y=40.00004521452722, AL Moving_Avg_3Y=40.00004521452722, AL Moving_Avg_5Y=40.00004521452722, AL Moving_Avg_10Y=40.000045214527226
# 2024-11-19 16:25:10,435 - INFO - Predicted value for Andorra in 2020: 40.01203591827993
# 2024-11-19 16:25:10,436 - INFO - Prediction inputs for Andorra in 2021: Year=2021, AL Moving_Avg_2Y=40.00604056640357, AL Moving_Avg_3Y=40.00803901702903, AL Moving_Avg_5Y=40.009637777529385, AL Moving_Avg_10Y=40.010836847904656
# 2024-11-19 16:25:10,437 - INFO - Predicted value for Andorra in 2021: 40.01800391712325
# 2024-11-19 16:25:10,438 - INFO - Prediction inputs for Andorra in 2022: Year=2022, AL Moving_Avg_2Y=40.01501991770159, AL Moving_Avg_3Y=40.0100283499768, AL Moving_Avg_5Y=40.01321857683538, AL Moving_Avg_10Y=40.015611246979326
# 2024-11-19 16:25:10,440 - INFO - Predicted value for Andorra in 2022: 40.01882898691304
# 2024-11-19 16:25:10,440 - INFO - Prediction inputs for Andorra in 2023: Year=2023, AL Moving_Avg_2Y=40.018416452018144, AL Moving_Avg_3Y=40.01628960743874, AL Moving_Avg_5Y=40.0135486047513, AL Moving_Avg_10Y=40.01618879583217
# 2024-11-19 16:25:10,442 - INFO - Predicted value for Andorra in 2023: 40.01882898691304
# 2024-11-19 16:25:10,442 - INFO - Prediction inputs for Andorra in 2024: Year=2024, AL Moving_Avg_2Y=40.01882898691304, AL Moving_Avg_3Y=40.01855396364977, AL Moving_Avg_5Y=40.01354860475129, AL Moving_Avg_10Y=40.01618879583217
# 2024-11-19 16:25:10,444 - INFO - Predicted value for Andorra in 2024: 40.02021616958897
# 2024-11-19 16:25:10,444 - INFO - Prediction inputs for Andorra in 2025: Year=2025, AL Moving_Avg_2Y=40.01952257825101, AL Moving_Avg_3Y=40.01929138113835, AL Moving_Avg_5Y=40.017582795763644, AL Moving_Avg_10Y=40.016882387170135
# 2024-11-19 16:25:10,446 - INFO - Predicted value for Andorra in 2025: 40.02021616958897
# 2024-11-19 16:25:10,446 - INFO - Prediction inputs for Andorra in 2026: Year=2026, AL Moving_Avg_2Y=40.02021616958897, AL Moving_Avg_3Y=40.01975377536366, AL Moving_Avg_5Y=40.01921884602545, AL Moving_Avg_10Y=40.01688238717014
# 2024-11-19 16:25:10,448 - INFO - Predicted value for Andorra in 2026: 40.01640127597194
# 2024-11-19 16:25:10,448 - INFO - Prediction inputs for Andorra in 2027: Year=2027, AL Moving_Avg_2Y=40.01830872278045, AL Moving_Avg_3Y=40.018944538383295, AL Moving_Avg_5Y=40.01889831779519, AL Moving_Avg_10Y=40.015737919085026
# 2024-11-19 16:25:10,450 - INFO - Predicted value for Andorra in 2027: 40.01640127597194
# 2024-11-19 16:25:10,450 - INFO - Prediction inputs for Andorra in 2028: Year=2028, AL Moving_Avg_2Y=40.01640127597194, AL Moving_Avg_3Y=40.01767290717762, AL Moving_Avg_5Y=40.01841277560697, AL Moving_Avg_10Y=40.015737919085026
# 2024-11-19 16:25:10,452 - INFO - Predicted value for Andorra in 2028: 40.01501409329601
# 2024-11-19 16:25:10,452 - INFO - Prediction inputs for Andorra in 2029: Year=2029, AL Moving_Avg_2Y=40.01570768463397, AL Moving_Avg_3Y=40.01593888174663, AL Moving_Avg_5Y=40.01764979688356, AL Moving_Avg_10Y=40.01559920081743
# 2024-11-19 16:25:10,454 - INFO - Predicted value for Andorra in 2029: 40.01882898691304
# 2024-11-19 16:25:10,454 - INFO - Prediction inputs for Andorra in 2030: Year=2030, AL Moving_Avg_2Y=40.016921540104526, AL Moving_Avg_3Y=40.016748118727, AL Moving_Avg_5Y=40.017372360348375, AL Moving_Avg_10Y=40.01747757805602
# 2024-11-19 16:25:10,456 - INFO - Predicted value for Andorra in 2030: 40.01882898691304
# 2024-11-19 16:25:10,456 - INFO - Processing country: Angola
# 2024-11-19 16:25:10,457 - INFO - Prediction inputs for Angola in 2019: Year=2019, AL Moving_Avg_2Y=36.76465869896525, AL Moving_Avg_3Y=36.747947915831105, AL Moving_Avg_5Y=36.74564851207187, AL Moving_Avg_10Y=36.551295419908556
# 2024-11-19 16:25:10,459 - INFO - Predicted value for Angola in 2019: 36.78137670764235
# 2024-11-19 16:25:10,459 - INFO - Prediction inputs for Angola in 2020: Year=2020, AL Moving_Avg_2Y=36.78137670764235, AL Moving_Avg_3Y=36.78137670764235, AL Moving_Avg_5Y=36.78137670764235, AL Moving_Avg_10Y=36.78137670764236
# 2024-11-19 16:25:10,461 - INFO - Predicted value for Angola in 2020: 36.80166635573563
# 2024-11-19 16:25:10,461 - INFO - Prediction inputs for Angola in 2021: Year=2021, AL Moving_Avg_2Y=36.791521531688986, AL Moving_Avg_3Y=36.79490313970453, AL Moving_Avg_5Y=36.79760842611697, AL Moving_Avg_10Y=36.79963739092629
# 2024-11-19 16:25:10,463 - INFO - Predicted value for Angola in 2021: 36.8221108973658
# 2024-11-19 16:25:10,463 - INFO - Prediction inputs for Angola in 2022: Year=2022, AL Moving_Avg_2Y=36.81188862655071, AL Moving_Avg_3Y=36.80171798691459, AL Moving_Avg_5Y=36.80987515109508, AL Moving_Avg_10Y=36.81599302423044
# 2024-11-19 16:25:10,465 - INFO - Predicted value for Angola in 2022: 36.8221108973658
# 2024-11-19 16:25:10,466 - INFO - Prediction inputs for Angola in 2023: Year=2023, AL Moving_Avg_2Y=36.8221108973658, AL Moving_Avg_3Y=36.815296050155744, AL Moving_Avg_5Y=36.80987515109508, AL Moving_Avg_10Y=36.815993024230444
# 2024-11-19 16:25:10,467 - INFO - Predicted value for Angola in 2023: 36.8221108973658
# 2024-11-19 16:25:10,468 - INFO - Prediction inputs for Angola in 2024: Year=2024, AL Moving_Avg_2Y=36.8221108973658, AL Moving_Avg_3Y=36.8221108973658, AL Moving_Avg_5Y=36.80987515109508, AL Moving_Avg_10Y=36.815993024230444
# 2024-11-19 16:25:10,470 - INFO - Predicted value for Angola in 2024: 36.81195762204714
# 2024-11-19 16:25:10,470 - INFO - Prediction inputs for Angola in 2025: Year=2025, AL Moving_Avg_2Y=36.817034259706475, AL Moving_Avg_3Y=36.818726472259584, AL Moving_Avg_5Y=36.81599133397604, AL Moving_Avg_10Y=36.81091638657111
# 2024-11-19 16:25:10,472 - INFO - Predicted value for Angola in 2025: 36.81195762204714
# 2024-11-19 16:25:10,472 - INFO - Prediction inputs for Angola in 2026: Year=2026, AL Moving_Avg_2Y=36.81195762204714, AL Moving_Avg_3Y=36.815342047153365, AL Moving_Avg_5Y=36.81804958723834, AL Moving_Avg_10Y=36.81091638657111
# 2024-11-19 16:25:10,474 - INFO - Predicted value for Angola in 2026: 36.8221108973658
# 2024-11-19 16:25:10,474 - INFO - Prediction inputs for Angola in 2027: Year=2027, AL Moving_Avg_2Y=36.817034259706475, AL Moving_Avg_3Y=36.81534204715336, AL Moving_Avg_5Y=36.81804958723834, AL Moving_Avg_10Y=36.8139623691667
# 2024-11-19 16:25:10,476 - INFO - Predicted value for Angola in 2027: 36.8221108973658
# 2024-11-19 16:25:10,476 - INFO - Prediction inputs for Angola in 2028: Year=2028, AL Moving_Avg_2Y=36.8221108973658, AL Moving_Avg_3Y=36.818726472259584, AL Moving_Avg_5Y=36.81804958723834, AL Moving_Avg_10Y=36.8139623691667
# 2024-11-19 16:25:10,478 - INFO - Predicted value for Angola in 2028: 36.81195762204714
# 2024-11-19 16:25:10,478 - INFO - Prediction inputs for Angola in 2029: Year=2029, AL Moving_Avg_2Y=36.817034259706475, AL Moving_Avg_3Y=36.818726472259584, AL Moving_Avg_5Y=36.81601893217461, AL Moving_Avg_10Y=36.81294704163484
# 2024-11-19 16:25:10,480 - INFO - Predicted value for Angola in 2029: 36.81195762204714
# 2024-11-19 16:25:10,480 - INFO - Prediction inputs for Angola in 2030: Year=2030, AL Moving_Avg_2Y=36.81195762204714, AL Moving_Avg_3Y=36.815342047153365, AL Moving_Avg_5Y=36.81601893217461, AL Moving_Avg_10Y=36.81600513307532
# 2024-11-19 16:25:10,482 - INFO - Predicted value for Angola in 2030: 36.8221108973658
# 2024-11-19 16:25:10,482 - INFO - Processing country: Antigua and Barbuda
# 2024-11-19 16:25:10,483 - INFO - Prediction inputs for Antigua and Barbuda in 2019: Year=2019, AL Moving_Avg_2Y=20.4545454545455, AL Moving_Avg_3Y=20.4545454545455, AL Moving_Avg_5Y=20.4545454545455, AL Moving_Avg_10Y=20.4545454545455
# 2024-11-19 16:25:10,485 - INFO - Predicted value for Antigua and Barbuda in 2019: 20.448453237410114
# 2024-11-19 16:25:10,485 - INFO - Prediction inputs for Antigua and Barbuda in 2020: Year=2020, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,487 - INFO - Predicted value for Antigua and Barbuda in 2020: 20.448453237410114
# 2024-11-19 16:25:10,487 - INFO - Prediction inputs for Antigua and Barbuda in 2021: Year=2021, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,489 - INFO - Predicted value for Antigua and Barbuda in 2021: 20.448453237410114
# 2024-11-19 16:25:10,489 - INFO - Prediction inputs for Antigua and Barbuda in 2022: Year=2022, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,491 - INFO - Predicted value for Antigua and Barbuda in 2022: 20.448453237410114
# 2024-11-19 16:25:10,491 - INFO - Prediction inputs for Antigua and Barbuda in 2023: Year=2023, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,493 - INFO - Predicted value for Antigua and Barbuda in 2023: 20.448453237410114
# 2024-11-19 16:25:10,494 - INFO - Prediction inputs for Antigua and Barbuda in 2024: Year=2024, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,495 - INFO - Predicted value for Antigua and Barbuda in 2024: 20.448453237410114
# 2024-11-19 16:25:10,496 - INFO - Prediction inputs for Antigua and Barbuda in 2025: Year=2025, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,497 - INFO - Predicted value for Antigua and Barbuda in 2025: 20.448453237410114
# 2024-11-19 16:25:10,498 - INFO - Prediction inputs for Antigua and Barbuda in 2026: Year=2026, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,500 - INFO - Predicted value for Antigua and Barbuda in 2026: 20.448453237410114
# 2024-11-19 16:25:10,500 - INFO - Prediction inputs for Antigua and Barbuda in 2027: Year=2027, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,502 - INFO - Predicted value for Antigua and Barbuda in 2027: 20.448453237410114
# 2024-11-19 16:25:10,502 - INFO - Prediction inputs for Antigua and Barbuda in 2028: Year=2028, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,504 - INFO - Predicted value for Antigua and Barbuda in 2028: 20.448453237410114
# 2024-11-19 16:25:10,504 - INFO - Prediction inputs for Antigua and Barbuda in 2029: Year=2029, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,506 - INFO - Predicted value for Antigua and Barbuda in 2029: 20.448453237410114
# 2024-11-19 16:25:10,506 - INFO - Prediction inputs for Antigua and Barbuda in 2030: Year=2030, AL Moving_Avg_2Y=20.448453237410114, AL Moving_Avg_3Y=20.448453237410114, AL Moving_Avg_5Y=20.448453237410114, AL Moving_Avg_10Y=20.448453237410117
# 2024-11-19 16:25:10,508 - INFO - Predicted value for Antigua and Barbuda in 2030: 20.448453237410114
# 2024-11-19 16:25:10,508 - INFO - Processing country: Argentina
# 2024-11-19 16:25:10,508 - INFO - Prediction inputs for Argentina in 2019: Year=2019, AL Moving_Avg_2Y=42.4811577855, AL Moving_Avg_3Y=42.64956564316747, AL Moving_Avg_5Y=43.109392689709104, AL Moving_Avg_10Y=44.226409253514284
# 2024-11-19 16:25:10,510 - INFO - Predicted value for Argentina in 2019: 42.492373365478876
# 2024-11-19 16:25:10,511 - INFO - Prediction inputs for Argentina in 2020: Year=2020, AL Moving_Avg_2Y=42.492373365478876, AL Moving_Avg_3Y=42.492373365478876, AL Moving_Avg_5Y=42.492373365478876, AL Moving_Avg_10Y=42.49237336547888
# 2024-11-19 16:25:10,513 - INFO - Predicted value for Argentina in 2020: 42.600141672704424
# 2024-11-19 16:25:10,513 - INFO - Prediction inputs for Argentina in 2021: Year=2021, AL Moving_Avg_2Y=42.546257519091654, AL Moving_Avg_3Y=42.564218903629246, AL Moving_Avg_5Y=42.57858801125932, AL Moving_Avg_10Y=42.58936484198186
# 2024-11-19 16:25:10,515 - INFO - Predicted value for Argentina in 2021: 42.62236670382353
# 2024-11-19 16:25:10,515 - INFO - Prediction inputs for Argentina in 2022: Year=2022, AL Moving_Avg_2Y=42.61125418826398, AL Moving_Avg_3Y=42.57162724733561, AL Moving_Avg_5Y=42.59192302993078, AL Moving_Avg_10Y=42.60714486687715
# 2024-11-19 16:25:10,517 - INFO - Predicted value for Argentina in 2022: 42.65263201298754
# 2024-11-19 16:25:10,517 - INFO - Prediction inputs for Argentina in 2023: Year=2023, AL Moving_Avg_2Y=42.637499358405535, AL Moving_Avg_3Y=42.62504679650517, AL Moving_Avg_5Y=42.604029153596386, AL Moving_Avg_10Y=42.62833058329196
# 2024-11-19 16:25:10,519 - INFO - Predicted value for Argentina in 2023: 42.64263427882725
# 2024-11-19 16:25:10,519 - INFO - Prediction inputs for Argentina in 2024: Year=2024, AL Moving_Avg_2Y=42.64763314590739, AL Moving_Avg_3Y=42.639210998546105, AL Moving_Avg_5Y=42.602029606764326, AL Moving_Avg_10Y=42.62233194279578
# 2024-11-19 16:25:10,521 - INFO - Predicted value for Argentina in 2024: 42.63857227982954
# 2024-11-19 16:25:10,521 - INFO - Prediction inputs for Argentina in 2025: Year=2025, AL Moving_Avg_2Y=42.640603279328396, AL Moving_Avg_3Y=42.644612857214774, AL Moving_Avg_5Y=42.631269389634454, AL Moving_Avg_10Y=42.620300943296925
# 2024-11-19 16:25:10,523 - INFO - Predicted value for Argentina in 2025: 42.63924284114149
# 2024-11-19 16:25:10,523 - INFO - Prediction inputs for Argentina in 2026: Year=2026, AL Moving_Avg_2Y=42.638907560485514, AL Moving_Avg_3Y=42.640149799932765, AL Moving_Avg_5Y=42.639089623321865, AL Moving_Avg_10Y=42.62056916782171
# 2024-11-19 16:25:10,525 - INFO - Predicted value for Argentina in 2026: 42.63882592951088
# 2024-11-19 16:25:10,525 - INFO - Prediction inputs for Argentina in 2027: Year=2027, AL Moving_Avg_2Y=42.639034385326184, AL Moving_Avg_3Y=42.63888035016063, AL Moving_Avg_5Y=42.642381468459334, AL Moving_Avg_10Y=42.62044409433253
# 2024-11-19 16:25:10,527 - INFO - Predicted value for Argentina in 2027: 42.63882592951088
# 2024-11-19 16:25:10,527 - INFO - Prediction inputs for Argentina in 2028: Year=2028, AL Moving_Avg_2Y=42.63882592951088, AL Moving_Avg_3Y=42.63896490005442, AL Moving_Avg_5Y=42.639620251764015, AL Moving_Avg_10Y=42.62044409433253
# 2024-11-19 16:25:10,529 - INFO - Predicted value for Argentina in 2028: 42.63882592951088
# 2024-11-19 16:25:10,529 - INFO - Prediction inputs for Argentina in 2029: Year=2029, AL Moving_Avg_2Y=42.63882592951088, AL Moving_Avg_3Y=42.63882592951088, AL Moving_Avg_5Y=42.638858581900735, AL Moving_Avg_10Y=42.62044409433252
# 2024-11-19 16:25:10,531 - INFO - Predicted value for Argentina in 2029: 42.63882592951088
# 2024-11-19 16:25:10,531 - INFO - Prediction inputs for Argentina in 2030: Year=2030, AL Moving_Avg_2Y=42.63882592951088, AL Moving_Avg_3Y=42.63882592951088, AL Moving_Avg_5Y=42.638909311837004, AL Moving_Avg_10Y=42.635089350735726
# 2024-11-19 16:25:10,533 - INFO - Predicted value for Argentina in 2030: 42.63882592951088
# 2024-11-19 16:25:10,534 - INFO - Processing country: Armenia
# 2024-11-19 16:25:10,534 - INFO - Prediction inputs for Armenia in 2019: Year=2019, AL Moving_Avg_2Y=58.90937829293995, AL Moving_Avg_3Y=58.8970846505093, AL Moving_Avg_5Y=58.89638215665612, AL Moving_Avg_10Y=59.23322795925535
# 2024-11-19 16:25:10,536 - INFO - Predicted value for Armenia in 2019: 58.90732672336991
# 2024-11-19 16:25:10,536 - INFO - Prediction inputs for Armenia in 2020: Year=2020, AL Moving_Avg_2Y=58.90732672336991, AL Moving_Avg_3Y=58.90732672336991, AL Moving_Avg_5Y=58.907326723369906, AL Moving_Avg_10Y=58.907326723369906
# 2024-11-19 16:25:10,538 - INFO - Predicted value for Armenia in 2020: 58.881405602582575
# 2024-11-19 16:25:10,538 - INFO - Prediction inputs for Armenia in 2021: Year=2021, AL Moving_Avg_2Y=58.89436616297624, AL Moving_Avg_3Y=58.89004597617835, AL Moving_Avg_5Y=58.88658982674004, AL Moving_Avg_10Y=58.883997714661305
# 2024-11-19 16:25:10,540 - INFO - Predicted value for Armenia in 2021: 58.87787482507925
# 2024-11-19 16:25:10,541 - INFO - Prediction inputs for Armenia in 2022: Year=2022, AL Moving_Avg_2Y=58.87964021383091, AL Moving_Avg_3Y=58.888869050343914, AL Moving_Avg_5Y=58.884471360238045, AL Moving_Avg_10Y=58.88117309265865
# 2024-11-19 16:25:10,542 - INFO - Predicted value for Armenia in 2022: 58.87560162006633
# 2024-11-19 16:25:10,543 - INFO - Prediction inputs for Armenia in 2023: Year=2023, AL Moving_Avg_2Y=58.87673822257279, AL Moving_Avg_3Y=58.87829401590938, AL Moving_Avg_5Y=58.88356207823288, AL Moving_Avg_10Y=58.8795818491496
# 2024-11-19 16:25:10,544 - INFO - Predicted value for Armenia in 2023: 58.87560162006633
# 2024-11-19 16:25:10,545 - INFO - Prediction inputs for Armenia in 2024: Year=2024, AL Moving_Avg_2Y=58.87560162006633, AL Moving_Avg_3Y=58.87635935507063, AL Moving_Avg_5Y=58.88356207823288, AL Moving_Avg_10Y=58.87958184914959
# 2024-11-19 16:25:10,547 - INFO - Predicted value for Armenia in 2024: 58.87560162006633
# 2024-11-19 16:25:10,547 - INFO - Prediction inputs for Armenia in 2025: Year=2025, AL Moving_Avg_2Y=58.87560162006633, AL Moving_Avg_3Y=58.87560162006633, AL Moving_Avg_5Y=58.87721705757216, AL Moving_Avg_10Y=58.87958184914959
# 2024-11-19 16:25:10,549 - INFO - Predicted value for Armenia in 2025: 58.87283224486545
# 2024-11-19 16:25:10,549 - INFO - Prediction inputs for Armenia in 2026: Year=2026, AL Moving_Avg_2Y=58.874216932465885, AL Moving_Avg_3Y=58.874678494999365, AL Moving_Avg_5Y=58.875502386028735, AL Moving_Avg_10Y=58.87847409906925
# 2024-11-19 16:25:10,551 - INFO - Predicted value for Armenia in 2026: 58.869641373352664
# 2024-11-19 16:25:10,551 - INFO - Prediction inputs for Armenia in 2027: Year=2027, AL Moving_Avg_2Y=58.87123680910906, AL Moving_Avg_3Y=58.87269174609481, AL Moving_Avg_5Y=58.87385569568342, AL Moving_Avg_10Y=58.87751683761542
# 2024-11-19 16:25:10,553 - INFO - Predicted value for Armenia in 2027: 58.869641373352664
# 2024-11-19 16:25:10,553 - INFO - Prediction inputs for Armenia in 2028: Year=2028, AL Moving_Avg_2Y=58.869641373352664, AL Moving_Avg_3Y=58.87070499719025, AL Moving_Avg_5Y=58.87266364634068, AL Moving_Avg_10Y=58.87751683761542
# 2024-11-19 16:25:10,555 - INFO - Predicted value for Armenia in 2028: 58.869641373352664
# 2024-11-19 16:25:10,555 - INFO - Prediction inputs for Armenia in 2029: Year=2029, AL Moving_Avg_2Y=58.869641373352664, AL Moving_Avg_3Y=58.869641373352664, AL Moving_Avg_5Y=58.87147159699796, AL Moving_Avg_10Y=58.87751683761542
# 2024-11-19 16:25:10,557 - INFO - Predicted value for Armenia in 2029: 58.869641373352664
# 2024-11-19 16:25:10,557 - INFO - Prediction inputs for Armenia in 2030: Year=2030, AL Moving_Avg_2Y=58.869641373352664, AL Moving_Avg_3Y=58.869641373352664, AL Moving_Avg_5Y=58.870279547655215, AL Moving_Avg_10Y=58.87374830261369
# 2024-11-19 16:25:10,559 - INFO - Predicted value for Armenia in 2030: 58.869641373352664
# 2024-11-19 16:25:10,559 - INFO - Processing country: Australia
# 2024-11-19 16:25:10,560 - INFO - Prediction inputs for Australia in 2019: Year=2019, AL Moving_Avg_2Y=46.8909337209212, AL Moving_Avg_3Y=47.374161793651105, AL Moving_Avg_5Y=46.3953670479775, AL Moving_Avg_10Y=48.004928750027815
# 2024-11-19 16:25:10,562 - INFO - Predicted value for Australia in 2019: 47.07323254261755
# 2024-11-19 16:25:10,562 - INFO - Prediction inputs for Australia in 2020: Year=2020, AL Moving_Avg_2Y=47.07323254261755, AL Moving_Avg_3Y=47.07323254261755, AL Moving_Avg_5Y=47.07323254261755, AL Moving_Avg_10Y=47.07323254261756
# 2024-11-19 16:25:10,564 - INFO - Predicted value for Australia in 2020: 47.13693771068821
# 2024-11-19 16:25:10,564 - INFO - Prediction inputs for Australia in 2021: Year=2021, AL Moving_Avg_2Y=47.10508512665288, AL Moving_Avg_3Y=47.11570265466466, AL Moving_Avg_5Y=47.124196677074075, AL Moving_Avg_10Y=47.130567193881134
# 2024-11-19 16:25:10,566 - INFO - Predicted value for Australia in 2021: 47.145464948454666
# 2024-11-19 16:25:10,566 - INFO - Prediction inputs for Australia in 2022: Year=2022, AL Moving_Avg_2Y=47.14120132957144, AL Moving_Avg_3Y=47.11854506725348, AL Moving_Avg_5Y=47.12931301973396, AL Moving_Avg_10Y=47.13738898409431
# 2024-11-19 16:25:10,568 - INFO - Predicted value for Australia in 2022: 47.145443653550295
# 2024-11-19 16:25:10,568 - INFO - Prediction inputs for Australia in 2023: Year=2023, AL Moving_Avg_2Y=47.14545430100248, AL Moving_Avg_3Y=47.14261543756439, AL Moving_Avg_5Y=47.12930450177221, AL Moving_Avg_10Y=47.13737407766125
# 2024-11-19 16:25:10,587 - INFO - Predicted value for Australia in 2023: 47.14483968065135
# 2024-11-19 16:25:10,588 - INFO - Prediction inputs for Australia in 2024: Year=2024, AL Moving_Avg_2Y=47.14514166710082, AL Moving_Avg_3Y=47.1452494275521, AL Moving_Avg_5Y=47.12918370719242, AL Moving_Avg_10Y=47.13701169392188
# 2024-11-19 16:25:10,590 - INFO - Predicted value for Australia in 2024: 47.14483968065135
# 2024-11-19 16:25:10,591 - INFO - Prediction inputs for Australia in 2025: Year=2025, AL Moving_Avg_2Y=47.14483968065135, AL Moving_Avg_3Y=47.145041004951, AL Moving_Avg_5Y=47.14350513479918, AL Moving_Avg_10Y=47.13701169392188
# 2024-11-19 16:25:10,593 - INFO - Predicted value for Australia in 2025: 47.14497329092234
# 2024-11-19 16:25:10,593 - INFO - Prediction inputs for Australia in 2026: Year=2026, AL Moving_Avg_2Y=47.14490648578685, AL Moving_Avg_3Y=47.144884217408354, AL Moving_Avg_5Y=47.145112250846, AL Moving_Avg_10Y=47.13706513803027
# 2024-11-19 16:25:10,595 - INFO - Predicted value for Australia in 2026: 47.14497329092234
# 2024-11-19 16:25:10,595 - INFO - Prediction inputs for Australia in 2027: Year=2027, AL Moving_Avg_2Y=47.14497329092234, AL Moving_Avg_3Y=47.14492875416534, AL Moving_Avg_5Y=47.14501391933953, AL Moving_Avg_10Y=47.13706513803027
# 2024-11-19 16:25:10,597 - INFO - Predicted value for Australia in 2027: 47.14497329092234
# 2024-11-19 16:25:10,598 - INFO - Prediction inputs for Australia in 2028: Year=2028, AL Moving_Avg_2Y=47.14497329092234, AL Moving_Avg_3Y=47.14497329092234, AL Moving_Avg_5Y=47.14491984681395, AL Moving_Avg_10Y=47.13706513803028
# 2024-11-19 16:25:10,601 - INFO - Predicted value for Australia in 2028: 47.14497329092234
# 2024-11-19 16:25:10,601 - INFO - Prediction inputs for Australia in 2029: Year=2029, AL Moving_Avg_2Y=47.14497329092234, AL Moving_Avg_3Y=47.14497329092234, AL Moving_Avg_5Y=47.14494656886814, AL Moving_Avg_10Y=47.13706513803028
# 2024-11-19 16:25:10,603 - INFO - Predicted value for Australia in 2029: 47.14497329092234
# 2024-11-19 16:25:10,603 - INFO - Prediction inputs for Australia in 2030: Year=2030, AL Moving_Avg_2Y=47.14497329092234, AL Moving_Avg_3Y=47.14497329092234, AL Moving_Avg_5Y=47.14497329092234, AL Moving_Avg_10Y=47.14423921286076
# 2024-11-19 16:25:10,605 - INFO - Predicted value for Australia in 2030: 47.143795091259996
# 2024-11-19 16:25:10,606 - INFO - Processing country: Austria
# 2024-11-19 16:25:10,606 - INFO - Prediction inputs for Austria in 2019: Year=2019, AL Moving_Avg_2Y=32.13790596219095, AL Moving_Avg_3Y=32.14840846663433, AL Moving_Avg_5Y=32.34920019389238, AL Moving_Avg_10Y=32.77942317014057
# 2024-11-19 16:25:10,608 - INFO - Predicted value for Austria in 2019: 32.22990236516924
# 2024-11-19 16:25:10,609 - INFO - Prediction inputs for Austria in 2020: Year=2020, AL Moving_Avg_2Y=32.22990236516924, AL Moving_Avg_3Y=32.22990236516924, AL Moving_Avg_5Y=32.22990236516924, AL Moving_Avg_10Y=32.22990236516923
# 2024-11-19 16:25:10,611 - INFO - Predicted value for Austria in 2020: 32.2552970289269
# 2024-11-19 16:25:10,611 - INFO - Prediction inputs for Austria in 2021: Year=2021, AL Moving_Avg_2Y=32.242599697048064, AL Moving_Avg_3Y=32.24683214100767, AL Moving_Avg_5Y=32.25021809617537, AL Moving_Avg_10Y=32.25275756255114
# 2024-11-19 16:25:10,613 - INFO - Predicted value for Austria in 2021: 32.24763050628395
# 2024-11-19 16:25:10,613 - INFO - Prediction inputs for Austria in 2022: Year=2022, AL Moving_Avg_2Y=32.25146376760542, AL Moving_Avg_3Y=32.244276633460025, AL Moving_Avg_5Y=32.245618182589595, AL Moving_Avg_10Y=32.24662434443677
# 2024-11-19 16:25:10,615 - INFO - Predicted value for Austria in 2022: 32.26754173290098
# 2024-11-19 16:25:10,615 - INFO - Prediction inputs for Austria in 2023: Year=2023, AL Moving_Avg_2Y=32.25758611959246, AL Moving_Avg_3Y=32.256823089370606, AL Moving_Avg_5Y=32.25358267323641, AL Moving_Avg_10Y=32.260562203068694
# 2024-11-19 16:25:10,617 - INFO - Predicted value for Austria in 2023: 32.26566673290098
# 2024-11-19 16:25:10,617 - INFO - Prediction inputs for Austria in 2024: Year=2024, AL Moving_Avg_2Y=32.26660423290098, AL Moving_Avg_3Y=32.26027965736197, AL Moving_Avg_5Y=32.25320767323641, AL Moving_Avg_10Y=32.25943720306869
# 2024-11-19 16:25:10,619 - INFO - Predicted value for Austria in 2024: 32.26923631707996
# 2024-11-19 16:25:10,619 - INFO - Prediction inputs for Austria in 2025: Year=2025, AL Moving_Avg_2Y=32.26745152499047, AL Moving_Avg_3Y=32.267481594293976, AL Moving_Avg_5Y=32.261074463618556, AL Moving_Avg_10Y=32.26122199515818
# 2024-11-19 16:25:10,621 - INFO - Predicted value for Austria in 2025: 32.27355766330202
# 2024-11-19 16:25:10,621 - INFO - Prediction inputs for Austria in 2026: Year=2026, AL Moving_Avg_2Y=32.27139699019099, AL Moving_Avg_3Y=32.26948690442765, AL Moving_Avg_5Y=32.26472659049358, AL Moving_Avg_10Y=32.26295053364701
# 2024-11-19 16:25:10,623 - INFO - Predicted value for Austria in 2026: 32.27194344041268
# 2024-11-19 16:25:10,623 - INFO - Prediction inputs for Austria in 2027: Year=2027, AL Moving_Avg_2Y=32.27275055185735, AL Moving_Avg_3Y=32.27157914026489, AL Moving_Avg_5Y=32.269589177319325, AL Moving_Avg_10Y=32.26246626678021
# 2024-11-19 16:25:10,625 - INFO - Predicted value for Austria in 2027: 32.28015660085862
# 2024-11-19 16:25:10,625 - INFO - Prediction inputs for Austria in 2028: Year=2028, AL Moving_Avg_2Y=32.27605002063565, AL Moving_Avg_3Y=32.27521923485777, AL Moving_Avg_5Y=32.27211215091085, AL Moving_Avg_10Y=32.264108898869395
# 2024-11-19 16:25:10,627 - INFO - Predicted value for Austria in 2028: 32.275156600858615
# 2024-11-19 16:25:10,627 - INFO - Prediction inputs for Austria in 2029: Year=2029, AL Moving_Avg_2Y=32.27765660085862, AL Moving_Avg_3Y=32.27575221404331, AL Moving_Avg_5Y=32.27401012450238, AL Moving_Avg_10Y=32.26360889886939
# 2024-11-19 16:25:10,629 - INFO - Predicted value for Austria in 2029: 32.275156600858615
# 2024-11-19 16:25:10,630 - INFO - Prediction inputs for Austria in 2030: Year=2030, AL Moving_Avg_2Y=32.275156600858615, AL Moving_Avg_3Y=32.27682326752529, AL Moving_Avg_5Y=32.27519418125811, AL Moving_Avg_10Y=32.268134322438335
# 2024-11-19 16:25:10,631 - INFO - Predicted value for Austria in 2030: 32.275156600858615
# 2024-11-19 16:25:10,632 - INFO - Processing country: Azerbaijan
# 2024-11-19 16:25:10,632 - INFO - Prediction inputs for Azerbaijan in 2019: Year=2019, AL Moving_Avg_2Y=57.82660246328065, AL Moving_Avg_3Y=57.81626876371817, AL Moving_Avg_5Y=57.777226873981, AL Moving_Avg_10Y=57.734059895201554
# 2024-11-19 16:25:10,634 - INFO - Predicted value for Azerbaijan in 2019: 57.83457328724314
# 2024-11-19 16:25:10,634 - INFO - Prediction inputs for Azerbaijan in 2020: Year=2020, AL Moving_Avg_2Y=57.83457328724314, AL Moving_Avg_3Y=57.83457328724314, AL Moving_Avg_5Y=57.834573287243146, AL Moving_Avg_10Y=57.834573287243146
# 2024-11-19 16:25:10,636 - INFO - Predicted value for Azerbaijan in 2020: 57.84431736611827
# 2024-11-19 16:25:10,637 - INFO - Prediction inputs for Azerbaijan in 2021: Year=2021, AL Moving_Avg_2Y=57.8394453266807, AL Moving_Avg_3Y=57.84106933982656, AL Moving_Avg_5Y=57.84236855034324, AL Moving_Avg_10Y=57.84334295823076
# 2024-11-19 16:25:10,638 - INFO - Predicted value for Azerbaijan in 2021: 57.844873006812314
# 2024-11-19 16:25:10,639 - INFO - Prediction inputs for Azerbaijan in 2022: Year=2022, AL Moving_Avg_2Y=57.84459518646529, AL Moving_Avg_3Y=57.841254553391245, AL Moving_Avg_5Y=57.84270193475967, AL Moving_Avg_10Y=57.84378747078599
# 2024-11-19 16:25:10,641 - INFO - Predicted value for Azerbaijan in 2022: 57.844873006812314
# 2024-11-19 16:25:10,641 - INFO - Prediction inputs for Azerbaijan in 2023: Year=2023, AL Moving_Avg_2Y=57.844873006812314, AL Moving_Avg_3Y=57.84468779324763, AL Moving_Avg_5Y=57.84270193475967, AL Moving_Avg_10Y=57.84378747078599
# 2024-11-19 16:25:10,643 - INFO - Predicted value for Azerbaijan in 2023: 57.844873006812314
# 2024-11-19 16:25:10,643 - INFO - Prediction inputs for Azerbaijan in 2024: Year=2024, AL Moving_Avg_2Y=57.844873006812314, AL Moving_Avg_3Y=57.844873006812314, AL Moving_Avg_5Y=57.84270193475967, AL Moving_Avg_10Y=57.84378747078599
# 2024-11-19 16:25:10,645 - INFO - Predicted value for Azerbaijan in 2024: 57.844873006812314
# 2024-11-19 16:25:10,645 - INFO - Prediction inputs for Azerbaijan in 2025: Year=2025, AL Moving_Avg_2Y=57.844873006812314, AL Moving_Avg_3Y=57.844873006812314, AL Moving_Avg_5Y=57.8447618786735, AL Moving_Avg_10Y=57.84378747078599
# 2024-11-19 16:25:10,647 - INFO - Predicted value for Azerbaijan in 2025: 57.844873006812314
# 2024-11-19 16:25:10,647 - INFO - Prediction inputs for Azerbaijan in 2026: Year=2026, AL Moving_Avg_2Y=57.844873006812314, AL Moving_Avg_3Y=57.844873006812314, AL Moving_Avg_5Y=57.844873006812314, AL Moving_Avg_10Y=57.84378747078599
# 2024-11-19 16:25:10,649 - INFO - Predicted value for Azerbaijan in 2026: 57.844873006812314
# 2024-11-19 16:25:10,649 - INFO - Prediction inputs for Azerbaijan in 2027: Year=2027, AL Moving_Avg_2Y=57.844873006812314, AL Moving_Avg_3Y=57.844873006812314, AL Moving_Avg_5Y=57.844873006812314, AL Moving_Avg_10Y=57.84378747078599
# 2024-11-19 16:25:10,651 - INFO - Predicted value for Azerbaijan in 2027: 57.844873006812314
# 2024-11-19 16:25:10,651 - INFO - Prediction inputs for Azerbaijan in 2028: Year=2028, AL Moving_Avg_2Y=57.844873006812314, AL Moving_Avg_3Y=57.844873006812314, AL Moving_Avg_5Y=57.844873006812314, AL Moving_Avg_10Y=57.84378747078599
# 2024-11-19 16:25:10,653 - INFO - Predicted value for Azerbaijan in 2028: 57.844873006812314
# 2024-11-19 16:25:10,653 - INFO - Prediction inputs for Azerbaijan in 2029: Year=2029, AL Moving_Avg_2Y=57.844873006812314, AL Moving_Avg_3Y=57.844873006812314, AL Moving_Avg_5Y=57.844873006812314, AL Moving_Avg_10Y=57.84378747078599
# 2024-11-19 16:25:10,655 - INFO - Predicted value for Azerbaijan in 2029: 57.844873006812314
# 2024-11-19 16:25:10,656 - INFO - Prediction inputs for Azerbaijan in 2030: Year=2030, AL Moving_Avg_2Y=57.844873006812314, AL Moving_Avg_3Y=57.844873006812314, AL Moving_Avg_5Y=57.844873006812314, AL Moving_Avg_10Y=57.84481744274291
# 2024-11-19 16:25:10,657 - INFO - Predicted value for Azerbaijan in 2030: 57.844873006812314
# 2024-11-19 16:25:10,658 - INFO - Processing country: Bahamas, The
# 2024-11-19 16:25:10,658 - INFO - Prediction inputs for Bahamas, The in 2019: Year=2019, AL Moving_Avg_2Y=1.2987012987013, AL Moving_Avg_3Y=1.2987012987013, AL Moving_Avg_5Y=1.2987012987013, AL Moving_Avg_10Y=1.2887112887112901
# 2024-11-19 16:25:10,660 - INFO - Predicted value for Bahamas, The in 2019: 1.2987012987013022
# 2024-11-19 16:25:10,660 - INFO - Prediction inputs for Bahamas, The in 2020: Year=2020, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,662 - INFO - Predicted value for Bahamas, The in 2020: 1.2987012987013022
# 2024-11-19 16:25:10,662 - INFO - Prediction inputs for Bahamas, The in 2021: Year=2021, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,664 - INFO - Predicted value for Bahamas, The in 2021: 1.2987012987013022
# 2024-11-19 16:25:10,664 - INFO - Prediction inputs for Bahamas, The in 2022: Year=2022, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,666 - INFO - Predicted value for Bahamas, The in 2022: 1.2987012987013022
# 2024-11-19 16:25:10,666 - INFO - Prediction inputs for Bahamas, The in 2023: Year=2023, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,668 - INFO - Predicted value for Bahamas, The in 2023: 1.2987012987013022
# 2024-11-19 16:25:10,669 - INFO - Prediction inputs for Bahamas, The in 2024: Year=2024, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,671 - INFO - Predicted value for Bahamas, The in 2024: 1.2987012987013022
# 2024-11-19 16:25:10,671 - INFO - Prediction inputs for Bahamas, The in 2025: Year=2025, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,673 - INFO - Predicted value for Bahamas, The in 2025: 1.2987012987013022
# 2024-11-19 16:25:10,673 - INFO - Prediction inputs for Bahamas, The in 2026: Year=2026, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,675 - INFO - Predicted value for Bahamas, The in 2026: 1.2987012987013022
# 2024-11-19 16:25:10,675 - INFO - Prediction inputs for Bahamas, The in 2027: Year=2027, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,677 - INFO - Predicted value for Bahamas, The in 2027: 1.2987012987013022
# 2024-11-19 16:25:10,677 - INFO - Prediction inputs for Bahamas, The in 2028: Year=2028, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,679 - INFO - Predicted value for Bahamas, The in 2028: 1.2987012987013022
# 2024-11-19 16:25:10,679 - INFO - Prediction inputs for Bahamas, The in 2029: Year=2029, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,681 - INFO - Predicted value for Bahamas, The in 2029: 1.2987012987013022
# 2024-11-19 16:25:10,681 - INFO - Prediction inputs for Bahamas, The in 2030: Year=2030, AL Moving_Avg_2Y=1.2987012987013022, AL Moving_Avg_3Y=1.2987012987013022, AL Moving_Avg_5Y=1.2987012987013022, AL Moving_Avg_10Y=1.2987012987013025
# 2024-11-19 16:25:10,683 - INFO - Predicted value for Bahamas, The in 2030: 1.2987012987013022
# 2024-11-19 16:25:10,683 - INFO - Processing country: Bahrain
# 2024-11-19 16:25:10,684 - INFO - Prediction inputs for Bahrain in 2019: Year=2019, AL Moving_Avg_2Y=10.3979632193, AL Moving_Avg_3Y=10.3977874453453, AL Moving_Avg_5Y=10.4878878940117, AL Moving_Avg_10Y=10.868121176951789
# 2024-11-19 16:25:10,686 - INFO - Predicted value for Bahrain in 2019: 10.404267109339498
# 2024-11-19 16:25:10,686 - INFO - Prediction inputs for Bahrain in 2020: Year=2020, AL Moving_Avg_2Y=10.404267109339498, AL Moving_Avg_3Y=10.404267109339498, AL Moving_Avg_5Y=10.404267109339498, AL Moving_Avg_10Y=10.404267109339498
# 2024-11-19 16:25:10,688 - INFO - Predicted value for Bahrain in 2020: 10.405334936114269
# ...
# 2024-11-19 16:25:16,146 - INFO - Predicted value for Venezuela, RB in 2029: 24.375035428830596
# 2024-11-19 16:25:16,147 - INFO - Prediction inputs for Venezuela, RB in 2030: Year=2030, AL Moving_Avg_2Y=24.375035428830596, AL Moving_Avg_3Y=24.375035428830596, AL Moving_Avg_5Y=24.375035428830596, AL Moving_Avg_10Y=24.375035428830593
# 2024-11-19 16:25:16,149 - INFO - Predicted value for Venezuela, RB in 2030: 24.375035428830596
# 2024-11-19 16:25:16,149 - INFO - Processing country: Vietnam
# 2024-11-19 16:25:16,150 - INFO - Prediction inputs for Vietnam in 2019: Year=2019, AL Moving_Avg_2Y=39.1292764868599, AL Moving_Avg_3Y=39.02883856421573, AL Moving_Avg_5Y=38.93814800683616, AL Moving_Avg_10Y=36.7213989497208
# 2024-11-19 16:25:16,152 - INFO - Predicted value for Vietnam in 2019: 39.400781358147476
# 2024-11-19 16:25:16,152 - INFO - Prediction inputs for Vietnam in 2020: Year=2020, AL Moving_Avg_2Y=39.400781358147476, AL Moving_Avg_3Y=39.400781358147476, AL Moving_Avg_5Y=39.400781358147476, AL Moving_Avg_10Y=39.400781358147476
# 2024-11-19 16:25:16,154 - INFO - Predicted value for Vietnam in 2020: 39.5447587177912
# 2024-11-19 16:25:16,155 - INFO - Prediction inputs for Vietnam in 2021: Year=2021, AL Moving_Avg_2Y=39.47277003796934, AL Moving_Avg_3Y=39.49676626457663, AL Moving_Avg_5Y=39.51596324586245, AL Moving_Avg_10Y=39.53036098182682
# 2024-11-19 16:25:16,157 - INFO - Predicted value for Vietnam in 2021: 39.43271051811129
# 2024-11-19 16:25:16,157 - INFO - Prediction inputs for Vietnam in 2022: Year=2022, AL Moving_Avg_2Y=39.488734617951245, AL Moving_Avg_3Y=39.45941686468333, AL Moving_Avg_5Y=39.448734326054506, AL Moving_Avg_10Y=39.4407224220829
# 2024-11-19 16:25:16,159 - INFO - Predicted value for Vietnam in 2022: 39.46742888262888
# 2024-11-19 16:25:16,159 - INFO - Prediction inputs for Vietnam in 2023: Year=2023, AL Moving_Avg_2Y=39.450069700370086, AL Moving_Avg_3Y=39.48163270617712, AL Moving_Avg_5Y=39.462621671861555, AL Moving_Avg_10Y=39.46502527724521
# 2024-11-19 16:25:16,161 - INFO - Predicted value for Vietnam in 2023: 39.455483128765515
# 2024-11-19 16:25:16,162 - INFO - Prediction inputs for Vietnam in 2024: Year=2024, AL Moving_Avg_2Y=39.4614560056972, AL Moving_Avg_3Y=39.451874176501896, AL Moving_Avg_5Y=39.46023252108888, AL Moving_Avg_10Y=39.457857824927196
# 2024-11-19 16:25:16,163 - INFO - Predicted value for Vietnam in 2024: 39.45784954660786
# 2024-11-19 16:25:16,164 - INFO - Prediction inputs for Vietnam in 2025: Year=2025, AL Moving_Avg_2Y=39.456666337686684, AL Moving_Avg_3Y=39.46025385266742, AL Moving_Avg_5Y=39.47164615878095, AL Moving_Avg_10Y=39.45904103384837
# 2024-11-19 16:25:16,165 - INFO - Predicted value for Vietnam in 2025: 39.45893638451354
# 2024-11-19 16:25:16,166 - INFO - Prediction inputs for Vietnam in 2026: Year=2026, AL Moving_Avg_2Y=39.458392965560705, AL Moving_Avg_3Y=39.457423019962306, AL Moving_Avg_5Y=39.45448169212542, AL Moving_Avg_10Y=39.45947576901064
# 2024-11-19 16:25:16,167 - INFO - Predicted value for Vietnam in 2026: 39.45741100132565
# 2024-11-19 16:25:16,168 - INFO - Prediction inputs for Vietnam in 2027: Year=2027, AL Moving_Avg_2Y=39.4581736929196, AL Moving_Avg_3Y=39.45806564414902, AL Moving_Avg_5Y=39.459421788768296, AL Moving_Avg_10Y=39.45901815405428
# 2024-11-19 16:25:16,169 - INFO - Predicted value for Vietnam in 2027: 39.45784954660786
# 2024-11-19 16:25:16,170 - INFO - Prediction inputs for Vietnam in 2028: Year=2028, AL Moving_Avg_2Y=39.45763027396676, AL Moving_Avg_3Y=39.45806564414902, AL Moving_Avg_5Y=39.457505921564085, AL Moving_Avg_10Y=39.459105863110715
# 2024-11-19 16:25:16,172 - INFO - Predicted value for Vietnam in 2028: 39.45741100132565
# 2024-11-19 16:25:16,172 - INFO - Prediction inputs for Vietnam in 2029: Year=2029, AL Moving_Avg_2Y=39.45763027396676, AL Moving_Avg_3Y=39.45755718308639, AL Moving_Avg_5Y=39.457891496076115, AL Moving_Avg_10Y=39.459062008582485
# 2024-11-19 16:25:16,174 - INFO - Predicted value for Vietnam in 2029: 39.45741100132565
# 2024-11-19 16:25:16,174 - INFO - Prediction inputs for Vietnam in 2030: Year=2030, AL Moving_Avg_2Y=39.45741100132565, AL Moving_Avg_3Y=39.45755718308639, AL Moving_Avg_5Y=39.45780378701967, AL Moving_Avg_10Y=39.46472497290031
# 2024-11-19 16:25:16,176 - INFO - Predicted value for Vietnam in 2030: 39.45741100132565
# 2024-11-19 16:25:16,176 - INFO - Processing country: Yemen, Rep.
# 2024-11-19 16:25:16,177 - INFO - Prediction inputs for Yemen, Rep. in 2019: Year=2019, AL Moving_Avg_2Y=44.4191904843078, AL Moving_Avg_3Y=44.4191904843078, AL Moving_Avg_5Y=44.38676439949238, AL Moving_Avg_10Y=44.445138928348186
# 2024-11-19 16:25:16,178 - INFO - Predicted value for Yemen, Rep. in 2019: 44.424194279316616
# 2024-11-19 16:25:16,179 - INFO - Prediction inputs for Yemen, Rep. in 2020: Year=2020, AL Moving_Avg_2Y=44.424194279316616, AL Moving_Avg_3Y=44.424194279316616, AL Moving_Avg_5Y=44.424194279316616, AL Moving_Avg_10Y=44.424194279316616
# 2024-11-19 16:25:16,181 - INFO - Predicted value for Yemen, Rep. in 2020: 44.42000425879457
# 2024-11-19 16:25:16,181 - INFO - Prediction inputs for Yemen, Rep. in 2021: Year=2021, AL Moving_Avg_2Y=44.42209926905559, AL Moving_Avg_3Y=44.421400932301914, AL Moving_Avg_5Y=44.42084226289898, AL Moving_Avg_10Y=44.420423260846775
# 2024-11-19 16:25:16,183 - INFO - Predicted value for Yemen, Rep. in 2021: 44.4204892512152
# 2024-11-19 16:25:16,183 - INFO - Prediction inputs for Yemen, Rep. in 2022: Year=2022, AL Moving_Avg_2Y=44.42024675500488, AL Moving_Avg_3Y=44.42156259644213, AL Moving_Avg_5Y=44.42113325835136, AL Moving_Avg_10Y=44.42081125478328
# 2024-11-19 16:25:16,185 - INFO - Predicted value for Yemen, Rep. in 2022: 44.42319746258955
# 2024-11-19 16:25:16,185 - INFO - Prediction inputs for Yemen, Rep. in 2023: Year=2023, AL Moving_Avg_2Y=44.42184335690237, AL Moving_Avg_3Y=44.42123032419977, AL Moving_Avg_5Y=44.4222165429011, AL Moving_Avg_10Y=44.42270700274533
# 2024-11-19 16:25:16,187 - INFO - Predicted value for Yemen, Rep. in 2023: 44.4204892512152
# 2024-11-19 16:25:16,187 - INFO - Prediction inputs for Yemen, Rep. in 2024: Year=2024, AL Moving_Avg_2Y=44.42184335690237, AL Moving_Avg_3Y=44.421391988339984, AL Moving_Avg_5Y=44.42167490062623, AL Moving_Avg_10Y=44.421082075920715
# 2024-11-19 16:25:16,189 - INFO - Predicted value for Yemen, Rep. in 2024: 44.4204892512152
# 2024-11-19 16:25:16,189 - INFO - Prediction inputs for Yemen, Rep. in 2025: Year=2025, AL Moving_Avg_2Y=44.4204892512152, AL Moving_Avg_3Y=44.421391988339984, AL Moving_Avg_5Y=44.420933895005945, AL Moving_Avg_10Y=44.421082075920715
# 2024-11-19 16:25:16,191 - INFO - Predicted value for Yemen, Rep. in 2025: 44.42319746258955
# 2024-11-19 16:25:16,192 - INFO - Prediction inputs for Yemen, Rep. in 2026: Year=2026, AL Moving_Avg_2Y=44.42184335690237, AL Moving_Avg_3Y=44.421391988339984, AL Moving_Avg_5Y=44.42157253576494, AL Moving_Avg_10Y=44.42216536047046
# 2024-11-19 16:25:16,193 - INFO - Predicted value for Yemen, Rep. in 2026: 44.4204892512152
# 2024-11-19 16:25:16,194 - INFO - Prediction inputs for Yemen, Rep. in 2027: Year=2027, AL Moving_Avg_2Y=44.42184335690237, AL Moving_Avg_3Y=44.421391988339984, AL Moving_Avg_5Y=44.42157253576494, AL Moving_Avg_10Y=44.42135289705815
# 2024-11-19 16:25:16,196 - INFO - Predicted value for Yemen, Rep. in 2027: 44.4204892512152
# 2024-11-19 16:25:16,196 - INFO - Prediction inputs for Yemen, Rep. in 2028: Year=2028, AL Moving_Avg_2Y=44.4204892512152, AL Moving_Avg_3Y=44.421391988339984, AL Moving_Avg_5Y=44.42103089349007, AL Moving_Avg_10Y=44.42135289705815
# 2024-11-19 16:25:16,198 - INFO - Predicted value for Yemen, Rep. in 2028: 44.42319746258955
# 2024-11-19 16:25:16,198 - INFO - Prediction inputs for Yemen, Rep. in 2029: Year=2029, AL Moving_Avg_2Y=44.42184335690237, AL Moving_Avg_3Y=44.421391988339984, AL Moving_Avg_5Y=44.42157253576494, AL Moving_Avg_10Y=44.42162371819558
# 2024-11-19 16:25:16,200 - INFO - Predicted value for Yemen, Rep. in 2029: 44.4204892512152
# 2024-11-19 16:25:16,200 - INFO - Prediction inputs for Yemen, Rep. in 2030: Year=2030, AL Moving_Avg_2Y=44.42184335690237, AL Moving_Avg_3Y=44.421391988339984, AL Moving_Avg_5Y=44.42157253576494, AL Moving_Avg_10Y=44.42125321538544
# 2024-11-19 16:25:16,202 - INFO - Predicted value for Yemen, Rep. in 2030: 44.4204892512152
# 2024-11-19 16:25:16,202 - INFO - Processing country: Zambia
# 2024-11-19 16:25:16,203 - INFO - Prediction inputs for Zambia in 2019: Year=2019, AL Moving_Avg_2Y=32.0679589448338, AL Moving_Avg_3Y=32.0679589448338, AL Moving_Avg_5Y=32.01415138756239, AL Moving_Avg_10Y=31.93182582493713
# 2024-11-19 16:25:16,205 - INFO - Predicted value for Zambia in 2019: 32.06761577478899
# 2024-11-19 16:25:16,205 - INFO - Prediction inputs for Zambia in 2020: Year=2020, AL Moving_Avg_2Y=32.06761577478899, AL Moving_Avg_3Y=32.06761577478899, AL Moving_Avg_5Y=32.06761577478899, AL Moving_Avg_10Y=32.06761577478898
# 2024-11-19 16:25:16,207 - INFO - Predicted value for Zambia in 2020: 32.07526450644398
# 2024-11-19 16:25:16,207 - INFO - Prediction inputs for Zambia in 2021: Year=2021, AL Moving_Avg_2Y=32.07144014061649, AL Moving_Avg_3Y=32.07271492922565, AL Moving_Avg_5Y=32.07373476011298, AL Moving_Avg_10Y=32.07449963327848
# 2024-11-19 16:25:16,209 - INFO - Predicted value for Zambia in 2021: 32.07526450644398
# 2024-11-19 16:25:16,209 - INFO - Prediction inputs for Zambia in 2022: Year=2022, AL Moving_Avg_2Y=32.07526450644398, AL Moving_Avg_3Y=32.07271492922565, AL Moving_Avg_5Y=32.07373476011298, AL Moving_Avg_10Y=32.07449963327848
# 2024-11-19 16:25:16,211 - INFO - Predicted value for Zambia in 2022: 32.07898237285418
# 2024-11-19 16:25:16,211 - INFO - Prediction inputs for Zambia in 2023: Year=2023, AL Moving_Avg_2Y=32.07712343964908, AL Moving_Avg_3Y=32.07650379524738, AL Moving_Avg_5Y=32.07522190667706, AL Moving_Avg_10Y=32.07710213976562
# 2024-11-19 16:25:16,213 - INFO - Predicted value for Zambia in 2023: 32.07898237285418
# 2024-11-19 16:25:16,213 - INFO - Prediction inputs for Zambia in 2024: Year=2024, AL Moving_Avg_2Y=32.07898237285418, AL Moving_Avg_3Y=32.07774308405078, AL Moving_Avg_5Y=32.07522190667706, AL Moving_Avg_10Y=32.077102139765614
# 2024-11-19 16:25:16,215 - INFO - Predicted value for Zambia in 2024: 32.07799028340583
# 2024-11-19 16:25:16,216 - INFO - Prediction inputs for Zambia in 2025: Year=2025, AL Moving_Avg_2Y=32.078486328130005, AL Moving_Avg_3Y=32.0786516763714, AL Moving_Avg_5Y=32.077296808400426, AL Moving_Avg_10Y=32.07660609504144
# 2024-11-19 16:25:16,218 - INFO - Predicted value for Zambia in 2025: 32.07799028340583
# 2024-11-19 16:25:16,218 - INFO - Prediction inputs for Zambia in 2026: Year=2026, AL Moving_Avg_2Y=32.07799028340583, AL Moving_Avg_3Y=32.078320979888616, AL Moving_Avg_5Y=32.0778419637928, AL Moving_Avg_10Y=32.07660609504144
# 2024-11-19 16:25:16,220 - INFO - Predicted value for Zambia in 2026: 32.07799028340583
# 2024-11-19 16:25:16,220 - INFO - Prediction inputs for Zambia in 2027: Year=2027, AL Moving_Avg_2Y=32.07799028340583, AL Moving_Avg_3Y=32.07799028340583, AL Moving_Avg_5Y=32.078387119185166, AL Moving_Avg_10Y=32.07660609504144
# 2024-11-19 16:25:16,222 - INFO - Predicted value for Zambia in 2027: 32.07799028340583
# 2024-11-19 16:25:16,222 - INFO - Prediction inputs for Zambia in 2028: Year=2028, AL Moving_Avg_2Y=32.07799028340583, AL Moving_Avg_3Y=32.07799028340583, AL Moving_Avg_5Y=32.0781887012955, AL Moving_Avg_10Y=32.07660609504144
# 2024-11-19 16:25:16,224 - INFO - Predicted value for Zambia in 2028: 32.07799028340583
# 2024-11-19 16:25:16,224 - INFO - Prediction inputs for Zambia in 2029: Year=2029, AL Moving_Avg_2Y=32.07799028340583, AL Moving_Avg_3Y=32.07799028340583, AL Moving_Avg_5Y=32.07799028340583, AL Moving_Avg_10Y=32.07660609504144
# 2024-11-19 16:25:16,226 - INFO - Predicted value for Zambia in 2029: 32.07799028340583
# 2024-11-19 16:25:16,226 - INFO - Prediction inputs for Zambia in 2030: Year=2030, AL Moving_Avg_2Y=32.07799028340583, AL Moving_Avg_3Y=32.07799028340583, AL Moving_Avg_5Y=32.07799028340583, AL Moving_Avg_10Y=32.07764354590313
# 2024-11-19 16:25:16,228 - INFO - Predicted value for Zambia in 2030: 32.07799028340583
# 2024-11-19 16:25:16,229 - INFO - Processing country: Zimbabwe
# 2024-11-19 16:25:16,229 - INFO - Prediction inputs for Zimbabwe in 2019: Year=2019, AL Moving_Avg_2Y=41.8766963939511, AL Moving_Avg_3Y=41.8766963939511, AL Moving_Avg_5Y=41.8766963939511, AL Moving_Avg_10Y=41.92839601912882
# 2024-11-19 16:25:16,231 - INFO - Predicted value for Zimbabwe in 2019: 41.881351293883206
# 2024-11-19 16:25:16,231 - INFO - Prediction inputs for Zimbabwe in 2020: Year=2020, AL Moving_Avg_2Y=41.881351293883206, AL Moving_Avg_3Y=41.881351293883206, AL Moving_Avg_5Y=41.881351293883206, AL Moving_Avg_10Y=41.881351293883206
# 2024-11-19 16:25:16,233 - INFO - Predicted value for Zimbabwe in 2020: 41.88131736600419
# 2024-11-19 16:25:16,233 - INFO - Prediction inputs for Zimbabwe in 2021: Year=2021, AL Moving_Avg_2Y=41.8813343299437, AL Moving_Avg_3Y=41.8813286752972, AL Moving_Avg_5Y=41.88132415157999, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,235 - INFO - Predicted value for Zimbabwe in 2021: 41.88131736600419
# 2024-11-19 16:25:16,236 - INFO - Prediction inputs for Zimbabwe in 2022: Year=2022, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.8813286752972, AL Moving_Avg_5Y=41.881324151579996, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,237 - INFO - Predicted value for Zimbabwe in 2022: 41.88131736600419
# 2024-11-19 16:25:16,238 - INFO - Prediction inputs for Zimbabwe in 2023: Year=2023, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.88131736600419, AL Moving_Avg_5Y=41.881324151579996, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,240 - INFO - Predicted value for Zimbabwe in 2023: 41.88131736600419
# 2024-11-19 16:25:16,240 - INFO - Prediction inputs for Zimbabwe in 2024: Year=2024, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.88131736600419, AL Moving_Avg_5Y=41.881324151579996, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,242 - INFO - Predicted value for Zimbabwe in 2024: 41.88131736600419
# 2024-11-19 16:25:16,242 - INFO - Prediction inputs for Zimbabwe in 2025: Year=2025, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.88131736600419, AL Moving_Avg_5Y=41.88131736600419, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,244 - INFO - Predicted value for Zimbabwe in 2025: 41.88131736600419
# 2024-11-19 16:25:16,244 - INFO - Prediction inputs for Zimbabwe in 2026: Year=2026, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.88131736600419, AL Moving_Avg_5Y=41.88131736600419, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,246 - INFO - Predicted value for Zimbabwe in 2026: 41.88131736600419
# 2024-11-19 16:25:16,246 - INFO - Prediction inputs for Zimbabwe in 2027: Year=2027, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.88131736600419, AL Moving_Avg_5Y=41.88131736600419, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,248 - INFO - Predicted value for Zimbabwe in 2027: 41.88131736600419
# 2024-11-19 16:25:16,248 - INFO - Prediction inputs for Zimbabwe in 2028: Year=2028, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.88131736600419, AL Moving_Avg_5Y=41.88131736600419, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,250 - INFO - Predicted value for Zimbabwe in 2028: 41.88131736600419
# 2024-11-19 16:25:16,250 - INFO - Prediction inputs for Zimbabwe in 2029: Year=2029, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.88131736600419, AL Moving_Avg_5Y=41.88131736600419, AL Moving_Avg_10Y=41.881320758792086
# 2024-11-19 16:25:16,252 - INFO - Predicted value for Zimbabwe in 2029: 41.88131736600419
# 2024-11-19 16:25:16,252 - INFO - Prediction inputs for Zimbabwe in 2030: Year=2030, AL Moving_Avg_2Y=41.88131736600419, AL Moving_Avg_3Y=41.88131736600419, AL Moving_Avg_5Y=41.88131736600419, AL Moving_Avg_10Y=41.88131736600418
# 2024-11-19 16:25:16,254 - INFO - Predicted value for Zimbabwe in 2030: 41.88131736600419

# %%
# Converting the dictionary of predictions for each country (country_recursive_predictions_rf) into a DataFrame
# Initialize an empty list to store rows for the DataFrame
rows = []

# Loop through each country and its predictions to build the DataFrame rows
for country, predictions in country_recursive_predictions_rf.items():
    for year, ag_land in predictions.items():
        # Append each prediction as a new row with the country, year, and predicted value
        rows.append({'Country Name': country, 'Year': year, 'Agricultural land (% of land area)': ag_land})

# Convert the list of rows into a DataFrame
predictions_df_2= pd.DataFrame(rows)

# %%
# Displaying feature importances from the Random Forest model directly

# Calculating feature importances
feature_importances = model_rf.feature_importances_
feature_names = ['Year', 'Moving_Avg_2Y', 'Moving_Avg_3Y', 'Moving_Avg_5Y', 'Moving_Avg_10Y']

# Creating a DataFrame to organize and sort feature importances
import pandas as pd
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# %% [markdown]
# ## Indicator 3 - Train and Test Machine Learning

# %%
# Selecting specified columns
selected_df_3 = merged_df[['Country Name', 'Country Code', 'Year', 'Population density (people per sq. km of land area)']].copy()

# Sorting by 'Country Name' and 'Year' to prepare for rolling calculations
selected_df_3 = selected_df_3.sort_values(by=['Country Name', 'Year'])

selected_df_3['Year'] = selected_df_3['Year'].astype(int)

# Creating Moving Average and STD columns for the specified time frames (2, 3, 5, and 10 years)
# time_frames = [2, 3, 5, 10]
time_frames = [2, 3, 5, 10]
for window in time_frames:
    selected_df_3[f'PD Moving_Avg_{window}Y'] = selected_df_3.groupby('Country Name')['Population density (people per sq. km of land area)'].transform(lambda x: x.rolling(window, min_periods=1).mean())
    # selected_df[f'STD_{window}Y'] = selected_df.groupby('Country Name')['Life expectancy at birth, total (years)'].transform(lambda x: x.rolling(window, min_periods=1).std())

# Displaying the first few rows of the updated DataFrame
selected_df_3.loc[selected_df_3['Country Name'] == 'Austria']
# Out:
#     Country Name Country Code  Year  \
# 567      Austria          AUT  1960
# 568      Austria          AUT  1961
# 569      Austria          AUT  1962
# 570      Austria          AUT  1963
# 571      Austria          AUT  1964
# ..           ...          ...   ...
# 625      Austria          AUT  2018
# 626      Austria          AUT  2019
# 627      Austria          AUT  2020
# 628      Austria          AUT  2021
# 629      Austria          AUT  2022
#
#      Population density (people per sq. km of land area)  PD Moving_Avg_2Y  \
# 567                                                NaN                 NaN
# 568                                          85.873715           85.873715
# 569                                          86.401648           86.137682
# 570                                          86.958446           86.680047
# 571                                          87.540002           87.249224
# ..                                                 ...                 ...
# 625                                         107.131859          106.871589
# 626                                         107.609307          107.370583
# 627                                         108.057004          107.833156
# 628                                         108.528805          108.292905
# 629                                                NaN          108.528805
#
#      PD Moving_Avg_3Y  PD Moving_Avg_5Y  PD Moving_Avg_10Y
# 567               NaN               NaN                NaN
# 568         85.873715         85.873715          85.873715
# 569         86.137682         86.137682          86.137682
# 570         86.411270         86.411270          86.411270
# 571         86.966699         86.693453          86.693453
# ..                ...               ...                ...
# 625        106.538839        105.583640         103.698490
# 626        107.117495        106.392084         104.348753
# 627        107.599390        107.056566         105.019451
# 628        108.065039        107.587659         105.703108
# 629        108.292905        107.831744         106.097127
#
# [63 rows x 8 columns]

# %%
# Define year variables for training and prediction
TRAIN_START_YEAR = 1990
TRAIN_END_YEAR = 2009
PREDICTION_START_YEAR = 2010
PREDICTION_END_YEAR = 2019

# Setting up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Splitting data into training (2000-2019) set and setting up prediction years
train_df_3 = selected_df_3[(selected_df_3['Year'] >= TRAIN_START_YEAR) & (selected_df_3['Year'] <= TRAIN_END_YEAR)].dropna(subset=['Population density (people per sq. km of land area)'])
prediction_years = range(PREDICTION_START_YEAR, PREDICTION_END_YEAR + 1)

# Preparing training data for the model
X_train = train_df_3[['Year', 'PD Moving_Avg_2Y', 'PD Moving_Avg_3Y', 'PD Moving_Avg_5Y', 'PD Moving_Avg_10Y']].values
y_train = train_df_3['Population density (people per sq. km of land area)'].values

# Initializing and training the Random Forest model on all training data
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)
logger.info(f"Model trained on all countries' data ({TRAIN_START_YEAR}-{TRAIN_END_YEAR}). Starting recursive forecasting.")

# Dictionary to store predictions for each country
country_recursive_predictions_rf = {}

# Recursive forecasting for each country separately with detailed logging
for country in train_df_3['Country Name'].unique():
    logger.info(f"Processing country: {country}")

    # Get the last available data point for the country to start recursive prediction
    country_data = train_df_3[train_df_3['Country Name'] == country].iloc[-1].copy()
    predictions_per_country = {country_data['Year']: country_data['Population density (people per sq. km of land area)']}

    # Recursive prediction loop from PREDICTION_START_YEAR to PREDICTION_END_YEAR
    for year in prediction_years:
        country_data['Year'] = year
        
        # Logging the input data used for this prediction
        logger.info(f"Prediction inputs for {country} in {year}: Year={year}, "
                    f"PD Moving_Avg_2Y={country_data['PD Moving_Avg_2Y']}, "
                    f"PD Moving_Avg_3Y={country_data['PD Moving_Avg_3Y']}, "
                    f"PD Moving_Avg_5Y={country_data['PD Moving_Avg_5Y']}, "
                    f"PD Moving_Avg_10Y={country_data['PD Moving_Avg_10Y']}")
        
        # Preparing the features for the current prediction
        X_test = country_data[['Year', 'PD Moving_Avg_2Y', 'PD Moving_Avg_3Y', 'PD Moving_Avg_5Y', 'PD Moving_Avg_10Y']].values.reshape(1, -1)
        
        # Predicting life expectancy for the current year
        predicted_value = model_rf.predict(X_test)[0]
        logger.info(f"Predicted value for {country} in {year}: {predicted_value}")
        
        # Update the prediction in the dictionary
        predictions_per_country[year] = predicted_value
        
        # Update the features for the next prediction year based on the new prediction
        country_data['Population density (people per sq. km of land area)'] = predicted_value
        country_data['PD Moving_Avg_2Y'] = (predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 2
        country_data['PD Moving_Avg_3Y'] = (predictions_per_country.get(year - 2, predicted_value) +
                                         predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 3
        country_data['PD Moving_Avg_5Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 4, year + 1)) / 5)
        country_data['PD Moving_Avg_10Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 9, year + 1)) / 10)

    # Store the predictions for the country
    country_recursive_predictions_rf[country] = predictions_per_country
# Out:
# 2024-11-19 16:25:17,360 - INFO - Model trained on all countries' data (1990-2009). Starting recursive forecasting.
# 2024-11-19 16:25:17,361 - INFO - Processing country: Afghanistan
# 2024-11-19 16:25:17,362 - INFO - Prediction inputs for Afghanistan in 2010: Year=2010, PD Moving_Avg_2Y=41.2527068672094, PD Moving_Avg_3Y=40.740131037619626, PD Moving_Avg_5Y=39.731365315916165, PD Moving_Avg_10Y=36.183630467779764
# 2024-11-19 16:25:17,364 - INFO - Predicted value for Afghanistan in 2010: 41.85541467310776
# 2024-11-19 16:25:17,364 - INFO - Prediction inputs for Afghanistan in 2011: Year=2011, PD Moving_Avg_2Y=41.92130392058098, PD Moving_Avg_3Y=41.899340838089906, PD Moving_Avg_5Y=41.88177037209705, PD Moving_Avg_10Y=41.868592522602405
# 2024-11-19 16:25:17,367 - INFO - Predicted value for Afghanistan in 2011: 41.86779262908249
# 2024-11-19 16:25:17,367 - INFO - Prediction inputs for Afghanistan in 2012: Year=2012, PD Moving_Avg_2Y=41.86160365109512, PD Moving_Avg_3Y=41.90346682341482, PD Moving_Avg_5Y=41.889197145681884, PD Moving_Avg_10Y=41.87849488738219
# 2024-11-19 16:25:17,369 - INFO - Predicted value for Afghanistan in 2012: 41.74065431719473
# 2024-11-19 16:25:17,369 - INFO - Prediction inputs for Afghanistan in 2013: Year=2013, PD Moving_Avg_2Y=41.804223473138606, PD Moving_Avg_3Y=41.821287206461655, PD Moving_Avg_5Y=41.83834182092678, PD Moving_Avg_10Y=41.789498069060755
# 2024-11-19 16:25:17,371 - INFO - Predicted value for Afghanistan in 2013: 41.57419929256992
# 2024-11-19 16:25:17,371 - INFO - Prediction inputs for Afghanistan in 2014: Year=2014, PD Moving_Avg_2Y=41.65742680488233, PD Moving_Avg_3Y=41.72754874628237, PD Moving_Avg_5Y=41.80505081600182, PD Moving_Avg_10Y=41.68962505428588
# 2024-11-19 16:25:17,373 - INFO - Predicted value for Afghanistan in 2014: 41.43273383563786
# 2024-11-19 16:25:17,373 - INFO - Prediction inputs for Afghanistan in 2015: Year=2015, PD Moving_Avg_2Y=41.50346656410389, PD Moving_Avg_3Y=41.58252914846751, PD Moving_Avg_5Y=41.69415894951855, PD Moving_Avg_10Y=41.61889232581984
# 2024-11-19 16:25:17,375 - INFO - Predicted value for Afghanistan in 2015: 41.38938493151764
# 2024-11-19 16:25:17,375 - INFO - Prediction inputs for Afghanistan in 2016: Year=2016, PD Moving_Avg_2Y=41.41105938357775, PD Moving_Avg_3Y=41.465439353241806, PD Moving_Avg_5Y=41.60095300120052, PD Moving_Avg_10Y=41.60155276417176
# 2024-11-19 16:25:17,377 - INFO - Predicted value for Afghanistan in 2016: 41.40977001450659
# 2024-11-19 16:25:17,377 - INFO - Prediction inputs for Afghanistan in 2017: Year=2017, PD Moving_Avg_2Y=41.399577473012116, PD Moving_Avg_3Y=41.410629593887364, PD Moving_Avg_5Y=41.50934847828535, PD Moving_Avg_10Y=41.607668289068435
# 2024-11-19 16:25:17,379 - INFO - Predicted value for Afghanistan in 2017: 41.424848914249175
# 2024-11-19 16:25:17,380 - INFO - Prediction inputs for Afghanistan in 2018: Year=2018, PD Moving_Avg_2Y=41.41730946437788, PD Moving_Avg_3Y=41.4080012867578, PD Moving_Avg_5Y=41.446187397696235, PD Moving_Avg_10Y=41.610684069016955
# 2024-11-19 16:25:17,381 - INFO - Predicted value for Afghanistan in 2018: 41.46425885134706
# 2024-11-19 16:25:17,382 - INFO - Prediction inputs for Afghanistan in 2019: Year=2019, PD Moving_Avg_2Y=41.44455388279812, PD Moving_Avg_3Y=41.43295926003427, PD Moving_Avg_5Y=41.424199309451666, PD Moving_Avg_10Y=41.614625062726745
# 2024-11-19 16:25:17,384 - INFO - Predicted value for Afghanistan in 2019: 41.54312873990517
# 2024-11-19 16:25:17,384 - INFO - Processing country: Albania
# 2024-11-19 16:25:17,384 - INFO - Prediction inputs for Albania in 2010: Year=2010, PD Moving_Avg_2Y=107.204981751825, PD Moving_Avg_3Y=107.601581508516, PD Moving_Avg_5Y=108.38601459854019, PD Moving_Avg_10Y=109.91112773722621
# 2024-11-19 16:25:17,386 - INFO - Predicted value for Albania in 2010: 107.0527213229879
# 2024-11-19 16:25:17,387 - INFO - Prediction inputs for Albania in 2011: Year=2011, PD Moving_Avg_2Y=106.94824022353795, PD Moving_Avg_3Y=106.98306725668795, PD Moving_Avg_5Y=107.01092888320791, PD Moving_Avg_10Y=107.03182510309793
# 2024-11-19 16:25:17,388 - INFO - Predicted value for Albania in 2011: 107.42951129515001
# 2024-11-19 16:25:17,389 - INFO - Prediction inputs for Albania in 2012: Year=2012, PD Moving_Avg_2Y=107.24111630906896, PD Moving_Avg_3Y=107.10866391407531, PD Moving_Avg_5Y=107.2370028665052, PD Moving_Avg_10Y=107.33325708082756
# 2024-11-19 16:25:17,390 - INFO - Predicted value for Albania in 2012: 107.49406741597176
# 2024-11-19 16:25:17,391 - INFO - Prediction inputs for Albania in 2013: Year=2013, PD Moving_Avg_2Y=107.46178935556088, PD Moving_Avg_3Y=107.32543334470323, PD Moving_Avg_5Y=107.26282531483389, PD Moving_Avg_10Y=107.37844636540282
# 2024-11-19 16:25:17,393 - INFO - Predicted value for Albania in 2013: 107.48112255149063
# 2024-11-19 16:25:17,393 - INFO - Prediction inputs for Albania in 2014: Year=2014, PD Moving_Avg_2Y=107.48759498373119, PD Moving_Avg_3Y=107.46823375420412, PD Moving_Avg_5Y=107.26023634193766, PD Moving_Avg_10Y=107.37067944671415
# 2024-11-19 16:25:17,395 - INFO - Predicted value for Albania in 2014: 107.49060967643386
# 2024-11-19 16:25:17,395 - INFO - Prediction inputs for Albania in 2015: Year=2015, PD Moving_Avg_2Y=107.48586611396225, PD Moving_Avg_3Y=107.48859988129874, PD Moving_Avg_5Y=107.38960645240684, PD Moving_Avg_10Y=107.37542300918577
# 2024-11-19 16:25:17,397 - INFO - Predicted value for Albania in 2015: 107.46847091585089
# 2024-11-19 16:25:17,397 - INFO - Prediction inputs for Albania in 2016: Year=2016, PD Moving_Avg_2Y=107.47954029614237, PD Moving_Avg_3Y=107.48006771459178, PD Moving_Avg_5Y=107.47275637097941, PD Moving_Avg_10Y=107.36656750495258
# 2024-11-19 16:25:17,399 - INFO - Predicted value for Albania in 2016: 107.46948308692694
# 2024-11-19 16:25:17,399 - INFO - Prediction inputs for Albania in 2017: Year=2017, PD Moving_Avg_2Y=107.46897700138891, PD Moving_Avg_3Y=107.47618789307057, PD Moving_Avg_5Y=107.48075072933482, PD Moving_Avg_10Y=107.3668711562754
# 2024-11-19 16:25:17,413 - INFO - Predicted value for Albania in 2017: 107.46948308692694
# 2024-11-19 16:25:17,417 - INFO - Prediction inputs for Albania in 2018: Year=2018, PD Moving_Avg_2Y=107.46948308692694, PD Moving_Avg_3Y=107.46914569656826, PD Moving_Avg_5Y=107.47583386352585, PD Moving_Avg_10Y=107.3668711562754
# 2024-11-19 16:25:17,419 - INFO - Predicted value for Albania in 2018: 107.46948308692694
# 2024-11-19 16:25:17,419 - INFO - Prediction inputs for Albania in 2019: Year=2019, PD Moving_Avg_2Y=107.46948308692694, PD Moving_Avg_3Y=107.46948308692693, PD Moving_Avg_5Y=107.47350597061313, PD Moving_Avg_10Y=107.3668711562754
# 2024-11-19 16:25:17,423 - INFO - Predicted value for Albania in 2019: 107.46948308692694
# 2024-11-19 16:25:17,424 - INFO - Processing country: Algeria
# 2024-11-19 16:25:17,424 - INFO - Prediction inputs for Algeria in 2010: Year=2010, PD Moving_Avg_2Y=14.6459372139696, PD Moving_Avg_3Y=14.520120584110765, PD Moving_Avg_5Y=14.28713679914684, PD Moving_Avg_10Y=13.784359207974001
# 2024-11-19 16:25:17,427 - INFO - Predicted value for Algeria in 2010: 14.741503378737947
# 2024-11-19 16:25:17,427 - INFO - Prediction inputs for Algeria in 2011: Year=2011, PD Moving_Avg_2Y=14.759475269608624, PD Moving_Avg_3Y=14.7534846393184, PD Moving_Avg_5Y=14.74869213508622, PD Moving_Avg_10Y=14.745097756912083
# 2024-11-19 16:25:17,429 - INFO - Predicted value for Algeria in 2011: 14.946313263361176
# 2024-11-19 16:25:17,429 - INFO - Prediction inputs for Algeria in 2012: Year=2012, PD Moving_Avg_2Y=14.843908321049561, PD Moving_Avg_3Y=14.821754600859473, PD Moving_Avg_5Y=14.871578065860154, PD Moving_Avg_10Y=14.908945664610666
# 2024-11-19 16:25:17,431 - INFO - Predicted value for Algeria in 2012: 15.08735033203373
# 2024-11-19 16:25:17,431 - INFO - Prediction inputs for Algeria in 2013: Year=2013, PD Moving_Avg_2Y=15.016831797697453, PD Moving_Avg_3Y=14.925055658044284, PD Moving_Avg_5Y=14.927992893329176, PD Moving_Avg_10Y=15.007671612681454
# 2024-11-19 16:25:17,433 - INFO - Predicted value for Algeria in 2013: 15.302303835589342
# 2024-11-19 16:25:17,433 - INFO - Prediction inputs for Algeria in 2014: Year=2014, PD Moving_Avg_2Y=15.194827083811536, PD Moving_Avg_3Y=15.111989143661416, PD Moving_Avg_5Y=14.970983594040296, PD Moving_Avg_10Y=15.136643714814818
# 2024-11-19 16:25:17,435 - INFO - Predicted value for Algeria in 2014: 15.428728584817682
# 2024-11-19 16:25:17,436 - INFO - Prediction inputs for Algeria in 2015: Year=2015, PD Moving_Avg_2Y=15.365516210203513, PD Moving_Avg_3Y=15.272794250813584, PD Moving_Avg_5Y=15.101239878907975, PD Moving_Avg_10Y=15.199856089428994
# 2024-11-19 16:25:17,437 - INFO - Predicted value for Algeria in 2015: 15.61109198808972
# 2024-11-19 16:25:17,438 - INFO - Prediction inputs for Algeria in 2016: Year=2016, PD Moving_Avg_2Y=15.519910286453701, PD Moving_Avg_3Y=15.447374802832249, PD Moving_Avg_5Y=15.275157600778332, PD Moving_Avg_10Y=15.272801450737806
# 2024-11-19 16:25:17,440 - INFO - Predicted value for Algeria in 2016: 15.747866629283491
# 2024-11-19 16:25:17,440 - INFO - Prediction inputs for Algeria in 2017: Year=2017, PD Moving_Avg_2Y=15.679479308686606, PD Moving_Avg_3Y=15.595895734063632, PD Moving_Avg_5Y=15.435468273962792, PD Moving_Avg_10Y=15.313833843095939
# 2024-11-19 16:25:17,442 - INFO - Predicted value for Algeria in 2017: 15.916373642293525
# 2024-11-19 16:25:17,442 - INFO - Prediction inputs for Algeria in 2018: Year=2018, PD Moving_Avg_2Y=15.832120135788507, PD Moving_Avg_3Y=15.75844408655558, PD Moving_Avg_5Y=15.601272936014752, PD Moving_Avg_10Y=15.347535245697944
# 2024-11-19 16:25:17,444 - INFO - Predicted value for Algeria in 2018: 16.122801475245772
# 2024-11-19 16:25:17,444 - INFO - Prediction inputs for Algeria in 2019: Year=2019, PD Moving_Avg_2Y=16.01958755876965, PD Moving_Avg_3Y=15.929013915607596, PD Moving_Avg_5Y=15.76537246394604, PD Moving_Avg_10Y=15.368178028993167
# 2024-11-19 16:25:17,446 - INFO - Predicted value for Algeria in 2019: 16.228223772049702
# 2024-11-19 16:25:17,446 - INFO - Processing country: Andorra
# 2024-11-19 16:25:17,446 - INFO - Prediction inputs for Andorra in 2010: Year=2010, PD Moving_Avg_2Y=159.4755319148935, PD Moving_Avg_3Y=161.755319148936, PD Moving_Avg_5Y=165.1582978723402, PD Moving_Avg_10Y=158.23999999999992
# 2024-11-19 16:25:17,449 - INFO - Predicted value for Andorra in 2010: 157.86539511199928
# 2024-11-19 16:25:17,449 - INFO - Prediction inputs for Andorra in 2011: Year=2011, PD Moving_Avg_2Y=157.49865500280814, PD Moving_Avg_3Y=157.62090170587183, PD Moving_Avg_5Y=157.71869906832282, PD Moving_Avg_10Y=157.79204709016105
# 2024-11-19 16:25:17,451 - INFO - Predicted value for Andorra in 2011: 157.660494351398
# 2024-11-19 16:25:17,451 - INFO - Prediction inputs for Andorra in 2012: Year=2012, PD Moving_Avg_2Y=157.76294473169864, PD Moving_Avg_3Y=157.55260145233808, PD Moving_Avg_5Y=157.59575861196205, PD Moving_Avg_10Y=157.62812648168003
# 2024-11-19 16:25:17,453 - INFO - Predicted value for Andorra in 2012: 157.73645639780437
# 2024-11-19 16:25:17,453 - INFO - Prediction inputs for Andorra in 2013: Year=2013, PD Moving_Avg_2Y=157.69847537460117, PD Moving_Avg_3Y=157.7541152870672, PD Moving_Avg_5Y=157.6261434305246, PD Moving_Avg_10Y=157.68129991416453
# 2024-11-19 16:25:17,455 - INFO - Predicted value for Andorra in 2013: 157.74364211209007
# 2024-11-19 16:25:17,455 - INFO - Prediction inputs for Andorra in 2014: Year=2014, PD Moving_Avg_2Y=157.74004925494722, PD Moving_Avg_3Y=157.71353095376415, PD Moving_Avg_5Y=157.62758057338175, PD Moving_Avg_10Y=157.68561134273594
# 2024-11-19 16:25:17,457 - INFO - Predicted value for Andorra in 2014: 157.74364211209007
# 2024-11-19 16:25:17,458 - INFO - Prediction inputs for Andorra in 2015: Year=2015, PD Moving_Avg_2Y=157.74364211209007, PD Moving_Avg_3Y=157.74124687399484, PD Moving_Avg_5Y=157.74992601707635, PD Moving_Avg_10Y=157.68561134273594
# 2024-11-19 16:25:17,459 - INFO - Predicted value for Andorra in 2015: 157.74364211209007
# 2024-11-19 16:25:17,460 - INFO - Prediction inputs for Andorra in 2016: Year=2016, PD Moving_Avg_2Y=157.74364211209007, PD Moving_Avg_3Y=157.74364211209007, PD Moving_Avg_5Y=157.72557541709452, PD Moving_Avg_10Y=157.68561134273594
# 2024-11-19 16:25:17,461 - INFO - Predicted value for Andorra in 2016: 157.74364211209007
# 2024-11-19 16:25:17,462 - INFO - Prediction inputs for Andorra in 2017: Year=2017, PD Moving_Avg_2Y=157.74364211209007, PD Moving_Avg_3Y=157.74364211209007, PD Moving_Avg_5Y=157.74220496923294, PD Moving_Avg_10Y=157.68561134273594
# 2024-11-19 16:25:17,464 - INFO - Predicted value for Andorra in 2017: 157.74364211209007
# 2024-11-19 16:25:17,464 - INFO - Prediction inputs for Andorra in 2018: Year=2018, PD Moving_Avg_2Y=157.74364211209007, PD Moving_Avg_3Y=157.74364211209007, PD Moving_Avg_5Y=157.74364211209007, PD Moving_Avg_10Y=157.68561134273594
# 2024-11-19 16:25:17,466 - INFO - Predicted value for Andorra in 2018: 157.74364211209007
# 2024-11-19 16:25:17,466 - INFO - Prediction inputs for Andorra in 2019: Year=2019, PD Moving_Avg_2Y=157.74364211209007, PD Moving_Avg_3Y=157.74364211209007, PD Moving_Avg_5Y=157.74364211209007, PD Moving_Avg_10Y=157.68561134273594
# 2024-11-19 16:25:17,468 - INFO - Predicted value for Andorra in 2019: 157.74364211209007
# 2024-11-19 16:25:17,468 - INFO - Processing country: Angola
# 2024-11-19 16:25:17,469 - INFO - Prediction inputs for Angola in 2010: Year=2010, PD Moving_Avg_2Y=17.7264762974252, PD Moving_Avg_3Y=17.408325980588767, PD Moving_Avg_5Y=16.79990037699528, PD Moving_Avg_10Y=15.438311863319171
# 2024-11-19 16:25:17,470 - INFO - Predicted value for Angola in 2010: 17.994472706226485
# 2024-11-19 16:25:17,471 - INFO - Prediction inputs for Angola in 2011: Year=2011, PD Moving_Avg_2Y=18.024136970743793, PD Moving_Avg_3Y=18.014248882571355, PD Moving_Avg_5Y=18.006338412033408, PD Moving_Avg_10Y=18.000405559129945
# 2024-11-19 16:25:17,473 - INFO - Predicted value for Angola in 2011: 18.165362132948218
# 2024-11-19 16:25:17,473 - INFO - Prediction inputs for Angola in 2012: Year=2012, PD Moving_Avg_2Y=18.079917419587353, PD Moving_Avg_3Y=18.071212024811935, PD Moving_Avg_5Y=18.10887206806645, PD Moving_Avg_10Y=18.137117100507332
# 2024-11-19 16:25:17,475 - INFO - Predicted value for Angola in 2012: 18.19690863798294
# 2024-11-19 16:25:17,475 - INFO - Prediction inputs for Angola in 2013: Year=2013, PD Moving_Avg_2Y=18.18113538546558, PD Moving_Avg_3Y=18.118914492385883, PD Moving_Avg_5Y=18.121490670080338, PD Moving_Avg_10Y=18.15919965403164
# 2024-11-19 16:25:17,477 - INFO - Predicted value for Angola in 2013: 18.30277044777655
# 2024-11-19 16:25:17,477 - INFO - Prediction inputs for Angola in 2014: Year=2014, PD Moving_Avg_2Y=18.249839542879744, PD Moving_Avg_3Y=18.221680406235905, PD Moving_Avg_5Y=18.14266303203906, PD Moving_Avg_10Y=18.222716739907803
# 2024-11-19 16:25:17,479 - INFO - Predicted value for Angola in 2014: 18.419601553892342
# 2024-11-19 16:25:17,479 - INFO - Prediction inputs for Angola in 2015: Year=2015, PD Moving_Avg_2Y=18.361186000834444, PD Moving_Avg_3Y=18.306426879883944, PD Moving_Avg_5Y=18.21582309576531, PD Moving_Avg_10Y=18.2811322929657
# 2024-11-19 16:25:17,481 - INFO - Predicted value for Angola in 2015: 18.47022329880552
# 2024-11-19 16:25:17,481 - INFO - Prediction inputs for Angola in 2016: Year=2016, PD Moving_Avg_2Y=18.44491242634893, PD Moving_Avg_3Y=18.3975317668248, PD Moving_Avg_5Y=18.310973214281116, PD Moving_Avg_10Y=18.301380990930973
# 2024-11-19 16:25:17,483 - INFO - Predicted value for Angola in 2016: 18.60713440245081
# 2024-11-19 16:25:17,483 - INFO - Prediction inputs for Angola in 2017: Year=2017, PD Moving_Avg_2Y=18.538678850628166, PD Moving_Avg_3Y=18.49898641838289, PD Moving_Avg_5Y=18.399327668181634, PD Moving_Avg_10Y=18.342454322024558
# 2024-11-19 16:25:17,485 - INFO - Predicted value for Angola in 2017: 18.707356218064152
# 2024-11-19 16:25:17,485 - INFO - Prediction inputs for Angola in 2018: Year=2018, PD Moving_Avg_2Y=18.65724531025748, PD Moving_Avg_3Y=18.594904639773493, PD Moving_Avg_5Y=18.501417184197873, PD Moving_Avg_10Y=18.362498685147226
# 2024-11-19 16:25:17,487 - INFO - Predicted value for Angola in 2018: 18.794837025297465
# 2024-11-19 16:25:17,488 - INFO - Prediction inputs for Angola in 2019: Year=2019, PD Moving_Avg_2Y=18.75109662168081, PD Moving_Avg_3Y=18.70310921527081, PD Moving_Avg_5Y=18.59983049970206, PD Moving_Avg_10Y=18.37124676587056
# 2024-11-19 16:25:17,489 - INFO - Predicted value for Angola in 2019: 18.87059459035522
# 2024-11-19 16:25:17,490 - INFO - Processing country: Antigua and Barbuda
# 2024-11-19 16:25:17,490 - INFO - Prediction inputs for Antigua and Barbuda in 2010: Year=2010, PD Moving_Avg_2Y=190.66477272727246, PD Moving_Avg_3Y=189.24318181818168, PD Moving_Avg_5Y=186.6204545454546, PD Moving_Avg_10Y=180.9195454545455
# 2024-11-19 16:25:17,492 - INFO - Predicted value for Antigua and Barbuda in 2010: 191.8604863106841
# 2024-11-19 16:25:17,492 - INFO - Prediction inputs for Antigua and Barbuda in 2011: Year=2011, PD Moving_Avg_2Y=191.99160679170555, PD Moving_Avg_3Y=191.9478999646984, PD Moving_Avg_5Y=191.91293450309269, PD Moving_Avg_10Y=191.8867104068884
# 2024-11-19 16:25:17,494 - INFO - Predicted value for Antigua and Barbuda in 2011: 193.34267366032364
# 2024-11-19 16:25:17,495 - INFO - Prediction inputs for Antigua and Barbuda in 2012: Year=2012, PD Moving_Avg_2Y=192.60157998550386, PD Moving_Avg_3Y=192.44196241457826, PD Moving_Avg_5Y=192.8022469128764, PD Moving_Avg_10Y=193.07246028660003
# 2024-11-19 16:25:17,496 - INFO - Predicted value for Antigua and Barbuda in 2012: 193.30373771774305
# 2024-11-19 16:25:17,497 - INFO - Prediction inputs for Antigua and Barbuda in 2013: Year=2013, PD Moving_Avg_2Y=193.32320568903333, PD Moving_Avg_3Y=192.8356325629169, PD Moving_Avg_5Y=192.78667253584416, PD Moving_Avg_10Y=193.0452051267936
# 2024-11-19 16:25:17,498 - INFO - Predicted value for Antigua and Barbuda in 2013: 193.49064984364787
# 2024-11-19 16:25:17,499 - INFO - Prediction inputs for Antigua and Barbuda in 2014: Year=2014, PD Moving_Avg_2Y=193.39719378069546, PD Moving_Avg_3Y=193.37902040723816, PD Moving_Avg_5Y=192.82405496102515, PD Moving_Avg_10Y=193.1573524023365
# 2024-11-19 16:25:17,501 - INFO - Predicted value for Antigua and Barbuda in 2014: 194.01730781175868
# 2024-11-19 16:25:17,501 - INFO - Prediction inputs for Antigua and Barbuda in 2015: Year=2015, PD Moving_Avg_2Y=193.7539788277033, PD Moving_Avg_3Y=193.60389845771655, PD Moving_Avg_5Y=193.20297106883146, PD Moving_Avg_10Y=193.4206813863919
# 2024-11-19 16:25:17,503 - INFO - Predicted value for Antigua and Barbuda in 2015: 194.17061679143978
# 2024-11-19 16:25:17,503 - INFO - Prediction inputs for Antigua and Barbuda in 2016: Year=2016, PD Moving_Avg_2Y=194.09396230159922, PD Moving_Avg_3Y=193.8928581489488, PD Moving_Avg_5Y=193.6649971649826, PD Moving_Avg_10Y=193.48200497826434
# 2024-11-19 16:25:17,505 - INFO - Predicted value for Antigua and Barbuda in 2016: 195.36410194520263
# 2024-11-19 16:25:17,505 - INFO - Prediction inputs for Antigua and Barbuda in 2017: Year=2017, PD Moving_Avg_2Y=194.7673593683212, PD Moving_Avg_3Y=194.51734218280035, PD Moving_Avg_5Y=194.0692828219584, PD Moving_Avg_10Y=193.84005052439318
# 2024-11-19 16:25:17,507 - INFO - Predicted value for Antigua and Barbuda in 2017: 196.0368745293598
# 2024-11-19 16:25:17,507 - INFO - Prediction inputs for Antigua and Barbuda in 2018: Year=2018, PD Moving_Avg_2Y=195.7004882372812, PD Moving_Avg_3Y=195.1905310886674, PD Moving_Avg_5Y=194.61591018428174, PD Moving_Avg_10Y=193.97460504122463
# 2024-11-19 16:25:17,509 - INFO - Predicted value for Antigua and Barbuda in 2018: 196.38673646552482
# 2024-11-19 16:25:17,509 - INFO - Prediction inputs for Antigua and Barbuda in 2019: Year=2019, PD Moving_Avg_2Y=196.2118054974423, PD Moving_Avg_3Y=195.92923764669573, PD Moving_Avg_5Y=195.19512750865712, PD Moving_Avg_10Y=194.00959123484114
# 2024-11-19 16:25:17,511 - INFO - Predicted value for Antigua and Barbuda in 2019: 196.94314995988483
# 2024-11-19 16:25:17,511 - INFO - Processing country: Argentina
# 2024-11-19 16:25:17,512 - INFO - Prediction inputs for Argentina in 2010: Year=2010, PD Moving_Avg_2Y=14.79124544614115, PD Moving_Avg_3Y=14.717806060118866, PD Moving_Avg_5Y=14.571001465273758, PD Moving_Avg_10Y=14.205658112537417
# 2024-11-19 16:25:17,514 - INFO - Predicted value for Argentina in 2010: 14.931881300201958
# 2024-11-19 16:25:17,514 - INFO - Prediction inputs for Argentina in 2011: Year=2011, PD Moving_Avg_2Y=14.89906935667718, PD Moving_Avg_3Y=14.910006671185437, PD Moving_Avg_5Y=14.918756522792046, PD Moving_Avg_10Y=14.925318911496998
# 2024-11-19 16:25:17,516 - INFO - Predicted value for Argentina in 2011: 15.162709192715996
# 2024-11-19 16:25:17,516 - INFO - Prediction inputs for Argentina in 2012: Year=2012, PD Moving_Avg_2Y=15.047295246458976, PD Moving_Avg_3Y=14.986949302023453, PD Moving_Avg_5Y=15.057253258300468, PD Moving_Avg_10Y=15.109981225508232
# 2024-11-19 16:25:17,518 - INFO - Predicted value for Argentina in 2012: 15.3192245596887
# 2024-11-19 16:25:17,518 - INFO - Prediction inputs for Argentina in 2013: Year=2013, PD Moving_Avg_2Y=15.240966876202346, PD Moving_Avg_3Y=15.137938350868884, PD Moving_Avg_5Y=15.119859405089551, PD Moving_Avg_10Y=15.219541982389126
# 2024-11-19 16:25:17,520 - INFO - Predicted value for Argentina in 2013: 15.55901595540775
# 2024-11-19 16:25:17,520 - INFO - Prediction inputs for Argentina in 2014: Year=2014, PD Moving_Avg_2Y=15.439120257548225, PD Moving_Avg_3Y=15.346983235937481, PD Moving_Avg_5Y=15.167817684233361, PD Moving_Avg_10Y=15.363416819820554
# 2024-11-19 16:25:17,522 - INFO - Predicted value for Argentina in 2014: 15.695916598291694
# 2024-11-19 16:25:17,522 - INFO - Prediction inputs for Argentina in 2015: Year=2015, PD Moving_Avg_2Y=15.627466276849722, PD Moving_Avg_3Y=15.524719037796048, PD Moving_Avg_5Y=15.33374952126122, PD Moving_Avg_10Y=15.431867141262526
# 2024-11-19 16:25:17,524 - INFO - Predicted value for Argentina in 2015: 15.839558549969542
# 2024-11-19 16:25:17,524 - INFO - Prediction inputs for Argentina in 2016: Year=2016, PD Moving_Avg_2Y=15.767737574130617, PD Moving_Avg_3Y=15.698163701222995, PD Moving_Avg_5Y=15.515284971214736, PD Moving_Avg_10Y=15.489323921933666
# 2024-11-19 16:25:17,526 - INFO - Predicted value for Argentina in 2016: 15.958102223171558
# 2024-11-19 16:25:17,526 - INFO - Prediction inputs for Argentina in 2017: Year=2017, PD Moving_Avg_2Y=15.89883038657055, PD Moving_Avg_3Y=15.831192457144263, PD Moving_Avg_5Y=15.674363577305849, PD Moving_Avg_10Y=15.524887023894271
# 2024-11-19 16:25:17,528 - INFO - Predicted value for Argentina in 2017: 16.165145238482967
# 2024-11-19 16:25:17,528 - INFO - Prediction inputs for Argentina in 2018: Year=2018, PD Moving_Avg_2Y=16.061623730827264, PD Moving_Avg_3Y=15.98760200387469, PD Moving_Avg_5Y=15.843547713064703, PD Moving_Avg_10Y=15.566295626956554
# 2024-11-19 16:25:17,530 - INFO - Predicted value for Argentina in 2018: 16.276206831752642
# 2024-11-19 16:25:17,530 - INFO - Prediction inputs for Argentina in 2019: Year=2019, PD Moving_Avg_2Y=16.220676035117805, PD Moving_Avg_3Y=16.133151431135726, PD Moving_Avg_5Y=15.986985888333681, PD Moving_Avg_10Y=15.57740178628352
# 2024-11-19 16:25:17,532 - INFO - Predicted value for Argentina in 2019: 16.42880974254381
# 2024-11-19 16:25:17,532 - INFO - Processing country: Armenia
# 2024-11-19 16:25:17,533 - INFO - Prediction inputs for Armenia in 2010: Year=2010, PD Moving_Avg_2Y=104.455865823674, PD Moving_Avg_3Y=104.81337079967199, PD Moving_Avg_5Y=105.555616438356, PD Moving_Avg_10Y=107.41967685282751
# 2024-11-19 16:25:17,535 - INFO - Predicted value for Armenia in 2010: 104.46757351460901
# 2024-11-19 16:25:17,536 - INFO - Prediction inputs for Armenia in 2011: Year=2011, PD Moving_Avg_2Y=104.293779732366, PD Moving_Avg_3Y=104.35171099311367, PD Moving_Avg_5Y=104.39805600171182, PD Moving_Avg_10Y=104.43281475816043
# 2024-11-19 16:25:17,537 - INFO - Predicted value for Armenia in 2011: 104.77962208709832
# 2024-11-19 16:25:17,538 - INFO - Prediction inputs for Armenia in 2012: Year=2012, PD Moving_Avg_2Y=104.62359780085367, PD Moving_Avg_3Y=104.45572718394344, PD Moving_Avg_5Y=104.5852851452054, PD Moving_Avg_10Y=104.68245361615186
# 2024-11-19 16:25:17,539 - INFO - Predicted value for Armenia in 2012: 104.73787882822296
# 2024-11-19 16:25:17,540 - INFO - Prediction inputs for Armenia in 2013: Year=2013, PD Moving_Avg_2Y=104.75875045766064, PD Moving_Avg_3Y=104.66169147664344, PD Moving_Avg_5Y=104.56858784165524, PD Moving_Avg_10Y=104.65323333493912
# 2024-11-19 16:25:17,542 - INFO - Predicted value for Armenia in 2013: 105.40270159047299
# 2024-11-19 16:25:17,542 - INFO - Prediction inputs for Armenia in 2014: Year=2014, PD Moving_Avg_2Y=105.07029020934797, PD Moving_Avg_3Y=104.97340083526474, PD Moving_Avg_5Y=104.70155239410524, PD Moving_Avg_10Y=105.05212699228915
# 2024-11-19 16:25:17,544 - INFO - Predicted value for Armenia in 2014: 105.40312392694048
# 2024-11-19 16:25:17,544 - INFO - Prediction inputs for Armenia in 2015: Year=2015, PD Moving_Avg_2Y=105.40291275870673, PD Moving_Avg_3Y=105.18123478187881, PD Moving_Avg_5Y=104.95817998946875, PD Moving_Avg_10Y=105.05233816052286
# 2024-11-19 16:25:17,546 - INFO - Predicted value for Armenia in 2015: 105.58651445096707
# 2024-11-19 16:25:17,546 - INFO - Prediction inputs for Armenia in 2016: Year=2016, PD Moving_Avg_2Y=105.49481918895378, PD Moving_Avg_3Y=105.46411332279352, PD Moving_Avg_5Y=105.18196817674036, PD Moving_Avg_10Y=105.12569437013352
# 2024-11-19 16:25:17,548 - INFO - Predicted value for Armenia in 2016: 106.30150305928235
# 2024-11-19 16:25:17,548 - INFO - Prediction inputs for Armenia in 2017: Year=2017, PD Moving_Avg_2Y=105.94400875512471, PD Moving_Avg_3Y=105.76371381239665, PD Moving_Avg_5Y=105.48634437117717, PD Moving_Avg_10Y=105.34019095262809
# 2024-11-19 16:25:17,550 - INFO - Predicted value for Armenia in 2017: 105.91061666446791
# 2024-11-19 16:25:17,550 - INFO - Prediction inputs for Armenia in 2018: Year=2018, PD Moving_Avg_2Y=106.10605986187514, PD Moving_Avg_3Y=105.93287805823911, PD Moving_Avg_5Y=105.72089193842616, PD Moving_Avg_10Y=105.26201367366521
# 2024-11-19 16:25:17,552 - INFO - Predicted value for Armenia in 2018: 105.96377788544798
# 2024-11-19 16:25:17,552 - INFO - Prediction inputs for Armenia in 2019: Year=2019, PD Moving_Avg_2Y=105.93719727495795, PD Moving_Avg_3Y=106.05863253639943, PD Moving_Avg_5Y=105.83310719742117, PD Moving_Avg_10Y=105.2673297957632
# 2024-11-19 16:25:17,554 - INFO - Predicted value for Armenia in 2019: 105.98294150539814
# 2024-11-19 16:25:17,554 - INFO - Processing country: Australia
# 2024-11-19 16:25:17,555 - INFO - Prediction inputs for Australia in 2010: Year=2010, PD Moving_Avg_2Y=2.794791403616105, PD Moving_Avg_3Y=2.7669002772607167, PD Moving_Avg_5Y=2.717839292920088, PD Moving_Avg_10Y=2.627448238157842
# 2024-11-19 16:25:17,557 - INFO - Predicted value for Australia in 2010: 2.817241850231217
# 2024-11-19 16:25:17,557 - INFO - Prediction inputs for Australia in 2011: Year=2011, PD Moving_Avg_2Y=2.8204151143558085, PD Moving_Avg_3Y=2.8193573596476114, PD Moving_Avg_5Y=2.818511155881054, PD Moving_Avg_10Y=2.8178765030561346
# 2024-11-19 16:25:17,559 - INFO - Predicted value for Australia in 2011: 2.8621076149654594
# 2024-11-19 16:25:17,559 - INFO - Prediction inputs for Australia in 2012: Year=2012, PD Moving_Avg_2Y=2.839674732598338, PD Moving_Avg_3Y=2.834312614559025, PD Moving_Avg_5Y=2.845430614721599, PD Moving_Avg_10Y=2.853769114843529
# 2024-11-19 16:25:17,561 - INFO - Predicted value for Australia in 2012: 2.884599162045198
# 2024-11-19 16:25:17,561 - INFO - Prediction inputs for Australia in 2013: Year=2013, PD Moving_Avg_2Y=2.8733533885053286, PD Moving_Avg_3Y=2.854649542413958, PD Moving_Avg_5Y=2.854427233553495, PD Moving_Avg_10Y=2.8695131977993458
# 2024-11-19 16:25:17,563 - INFO - Predicted value for Australia in 2013: 2.9159366310424457
# 2024-11-19 16:25:17,563 - INFO - Prediction inputs for Australia in 2014: Year=2014, PD Moving_Avg_2Y=2.9002678965438218, PD Moving_Avg_3Y=2.887547802684368, PD Moving_Avg_5Y=2.8606947273529437, PD Moving_Avg_10Y=2.888315679197695
# 2024-11-19 16:25:17,565 - INFO - Predicted value for Australia in 2014: 2.9322059934955793
# 2024-11-19 16:25:17,566 - INFO - Prediction inputs for Australia in 2015: Year=2015, PD Moving_Avg_2Y=2.9240713122690125, PD Moving_Avg_3Y=2.910913928861074, PD Moving_Avg_5Y=2.88241825035598, PD Moving_Avg_10Y=2.8964503604242617
# 2024-11-19 16:25:17,568 - INFO - Predicted value for Australia in 2015: 2.9723038264733996
# 2024-11-19 16:25:17,568 - INFO - Prediction inputs for Australia in 2016: Year=2016, PD Moving_Avg_2Y=2.9522549099844895, PD Moving_Avg_3Y=2.940148817003808, PD Moving_Avg_5Y=2.9134306456044166, PD Moving_Avg_10Y=2.91248949361539
# 2024-11-19 16:25:17,570 - INFO - Predicted value for Australia in 2016: 3.0124791967267055
# 2024-11-19 16:25:17,570 - INFO - Prediction inputs for Australia in 2017: Year=2017, PD Moving_Avg_2Y=2.9923915116000526, PD Moving_Avg_3Y=2.972329672231895, PD Moving_Avg_5Y=2.9435049619566653, PD Moving_Avg_10Y=2.9245421046913815
# 2024-11-19 16:25:17,572 - INFO - Predicted value for Australia in 2017: 3.042389786719605
# 2024-11-19 16:25:17,572 - INFO - Prediction inputs for Australia in 2018: Year=2018, PD Moving_Avg_2Y=3.027434491723155, PD Moving_Avg_3Y=3.00905760330657, PD Moving_Avg_5Y=2.975063086891547, PD Moving_Avg_10Y=2.9305242226899617
# 2024-11-19 16:25:17,574 - INFO - Predicted value for Australia in 2018: 3.079254277419831
# 2024-11-19 16:25:17,574 - INFO - Prediction inputs for Australia in 2019: Year=2019, PD Moving_Avg_2Y=3.060822032069718, PD Moving_Avg_3Y=3.044707753622047, PD Moving_Avg_5Y=3.007726616167024, PD Moving_Avg_10Y=2.9342106717599843
# 2024-11-19 16:25:17,576 - INFO - Predicted value for Australia in 2019: 3.09829601751051
# 2024-11-19 16:25:17,576 - INFO - Processing country: Austria
# 2024-11-19 16:25:17,577 - INFO - Prediction inputs for Austria in 2010: Year=2010, PD Moving_Avg_2Y=100.97442438196799, PD Moving_Avg_3Y=100.82527872031034, PD Moving_Avg_5Y=100.47691711100347, PD Moving_Avg_10Y=99.23167838099859
# 2024-11-19 16:25:17,579 - INFO - Predicted value for Austria in 2010: 101.11930335946627
# 2024-11-19 16:25:17,579 - INFO - Prediction inputs for Austria in 2011: Year=2011, PD Moving_Avg_2Y=101.11299026431863, PD Moving_Avg_3Y=101.11509462936783, PD Moving_Avg_5Y=101.11677812140722, PD Moving_Avg_10Y=101.11804074043673
# 2024-11-19 16:25:17,581 - INFO - Predicted value for Austria in 2011: 101.1221589971893
# 2024-11-19 16:25:17,581 - INFO - Prediction inputs for Austria in 2012: Year=2012, PD Moving_Avg_2Y=101.12073117832779, PD Moving_Avg_3Y=101.11604650860886, PD Moving_Avg_5Y=101.11849150404105, PD Moving_Avg_10Y=101.12032525061518
# 2024-11-19 16:25:17,583 - INFO - Predicted value for Austria in 2012: 101.12744843616727
# 2024-11-19 16:25:17,583 - INFO - Prediction inputs for Austria in 2013: Year=2013, PD Moving_Avg_2Y=101.12480371667829, PD Moving_Avg_3Y=101.12297026427427, PD Moving_Avg_5Y=101.12060727963221, PD Moving_Avg_10Y=101.12402785789973
# 2024-11-19 16:25:17,585 - INFO - Predicted value for Austria in 2013: 101.13625431215297
# 2024-11-19 16:25:17,585 - INFO - Prediction inputs for Austria in 2014: Year=2014, PD Moving_Avg_2Y=101.13185137416012, PD Moving_Avg_3Y=101.12862058183651, PD Moving_Avg_5Y=101.12236845482936, PD Moving_Avg_10Y=101.12931138349116
# 2024-11-19 16:25:17,587 - INFO - Predicted value for Austria in 2014: 101.13625431215297
# 2024-11-19 16:25:17,587 - INFO - Prediction inputs for Austria in 2015: Year=2015, PD Moving_Avg_2Y=101.13625431215297, PD Moving_Avg_3Y=101.13331902015773, PD Moving_Avg_5Y=101.12828388342575, PD Moving_Avg_10Y=101.12931138349116
# 2024-11-19 16:25:17,589 - INFO - Predicted value for Austria in 2015: 101.13625431215297
# 2024-11-19 16:25:17,589 - INFO - Prediction inputs for Austria in 2016: Year=2016, PD Moving_Avg_2Y=101.13625431215297, PD Moving_Avg_3Y=101.13625431215297, PD Moving_Avg_5Y=101.1316740739631, PD Moving_Avg_10Y=101.12931138349116
# 2024-11-19 16:25:17,591 - INFO - Predicted value for Austria in 2016: 101.13625431215297
# 2024-11-19 16:25:17,592 - INFO - Prediction inputs for Austria in 2017: Year=2017, PD Moving_Avg_2Y=101.13625431215297, PD Moving_Avg_3Y=101.13625431215297, PD Moving_Avg_5Y=101.13449313695583, PD Moving_Avg_10Y=101.12931138349116
# 2024-11-19 16:25:17,593 - INFO - Predicted value for Austria in 2017: 101.13625431215297
# 2024-11-19 16:25:17,594 - INFO - Prediction inputs for Austria in 2018: Year=2018, PD Moving_Avg_2Y=101.13625431215297, PD Moving_Avg_3Y=101.13625431215297, PD Moving_Avg_5Y=101.13625431215297, PD Moving_Avg_10Y=101.12931138349116
# 2024-11-19 16:25:17,596 - INFO - Predicted value for Austria in 2018: 101.13625431215297
# 2024-11-19 16:25:17,596 - INFO - Prediction inputs for Austria in 2019: Year=2019, PD Moving_Avg_2Y=101.13625431215297, PD Moving_Avg_3Y=101.13625431215297, PD Moving_Avg_5Y=101.13625431215297, PD Moving_Avg_10Y=101.12931138349116
# 2024-11-19 16:25:17,598 - INFO - Predicted value for Austria in 2019: 101.13625431215297
# 2024-11-19 16:25:17,598 - INFO - Processing country: Azerbaijan
# 2024-11-19 16:25:17,598 - INFO - Prediction inputs for Azerbaijan in 2010: Year=2010, PD Moving_Avg_2Y=107.175526501339, PD Moving_Avg_3Y=106.06814055823133, PD Moving_Avg_5Y=104.479891032806, PD Moving_Avg_10Y=101.70395879257697
# 2024-11-19 16:25:17,600 - INFO - Predicted value for Azerbaijan in 2010: 108.12173267290252
# 2024-11-19 16:25:17,600 - INFO - Prediction inputs for Azerbaijan in 2011: Year=2011, PD Moving_Avg_2Y=108.20651156411476, PD Moving_Avg_3Y=108.17825193371068, PD Moving_Avg_5Y=108.15564422938742, PD Moving_Avg_10Y=108.13868845114499
# 2024-11-19 16:25:17,602 - INFO - Predicted value for Azerbaijan in 2011: 108.55846017314312
# 2024-11-19 16:25:17,603 - INFO - Prediction inputs for Azerbaijan in 2012: Year=2012, PD Moving_Avg_2Y=108.34009642302283, PD Moving_Avg_3Y=108.32382776712421, PD Moving_Avg_5Y=108.41768072953178, PD Moving_Avg_10Y=108.48807045133745
# 2024-11-19 16:25:17,604 - INFO - Predicted value for Azerbaijan in 2012: 108.67582090745549
# 2024-11-19 16:25:17,605 - INFO - Prediction inputs for Azerbaijan in 2013: Year=2013, PD Moving_Avg_2Y=108.6171405402993, PD Moving_Avg_3Y=108.45200458450039, PD Moving_Avg_5Y=108.46462502325672, PD Moving_Avg_10Y=108.57022296535612
# 2024-11-19 16:25:17,606 - INFO - Predicted value for Azerbaijan in 2013: 108.70751955688402
# 2024-11-19 16:25:17,607 - INFO - Prediction inputs for Azerbaijan in 2014: Year=2014, PD Moving_Avg_2Y=108.69167023216976, PD Moving_Avg_3Y=108.64726687916088, PD Moving_Avg_5Y=108.47096475314243, PD Moving_Avg_10Y=108.58924215501324
# 2024-11-19 16:25:17,608 - INFO - Predicted value for Azerbaijan in 2014: 108.68493821025803
# 2024-11-19 16:25:17,609 - INFO - Prediction inputs for Azerbaijan in 2015: Year=2015, PD Moving_Avg_2Y=108.69622888357102, PD Moving_Avg_3Y=108.68942622486584, PD Moving_Avg_5Y=108.54969430412864, PD Moving_Avg_10Y=108.57795148170024
# 2024-11-19 16:25:17,611 - INFO - Predicted value for Azerbaijan in 2015: 108.68278912910085
# 2024-11-19 16:25:17,611 - INFO - Prediction inputs for Azerbaijan in 2016: Year=2016, PD Moving_Avg_2Y=108.68386366967944, PD Moving_Avg_3Y=108.6917489654143, PD Moving_Avg_5Y=108.66190559536831, PD Moving_Avg_10Y=108.57709184923735
# 2024-11-19 16:25:17,613 - INFO - Predicted value for Azerbaijan in 2016: 108.68344710475745
# 2024-11-19 16:25:17,613 - INFO - Prediction inputs for Azerbaijan in 2017: Year=2017, PD Moving_Avg_2Y=108.68311811692915, PD Moving_Avg_3Y=108.68372481470544, PD Moving_Avg_5Y=108.68690298169118, PD Moving_Avg_10Y=108.57728924193434
# 2024-11-19 16:25:17,615 - INFO - Predicted value for Azerbaijan in 2017: 108.67623168995034
# 2024-11-19 16:25:17,615 - INFO - Prediction inputs for Azerbaijan in 2018: Year=2018, PD Moving_Avg_2Y=108.6798393973539, PD Moving_Avg_3Y=108.68082264126956, PD Moving_Avg_5Y=108.68698513819012, PD Moving_Avg_10Y=108.57584615897292
# 2024-11-19 16:25:17,617 - INFO - Predicted value for Azerbaijan in 2018: 108.67623168995034
# 2024-11-19 16:25:17,617 - INFO - Prediction inputs for Azerbaijan in 2019: Year=2019, PD Moving_Avg_2Y=108.67623168995034, PD Moving_Avg_3Y=108.67863682821938, PD Moving_Avg_5Y=108.68072756480339, PD Moving_Avg_10Y=108.57584615897292
# 2024-11-19 16:25:17,619 - INFO - Predicted value for Azerbaijan in 2019: 108.6751119557969
# 2024-11-19 16:25:17,619 - INFO - Processing country: Bahamas, The
# 2024-11-19 16:25:17,620 - INFO - Prediction inputs for Bahamas, The in 2010: Year=2010, PD Moving_Avg_2Y=36.506093906093895, PD Moving_Avg_3Y=36.247685647685636, PD Moving_Avg_5Y=35.743976023976, PD Moving_Avg_10Y=34.55751248751248
# 2024-11-19 16:25:17,622 - INFO - Predicted value for Bahamas, The in 2010: 36.79262378192047
# 2024-11-19 16:25:17,622 - INFO - Prediction inputs for Bahamas, The in 2011: Year=2011, PD Moving_Avg_2Y=36.78077742542578, PD Moving_Avg_3Y=36.78472621092401, PD Moving_Avg_5Y=36.78788523932259, PD Moving_Avg_10Y=36.79025451062154
# 2024-11-19 16:25:17,624 - INFO - Predicted value for Bahamas, The in 2011: 37.1810900423541
# 2024-11-19 16:25:17,624 - INFO - Prediction inputs for Bahamas, The in 2012: Year=2012, PD Moving_Avg_2Y=36.986856912137284, PD Moving_Avg_3Y=36.914214964401886, PD Moving_Avg_5Y=37.02096499558277, PD Moving_Avg_10Y=37.10102751896844
# 2024-11-19 16:25:17,626 - INFO - Predicted value for Bahamas, The in 2012: 37.2347216484558
# 2024-11-19 16:25:17,626 - INFO - Prediction inputs for Bahamas, The in 2013: Year=2013, PD Moving_Avg_2Y=37.20790584540495, PD Moving_Avg_3Y=37.06947849091012, PD Moving_Avg_5Y=37.04241763802345, PD Moving_Avg_10Y=37.13856964323962
# 2024-11-19 16:25:17,628 - INFO - Predicted value for Bahamas, The in 2013: 37.33447467783197
# 2024-11-19 16:25:17,628 - INFO - Prediction inputs for Bahamas, The in 2014: Year=2014, PD Moving_Avg_2Y=37.28459816314388, PD Moving_Avg_3Y=37.250095456213955, PD Moving_Avg_5Y=37.06236824389869, PD Moving_Avg_10Y=37.198421460865326
# 2024-11-19 16:25:17,630 - INFO - Predicted value for Bahamas, The in 2014: 37.26928142443774
# 2024-11-19 16:25:17,630 - INFO - Prediction inputs for Bahamas, The in 2015: Year=2015, PD Moving_Avg_2Y=37.30187805113486, PD Moving_Avg_3Y=37.27949258357517, PD Moving_Avg_5Y=37.16243831500002, PD Moving_Avg_10Y=37.16582483416821
# 2024-11-19 16:25:17,632 - INFO - Predicted value for Bahamas, The in 2015: 37.33984109858859
# 2024-11-19 16:25:17,633 - INFO - Prediction inputs for Bahamas, The in 2016: Year=2016, PD Moving_Avg_2Y=37.30456126151317, PD Moving_Avg_3Y=37.314532400286105, PD Moving_Avg_5Y=37.271881778333636, PD Moving_Avg_10Y=37.19404870382856
# 2024-11-19 16:25:17,634 - INFO - Predicted value for Bahamas, The in 2016: 37.33437838587227
# 2024-11-19 16:25:17,635 - INFO - Prediction inputs for Bahamas, The in 2017: Year=2017, PD Moving_Avg_2Y=37.33710974223043, PD Moving_Avg_3Y=37.3145003029662, PD Moving_Avg_5Y=37.302539447037276, PD Moving_Avg_10Y=37.19240989001365
# 2024-11-19 16:25:17,636 - INFO - Predicted value for Bahamas, The in 2017: 37.33506604175621
# 2024-11-19 16:25:17,637 - INFO - Prediction inputs for Bahamas, The in 2018: Year=2018, PD Moving_Avg_2Y=37.33472221381424, PD Moving_Avg_3Y=37.336428508739026, PD Moving_Avg_5Y=37.32260832569735, PD Moving_Avg_10Y=37.19254742119045
# 2024-11-19 16:25:17,639 - INFO - Predicted value for Bahamas, The in 2018: 37.33506604175621
# 2024-11-19 16:25:17,639 - INFO - Prediction inputs for Bahamas, The in 2019: Year=2019, PD Moving_Avg_2Y=37.33506604175621, PD Moving_Avg_3Y=37.33483682312823, PD Moving_Avg_5Y=37.3227265984822, PD Moving_Avg_10Y=37.19254742119044
# 2024-11-19 16:25:17,641 - INFO - Predicted value for Bahamas, The in 2019: 37.33506604175621
# 2024-11-19 16:25:17,641 - INFO - Processing country: Bahrain
# 2024-11-19 16:25:17,641 - INFO - Prediction inputs for Bahrain in 2010: Year=2010, PD Moving_Avg_2Y=1506.444736842105, PD Moving_Avg_3Y=1466.7551578947368, PD Moving_Avg_5Y=1386.242824466572, PD Moving_Avg_10Y=1223.8378368693818
# 2024-11-19 16:25:17,644 - INFO - Predicted value for Bahrain in 2010: 1482.7724637499985
# 2024-11-19 16:25:17,644 - INFO - Prediction inputs for Bahrain in 2011: Year=2011, PD Moving_Avg_2Y=1517.3421529276293, PD Moving_Avg_3Y=1505.8189232017523, PD Moving_Avg_5Y=1496.6003394210506, PD Moving_Avg_10Y=1489.6864015855242
# 2024-11-19 16:25:17,646 - INFO - Predicted value for Bahrain in 2011: 1483.0490574999983
# 2024-11-19 16:25:17,646 - INFO - Prediction inputs for Bahrain in 2012: Year=2012, PD Moving_Avg_2Y=1482.9107606249984, PD Moving_Avg_3Y=1505.911121118419, PD Moving_Avg_5Y=1496.7662956710506, PD Moving_Avg_10Y=1489.9076765855243
# 2024-11-19 16:25:17,648 - INFO - Predicted value for Bahrain in 2012: 1483.0490574999983
# 2024-11-19 16:25:17,648 - INFO - Prediction inputs for Bahrain in 2013: Year=2013, PD Moving_Avg_2Y=1483.0490574999983, PD Moving_Avg_3Y=1482.9568595833316, PD Moving_Avg_5Y=1496.7662956710508, PD Moving_Avg_10Y=1489.9076765855245
# 2024-11-19 16:25:17,650 - INFO - Predicted value for Bahrain in 2013: 1483.0490574999983
# 2024-11-19 16:25:17,650 - INFO - Prediction inputs for Bahrain in 2014: Year=2014, PD Moving_Avg_2Y=1483.0490574999983, PD Moving_Avg_3Y=1483.0490574999983, PD Moving_Avg_5Y=1496.7662956710508, PD Moving_Avg_10Y=1489.9076765855245
# 2024-11-19 16:25:17,652 - INFO - Predicted value for Bahrain in 2014: 1483.0490574999983
# 2024-11-19 16:25:17,653 - INFO - Prediction inputs for Bahrain in 2015: Year=2015, PD Moving_Avg_2Y=1483.0490574999983, PD Moving_Avg_3Y=1483.0490574999983, PD Moving_Avg_5Y=1482.9937387499983, PD Moving_Avg_10Y=1489.9076765855245
# 2024-11-19 16:25:17,654 - INFO - Predicted value for Bahrain in 2015: 1483.0490574999983
# 2024-11-19 16:25:17,655 - INFO - Prediction inputs for Bahrain in 2016: Year=2016, PD Moving_Avg_2Y=1483.0490574999983, PD Moving_Avg_3Y=1483.0490574999983, PD Moving_Avg_5Y=1483.0490574999983, PD Moving_Avg_10Y=1489.9076765855245
# 2024-11-19 16:25:17,656 - INFO - Predicted value for Bahrain in 2016: 1483.0490574999983
# 2024-11-19 16:25:17,657 - INFO - Prediction inputs for Bahrain in 2017: Year=2017, PD Moving_Avg_2Y=1483.0490574999983, PD Moving_Avg_3Y=1483.0490574999983, PD Moving_Avg_5Y=1483.0490574999983, PD Moving_Avg_10Y=1489.9076765855245
# 2024-11-19 16:25:17,658 - INFO - Predicted value for Bahrain in 2017: 1483.0490574999983
# 2024-11-19 16:25:17,659 - INFO - Prediction inputs for Bahrain in 2018: Year=2018, PD Moving_Avg_2Y=1483.0490574999983, PD Moving_Avg_3Y=1483.0490574999983, PD Moving_Avg_5Y=1483.0490574999983, PD Moving_Avg_10Y=1489.9076765855248
# 2024-11-19 16:25:17,660 - INFO - Predicted value for Bahrain in 2018: 1483.0490574999983
# 2024-11-19 16:25:17,661 - INFO - Prediction inputs for Bahrain in 2019: Year=2019, PD Moving_Avg_2Y=1483.0490574999983, PD Moving_Avg_3Y=1483.0490574999983, PD Moving_Avg_5Y=1483.0490574999983, PD Moving_Avg_10Y=1489.9076765855248
# 2024-11-19 16:25:17,663 - INFO - Predicted value for Bahrain in 2019: 1483.0490574999983
# 2024-11-19 16:25:17,663 - INFO - Processing country: Bangladesh
# 2024-11-19 16:25:17,663 - INFO - Prediction inputs for Bangladesh in 2010: Year=2010, PD Moving_Avg_2Y=1122.102358454325, PD Moving_Avg_3Y=1117.1648920642199, PD Moving_Avg_5Y=1105.946812629636, PD Moving_Avg_10Y=1067.9127686871002
# 2024-11-19 16:25:17,665 - INFO - Predicted value for Bangladesh in 2010: 1127.3398815381856
# 2024-11-19 16:25:17,665 - INFO - Prediction inputs for Bangladesh in 2011: Year=2011, PD Moving_Avg_2Y=1127.189991472018, PD Moving_Avg_3Y=1127.2399548274072, PD Moving_Avg_5Y=1127.2799255117184, PD Moving_Avg_10Y=1127.3099035249522
# 2024-11-19 16:25:17,667 - INFO - Predicted value for Bangladesh in 2011: 1140.457523419957
# 2024-11-19 16:25:17,668 - INFO - Prediction inputs for Bangladesh in 2012: Year=2012, PD Moving_Avg_2Y=1133.8987024790713, PD Moving_Avg_3Y=1131.6125021213309, PD Moving_Avg_5Y=1135.150510640781, PD Moving_Avg_10Y=1137.8040170303689
# 2024-11-19 16:25:17,669 - INFO - Predicted value for Bangladesh in 2012: 1152.3978461501733
# 2024-11-19 16:25:17,670 - INFO - Prediction inputs for Bangladesh in 2013: Year=2013, PD Moving_Avg_2Y=1146.4276847850651, PD Moving_Avg_3Y=1140.065083702772, PD Moving_Avg_5Y=1139.926639732868, PD Moving_Avg_10Y=1146.1622429415206
# 2024-11-19 16:25:17,671 - INFO - Predicted value for Bangladesh in 2013: 1166.8150214966804
# 2024-11-19 16:25:17,672 - INFO - Prediction inputs for Bangladesh in 2014: Year=2014, PD Moving_Avg_2Y=1159.6064338234269, PD Moving_Avg_3Y=1153.2234636889368, PD Moving_Avg_5Y=1142.8100748021693, PD Moving_Avg_10Y=1154.8125481494249
# 2024-11-19 16:25:17,674 - INFO - Predicted value for Bangladesh in 2014: 1174.395750733616
# 2024-11-19 16:25:17,674 - INFO - Prediction inputs for Bangladesh in 2015: Year=2015, PD Moving_Avg_2Y=1170.6053861151481, PD Moving_Avg_3Y=1164.5362061268233, PD Moving_Avg_5Y=1152.2812046677225, PD Moving_Avg_10Y=1158.6029127678926
# 2024-11-19 16:25:17,676 - INFO - Predicted value for Bangladesh in 2015: 1193.738552252251
# 2024-11-19 16:25:17,676 - INFO - Prediction inputs for Bangladesh in 2016: Year=2016, PD Moving_Avg_2Y=1184.0671514929336, PD Moving_Avg_3Y=1178.3164414941823, PD Moving_Avg_5Y=1165.5609388105354, PD Moving_Avg_10Y=1166.3400333753466
# 2024-11-19 16:25:17,678 - INFO - Predicted value for Bangladesh in 2016: 1214.4656114864854
# 2024-11-19 16:25:17,678 - INFO - Prediction inputs for Bangladesh in 2017: Year=2017, PD Moving_Avg_2Y=1204.1020818693682, PD Moving_Avg_3Y=1194.1999714907843, PD Moving_Avg_5Y=1180.3625564238414, PD Moving_Avg_10Y=1172.558151145617
# 2024-11-19 16:25:17,680 - INFO - Predicted value for Bangladesh in 2017: 1221.4746030405413
# 2024-11-19 16:25:17,680 - INFO - Prediction inputs for Bangladesh in 2018: Year=2018, PD Moving_Avg_2Y=1217.9701072635135, PD Moving_Avg_3Y=1209.8929222597592, PD Moving_Avg_5Y=1194.177907801915, PD Moving_Avg_10Y=1173.9599494564281
# 2024-11-19 16:25:17,682 - INFO - Predicted value for Bangladesh in 2018: 1228.6322804054057
# 2024-11-19 16:25:17,682 - INFO - Prediction inputs for Bangladesh in 2019: Year=2019, PD Moving_Avg_2Y=1225.0534417229735, PD Moving_Avg_3Y=1221.5241649774775, PD Moving_Avg_5Y=1206.5413595836599, PD Moving_Avg_10Y=1174.6757171929146
# 2024-11-19 16:25:17,684 - INFO - Predicted value for Bangladesh in 2019: 1237.6485819256748
# 2024-11-19 16:25:17,684 - INFO - Processing country: Barbados
# 2024-11-19 16:25:17,685 - INFO - Prediction inputs for Barbados in 2010: Year=2010, PD Moving_Avg_2Y=635.3790697674419, PD Moving_Avg_3Y=634.0077519379846, PD Moving_Avg_5Y=631.5218604651163, PD Moving_Avg_10Y=625.6430232558139
# 2024-11-19 16:25:17,687 - INFO - Predicted value for Barbados in 2010: 635.2090930232557
# 2024-11-19 16:25:17,687 - INFO - Prediction inputs for Barbados in 2011: Year=2011, PD Moving_Avg_2Y=635.9661744186049, PD Moving_Avg_3Y=635.7138139534885, PD Moving_Avg_5Y=635.5119255813954, PD Moving_Avg_10Y=635.3605093023256
# 2024-11-19 16:25:17,689 - INFO - Predicted value for Barbados in 2011: 655.8179110212337
# 2024-11-19 16:25:17,689 - INFO - Prediction inputs for Barbados in 2012: Year=2012, PD Moving_Avg_2Y=645.5135020222447, PD Moving_Avg_3Y=642.5834199528144, PD Moving_Avg_5Y=647.8772163801822, PD Moving_Avg_10Y=651.847563700708
# 2024-11-19 16:25:17,691 - INFO - Predicted value for Barbados in 2012: 666.6579237447605
# 2024-11-19 16:25:17,691 - INFO - Prediction inputs for Barbados in 2013: Year=2013, PD Moving_Avg_2Y=661.2379173829971, PD Moving_Avg_3Y=652.5616425964166, PD Moving_Avg_5Y=652.2132214695928, PD Moving_Avg_10Y=659.4355726071767
# 2024-11-19 16:25:17,693 - INFO - Predicted value for Barbados in 2013: 677.6060411531544
# 2024-11-19 16:25:17,693 - INFO - Prediction inputs for Barbados in 2014: Year=2014, PD Moving_Avg_2Y=672.1319824489574, PD Moving_Avg_3Y=666.6939586397162, PD Moving_Avg_5Y=654.4028449512716, PD Moving_Avg_10Y=666.0044430522131
# 2024-11-19 16:25:17,695 - INFO - Predicted value for Barbados in 2014: 677.6060411531544
# ...
# 2024-11-19 16:25:20,880 - INFO - Prediction inputs for Pakistan in 2018: Year=2018, PD Moving_Avg_2Y=251.71692381030903, PD Moving_Avg_3Y=251.3903198011249, PD Moving_Avg_5Y=250.72777655654653, PD Moving_Avg_10Y=249.46352128864032
# 2024-11-19 16:25:20,882 - INFO - Predicted value for Pakistan in 2018: 252.46097731571288
# 2024-11-19 16:25:20,883 - INFO - Prediction inputs for Pakistan in 2019: Year=2019, PD Moving_Avg_2Y=252.22632856663364, PD Moving_Avg_3Y=251.96494164544364, PD Moving_Avg_5Y=251.3563822858976, PD Moving_Avg_10Y=249.51045103845618
# 2024-11-19 16:25:20,884 - INFO - Predicted value for Pakistan in 2019: 253.05746044850673
# 2024-11-19 16:25:20,885 - INFO - Processing country: Palau
# 2024-11-19 16:25:20,885 - INFO - Prediction inputs for Palau in 2010: Year=2010, PD Moving_Avg_2Y=41.2260869565217, PD Moving_Avg_3Y=41.517391304347804, PD Moving_Avg_5Y=42.06260869565216, PD Moving_Avg_10Y=42.59478260869565
# 2024-11-19 16:25:20,887 - INFO - Predicted value for Palau in 2010: 41.10507096286833
# 2024-11-19 16:25:20,887 - INFO - Prediction inputs for Palau in 2011: Year=2011, PD Moving_Avg_2Y=41.01557895969502, PD Moving_Avg_3Y=41.04540962741945, PD Moving_Avg_5Y=41.06927416159901, PD Moving_Avg_10Y=41.087172562233675
# 2024-11-19 16:25:20,889 - INFO - Predicted value for Palau in 2011: 41.22192109902181
# 2024-11-19 16:25:20,890 - INFO - Prediction inputs for Palau in 2012: Year=2012, PD Moving_Avg_2Y=41.16349603094507, PD Moving_Avg_3Y=41.08435967280395, PD Moving_Avg_5Y=41.1393842432911, PD Moving_Avg_10Y=41.18065267115646
# 2024-11-19 16:25:20,891 - INFO - Predicted value for Palau in 2012: 41.258740429927805
# 2024-11-19 16:25:20,892 - INFO - Prediction inputs for Palau in 2013: Year=2013, PD Moving_Avg_2Y=41.240330764474805, PD Moving_Avg_3Y=41.195244163939314, PD Moving_Avg_5Y=41.15411197565349, PD Moving_Avg_10Y=41.206426202790645
# 2024-11-19 16:25:20,893 - INFO - Predicted value for Palau in 2013: 41.57977001947633
# 2024-11-19 16:25:20,893 - INFO - Prediction inputs for Palau in 2014: Year=2014, PD Moving_Avg_2Y=41.41925522470207, PD Moving_Avg_3Y=41.353477182808646, PD Moving_Avg_5Y=41.218317893563196, PD Moving_Avg_10Y=41.39904395651976
# 2024-11-19 16:25:20,895 - INFO - Predicted value for Palau in 2014: 41.597130115508854
# 2024-11-19 16:25:20,895 - INFO - Prediction inputs for Palau in 2015: Year=2015, PD Moving_Avg_2Y=41.58845006749259, PD Moving_Avg_3Y=41.478546854971, PD Moving_Avg_5Y=41.35252652536063, PD Moving_Avg_10Y=41.407724004536014
# 2024-11-19 16:25:20,897 - INFO - Predicted value for Palau in 2015: 41.686904214335975
# 2024-11-19 16:25:20,898 - INFO - Prediction inputs for Palau in 2016: Year=2016, PD Moving_Avg_2Y=41.642017164922414, PD Moving_Avg_3Y=41.62126811644038, PD Moving_Avg_5Y=41.46889317565415, PD Moving_Avg_10Y=41.44363364406687
# 2024-11-19 16:25:20,899 - INFO - Predicted value for Palau in 2016: 41.46977527494954
# 2024-11-19 16:25:20,900 - INFO - Prediction inputs for Palau in 2017: Year=2017, PD Moving_Avg_2Y=41.57833974464276, PD Moving_Avg_3Y=41.58460320159812, PD Moving_Avg_5Y=41.51846401083971, PD Moving_Avg_10Y=41.37849496225094
# 2024-11-19 16:25:20,901 - INFO - Predicted value for Palau in 2017: 41.51505733433471
# 2024-11-19 16:25:20,902 - INFO - Prediction inputs for Palau in 2018: Year=2018, PD Moving_Avg_2Y=41.49241630464213, PD Moving_Avg_3Y=41.55724560787341, PD Moving_Avg_5Y=41.56972739172109, PD Moving_Avg_10Y=41.38755137412797
# 2024-11-19 16:25:20,904 - INFO - Predicted value for Palau in 2018: 41.442521629082705
# 2024-11-19 16:25:20,904 - INFO - Prediction inputs for Palau in 2019: Year=2019, PD Moving_Avg_2Y=41.47878948170871, PD Moving_Avg_3Y=41.47578474612232, PD Moving_Avg_5Y=41.542277713642356, PD Moving_Avg_10Y=41.38029780360277
# 2024-11-19 16:25:20,906 - INFO - Predicted value for Palau in 2019: 41.45063500799465
# 2024-11-19 16:25:20,906 - INFO - Processing country: Panama
# 2024-11-19 16:25:20,906 - INFO - Prediction inputs for Panama in 2010: Year=2010, PD Moving_Avg_2Y=47.4483387140167, PD Moving_Avg_3Y=47.01924939467313, PD Moving_Avg_5Y=46.16807640570352, PD Moving_Avg_10Y=44.08035781544256
# 2024-11-19 16:25:20,908 - INFO - Predicted value for Panama in 2010: 47.87915503862327
# 2024-11-19 16:25:20,909 - INFO - Prediction inputs for Panama in 2011: Year=2011, PD Moving_Avg_2Y=47.879199526306536, PD Moving_Avg_3Y=47.87918469707878, PD Moving_Avg_5Y=47.87917283369658, PD Moving_Avg_10Y=47.87916393615991
# 2024-11-19 16:25:20,911 - INFO - Predicted value for Panama in 2011: 47.848864391772274
# 2024-11-19 16:25:20,911 - INFO - Prediction inputs for Panama in 2012: Year=2012, PD Moving_Avg_2Y=47.86400971519777, PD Moving_Avg_3Y=47.869087814795115, PD Moving_Avg_5Y=47.860998445585984, PD Moving_Avg_10Y=47.85493141867913
# 2024-11-19 16:25:20,913 - INFO - Predicted value for Panama in 2012: 47.87211103316545
# 2024-11-19 16:25:20,913 - INFO - Prediction inputs for Panama in 2013: Year=2013, PD Moving_Avg_2Y=47.86048771246887, PD Moving_Avg_3Y=47.86671015452033, PD Moving_Avg_5Y=47.87029710214325, PD Moving_Avg_10Y=47.871204067654354
# 2024-11-19 16:25:20,915 - INFO - Predicted value for Panama in 2013: 47.848864391772274
# 2024-11-19 16:25:20,915 - INFO - Prediction inputs for Panama in 2014: Year=2014, PD Moving_Avg_2Y=47.86048771246887, PD Moving_Avg_3Y=47.85661327223667, PD Moving_Avg_5Y=47.865647773864616, PD Moving_Avg_10Y=47.857256082818445
# 2024-11-19 16:25:20,917 - INFO - Predicted value for Panama in 2014: 47.87211103316545
# 2024-11-19 16:25:20,917 - INFO - Prediction inputs for Panama in 2015: Year=2015, PD Moving_Avg_2Y=47.86048771246887, PD Moving_Avg_3Y=47.86436215270106, PD Moving_Avg_5Y=47.86422117769975, PD Moving_Avg_10Y=47.86887940351503
# 2024-11-19 16:25:20,919 - INFO - Predicted value for Panama in 2015: 47.87211103316545
# 2024-11-19 16:25:20,919 - INFO - Prediction inputs for Panama in 2016: Year=2016, PD Moving_Avg_2Y=47.87211103316545, PD Moving_Avg_3Y=47.86436215270106, PD Moving_Avg_5Y=47.86281237660818, PD Moving_Avg_10Y=47.86887940351503
# 2024-11-19 16:25:20,921 - INFO - Predicted value for Panama in 2016: 47.87211103316545
# 2024-11-19 16:25:20,921 - INFO - Prediction inputs for Panama in 2017: Year=2017, PD Moving_Avg_2Y=47.87211103316545, PD Moving_Avg_3Y=47.87211103316545, PD Moving_Avg_5Y=47.86746170488682, PD Moving_Avg_10Y=47.86887940351503
# 2024-11-19 16:25:20,923 - INFO - Predicted value for Panama in 2017: 47.848864391772274
# 2024-11-19 16:25:20,923 - INFO - Prediction inputs for Panama in 2018: Year=2018, PD Moving_Avg_2Y=47.86048771246887, PD Moving_Avg_3Y=47.86436215270106, PD Moving_Avg_5Y=47.86281237660818, PD Moving_Avg_10Y=47.86423007523639
# 2024-11-19 16:25:20,925 - INFO - Predicted value for Panama in 2018: 47.87211103316545
# 2024-11-19 16:25:20,925 - INFO - Prediction inputs for Panama in 2019: Year=2019, PD Moving_Avg_2Y=47.86048771246887, PD Moving_Avg_3Y=47.86436215270106, PD Moving_Avg_5Y=47.86746170488682, PD Moving_Avg_10Y=47.866554739375715
# 2024-11-19 16:25:20,927 - INFO - Predicted value for Panama in 2019: 47.848864391772274
# 2024-11-19 16:25:20,927 - INFO - Processing country: Papua New Guinea
# 2024-11-19 16:25:20,928 - INFO - Prediction inputs for Papua New Guinea in 2010: Year=2010, PD Moving_Avg_2Y=16.0059157355474, PD Moving_Avg_3Y=15.764948696433033, PD Moving_Avg_5Y=15.29169235525328, PD Moving_Avg_10Y=14.156363335247102
# 2024-11-19 16:25:20,929 - INFO - Predicted value for Papua New Guinea in 2010: 16.208654411595308
# 2024-11-19 16:25:20,930 - INFO - Prediction inputs for Papua New Guinea in 2011: Year=2011, PD Moving_Avg_2Y=16.229233357809306, PD Moving_Avg_3Y=16.222373709071306, PD Moving_Avg_5Y=16.216885990080904, PD Moving_Avg_10Y=16.212770200838108
# 2024-11-19 16:25:20,932 - INFO - Predicted value for Papua New Guinea in 2011: 16.40748702001322
# 2024-11-19 16:25:20,932 - INFO - Prediction inputs for Papua New Guinea in 2012: Year=2012, PD Moving_Avg_2Y=16.308070715804263, PD Moving_Avg_3Y=16.288651245210612, PD Moving_Avg_5Y=16.336185555131657, PD Moving_Avg_10Y=16.37183628757244
# 2024-11-19 16:25:20,934 - INFO - Predicted value for Papua New Guinea in 2012: 16.483574417372537
# 2024-11-19 16:25:20,934 - INFO - Prediction inputs for Papua New Guinea in 2013: Year=2013, PD Moving_Avg_2Y=16.44553071869288, PD Moving_Avg_3Y=16.366571949660354, PD Moving_Avg_5Y=16.366620514075382, PD Moving_Avg_10Y=16.42509746572396
# 2024-11-19 16:25:20,936 - INFO - Predicted value for Papua New Guinea in 2013: 16.630688252117984
# 2024-11-19 16:25:20,936 - INFO - Prediction inputs for Papua New Guinea in 2014: Year=2014, PD Moving_Avg_2Y=16.55713133474526, PD Moving_Avg_3Y=16.507249896501246, PD Moving_Avg_5Y=16.39604328102447, PD Moving_Avg_10Y=16.513365766571223
# 2024-11-19 16:25:20,938 - INFO - Predicted value for Papua New Guinea in 2014: 16.786502011141838
# 2024-11-19 16:25:20,938 - INFO - Prediction inputs for Papua New Guinea in 2015: Year=2015, PD Moving_Avg_2Y=16.708595131629913, PD Moving_Avg_3Y=16.633588226877453, PD Moving_Avg_5Y=16.503381222448176, PD Moving_Avg_10Y=16.59127264608315
# 2024-11-19 16:25:20,940 - INFO - Predicted value for Papua New Guinea in 2015: 16.841617929065674
# 2024-11-19 16:25:20,940 - INFO - Prediction inputs for Papua New Guinea in 2016: Year=2016, PD Moving_Avg_2Y=16.814059970103756, PD Moving_Avg_3Y=16.7529360641085, PD Moving_Avg_5Y=16.629973925942252, PD Moving_Avg_10Y=16.61331901325269
# 2024-11-19 16:25:20,942 - INFO - Predicted value for Papua New Guinea in 2016: 16.92364507981669
# 2024-11-19 16:25:20,942 - INFO - Prediction inputs for Papua New Guinea in 2017: Year=2017, PD Moving_Avg_2Y=16.882631504441182, PD Moving_Avg_3Y=16.85058834000807, PD Moving_Avg_5Y=16.733205537902947, PD Moving_Avg_10Y=16.637927158477993
# 2024-11-19 16:25:20,944 - INFO - Predicted value for Papua New Guinea in 2017: 16.996205497550477
# 2024-11-19 16:25:20,944 - INFO - Prediction inputs for Papua New Guinea in 2018: Year=2018, PD Moving_Avg_2Y=16.959925288683586, PD Moving_Avg_3Y=16.92048950214428, PD Moving_Avg_5Y=16.835731753938536, PD Moving_Avg_10Y=16.652439242024748
# 2024-11-19 16:25:20,946 - INFO - Predicted value for Papua New Guinea in 2018: 17.08791165984945
# 2024-11-19 16:25:20,946 - INFO - Prediction inputs for Papua New Guinea in 2019: Year=2019, PD Moving_Avg_2Y=17.042058578699965, PD Moving_Avg_3Y=17.002587412405543, PD Moving_Avg_5Y=16.927176435484828, PD Moving_Avg_10Y=16.661609858254646
# 2024-11-19 16:25:20,948 - INFO - Predicted value for Papua New Guinea in 2019: 17.134832151116115
# 2024-11-19 16:25:20,949 - INFO - Processing country: Paraguay
# 2024-11-19 16:25:20,949 - INFO - Prediction inputs for Paraguay in 2010: Year=2010, PD Moving_Avg_2Y=14.2810495846967, PD Moving_Avg_3Y=14.2108121486702, PD Moving_Avg_5Y=14.0696803423106, PD Moving_Avg_10Y=13.67754090108231
# 2024-11-19 16:25:20,951 - INFO - Predicted value for Paraguay in 2010: 14.384932436667492
# 2024-11-19 16:25:20,951 - INFO - Prediction inputs for Paraguay in 2011: Year=2011, PD Moving_Avg_2Y=14.369126173027947, PD Moving_Avg_3Y=14.374394927574462, PD Moving_Avg_5Y=14.378609931211676, PD Moving_Avg_10Y=14.381771183939586
# 2024-11-19 16:25:20,953 - INFO - Predicted value for Paraguay in 2011: 14.528919015644258
# 2024-11-19 16:25:20,953 - INFO - Prediction inputs for Paraguay in 2012: Year=2012, PD Moving_Avg_2Y=14.456925726155875, PD Moving_Avg_3Y=14.42239045390005, PD Moving_Avg_5Y=14.465001878597732, PD Moving_Avg_10Y=14.496960447120994
# 2024-11-19 16:25:20,955 - INFO - Predicted value for Paraguay in 2012: 14.53962069747191
# 2024-11-19 16:25:20,955 - INFO - Prediction inputs for Paraguay in 2013: Year=2013, PD Moving_Avg_2Y=14.534269856558083, PD Moving_Avg_3Y=14.484490716594555, PD Moving_Avg_5Y=14.469282551328794, PD Moving_Avg_10Y=14.504451624400355
# 2024-11-19 16:25:20,957 - INFO - Predicted value for Paraguay in 2013: 14.618043833635763
# 2024-11-19 16:25:20,957 - INFO - Prediction inputs for Paraguay in 2014: Year=2014, PD Moving_Avg_2Y=14.578832265553837, PD Moving_Avg_3Y=14.562194515583977, PD Moving_Avg_5Y=14.484967178561565, PD Moving_Avg_10Y=14.551505506098668
# 2024-11-19 16:25:20,959 - INFO - Predicted value for Paraguay in 2014: 14.708260855521463
# 2024-11-19 16:25:20,960 - INFO - Prediction inputs for Paraguay in 2015: Year=2015, PD Moving_Avg_2Y=14.663152344578613, PD Moving_Avg_3Y=14.621975128876379, PD Moving_Avg_5Y=14.555955367788178, PD Moving_Avg_10Y=14.596614017041517
# 2024-11-19 16:25:20,961 - INFO - Predicted value for Paraguay in 2015: 14.736313629406391
# 2024-11-19 16:25:20,962 - INFO - Prediction inputs for Paraguay in 2016: Year=2016, PD Moving_Avg_2Y=14.722287242463928, PD Moving_Avg_3Y=14.687539439521204, PD Moving_Avg_5Y=14.626231606335958, PD Moving_Avg_10Y=14.60783512659549
# 2024-11-19 16:25:20,963 - INFO - Predicted value for Paraguay in 2016: 14.882206047290397
# 2024-11-19 16:25:20,964 - INFO - Prediction inputs for Paraguay in 2017: Year=2017, PD Moving_Avg_2Y=14.809259838348394, PD Moving_Avg_3Y=14.775593510739418, PD Moving_Avg_5Y=14.696889012665185, PD Moving_Avg_10Y=14.651602851960686
# 2024-11-19 16:25:20,966 - INFO - Predicted value for Paraguay in 2017: 14.99335267323218
# 2024-11-19 16:25:20,966 - INFO - Prediction inputs for Paraguay in 2018: Year=2018, PD Moving_Avg_2Y=14.937779360261288, PD Moving_Avg_3Y=14.870624116642988, PD Moving_Avg_5Y=14.787635407817238, PD Moving_Avg_10Y=14.673832177149043
# 2024-11-19 16:25:20,968 - INFO - Predicted value for Paraguay in 2018: 15.170265107193552
# 2024-11-19 16:25:20,968 - INFO - Prediction inputs for Paraguay in 2019: Year=2019, PD Moving_Avg_2Y=15.081808890212866, PD Moving_Avg_3Y=15.015274609238709, PD Moving_Avg_5Y=14.898079662528797, PD Moving_Avg_10Y=14.691523420545181
# 2024-11-19 16:25:20,970 - INFO - Predicted value for Paraguay in 2019: 15.355133436158624
# 2024-11-19 16:25:20,970 - INFO - Processing country: Peru
# 2024-11-19 16:25:20,970 - INFO - Prediction inputs for Peru in 2010: Year=2010, PD Moving_Avg_2Y=22.584183984375002, PD Moving_Avg_3Y=22.504140104166666, PD Moving_Avg_5Y=22.33503796875, PD Moving_Avg_10Y=21.83323015625
# 2024-11-19 16:25:20,972 - INFO - Predicted value for Peru in 2010: 22.757797246266954
# 2024-11-19 16:25:20,972 - INFO - Prediction inputs for Peru in 2011: Year=2011, PD Moving_Avg_2Y=22.710666591883477, PD Moving_Avg_3Y=22.726376810011303, PD Moving_Avg_5Y=22.738944984513562, PD Moving_Avg_10Y=22.748371115390263
# 2024-11-19 16:25:20,974 - INFO - Predicted value for Peru in 2011: 22.867627103852392
# 2024-11-19 16:25:20,974 - INFO - Prediction inputs for Peru in 2012: Year=2012, PD Moving_Avg_2Y=22.812712175059673, PD Moving_Avg_3Y=22.762986762539782, PD Moving_Avg_5Y=22.804842899064823, PD Moving_Avg_10Y=22.836235001458608
# 2024-11-19 16:25:20,976 - INFO - Predicted value for Peru in 2012: 23.041727430598815
# 2024-11-19 16:25:20,977 - INFO - Prediction inputs for Peru in 2013: Year=2013, PD Moving_Avg_2Y=22.954677267225605, PD Moving_Avg_3Y=22.88905059357272, PD Moving_Avg_5Y=22.87448302976339, PD Moving_Avg_10Y=22.958105230181108
# 2024-11-19 16:25:20,978 - INFO - Predicted value for Peru in 2013: 23.145584361370524
# 2024-11-19 16:25:20,979 - INFO - Prediction inputs for Peru in 2014: Year=2014, PD Moving_Avg_2Y=23.093655895984668, PD Moving_Avg_3Y=23.01831296527391, PD Moving_Avg_5Y=22.895254415917737, PD Moving_Avg_10Y=23.020419388644132
# 2024-11-19 16:25:20,980 - INFO - Predicted value for Peru in 2014: 23.30498233024678
# 2024-11-19 16:25:20,981 - INFO - Prediction inputs for Peru in 2015: Year=2015, PD Moving_Avg_2Y=23.225283345808652, PD Moving_Avg_3Y=23.164098040738708, PD Moving_Avg_5Y=23.023543694467094, PD Moving_Avg_10Y=23.10011837308226
# 2024-11-19 16:25:20,983 - INFO - Predicted value for Peru in 2015: 23.406877429928663
# 2024-11-19 16:25:20,983 - INFO - Prediction inputs for Peru in 2016: Year=2016, PD Moving_Avg_2Y=23.35592988008772, PD Moving_Avg_3Y=23.285814707181988, PD Moving_Avg_5Y=23.153359731199437, PD Moving_Avg_10Y=23.140876412955016
# 2024-11-19 16:25:20,985 - INFO - Predicted value for Peru in 2016: 23.527855170042475

# %%
# Initialize lists to collect all actual and predicted values across countries
all_actual_values = []
all_predicted_values = []

for country, predictions in country_recursive_predictions_rf.items():
    predicted_years = list(predictions.keys())
    predicted_values = list(predictions.values())

    # Extract actual values from selected_df for the specified prediction years
    actual_data = selected_df_3[(selected_df_3['Country Name'] == country) & (selected_df_3['Year'].isin(predicted_years))]
    actual_values = actual_data['Population density (people per sq. km of land area)'].values

    # Ensure no NaN or inf values in actual and predicted values
    if len(actual_values) == len(predicted_values):
        actual_values_clean = np.array(actual_values)
        predicted_values_clean = np.array(predicted_values)
        
        # Filter out any NaN or inf values
        valid_indices = ~np.isnan(actual_values_clean) & ~np.isinf(actual_values_clean) & \
                        ~np.isnan(predicted_values_clean) & ~np.isinf(predicted_values_clean)
        actual_values_clean = actual_values_clean[valid_indices]
        predicted_values_clean = predicted_values_clean[valid_indices]

        # Append clean values to the overall lists
        all_actual_values.extend(actual_values_clean)
        all_predicted_values.extend(predicted_values_clean)

# Calculate overall metrics across all countries
if len(all_actual_values) > 0:
    overall_mae = mean_absolute_error(all_actual_values, all_predicted_values)
    overall_mse = mean_squared_error(all_actual_values, all_predicted_values)
    overall_rmse = np.sqrt(overall_mse)
    overall_r2 = r2_score(all_actual_values, all_predicted_values)

else:
    logger.warning("No valid values available for metric calculation.")

# Displaying the overall metrics
print(f"Overall Mean Absolute Error (MAE): {overall_mae:.2f}")
print(f"Overall Mean Squared Error (MSE): {overall_mse:.2f}")
print(f"Overall Root Mean Squared Error (RMSE): {overall_rmse:.2f}")
print(f"Overall R-squared (R²): {overall_r2:.2f}")

# %%
# Initialize lists to collect all actual, predicted values, and years across countries
all_actual_values = []
all_predicted_values = []
all_years = []

for country, predictions in country_recursive_predictions_rf.items():
    # Get predictions and corresponding years
    predicted_years = [year for year in predictions.keys() if year >= 2010]
    predicted_values = [predictions[year] for year in predicted_years]

    # Extract actual values from selected_df for the specified prediction years
    actual_data = selected_df_3[(selected_df_3['Country Name'] == country) & (selected_df_3['Year'].isin(predicted_years))]
    actual_values = actual_data['Population density (people per sq. km of land area)'].values
    years = actual_data['Year'].values

    # Ensure no NaN or inf values in actual and predicted values
    if len(actual_values) == len(predicted_values):
        actual_values_clean = np.array(actual_values)
        predicted_values_clean = np.array(predicted_values)
        
        # Filter out any NaN or inf values
        valid_indices = ~np.isnan(actual_values_clean) & ~np.isinf(actual_values_clean) & \
                        ~np.isnan(predicted_values_clean) & ~np.isinf(predicted_values_clean)
        
        actual_values_clean = actual_values_clean[valid_indices]
        predicted_values_clean = predicted_values_clean[valid_indices]
        years_clean = years[valid_indices]

        # Append clean values from 2010 onward to the overall lists
        all_actual_values.extend(actual_values_clean)
        all_predicted_values.extend(predicted_values_clean)
        all_years.extend(years_clean)

# Create a DataFrame for easier plotting with hue
plot_data = pd.DataFrame({
    'Actual': all_actual_values,
    'Predicted': all_predicted_values,
    'Residuals': np.array(all_actual_values) - np.array(all_predicted_values),
    'Year': all_years
})

# %%
# Redefining test_df based on the years 2010-2019 from selected_df
test_df = selected_df_3[(selected_df_3['Year'] >= 2010) & (selected_df_3['Year'] <= 2019)].dropna(subset=['Population density (people per sq. km of land area)'])

# Rerun the plotting function for Kenya as an example
plot_country_predictions_vs_actual("United States", "Population density (people per sq. km of land area)")

# %% [markdown]
# ## Indicator 3 - Forecasting

# %%
# Define year variables for training and prediction
TRAIN_START_YEAR = 2000
TRAIN_END_YEAR = 2019
PREDICTION_START_YEAR = 2019
PREDICTION_END_YEAR = 2030

# Setting up logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

# Splitting data into training (2000-2019) set and setting up prediction years
train_df = selected_df_3[(selected_df_3['Year'] >= TRAIN_START_YEAR) & (selected_df_3['Year'] <= TRAIN_END_YEAR)].dropna(subset=['Population density (people per sq. km of land area)'])
prediction_years = range(PREDICTION_START_YEAR, PREDICTION_END_YEAR + 1)

# Preparing training data for the model
X_train = train_df[['Year', 'PD Moving_Avg_2Y', 'PD Moving_Avg_3Y', 'PD Moving_Avg_5Y', 'PD Moving_Avg_10Y']].values
y_train = train_df['Population density (people per sq. km of land area)'].values

# Initializing and training the Random Forest model on all training data
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)
logger.info(f"Model trained on all countries' data ({TRAIN_START_YEAR}-{TRAIN_END_YEAR}). Starting recursive forecasting.")

# Dictionary to store predictions for each country
country_recursive_predictions_rf = {}

# Recursive forecasting for each country separately with detailed logging
for country in train_df['Country Name'].unique():
    logger.info(f"Processing country: {country}")

    # Get the last available data point for the country to start recursive prediction
    country_data = train_df[train_df['Country Name'] == country].iloc[-1].copy()
    predictions_per_country = {country_data['Year']: country_data['Population density (people per sq. km of land area)']}

    # Recursive prediction loop from PREDICTION_START_YEAR to PREDICTION_END_YEAR
    for year in prediction_years:
        country_data['Year'] = year
        
        # Logging the input data used for this prediction
        logger.info(f"Prediction inputs for {country} in {year}: Year={year}, "
                    f"PD Moving_Avg_2Y={country_data['PD Moving_Avg_2Y']}, "
                    f"PD Moving_Avg_3Y={country_data['PD Moving_Avg_3Y']}, "
                    f"PD Moving_Avg_5Y={country_data['PD Moving_Avg_5Y']}, "
                    f"PD Moving_Avg_10Y={country_data['PD Moving_Avg_10Y']}")
        
        # Preparing the features for the current prediction
        X_test = country_data[['Year', 'PD Moving_Avg_2Y', 'PD Moving_Avg_3Y', 'PD Moving_Avg_5Y', 'PD Moving_Avg_10Y']].values.reshape(1, -1)
        
        # Predicting life expectancy for the current year
        predicted_value = model_rf.predict(X_test)[0]
        logger.info(f"Predicted value for {country} in {year}: {predicted_value}")
        
        # Update the prediction in the dictionary
        predictions_per_country[year] = predicted_value
        
        # Update the features for the next prediction year based on the new prediction
        country_data['Population density (people per sq. km of land area)'] = predicted_value
        country_data['PD Moving_Avg_2Y'] = (predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 2
        country_data['PD Moving_Avg_3Y'] = (predictions_per_country.get(year - 2, predicted_value) +
                                         predictions_per_country.get(year - 1, predicted_value) + predicted_value) / 3
        country_data['PD Moving_Avg_5Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 4, year + 1)) / 5)
        country_data['PD Moving_Avg_10Y'] = (sum(predictions_per_country.get(y, predicted_value) for y in range(year - 9, year + 1)) / 10)

    # Store the predictions for the country
    country_recursive_predictions_rf[country] = predictions_per_country

# %%
# Displaying feature importances from the Random Forest model directly

# Calculating feature importances
feature_importances = model_rf.feature_importances_
feature_names = ['Year', 'SPEI Moving_Avg_2Y', 'SPEI Moving_Avg_3Y', 'SPEI Moving_Avg_5Y', 'SPEI Moving_Avg_10Y']

# Creating a DataFrame to organize and sort feature importances
import pandas as pd
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# %%
# Converting the dictionary of predictions for each country (country_recursive_predictions_rf) into a DataFrame

# Initialize an empty list to store rows for the DataFrame
rows = []

# Loop through each country and its predictions to build the DataFrame rows
for country, predictions in country_recursive_predictions_rf.items():
    for year, precip in predictions.items():
        # Append each prediction as a new row with the country, year, and predicted value
        rows.append({'Country Name': country, 'Year': year, 'Population density (people per sq. km of land area)': precip})

# Convert the list of rows into a DataFrame
predictions_df_3 = pd.DataFrame(rows)

# %%
#Remove country code columns
selected_df_clean = selected_df.drop(['Country Code'],axis=1)
selected_df_2_clean = selected_df_2.drop(['Country Code'],axis=1)
selected_df_3_clean = selected_df_3.drop(['Country Code'],axis=1)

# %%
#Combine historical data from cleaned dataframes
combined_hist_df_1_2=pd.merge(selected_df_clean, selected_df_2_clean, on=['Country Name', 'Year','Agricultural land (% of land area)'], how='outer')
combined_hist_df_1_2_3 = pd.merge(combined_hist_df_1_2, selected_df_3_clean, on=['Country Name', 'Year','Population density (people per sq. km of land area)'], how='outer')

#Drop moving averages columns
columns_to_drop = combined_hist_df_1_2_3.columns[combined_hist_df_1_2_3.columns.str.contains('Moving_Avg')]
combined_hist_df_1_2_3_clean = combined_hist_df_1_2_3.drop(columns=columns_to_drop)

#Remove data from 2019 or greater, define historical data as all data before 2020 as our predictions begin in 2020
combined_hist_filtered = combined_hist_df_1_2_3_clean[combined_hist_df_1_2_3_clean['Year'] <= 2019]

#Combine predicted dataframes
combined_pred_1_2=pd.merge(predictions_df_1, predictions_df_2, on=['Country Name', 'Year'], how='outer')
combined_pred=pd.merge(combined_pred_1_2, predictions_df_3, on=['Country Name', 'Year'], how='outer')

#Ensure to only include predicted data from 2019 or greater
combined_pred_filtered = combined_pred[combined_pred['Year'] >= 2020]
combined_pred_filtered.columns = combined_hist_filtered.columns
combined_df = pd.merge(combined_hist_filtered, combined_pred_filtered,on = ['Country Name','Year','Life expectancy at birth, total (years)','Agricultural land (% of land area)','Population density (people per sq. km of land area)'], how='outer')

# %%
#Export results to a df to be read for finalized plotting

combined_df.to_excel('Historical and Predicted Indicator Data.xlsx', sheet_name='Results', index=False)
